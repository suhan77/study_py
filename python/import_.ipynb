# %%
import os
import threading
import zipfile
import traceback
import csv
import re
import codecs
import glob
from datetime import datetime, timedelta
import json

# %%
src = 'C:/Users/Suhan/Desktop/dev/python 스터디/서예진.zip'
museid = '01234'
dst_root = 'input/voice/서예진/'
dst_postfix_dir = 'python 서예진/'
src_names = 'input/voice/서예진.zip'
input_dir = 'input/json'

# %%
os.path.isfile(src)
# Out:
# True

# %%
class ZIP_Thread(threading.Thread):
    def __init__(self, src, museid, dst_root, dst_postfix_dir, src_names):
        threading.Thread.__init__(self, target=self.run)

        self.src = src
#         self.mongo = mongo
        self.museid = museid
        self.dst_root = dst_root # input/voice/**.zip
        self.dst_postfix_dir = dst_postfix_dir
        self.src_names = src_names
        self.result_json = None
        self.input_map = {}
        
    def write_json(path, data):
        with open(path, 'w') as f:
            json.dump(data, f, indent=4, sort_keys=True, ensure_ascii=False)
            
    def get_input_map(self):
        return self.input_map
        
        
    def go(self):
        tcount = 0
        meta_json = {}
        meta_json['muse_id'] = self.museid
        meta_json['records'] = []
        
        with zipfile.ZipFile(self.src) as zip:
            metafile = [ x for x in zip.namelist() if x and x.find('.csv') >= 0 ]
            if len(metafile) == 1:
                zip.extract(metafile[0], path=self.dst_root)
                csv_file_path = os.path.join(self.dst_root, metafile[0])

                try:
                    # utf-8로 읽기
                    print('utf-8')
                    with open(csv_file_path, 'r', encoding='utf-8') as meta_f:
                        reader = csv.reader(meta_f)
                        for line in reader:
                            iname = re.sub(codecs.BOM_UTF8.decode('utf-8'), '', line[0])
                            self.input_map[iname] = line[1].strip()

                except:
                    print('cp949')
                    try:
                        #cp949 형식으로 읽기
                        with open(csv_file_path,'r',encoding='cp949') as meta_f:
                            reader = csv.reader(meta_f)
                            for line in reader:
                                iname = re.sub(codecs.BOM_UTF8.decode('utf-8'), '', line[0])
                                self.input_map[iname] = line[1].strip().decode('utf-8')

                    except Exception as ex:
#                       
                        traceback.print_exc()
#                       

                if self.input_map:
                    zip.extractall(self.dst_root)

                    for (path, text) in self.input_map.items():
                        rpath = path
                        ipath = os.path.join(self.dst_root, path.lstrip('/'))
                        tcount += 1
                        

                        if not os.path.exists(ipath):
                            #ipath = os.path.join(dst_root, '**', '%s.*' % path.lstrip('/'))
                            ipath = os.path.join(self.dst_root, '%s.*' % path.lstrip('/'))

                            ipath_list = glob.glob(ipath, recursive=True)
                            if not ipath_list:
#                           
                                continue

#                            
                            rpath = os.path.relpath(ipath_list[0],self. dst_root)

                        meta_json['records'].append({
                            'file_url': os.path.join(self.dst_postfix_dir, rpath),
                            'text': text
                        })
                    if len(meta_json['records']) > 0:
                        self.result_json = os.path.join(input_dir, '%s_%s.json' % (self.museid, datetime.now().strftime('%y%m%d'))).replace('\\','/')
                        ZIP_Thread.write_json(self.result_json, meta_json)
            return meta_json['records'],self.result_json

# %%
preproc = ZIP_Thread(src, museid, dst_root, dst_postfix_dir, src_names)
x = preproc.go()
x
# Out:
# utf-8
# ([{'file_url': 'python 서예진/1.m4a',
#    'text': '내가 아직 어리고 지금보다 훨씬 더 쉽게 남의 말에 곧잘 화를 내던 시절 아버지께서는 나에게 한 가지 충고를 해주셨다.'},
#   {'file_url': 'python 서예진/2.m4a', 'text': '그 후로 나는 그 충고를 마음속으로 항상 되새기곤 했다.'},
#   {'file_url': 'python 서예진/3.m4a',
#    'text': '남 의 잘잘못을 따질 때는 언제든지 이 세상 사람들이 너처럼 좋은 환경에서 자라지 못했다는 것을 기억해야 한다.'},
#   {'file_url': 'python 서예진/4.m4a',
#    'text': '아버지께서는 더 이상 말씀하시지 않았지만, 우리는 말없는 가운데서도 서로의 뜻을 잘 이해할 수 있었다.'},
#   {'file_url': 'python 서예진/5.m4a',
#    'text': '나는 아버지의 그 충고 속에는 보다 더 깊은 뜻이 담겨 있다는 것을 알아차렸다.'},
#   {'file_url': 'python 서예진/6.m4a',
#    'text': '아버지의 그 충고로 말미암아 나는 모든 판단을 될 수 있으면 뒤로 미루는 태도를 취하곤 했다.'},
#   {'file_url': 'python 서예진/7.m4a',
#    'text': '그것 때문에 성가시게 치근덕거리는 몇몇 사람들로부터 어려움을 겪기도 했다.'},
#   {'file_url': 'python 서예진/8.m4a',
#    'text': '이러한 성격의 소유자들은 나와 같은 정상적인 사람이 나타나면 금방 눈치채고 가까이 오게 마련이다.'},
#   {'file_url': 'python 서예진/9.m4a',
#    'text': '그것은 내가 거친, 세상에 알려지지 않은 사람들의 은밀한 비애를 많이 알고 있었기 때문이었다.'},
#   {'file_url': 'python 서예진/10.m4a',
#    'text': '어떤 확실한 근거로 은밀한 이야기가 드러나려 할 때면 나는 잠을 자는 척하거나, 적의에 찬 경박한 짓을 하곤 했다.'},
#   {'file_url': 'python 서예진/11.m4a',
#    'text': '사실 젊은이들의 은밀한 이야기는, 적어도 그것을 표현할 때 쓰는 말투도 대개 남의 말을 표절하게 마련이다.'},
#   {'file_url': 'python 서예진/12.m4a',
#    'text': '때로는 어떤 의견 표명을 삼가고 있다는 것이 상대에게 무한한 희망을 줄 때도 있는 법이다.'},
#   {'file_url': 'python 서예진/13.m4a',
#    'text': '이처럼 나의 너그러움을 한껏 과시하고 난 후에야 나는 너그러움에도 한계가 있다는 것을 알게 되었다.'},
#   {'file_url': 'python 서예진/14.m4a',
#    'text': '어떤 한계만 넘기게 되면 나는 그 행위가 어떤 곳을 기반으로 해서 겉으로 드러나게 된 것이든 상관하지 않는다.'},
#   {'file_url': 'python 서예진/15.m4a',
#    'text': '작년 가을, 동부에서 돌아왔을 때 나는 사람들이 똑같은 차림을 하고 일종의 도덕적인 자세를 취해 주었으면 하고 바랐다.'},
#   {'file_url': 'python 서예진/16.m4a',
#    'text': '무슨 특권이라도 지닌 듯이 사람의 마음속을 힐끔힐끔 들여다보는, 야단스럽게 나서는 일에 진저리가 났다.'},
#   {'file_url': 'python 서예진/17.m4a',
#    'text': '오직 한 사람, 이 책의 주인공인 개츠비만은 앞에서 말한 나의 반발에서 제외된 사람이다.'},
#   {'file_url': 'python 서예진/18.m4a',
#    'text': '개츠비는 바로 내가 노골적으로 경멸한 모든 것을 포함하고 있는 대표적인 사람이었던 것이다.'},
#   {'file_url': 'python 서예진/19.m4a',
#    'text': '내가 지금껏 그 누구에게서도 발견하지 못했을 뿐 아니라 앞으로도 영원히 발견하지 못할 낭만적 감수성이었다.'},
#   {'file_url': 'python 서예진/20.m4a',
#    'text': "이 감수성은 저 '창의적인 기질'아래에 위엄을 떨치는 그 허약한 감수성과는 분명히 차이가 있었다."},
#   {'file_url': 'python 서예진/21.m4a',
#    'text': '우리 가족들은 이 중서부의 도시에서 3대에 걸쳐 꽤 이름이 알려진 유지로 부유하게 살아 왔다.'},
#   {'file_url': 'python 서예진/22.m4a',
#    'text': '캐러웨이가는 뛰어난 가문이며, 우리는 부클류 공작의 자손이라고 전해지고 있다.'},
#   {'file_url': 'python 서예진/23.m4a',
#    'text': '실제로 나의 가계를 일으켜 세운 사람은 1851년에 이 곳에 이주하셨다.'},
#   {'file_url': 'python 서예진/24.m4a',
#    'text': '남북 전쟁 때 자기 대신 다른 사람을 대신 내보내고, 철물 도매상을 시작하셨던 나의 증조부이시다.'},
#   {'file_url': 'python 서예진/25.m4a',
#    'text': '지금은 아버지가 그 사업을 이어받아 경영하고 계시다. 나는 그 증조부를 한 번도 뵌 적이 없다'},
#   {'file_url': 'python 서예진/26.m4a',
#    'text': '나는 1915년에 예일 대학을 졸업했는데, 그것은 아버지께서 그 학교를 졸업하신지 25년째 되던 해의 일이었다.'},
#   {'file_url': 'python 서예진/27.m4a',
#    'text': '얼마 후에 나는 1차 세계 대전이라는, 튜튼족의 때늦은 이동 작업에 참가했다.'},
#   {'file_url': 'python 서예진/28.m4a',
#    'text': '그때 나는 미국인의 유럽 역습을 마음껏 즐겼기 때문에 집에 와서도 한동안 들뜬 마음을 진정시킬 수가 없었다.'},
#   {'file_url': 'python 서예진/29.m4a',
#    'text': '미국의 중서부 지방이 이제는 세계의 활기찬 중심지가 아니라 우주의 초라한 변두리같이 보였다.'},
#   {'file_url': 'python 서예진/30.m4a',
#    'text': '나는 동부로 가서 증권업을 배우기로 결심했다. 내가 아는 사람들은 하나같이 증권업에 종사하고 있었기 때문이었다.'},
#   {'file_url': 'python 서예진/31.m4a',
#    'text': '집안 아주머니들은 마치 나를 위해 무슨 대학 진학의 예비 고교를 골라 주기라도 하는 것처럼 그 문제에 대해 여러 가지로 의논하셨다.'},
#   {'file_url': 'python 서예진/32.m4a',
#    'text': '마지막으로 매우 엄숙하고 망설이는 표정으로, "글세, 괜찮을 거야."라고 말씀하셨다.'},
#   {'file_url': 'python 서예진/33.m4a',
#    'text': '사무실의 한 젊은 동료가 기차 통근 거리의 마을에 셋집을 얻어 같이 생활하자고 말해 왔을 때 그것은 멋진 생각처럼 들렸다.'},
#   {'file_url': 'python 서예진/34.m4a',
#    'text': '월세 80달러짜리로 비바람에 낡은 싸구려 방갈로 집이었다. 마지막 순간에 그는 회사로부터 워싱턴으로의 전근 명령을 받았다.'},
#   {'file_url': 'python 서예진/35.m4a',
#    'text': '. 나는 그 때 개 한 마리를 갖고 있었는데 그 개가 달아나기 전까지 적어도 2, 3일 동안은 함께 생활했다.'},
#   {'file_url': 'python 서예진/36.m4a',
#    'text': '요리용 전기 난로 위로 몸을 구부리고는 알 수 없는 혼잣말로 핀란드 속담을 중얼거리곤 했다.'},
#   {'file_url': 'python 서예진/37.m4a',
#    'text': '하루 이틀은 무척 외로웠는데, 어느 날 아침 길에서 나보다 늦게 이사 온 어떤 사람이 나를 불러 세웠다.'},
#   {'file_url': 'python 서예진/38.m4a',
#    'text': '나는 안내자요 개척자요 맨 처음 이 곳에 초기 정착한 사람이 되었던 것이다.'},
#   {'file_url': 'python 서예진/39.m4a',
#    'text': '나는 햇빛과 그리고 고속 촬영 영화에서 식물이 자라는 것처럼 쑥쑥 크는 나뭇잎들을 보았다.'},
#   {'file_url': 'python 서예진/40.m4a',
#    'text': '인생은 여름과 함께 다시 시작된다는, 지극히 평범한 사실을 깨닫기에 이르렀다.'},
#   {'file_url': 'python 서예진/41.m4a',
#    'text': '우선 먼저 할 일은 독서와 더불어 신선한 호흡을 하게 해 주는 맑은 공기에서 건강을 얻어내는 일이었다.'},
#   {'file_url': 'python 서예진/42.m4a',
#    'text': '그것들은 조폐국에서 금방 찍어 낸 새 돈처럼 붉은빛과 황금빛을 띤 채 내 서가에 꽂혀있다.'},
#   {'file_url': 'python 서예진/43.m4a',
#    'text': "나는 대학 시절 문학에 제법 자신이 있었다. 1년간 '예일 뉴스'지에 아주 품위 있고 명확한 논설을 연재한 적도 있을 정도였다."},
#   {'file_url': 'python 서예진/44.m4a',
#    'text': "난 지금의 내 생활에서 이러한 것들을 다시 찾아냄으로써, 다시 '박식하고 원만한 사람'이 되어 보려는 생각이었다."},
#   {'file_url': 'python 서예진/45.m4a',
#    'text': '결국 인생이란 여럿이 아닌 단 하나의 창문으로 바라보면 성공하기가 훨씬 더 쉬운 것이다.'},
#   {'file_url': 'python 서예진/46.m4a',
#    'text': '내가 북아메리카에서 가장 낯선 동네에 집을 얻게 된 것은 우연히 일어난 일 때문이었다.'},
#   {'file_url': 'python 서예진/47.m4a',
#    'text': '집은 뉴욕의 동쪽으로 곧장 뻗은 그 길쭉하고 요란스러운 섬 위에 있었다.'},
#   {'file_url': 'python 서예진/48.m4a',
#    'text': '그곳에는 천연의 진기물들이 많이 있었는데, 그 가운데 특이한 지역이 두 군데 있었다.'},
#   {'file_url': 'python 서예진/49.m4a',
#    'text': '롱아일랜드 해협이라 불리는, 물에 젖은 넓은 뒷마당 안으로 솟아 나온 그 두 지대는 완전한 달걀 모양은 아니었다.'},
#   {'file_url': 'python 서예진/50.m4a',
#    'text': '날개가 없는 인간을 더욱 재미있게 하는 것은 그 두 지대가 모양과 크기를 빼고는 모든 점에서 닮은 점이 하나도 없다는 사실이었다.'},
#   {'file_url': 'python 서예진/51.m4a',
#    'text': '해협에서 50야드밖에 안 떨어진 맨 꼭대기 부분에 있는 나의 집은 어마어마하게 좋은 두 채의 저택 사이에 끼여 있었다.'},
#   {'file_url': 'python 서예진/52.m4a',
#    'text': '내가 세든 집의 오른쪽에 있는 저택은 어느 모로 보나 위압감을 주는 대저택이었다.'},
#   {'file_url': 'python 서예진/53.m4a',
#    'text': '노르망디의 어떤 시의 청사를 본떠 만든 것이었는데, 그 집은 개츠비의 저택이었다.'},
#   {'file_url': 'python 서예진/54.m4a',
#    'text': '나는 개츠비라는 사람을 단 한 번도 보지 못했으므로 그런 이름을 가진 신사가 살고 있는 저택이었다고 해야 옳을 것이다.'},
#   {'file_url': 'python 서예진/55.m4a',
#    'text': '내가 세든 집은 주위의 환경과는 어울리지 않았지만 아주 작았기 때문에 그다지 거슬리는 것은 아니었다.'},
#   {'file_url': 'python 서예진/56.m4a',
#    'text': '나는 바다도 바라보고, 내 이웃집 잔디밭도 내다보면서 백만장자들의 이웃이라는 위안을 받았다.'},
#   {'file_url': 'python 서예진/57.m4a',
#    'text': '이름뿐인 만 건너편은 바닷가를 따라 호화로운 이스트에그의 하얀 저택들이 번쩍거리고 있었다.'},
#   {'file_url': 'python 서예진/58.m4a',
#    'text': '내가 탐 부캐넌 부부와 저녁 식사를 하러 그 곳으로 차를 몰고 간 바로 그 날 저녁에 이 여름의 역사는 시작되었다.'},
#   {'file_url': 'python 서예진/59.m4a',
#    'text': '전쟁이 끝난 직후에 나는 시카고에 사는 그들 부부와 이틀 동안 함께 지냈었다'},
#   {'file_url': 'python 서예진/60.m4a',
#    'text': '탐은 여러 가지 운동을 했는데, 특히 예일 대학의 축구 선수로는 보기 드문 강력한 스크럼 선수 가운데 하나였다.'},
#   {'file_url': 'python 서예진/61.m4a',
#    'text': '젊은 나이에 이미 정상의 위치에 올라 있었기에 그 후로는 모든 일에 있어 내리막길을 걷고 있는 듯한 느낌을 주는 인물이었다.'},
#   {'file_url': 'python 서예진/62.m4a',
#    'text': '그는 굉장한 부자였다. 대학을 다닐 때도 돈에 전혀 신경 쓰지 않는 그의 생활은 비난의 대상이 되기도 했다.'},
#   {'file_url': 'python 서예진/63.m4a',
#    'text': '지금 그는 시카고를 떠난 사람들을 깜짝 놀라게 할 정도의 멋진 계획을 세워서 동부에 와 있는 것이다.'},
#   {'file_url': 'python 서예진/64.m4a',
#    'text': '그 한 예로 그는 레이크 퍼리트로부터 폴로 경기용 말 한 떼를 끌고 왔던 것이다.'},
#   {'file_url': 'python 서예진/65.m4a',
#    'text': '내 또래의 남자로 어마어마한 그런 일을 할 정도로 돈이 많다니, 정말로 이해하기가 어려웠다.'},
#   {'file_url': 'python 서예진/66.m4a',
#    'text': '그들은 1년 동안을 프랑스에서 지냈다. 돌아와서는 폴로 경기를 하며 돈 많은 사람들이 있는 곳을 찾아다녔다.'},
#   {'file_url': 'python 서예진/67.m4a',
#    'text': '데이지는 내게 전화를 걸어 이번에는 영원히 이 곳에서 살고 싶다고 말했지만 나는 믿지 않았다.'},
#   {'file_url': 'python 서예진/68.m4a',
#    'text': '나는 따뜻한 바람이 불던 어느 날 저녁, 안면만 있는 두 명의 친구를 만나기 위해 이스트에그로 자동차를 몰고 갔다.'},
#   {'file_url': 'python 서예진/69.m4a',
#    'text': '그들의 집은 내가 상상한 것보다 훨씬 정교하게 지은, 왕조 시대의 식민지풍 저택이었다.'},
#   {'file_url': 'python 서예진/70.m4a',
#    'text': '잔디가 해안에서부터 집의 현관문까지, 그것은 도중에 해시계와 벽돌을 깐 보도 그리고 붉게 타는 듯한 정원을 지나서도 계속되었다.'},
#   {'file_url': 'python 서예진/71.m4a',
#    'text': '마침내 집까지 이어져서는 한쪽으로 마치 관성의 법칙으로 인한 양 선명한 빛깔의 덩굴 숲으로 이어져 있었다.'},
#   {'file_url': 'python 서예진/72.m4a',
#    'text': '저택의 정면은 햇빛을 받아 금빛으로 반짝이고 한 줄로 가지런하게 달린 창문들은 따뜻한 바람을 맞으려고 활짝 열려져 있었다.'},
#   {'file_url': 'python 서예진/73.m4a',
#    'text': '마복 차림의 탐 부캐넌이 두 다리를 벌린 꼿꼿한 자세로 정면 베란다에 서 있었다.'},
#   {'file_url': 'python 서예진/74.m4a',
#    'text': '지금의 그는 건강한 체격에 밀짚빛 머리칼을 지닌 30대의 사나이로, 굳게 다문 입이 오만한 느낌을 주었다.'},
#   {'file_url': 'python 서예진/75.m4a',
#    'text': '거만스러운 두 눈이 얼굴을 온통 뒤덮고 있었으며, 싸울 상대를 만나기라도 한 것처럼 몸을 앞으로 굽히고 있었다.'},
#   {'file_url': 'python 서예진/76.m4a',
#    'text': '여자의 옷처럼 화려한 승마복도 그의 육체의 엄청난 힘을 감추지는 못했다.'},
#   {'file_url': 'python 서예진/77.m4a',
#    'text': '꽉 끼이는 것처럼 보이는 번쩍이는 장화의 맨 위쪽 끈은 팽팽하게 죄어져 있었다.'},
#   {'file_url': 'python 서예진/78.m4a',
#    'text': '얇은 상의 밑으로 어깨가 움직일 때마다 우람한 근육이 꿈틀거리는 것을 볼 수 있었다.'},
#   {'file_url': 'python 서예진/79.m4a',
#    'text': '거칠고 센 듯한 그의 고음 목소리는 성깔 있어 보이는 그의 인상을 한층 더 강렬하게 보이게 했다.'},
#   {'file_url': 'python 서예진/80.m4a',
#    'text': '그의 목소리에는 친절한 사람들을 대할 때조차 고압적이고 경멸감이 담겨 있는 것처럼 보였다.'},
#   {'file_url': 'python 서예진/81.m4a',
#    'text': '"이러한 문제들에 대한 나의 의견이 결론적인 것이라고 생각하면 안되지. 내가 당신보다 힘이 세고 남자답다는 이유만으로 말이야"'},
#   {'file_url': 'python 서예진/82.m4a',
#    'text': '그와 나는 4학년 때 같은 사교 클럽에 들어 있었다. 결코 친한 사이는 아니었지만 그는 내게 항상 친절했다.'},
#   {'file_url': 'python 서예진/83.m4a',
#    'text': '특유의 거칠고 시비조인 불만스러운 태도를 취하기는 했지만 내가 자기를 좋아하기를 바라는 눈치였다.'},
#   {'file_url': 'python 서예진/84.m4a',
#    'text': '한 팔로 나를 돌려 세우며 넓적하고 편편한 손을 들어 앞으로 펼쳐져 있는 경치를 가리켰다.'},
#   {'file_url': 'python 서예진/85.m4a',
#    'text': '그는 공손하면서도 갑작스럽게 나를 또다시 빙 돌려세우면서 말했다. "이제 안으로 들어가세."'},
#   {'file_url': 'python 서예진/86.m4a',
#    'text': '창문 아래로는 집 안쪽으로 침입한 듯한, 싱그러움을 안겨 주는 풀밭이 펼쳐져 있었다.'},
#   {'file_url': 'python 서예진/87.m4a',
#    'text': '방 안 의자에는 젊은 여자 두 명이 마치 강철 줄로 매 놓은 기구에 앉은 것처럼 앉아 있었다.'},
#   {'file_url': 'python 서예진/88.m4a',
#    'text': '그 옷들은 마치 집의 주변을 잠시 날아다니다 바람에 밀려 지금 막 들어온 것처럼 가볍게 나부끼고 있었다.'},
#   {'file_url': 'python 서예진/89.m4a',
#    'text': '나는 커튼의 펄럭이는 소리와 벽에 걸린 액자의 흔들리는 소리에 정신에 빼앗긴 채 한동안 그대로 서 있었음에 틀림없다.'},
#   {'file_url': 'python 서예진/90.m4a',
#    'text': '탐 부캐넌이 뒤뜰의 창문을 닫는 소리가 들리더니 이어 바람이 멎어 조용해졌다.'},
#   {'file_url': 'python 서예진/91.m4a',
#    'text': '그녀는 긴 의자의 한쪽 끝에 몸을 쭉 펴고 앉아서는 석고상처럼 움직이지 않았다.'},
#   {'file_url': 'python 서예진/92.m4a',
#    'text': '마치 그 위에다 뭔가를 얹어 놓고 그것이 떨어지면 큰일날까 걱정이 되어 균형을 잡고 있는 것처럼 보였다.'},
#   {'file_url': 'python 서예진/93.m4a',
#    'text': '그녀가 나를 곁눈질해 보았는지는 몰라도 전혀 아는 척하지 않았다.'},
#   {'file_url': 'python 서예진/94.m4a',
#    'text': '사실 나는 놀랐고, 그래서 방안에 들어와서 그녀의 심리적 균형을 깬 것에 대해 사과의 말을 중얼거릴 뻔했다.'},
#   {'file_url': 'python 서예진/95.m4a',
#    'text': '어색하지만 매력적인 웃음을 지었다. 얼떨결에 나 역시 따라 웃고는 방안으로 들어갔다.'},
#   {'file_url': 'python 서예진/96.m4a',
#    'text': '그녀는 내 손을 잡고 얼굴을 쳐다보면서 그 동안 보고 싶었다고 강조해서 말했다.'},
#   {'file_url': 'python 서예진/97.m4a',
#    'text': '그녀는 턱의 균형을 잡고 있는 것처럼 행동하고 있는 그 여자의 성은 베이커라고 나직하게 속삭여 주었다.'},
#   {'file_url': 'python 서예진/98.m4a',
#    'text': '데이지가 일부러 속삭이는 것은 듣는 사람이 자기에게로 몸을 기울이게 하기 위함이라는 말을 들은 적이 있다.'},
#   {'file_url': 'python 서예진/99.m4a',
#    'text': '그것은 얼토당토않은 모함이었으나, 그런 모함에도 불구하고 데이지의 그러한 속삭임은 매력적으로 보였다.'},
#   {'file_url': 'python 서예진/100.m4a',
#    'text': '베이커 양의 입술이 움직였고, 나를 향해 고개를 끄덕여 인사한 그녀는 다시 아까처럼 머리를 뒤로 젖혔다.'},
#   {'file_url': 'python 서예진/101.m4a',
#    'text': '그녀가 턱의 균형을 잡고 떨어뜨리지 않으려 하고 있던 물건이 약간 뒤뚱거려 그녀를 얼마쯤 놀래게 했다.'},
#   {'file_url': 'python 서예진/102.m4a',
#    'text': '누군가 자기 만족에 빠진 사람을 보면 항상 감동해서 찬사를 보내고 싶어진다.'},
#   {'file_url': 'python 서예진/103.m4a',
#    'text': '내가 다시 데이지 쪽을 쳐다보자 그녀는 나지막하지만 자극적인 목소리로 여러 가지에 대해 묻기 시작했다.'},
#   {'file_url': 'python 서예진/104.m4a',
#    'text': '그 목소리는 마치 다시는 연주될 수 없는 악곡과 같아서 듣는 사람의 귀는 그 목소리를 따라서 오르락내리락하게 되었다.'},
#   {'file_url': 'python 서예진/105.m4a',
#    'text': '그녀의 목소리는 좀 흥분되어 있어서 그녀에게 호감을 갖고 있는 남자라면 여간해서 그것을 잊을 수 없게 했다.'},
#   {'file_url': 'python 서예진/106.m4a',
#    'text': '나는 동부로 오는 길에 시카고에 들렀던 이야기를 해 주면서 그 곳의 친척이 그녀에게 안부를 전하더라고 알려주었다.'},
#   {'file_url': 'python 서예진/107.m4a',
#    'text': '"그분들이 저를 잊지 않았나요?"하고 그녀는 흥분을 감추지 못하며 들뜬 목소리로 소리쳤다.'},
#   {'file_url': 'python 서예진/108.m4a',
#    'text': '아까부터 방안을 불안스럽게 서성거리고 있던 탐 부캐넌이 갑자기 다가와서 내 어깨에 손을 얹었다.'},
#   {'file_url': 'python 서예진/109.m4a',
#    'text': '그는 더 중요한 어떤 일에 마음을 쓰고 있기나 한 듯 데이지를 힐끔 쳐다보고는 다시 나를 보면서 말했다.'},
#   {'file_url': 'python 서예진/110.m4a',
#    'text': '"정말 그래요!" 그녀가 너무나 갑작스럽게 소리쳤으므로 나는 깜짝 놀랐다.'},
#   {'file_url': 'python 서예진/111.m4a',
#    'text': '"몸이 너무 찌뿌드드해요." 자리에서 일어선 그녀가 투덜거렸다.'},
#   {'file_url': 'python 서예진/112.m4a',
#    'text': '내가 이 방에 들어온 후로 내가 처음 한 말이었다. 그 한 마디에 내가 놀란 것만큼이나 그녀도 놀란 것이 분명했다.'},
#   {'file_url': 'python 서예진/113.m4a',
#    'text': '왜냐하면 그녀는 입을 크게 벌리고는 빠르고도 능숙한 동작으로 일어섰으니까 말이다.'},
#   {'file_url': 'python 서예진/114.m4a',
#    'text': '그는 마치 술이 잔 밑바닥에 한 방울이라도 남아 있으면 안되기라도 한 듯 칵테일을 단숨에 마셨다.'},
#   {'file_url': 'python 서예진/115.m4a',
#    'text': "나는 베이커 양의 그 '해낸 일이 무엇인지 궁금했기 때문에 그녀를 바라보았다."},
#   {'file_url': 'python 서예진/116.m4a',
#    'text': '그녀는 가냘픈 몸에 곧은 몸매를 하고 있었는데, 마치 젊은 사관 후보생처럼 어깨를 뒤로 젖혀 곧은 몸매를 더욱 드러나게 했다.'},
#   {'file_url': 'python 서예진/117.m4a',
#    'text': '햇빛으로 찡그린 그녀의 회색 눈동자가 호기심에 찬 눈빛으로 나를 돌아다보았다.'},
#   {'file_url': 'python 서예진/118.m4a',
#    'text': '나는 문득 어디에선가 그녀를 혹은 그녀의 사진을 본 적이 있다는 생각이 들었다.'},
#   {'file_url': 'python 서예진/119.m4a',
#    'text': '"웨스트에그에 살고 계시다고요?" 그녀는 무시하는 투로 말했다.'},
#   {'file_url': 'python 서예진/120.m4a',
#    'text': '그 사람은 바로 내 집 옆에 살고 있다고 미처 대답하기 전에 하인이 저녁 식사가 준비되어 있다고 알려 왔다.'},
#   {'file_url': 'python 서예진/121.m4a',
#    'text': '그는 그의 억센 팔을 자기 마음대로 내 겨드랑이 밑으로 넣더니 장기 알을 다른 칸으로 옮기듯이 나를 방에서 이끌고 나갔다.'},
#   {'file_url': 'python 서예진/122.m4a',
#    'text': '두 여인은 손을 허리에 살며시 얹은 채 가볍고도 경쾌한 발걸음으로 앞장서서 지는 해를 향해 훤히 트여 있는 장밋빛 방으로 갔다.'},
#   {'file_url': 'python 서예진/123.m4a',
#    'text': '"촛불은 뭐 하러 켰지?" 데이지가 눈살을 찌푸리면서 짜증을 냈다.'},
#   {'file_url': 'python 서예진/124.m4a',
#    'text': '"2주일만 지나면 1년 중 가장 길다는 하지예요." 그녀는 밝은 얼굴로 우리들을 쳐다보았다.'},
#   {'file_url': 'python 서예진/125.m4a',
#    'text': '당신들도 일 년 중에서 낮이 가장 길다는 그 날을 기다렸으면서도 막상 다가오니까 그 날을 깜박 잊고 지나쳐 버리지요?'},
#   {'file_url': 'python 서예진/126.m4a',
#    'text': '저는 말이에요, 항상 그 날을 기다렸으면서도 깜박 그 날을 지나쳐 버리지 뭐예요.'},
#   {'file_url': 'python 서예진/127.m4a',
#    'text': '베이커 양이 하품을 하며 마치 잠자리에 들기라고 하듯이 식탁에 앉으면서 말했다.'},
#   {'file_url': 'python 서예진/128.m4a',
#    'text': '"무슨 계획을 세울까요?" 그녀는 별 뚜렷한 것이 생각나지 않는 듯 나를 쳐다보았다.'},
#   {'file_url': 'python 서예진/129.m4a',
#    'text': '내가 대답하기도 전에 그녀는 눈에 걱정스러운 빛을 띠고 자기의 새끼손가락을 천천히 들여다보았다.'},
#   {'file_url': 'python 서예진/130.m4a',
#    'text': '"여길 다쳤어요." 우리의 시선이 모두 그녀의 손가락을 향했다. 새끼손가락 마디는 검고 푸르스름했다.'},
#   {'file_url': 'python 서예진/131.m4a',
#    'text': '이것 역시 짐승 같은 남자, 산더미 만한, 괴물처럼 엄청나게 큰 몸집의 본보기 같은 남자와 결혼한 탓이에요.'},
#   {'file_url': 'python 서예진/132.m4a',
#    'text': '"괴물 같다는 소리는 정말로 듣기 싫소." 탐이 얼굴을 찡그리며 투덜거렸다.'},
#   {'file_url': 'python 서예진/133.m4a',
#    'text': '데이지와 베이커 양은 동시에 얘기를 하곤 했는데, 그들의 얘기는 아주 평범했다.'},
#   {'file_url': 'python 서예진/134.m4a',
#    'text': '그들은 입고 있는 흰옷이나 아무 욕망도 없어 보이는 무심한 눈만큼이나 태연한, 무미건조한 농담처럼 말했다.'},
#   {'file_url': 'python 서예진/135.m4a',
#    'text': '그들은 그저 이 곳에 있고, 대접을 받으려고 겸손하고 즐거운 척 위장을 하고 있었던 것뿐이다.'},
#   {'file_url': 'python 서예진/136.m4a',
#    'text': '그들은 식사가 곧 끝날 것이고, 조금 더 있으면 이 밤 또한 끝나 평범하게 잊혀지리라는 것을 알고 있었던 것이다.'},
#   {'file_url': 'python 서예진/137.m4a',
#    'text': '순간 자체가 긴장된 두려움 속에서 저녁의 끝을 향하여 한 단계 한 단계씩 급히 지나가 버리게 마련이었다.'},
#   {'file_url': 'python 서예진/138.m4a',
#    'text': '나는 코르크 냄새가 나지만 그런 대로 맛이 좋은 적포도주를 두 잔째 마시면서 진실을 말했다.'},
#   {'file_url': 'python 서예진/139.m4a',
#    'text': "나는 매사에 지독한 비관론자가 되어 버렸다네. 자네, '유색인 제국의 발흥'이라는 책을 읽어 본 적이 있나?"},
#   {'file_url': 'python 서예진/140.m4a',
#    'text': '그 책의 요지는 우리가 경계하지 않으면 백색 인종은 완전히 멸망해 버린다는 거야. 과학적으로 증명까지 하고 있지.'},
#   {'file_url': 'python 서예진/141.m4a',
#    'text': '"탐은 요즘 매우 심각한 생각을 많이 해." 데이지가 측은한 표정을 지으며 말했다.'},
#   {'file_url': 'python 서예진/142.m4a',
#    'text': '뜻도 모를 난해한 책들이 많아. 그 낱말의 뜻이 뭐였더라...?'},
#   {'file_url': 'python 서예진/143.m4a',
#    'text': '"모두 과학적인 책들이야." 탐은 참을성 없게 데이지를 힐끔 바라보며 자기 주장을 내세웠다.'},
#   {'file_url': 'python 서예진/144.m4a',
#    'text': '그건 지배적인 인종인 우리의 책임이야. 조심하지 않으면 다른 인종들이 모든 것을 지배하게 될 거야.'},
#   {'file_url': 'python 서예진/145.m4a',
#    'text': '"그 인종들을 타도해야죠." 강렬한 햇빛에 눈을 사납게 깜박이면서 그녀가 귓속말로 말했다.'},
#   {'file_url': 'python 서예진/146.m4a',
#    'text': '그가 둔한 몸을 일으켜 고쳐 앉음으로써 그녀의 말을 가로막았다.'},
#   {'file_url': 'python 서예진/147.m4a',
#    'text': '그 책이 말하고 있는 것은 우리가 북유럽 인종이라는 것이지. 나도 자네도, 그리고 당신도 말이야.'},
#   {'file_url': 'python 서예진/148.m4a',
#    'text': '그는 잠시 망설이더니 머리를 조금 끄덕이는 것으로 데이지도 그 속에 포함시켰다.'},
#   {'file_url': 'python 서예진/149.m4a',
#    'text': '문명을 형성하는 데에 필요한 모든 것들을 우리 백인이 만들어 냈던 것이네.'},
#   {'file_url': 'python 서예진/150.m4a',
#    'text': '평소보다 더 두드러진 자기 만족감도 더 이상 그를 충족시켜 주지 못하는 것같이 보였다.'},
#   {'file_url': 'python 서예진/151.m4a',
#    'text': '이 때 안에서 전화벨이 울려 하인이 방을 나가자, 데이지는 순간적으로 말이 중단된 틈을 타서 내게로 몸을 기울였다.'},
#   {'file_url': 'python 서예진/152.m4a',
#    'text': '"우리 집안의 비밀을 하나 가르쳐 드릴게요."  그녀는 신나는 듯이 속삭이었다.'},
#   {'file_url': 'python 서예진/153.m4a',
#    'text': '그녀의 붉어진 얼굴은 늦은 석양빛으로 낭만적인 감정이 맴돌았다.'},
#   {'file_url': 'python 서예진/154.m4a',
#    'text': '그녀의 목소리는 나로 하여금 숨을 죽이고 그녀의 몸 쪽으로 다가가도록 했다.'},
#   {'file_url': 'python 서예진/155.m4a',
#    'text': '탐은 찡그리며 의자를 뒤로 밀고는 한 마디 말도 없이 안으로 들어갔다.'},
#   {'file_url': 'python 서예진/156.m4a',
#    'text': '그것이 무슨 신호라도 된 듯이 데이지는 다시 앞으로 몸을 숙였고, 그녀의 목소리는 열기를 띠고 들떠 있었다.'},
#   {'file_url': 'python 서예진/157.m4a',
#    'text': '닉 오빠를 우리 집 저녁 식사에 모시게 되어 기뻐요. 오빠를 보고 있으면 아름답게 핀 장미꽃이 생각나요.'},
#   {'file_url': 'python 서예진/158.m4a',
#    'text': '데이지는 그저 생각나는 대로 말한 것이었지만, 그녀에게서는 사람을 충동시키는 마력이 넘쳐흐르고 있었다.'},
#   {'file_url': 'python 서예진/159.m4a',
#    'text': '그녀는 갑자기 냅킨을 식탁 위에 던지고는 실례하겠다고 짧게 말한 뒤 안으로 들어가 버렸다.'},
#   {'file_url': 'python 서예진/160.m4a',
#    'text': '베이커 양과 나는 아무 뜻 없이 무의식적으로 잠시 눈길을 주고받았다.'},
#   {'file_url': 'python 서예진/161.m4a',
#    'text': '내가 막 입을 열려고 하는 순간, 그녀가 재빠르게 자세를 고쳐 앉으며 경계하는 목소리로,  "쉬!"하고 말했다.'},
#   {'file_url': 'python 서예진/162.m4a',
#    'text': '저 쪽 방에서 흥분을 억제하며 숨을 죽여 가며 수군거리는 소리가 들려왔다.'},
#   {'file_url': 'python 서예진/163.m4a',
#    'text': '베이커 양은 예의도 잊은 듯 엿들으려고 몸을 안쪽으로 굽혔다.'},
#   {'file_url': 'python 서예진/164.m4a',
#    'text': '수군거리는 소리는 끊어질 듯 떨리며 낮아졌다가 흥분되어 커지더니 마침내 완전히 그쳐 버렸다.'},
#   {'file_url': 'python 서예진/165.m4a',
#    'text': '조금 전에 말한 그 개츠비라는 사람은 바로 나의 이웃입니다. 옆집에 살고 있지요.'},
#   {'file_url': 'python 서예진/166.m4a',
#    'text': '그녀는 망설이며 말했다. "탐은 뉴욕에 사귀는 여자가 있어요."'},
#   {'file_url': 'python 서예진/167.m4a',
#    'text': '그녀가 저녁 식사시간에는 전화를 삼가는 조심성 정도는 있어야 할 텐데요. 그렇게 생각하지 않아요?'},
#   {'file_url': 'python 서예진/168.m4a',
#    'text': '무슨 뜻인지 제대로 이해하기도 전에 탐과 데이지가 식탁으로 되돌아왔다.'},
#   {'file_url': 'python 서예진/169.m4a',
#    'text': '그녀는 자리에 앉아서 베이커 양과 나의 눈치를 살피고 나서 말을 이었다.'},
#   {'file_url': 'python 서예진/170.m4a',
#    'text': '나가 보니 아주 상쾌하더군요. 새가 한 마리 앉아 있었는데, 배를 타고 건너온 나이팅게일 같았어요.'},
#   {'file_url': 'python 서예진/171.m4a',
#    'text': '그녀의 목소리는 노래를 부르는 것 같았다. "로맨틱하지요, 안 그래요, 탐?"'},
#   {'file_url': 'python 서예진/172.m4a',
#    'text': '"굉장히 로맨틱한데." 탐은 이렇게 말하고 난 뒤 괴로운 표정으로 내게 말했다.'},
#   {'file_url': 'python 서예진/173.m4a',
#    'text': '"저녁 식사 후에도 날이 어두워지지 않으면 저 아래 있는 마구간을 보여 주고 싶은데."'},
#   {'file_url': 'python 서예진/174.m4a',
#    'text': '또다시 안에서 전화벨이 요란하게 울렸다. 데이지가 탐을 향해 단호하게 고개를 흔들자 마구간 문제는 없어져 버렸다.'},
#   {'file_url': 'python 서예진/175.m4a',
#    'text': '엉망이 된 그 날 저녁 식탁에서 기억에 남는 일이라고는 아무 의미도 없이 촛불이 다시 켜졌던 일뿐이었다.'},
#   {'file_url': 'python 서예진/176.m4a',
#    'text': '나는 모두가 어떤 표정을 짓고 있는지 살펴보고 싶었으나 왠지 모두의 시선과 마주치는 것을 피하게 되었다.'},
#   {'file_url': 'python 서예진/177.m4a',
#    'text': '나로서는 탐이나 데이지가 무슨 생각을 하고 있는지 도무지 짐작할 길이 없었다.'},
#   {'file_url': 'python 서예진/178.m4a',
#    'text': '베이커 양마저 그 전화벨의 주인공이 누구인지 궁금해하고 있는 것 같았다.'},
#   {'file_url': 'python 서예진/179.m4a',
#    'text': '어떤 사람에게는 일이 복잡하게 얽힌 것으로 보일는지도 모른다. 내 성미대로라면 전화로 경찰을 당장 불렀으면 싶었다.'},
#   {'file_url': 'python 서예진/180.m4a',
#    'text': '나는 흥미를 느끼는 동시에 데이지의 뒤를 따라 연결된 길다란 베란다를 돌아 정면 현관으로 갔다.'},
#   {'file_url': 'python 서예진/181.m4a',
#    'text': '데이지는 마치 자신의 사랑스러운 얼굴을 손으로 느끼기라도 하려는 듯이 두 손으로 얼굴을 감쌌다.'},
#   {'file_url': 'python 서예진/182.m4a',
#    'text': '그녀의 두 눈은 벨벳 색의 어둠 속으로 천천히 움직였다. 그녀가 몹시 흥분한 것처럼 보였다.'},
#   {'file_url': 'python 서예진/183.m4a',
#    'text': '나는 다소나마 그녀를 진정시켜 주고 싶었다. 그래서 그녀의 어린 딸에 대해 이것저것 물어 보았다.'},
#   {'file_url': 'python 서예진/184.m4a',
#    'text': '저는 무슨 일에든지 상당히 냉소적으로 대하는 나쁜 버릇이 생기고 말았죠.'},
#   {'file_url': 'python 서예진/185.m4a',
#    'text': '나는 다음 말을 기다렸지만, 그녀는 더 이상 아무 말도 하지 않았다.'},
#   {'file_url': 'python 서예진/186.m4a',
#    'text': '아이를 낳고 채 한 시간도 지나지 않았는데 탐은 행방을 감추었어요.'},
#   {'file_url': 'python 서예진/187.m4a',
#    'text': '마취에서 깨어나면서 완전히 자포자기해 버린 저는 간호사에게 아들인지 딸인지를 물었어요. 그러자 딸이라고 대답하더군요.'},
#   {'file_url': 'python 서예진/188.m4a',
#    'text': '여자 애라 다행이다. 그러나 좀 멍청해졌으면 좋겠다. 그게 이 세상에서 여자가 될 수 있는 최상의 것이니까.'},
#   {'file_url': 'python 서예진/189.m4a',
#    'text': '"오빠도 알겠지만, 전 이 세상 모든 일이 끔찍하다고 생각해요."그녀는 확신에 찬 목소리로 말을 계속했다.'},
#   {'file_url': 'python 서예진/190.m4a',
#    'text': '그녀의 눈은 탐의 눈과 닮은 도전적인 눈초리로 주위를 둘러보았다. 그러고는 소름 끼치는 자조적인 모습으로 웃어댔다.'},
#   {'file_url': 'python 서예진/191.m4a',
#    'text': '마치 이 저녁이 내게서 어떤 어울릴 감정을 자아내기 위한 술책인 것처럼 여겨져 불안하기만 했다.'},
#   {'file_url': 'python 서예진/192.m4a',
#    'text': '역시 생각한대로 그려는 그 사랑스러운 얼굴에 매우 능글맞은 웃음을 머금고 나를 바라볼 뿐이었다.'},
#   {'file_url': 'python 서예진/193.m4a',
#    'text': '그것은 마치 그녀와 탐이 속한 비교적 유명한 비밀 조직에 가입한 그녀의 회원 자격을 내세우는 듯한 태도였다.'},
#   {'file_url': 'python 서예진/194.m4a',
#    'text': '집 안에서는 진홍색 방이 등불로 눈부시게 빛나고 있었다. 탐과 베이커 양은 긴 의자의 양끝에 앉아 있었다.'},
#   {'file_url': 'python 서예진/195.m4a',
#    'text': '램프의 불빛이 탐의 장화를 밝게 비치고 가을 낙엽같이 노란 베이커 양의 머리도 희미하게 비치고 있었다.'},
#   {'file_url': 'python 서예진/196.m4a',
#    'text': '그녀의 가냘픈 두 팔이 움직이며 잡지를 넘길 때마다 종이도 따라 번득였다.'},
#   {'file_url': 'python 서예진/197.m4a',
#    'text': '우리가 들어서자 그녀는 손을 들어 잠깐 멈춰 있으라고 신호를 보냈다.'},
#   {'file_url': 'python 서예진/198.m4a',
#    'text': '그녀는 잡지를 테이블 위로 던지며 말했다. 그러고는 힘들게 일어섰다.  "10시군요."'},
#   {'file_url': 'python 서예진/199.m4a',
#    'text': '나는 그녀의 얼굴이 어디서 많이 본 듯했던 이유를 이제야 알게 되었다.'},
#   {'file_url': 'python 서예진/200.m4a',
#    'text': '나는 그녀에 대한 몇 가지 비판조의 좋지 않은 얘기도 들은 적이 있지만, 무슨 내용이었는지는 잊어버린 지 오래 되었다.'},
#   {'file_url': 'python 서예진/201.m4a',
#    'text': '별안간 두 사람을 린네르 옷장에 가두어서는 보트에 태워 바다로 띄워 보낸다거나, 뭐 그런 일들 있잖아요?'},
#   {'file_url': 'python 서예진/202.m4a',
#    'text': '"안녕히 주무세요." 베이커 양이 계단을 올라가며 소리쳤다.'},
#   {'file_url': 'python 서예진/203.m4a',
#    'text': '나는 아무 말도 듣지 않았다고 가볍게 받아넘기고 잠시 후 집에 가기 위해 일어섰다.'},
#   {'file_url': 'python 서예진/204.m4a',
#    'text': '기다려요! 뭘 좀 물어 본다는 게 그만 잊고 말았어요, 오빠가 서부에서 약혼을 했다는 얘기가 있던데요.'},
#   {'file_url': 'python 서예진/205.m4a',
#    'text': '"저는 그 소문을 세 사람한테서 들었으니까 사실임에 틀림없어요."'},
#   {'file_url': 'python 서예진/206.m4a',
#    'text': '물론 나도 그들이 무슨 말을 하고 있는지 알고는 있었지만, 나는 약혼 비슷한 것조차 한 적이 없었다.'},
#   {'file_url': 'python 서예진/207.m4a',
#    'text': '내가 동부로 오게 된 이유 중에 하나가 바로 그 소문 때문이었다. 뜬소문 때문에 오랜 친구와 교제를 끊을 수는 없었다.'},
#   {'file_url': 'python 서예진/208.m4a',
#    'text': '탐 부부의 관심은 모름지기 나를 감동시켰고, 그래서 그들이 굉장한 부자가 아닌 것처럼 보이게 했다.'},
#   {'file_url': 'python 서예진/209.m4a',
#    'text': '그럼에도 불구하고 나는 차를 몰면서 머리가 혼란스러워지고 약간 불쾌해지는 것을 느꼈다.'},
#   {'file_url': 'python 서예진/210.m4a',
#    'text': '내 생각에는 데이지가 할 수 있는 최선의 방법은 아이를 안고 그 집에서 뛰쳐나오는 것이었다.'},
#   {'file_url': 'python 서예진/211.m4a',
#    'text': '그것은 마치 그의 건장한 육체적 이기성이 더 이상은 건방진 심성에 자양분을 줄 수 없다는 것을 보이는 것과 같았다.'},
#   {'file_url': 'python 서예진/212.m4a',
#    'text': '길가에 늘어선 집들의 지붕 앞은 이미 여름이 온 듯했고, 빨간색 새 휘발유 펌프들이 한꺼번에 불빛을 받아 근사하게 보였다.'},
#   {'file_url': 'python 서예진/213.m4a',
#    'text': '내 집에 다다른 나는 차를 차고에 집어넣고 나서 마당에 내팽개쳐진 제초기에 잠시 걸터앉았다.'},
#   {'file_url': 'python 서예진/214.m4a',
#    'text': '바람이 불어오자 밤하늘에 나무들이 부딪히는 소리가 요란하게 울려 퍼졌고, 개구리들에게 생명을 가득 불어넣어 주었다.'},
#   {'file_url': 'python 서예진/215.m4a',
#    'text': '달빛 속에 움직이는 고양이 그림자가 아른거리고 있었는데, 고개를 돌렸다가 나는 내가 혼자가 아니었음을 알게 되었다.'},
#   {'file_url': 'python 서예진/216.m4a',
#    'text': '내 이웃의 저택 그늘로부터 어떤 사람의 모습이 손을 주머니에 찔러 넣은 채 은색 후추를 뿌려 놓은 것 같은 별들을 쳐다보고 있었다.'},
#   {'file_url': 'python 서예진/217.m4a',
#    'text': '어딘지 여유 있어 보이는 그 몸놀림과 잔디를 밟고 서 있는 다리의 확고한 자세가 그 사람이 개츠비임을 짐작하게 했다.'},
#   {'file_url': 'python 서예진/218.m4a',
#    'text': '그는 우리 고장의 하늘 중에서 자기 몫의 하늘을 찾아내기 위해 나온 사람처럼 보였다. 나는 그를 부르기로 마음먹었다.'},
#   {'file_url': 'python 서예진/219.m4a',
#    'text': '베이커 양이 저녁 식사 때 그의 얘기를 한 것이 소개 역할을 해 줄 것 같았다. 그렇지만 나는 그를 부르지 않았다.'},
#   {'file_url': 'python 서예진/220.m4a',
#    'text': '나는 그와 멀리 떨어져 있기는 했지만 그가 몸을 떨고 있다는 것을 확실히 알 수 있었다.'},
#   {'file_url': 'python 서예진/221.m4a',
#    'text': '어쩌면 부두의 끝일지도 모를 곳에서 녹색 불빛 하나가 반짝이는 걸 보았을 뿐 다른 것은 전혀 알아볼 수가 없었다.'},
#   {'file_url': 'python 서예진/222.m4a',
#    'text': '내가 다시 개츠비 쪽으로 시선을 돌렸을 때 그의 모습은 어느 새 사라지고 없었다.'},
#   {'file_url': 'python 서예진/223.m4a',
#    'text': '뉴욕으로 가는 중간쯤에서 자동차 도로는 철도 쪽으로 합해져서 4분의 1마일쯤 뻗어 나가다가 어떤 황량한 곳에 이르러 끝난다.'},
#   {'file_url': 'python 서예진/224.m4a',
#    'text': '재가 밀처럼 자라서 산마루도 되고 언덕도 되며 괴이한 정원도 되는 해괴한 농장이다.'},
#   {'file_url': 'python 서예진/225.m4a',
#    'text': '그 곳에서 재는 또 집이나 굴뚝 그리고 피어오르는 연기, 마침내는 어떤 대단한 노력을 거쳐서 잿빛 인간으로까지 변하는 것이다.'},
#   {'file_url': 'python 서예진/226.m4a',
#    'text': '그 인간들은 먼지투성이의 공기 속에서 무기력하게 움직이며 이미 거의 다 쓰러져 가고 있다.'},
#   {'file_url': 'python 서예진/227.m4a',
#    'text': '가끔 뿌연 먼지를 일으키는 차 행렬이 끝없는 도로를 따라 들어와서 소름 끼치는 소리를 내며 멈춰 선다.'},
#   {'file_url': 'python 서예진/228.m4a',
#    'text': '곧 잿빛 사람들이 떼지어 납빛 삽들을 가지고 모여 먼지 구름을 더욱 크게 일으켜 놓았다.'},
#   {'file_url': 'python 서예진/229.m4a',
#    'text': '그 먼지 구름이 그들의 희미한 동작을 가려 버려 우리 눈에는 보이지 않게 한다.'},
#   {'file_url': 'python 서예진/230.m4a',
#    'text': '잿빛 땅과 그 위를 끊임없이 떠도는, 경련적으로 일어나는 먼지 구름 넘어 살며시 박사의 눈이 나타난다.'},
#   {'file_url': 'python 서예진/231.m4a',
#    'text': '푸른빛을 띤 데다 위압감이 느껴질 정도로 큰 눈이 보인다.'},
#   {'file_url': 'python 서예진/232.m4a',
#    'text': '그 눈은 있지도 않은 콧등에 가로 걸려 있는 어마어마한 노란색 안경 너머로 이 쪽을 보고 있다.'},
#   {'file_url': 'python 서예진/233.m4a',
#    'text': '어떤 뻔뻔한 안과 의사가 퀸즈 구에서 거창하게 병원을 차리려고 그 곳에 설치해 놓았던 것이다.'},
#   {'file_url': 'python 서예진/234.m4a',
#    'text': '그 자신이 영원히 미지의 세계로 사라져 버렸거나 아니면 그 선전 간판을 설치해 놓았다는 사실을 잊어버리고 이사를 한 것이리라.'},
#   {'file_url': 'python 서예진/235.m4a',
#    'text': '그 눈은 세월이 흐르는 동안 햇빛과 비에 시달려 좀 흐려진 채 이 엄숙한 쓰레기 하치장을 아직도 의연하게 내려다보고 있다.'},
#   {'file_url': 'python 서예진/236.m4a',
#    'text': '화물선이 지나갈 수 있게 다리가 올라갈 때면 기차 안의 승객들은 길게는 30분 동안이나 그 광경을 지켜보면서 기다려야 했다.'},
#   {'file_url': 'python 서예진/237.m4a',
#    'text': '기차는 그 곳에서 이런 일이 아니더라도 1분간은 정차해 있었다.'},
#   {'file_url': 'python 서예진/238.m4a',
#    'text': '내가 탐 부캐넌의 정부를 처음으로 만나게 된 것도 이 때였다.'},
#   {'file_url': 'python 서예진/239.m4a',
#    'text': '탐에게 정부가 한 명 있다는 사실은 그가 나타나는 곳이라면 어디서든 화제가 되었다.'},
#   {'file_url': 'python 서예진/240.m4a',
#    'text': '그를 아는 사람들은 그가 정부를 데리고 대중 카페에 나타나  잡담 나누는 모습을 좋은 시선으로 보아주지 않았다.'},
#   {'file_url': 'python 서예진/241.m4a',
#    'text': '나는 그 여자를 한 번 보고 싶었지만 일부러 만나고 싶은 생각은 없었다. 그러나 나는 그녀를 만났다.'},
#   {'file_url': 'python 서예진/242.m4a',
#    'text': '기차가 잿더미 곁에 정차하자 탐은 벌떡 일어나더니 내 팔꿈치를 잡고서 막무가내로 나를 차에서 내리게 했다.'},
#   {'file_url': 'python 서예진/243.m4a',
#    'text': '그는 점심때 뭘 잘 먹은 모양이었다. 그리고 나를 대하는 모습은 거의 폭력에 가까웠다.'},
#   {'file_url': 'python 서예진/244.m4a',
#    'text': '그는 마침 일요일 오후라 내게 별다른 일이 없을 것이라고 멋대로 생각했던 것이다.'},
#   {'file_url': 'python 서예진/245.m4a',
#    'text': '나는 그를 따라 하얗게 칠한 나지막한 철로변 담을 넘었고, 박사의 끈질긴 시선을 받으며 기차를 타고 왔던 길을 되돌아갔다.'},
#   {'file_url': 'python 서예진/246.m4a',
#    'text': '건물이라고는 오직 그 황무지 가장자리에 서 있는 조그맣고 노란 벽돌 건물뿐이었다.'},
#   {'file_url': 'python 서예진/247.m4a',
#    'text': '그것은 이 황무지에 자리한 일종의 압축된 중심가라고 할 수 있는 것이었다.'},
#   {'file_url': 'python 서예진/248.m4a',
#    'text': '건물에는 가게가 있었는데, 하나는 야간 영업 레스토랑이었으며, 나머지 하나는 자동차 수리소였다.'},
#   {'file_url': 'python 서예진/249.m4a',
#    'text': '안은 생각보다 초라하고 썰렁했다. 보이는 것이라곤 어두운 구석에 처박혀 있는, 먼지투성이의 고물 포드 승용차 한 대뿐이었다.'},
#   {'file_url': 'python 서예진/250.m4a',
#    'text': '사치스럽고 로맨틱한 아파트가 위층에 감추어져 있을지도 모른다는 생각이 문득 떠올랐다.'},
#   {'file_url': 'python 서예진/251.m4a',
#    'text': '그 때 정비소 주인이 헝겊 조각으로 손을 닦으며 사무실 문간에 나타났다.'},
#   {'file_url': 'python 서예진/252.m4a',
#    'text': '금발의 그는 건강이 좋지 않은지 생기가 없어 보였으며 윤곽만은 제법 뚜렷한 미남이었다.'},
#   {'file_url': 'python 서예진/253.m4a',
#    'text': '우리를 본 그의 연푸른 두 눈에 흐릿한 희망의 빛이 스쳐 지나갔다.'},
#   {'file_url': 'python 서예진/254.m4a', 'text': '탐이 활기에 찬 목소리로 그의 어깨를 두드리며 말했다.'},
#   {'file_url': 'python 서예진/255.m4a',
#    'text': '"그저 그렇습니다."  윌슨이 힘없는 목소리로 대답했다.'},
#   {'file_url': 'python 서예진/256.m4a',
#    'text': '그런데 당신이 그렇게 생각하고 있다면 차라리 어디 다른 곳에다 파는 게 낫겠소'},
#   {'file_url': 'python 서예진/257.m4a',
#    'text': '잠시 후 좀 뚱뚱해 보이는 여자가 사무실 문으로 새어 나오는 불빛을 막아버렸다.'},
#   {'file_url': 'python 서예진/258.m4a',
#    'text': '30대 중반으로 보이는 그녀는 좀 뚱뚱하긴 했지만 관능적인 몸매를 지니고 있었다.'},
#   {'file_url': 'python 서예진/259.m4a',
#    'text': '짙푸른 점무늬의 크레프드신 드레스 위로 솟은 얼굴은 아무리 뜯어 봐도 평범할 뿐이었다.'},
#   {'file_url': 'python 서예진/260.m4a',
#    'text': '온몸의 신경이 끊임없이 불에 그을리고 타고 있기라도 한 것처럼 어디서나 눈에 띌 정도로 몸 전체에 생기가 흘러 넘쳤다.'},
#   {'file_url': 'python 서예진/261.m4a',
#    'text': '"의자라도 가져와요. 왜 가만히 있어요? 그래야 손님이 앉으실 수 있잖아요?"'},
#   {'file_url': 'python 서예진/262.m4a',
#    'text': '윌슨은 황급히 대답하고 나서 벽의 시멘트 색깔과 섞여 사라지듯이 조그마한 사무실 쪽으로 갔다.'},
#   {'file_url': 'python 서예진/263.m4a',
#    'text': '하얀 재먼지가 주변의 모든 것을 먼지로 덮어 버린 것과 마찬가지로 윌슨의 검정색 양복과 연한 빛의 머리칼도 먼지로 덮여 있었다.'},
#   {'file_url': 'python 서예진/264.m4a',
#    'text': '탐 곁에 바싹 다가와 있는 그의 아내만은 예외였다. "만나고 싶소." 탐이 은근한 목소리로 말했다.'},
#   {'file_url': 'python 서예진/265.m4a',
#    'text': '고개를 끄덕인 그녀가 의미심장한 웃음을 지으며 다가가자마자 조지 윌슨이 의자 두 개를 가지고 나타났다.'},
#   {'file_url': 'python 서예진/266.m4a',
#    'text': '우리는 길 아래쪽에서 남의 눈에 띄지 않게 그녀를 기다렸다. 그 날은 독립기념일인 7월 4일을 며칠 앞둔 날이었다.'},
#   {'file_url': 'python 서예진/267.m4a',
#    'text': '회색 옷을 입은 바싹 마른 이탈리아계 어린애가 철로 위에 딱총알을 일렬로 올려놓고 있었다.'},
#   {'file_url': 'python 서예진/268.m4a',
#    'text': '"지독한 동네군. 그렇지 않아?" 하고 탐이 얼굴을 찡그리고 박사의 얼굴을 쳐다보며 말했다.'},
#   {'file_url': 'python 서예진/269.m4a',
#    'text': '윌슨 말인가? 그는 아내가 뉴욕에 있는 처제를 만나러 가는 걸로 알고 있지. 너무 멍청해서 자기가 살아 있다는 것조차도 모르고 있어.'},
#   {'file_url': 'python 서예진/270.m4a',
#    'text': '이리하여 탐 부캐넌과 그의 정부, 그리고 나 이렇게 세 사람은 함께 뉴욕으로 갔다.'},
#   {'file_url': 'python 서예진/271.m4a',
#    'text': '정확하게 말하면 함께 갔다고는 할 수 없다. 왜냐하면 윌슨 부인은 다른 사람들의 눈을 피해 다른 칸에 앉아 있었기 때문이다.'},
#   {'file_url': 'python 서예진/272.m4a',
#    'text': '탐은 혹시 그 기차에 탔을지도 모를 이스트에그 사람들의 구설수에 그만큼 신경을 썼던 것이다.'},
#   {'file_url': 'python 서예진/273.m4a',
#    'text': '윌슨 부인은 모슬린 드레스로 갈아입고 있었는데, 탐의 부축을 받아 플랫폼에 내렸을 때 그 옷은 비교적 꽉 끼어 불편하게 보였다.'},
#   {'file_url': 'python 서예진/274.m4a',
#    'text': "그녀는 신문 판매점에서 '타운태틀'지 1부와 영화 잡지 1권, 그리고 역의 약국에서 콜드크림과 조그만 병에 든 향수를 샀다."},
#   {'file_url': 'python 서예진/275.m4a',
#    'text': '차에 오른 우리는 혼잡한 역을 빠져나가 이글거리는 햇볕 속으로 미끄러져 들어갔다.'},
#   {'file_url': 'python 서예진/276.m4a',
#    'text': '창문으로 바깥을 내다보고 있던 그녀가 갑자기 몸을 홱 돌려 앞으로 굽히고는 차창을 두드리며 말했다.'},
#   {'file_url': 'python 서예진/277.m4a',
#    'text': '"저런 강아지를 한 마리 갖고 싶어요." 그녀는 진지하게 말했다.'},
#   {'file_url': 'python 서예진/278.m4a',
#    'text': '"평소부터 아파트에 한 마리 기르고 싶었어요. 멋진 일이잖아요, 강아지를 한 마리 기른다는 건 말이에요."'},
#   {'file_url': 'python 서예진/279.m4a',
#    'text': '노인의 목에 매달린 바구니 안에는 태어난 지 얼마 되지 않은 혈통 좋은 강아지 10여 마리가 웅크리고 있었다.'},
#   {'file_url': 'python 서예진/280.m4a',
#    'text': '노인은 고개를 갸우뚱하며 바구니 속을 들여다보고는 손을 집어넣어서 한 마리의 강아지 뒷덜미를 잡아 끌어올렸다.'},
#   {'file_url': 'python 서예진/281.m4a',
#    'text': '그 강아지는 두려운 듯 바둥거리고 있었다. "그건 경찰견이 아니오."'},
#   {'file_url': 'python 서예진/282.m4a',
#    'text': '노인은 한 손으로 갈색 타월처럼 부드러운 강아지의 등을 쓰다듬었다.'},
#   {'file_url': 'python 서예진/283.m4a',
#    'text': '이 털을 좀 보세요. 대단하지요. 잔병치레로 주인을 성가시게 할 개는 결코 아닙니다.'},
#   {'file_url': 'python 서예진/284.m4a',
#    'text': '우리는 5번가 쪽으로 달렸다. 따뜻하고 온화한 여름철의 일요일 오후였다.'},
#   {'file_url': 'python 서예진/285.m4a',
#    'text': '하얀 양떼가 그 거리의 모퉁이를 돌아다닌다 하더라도 나는 놀라지 않았을 것이다.'},
#   {'file_url': 'python 서예진/286.m4a',
#    'text': '"자네가 아파트까지 같이 가지 않는다면 머틀이 기분 나빠할 걸. 안 그렇소, 머틀?"'},
#   {'file_url': 'python 서예진/287.m4a',
#    'text': '"제 동생 캐서린에게 전화하겠어요. 주위에 있는 사람들은 그 애가 아주 예쁘다고 칭찬을 하지요."'},
#   {'file_url': 'python 서예진/288.m4a',
#    'text': '우리가 이야기를 하고 있는 사이 차는 다시 한 번 센트럴 파크를 가로질러서 웨스트헌드리즈 가 쪽으로 가고 있었다.'},
#   {'file_url': 'python 서예진/289.m4a',
#    'text': '택시는 158번가에서 멋지게 생긴 아파트 단지로 들어가더니 한 동 앞에 멈춰 섰다.'},
#   {'file_url': 'python 서예진/290.m4a',
#    'text': '윌슨 부인은 외출에서 돌아온 사람처럼 주위를 한 바퀴 둘러본 후, 강아지와 그밖에 사 온 물건들을 들고 거만스럽게 안으로 들어갔다.'},
#   {'file_url': 'python 서예진/291.m4a',
#    'text': '그녀의 아파트는 꼭대기 층에 있었는데, 자그마한 거실과 식당, 침실 그리고 욕실로 나누어져 있었다.'},
#   {'file_url': 'python 서예진/292.m4a',
#    'text': '갖가지 무늬를 한 양탄자가 깔려 있는 거실에는 방에 비해 너무 큰 가구들이 문 앞을 가로막고 있었다.'},
#   {'file_url': 'python 서예진/293.m4a',
#    'text': '방안을 거닐다 보면 양탄자에 그려진 베르사유 궁전의 정원에서 그네를 타는 귀부인들 위를 넘어가는 것 같은 착각에 빠지게 했다.'},
#   {'file_url': 'python 서예진/294.m4a',
#    'text': '유일하게 걸려 있는 그림은 커다랗게 확대시킨 사진이었는데, 선명하지는 않지만 바위에 앉아 있는 암탉을 찍은 것이었다.'},
#   {'file_url': 'python 서예진/295.m4a',
#    'text': '그 암탉은 부인용 보네트처럼 보이기도 하고 비대하게 생긴 노부인이 빙그레 웃으며 방 안을 내려다보는 그림처럼 보이기도 했다.'},
#   {'file_url': 'python 서예진/296.m4a',
#    'text': '그 중 한 개의 비스켓은 우유잔에 담겨져 오후 내내 풀어질 대로 풀어지고 있었다.'},
#   {'file_url': 'python 서예진/297.m4a',
#    'text': '그 동안 탐은 잠겨 있던 장식장 문을 열고 위스키 한 병을 꺼냈다.'},
#   {'file_url': 'python 서예진/298.m4a',
#    'text': '나는 지금까지 취한 적이 딱 두 번 있었는데, 그 두 번째가 바로 이 날이었다.'},
#   {'file_url': 'python 서예진/299.m4a',
#    'text': '오후 8시가 넘도록 따사로운 햇볕이 아파트 안을 가득 채우고 있었다.'},
#   {'file_url': 'python 서예진/300.m4a',
#    'text': '그의 무릎에 걸터앉은 윌슨 부인은 전화로 사람들을 초대했다.'},
#   {'file_url': 'python 서예진/301.m4a',
#    'text': '나는 마침 담배가 떨어져서 길모퉁이에 있는 약국으로 담배를 사러 나갔다.'},
#   {'file_url': 'python 서예진/302.m4a',
#    'text': "나는 거실에 다소곳이 앉아 '사이먼은 피터를 불렀다'라는 책의 첫장을 폈다."},
#   {'file_url': 'python 서예진/303.m4a',
#    'text': '책이 형편없는 것이어서인지 아니면 위스키가 정신을 흐려 놓아서인지는 모르나, 그 책의 내용을 전혀 파악할 수 없었다.'},
#   {'file_url': 'python 서예진/304.m4a',
#    'text': '탐과 머틀이 잠시 후 나타났고, 이어서 손님들이 하나둘 도착하기 시작했다.'},
#   {'file_url': 'python 서예진/305.m4a',
#    'text': '캐서린은 가냘프고 고생을 많이 한 것 같아 보이는 30세 가량의 여자로, 붉은색 단발머리에 얼굴에는 화장을 진하게 하고 있었다.'},
#   {'file_url': 'python 서예진/306.m4a',
#    'text': '눈썹을 모두 뽑고 보다 더 요염하게 그리려 노력했지만, 그 노력은 얼굴의 분위기를 깨뜨리는 결과가 되고 말았다.'},
#   {'file_url': 'python 서예진/307.m4a',
#    'text': '몸을 움직일 때마다 양팔에 가득 찬 사기 팔찌들이 달그락거렸다.'},
#   {'file_url': 'python 서예진/308.m4a',
#    'text': '그녀는 마치 이 아파트의 주인이라도 되는 것처럼 가구에 이상이 없는지 일일이 둘러보기 시작했다.'},
#   {'file_url': 'python 서예진/309.m4a',
#    'text': '내가 그것에 대해 묻자, 그녀는 호들갑스럽게 웃고 나서 자기는 여자 친구와 호텔에서 살고 있다고 말했다.'},
#   {'file_url': 'python 서예진/310.m4a',
#    'text': '아래층에 산다는 머키는 얼굴이 창백하고 여성적인 사람이었다.'},
#   {'file_url': 'python 서예진/311.m4a',
#    'text': '그는 면도를 하다가 왔는지 광대뼈에 하얀 비누 거품이 묻어 있었다.'},
#   {'file_url': 'python 서예진/312.m4a',
#    'text': "방안에 있는 사람들에게 일일이 정중하게 인사를 한 그는 나에게 자신은 '예술업'에 종사하고 있다고 말했다."},
#   {'file_url': 'python 서예진/313.m4a',
#    'text': '나는 나중에야 그가 사진작가이며, 벽에 붙어 있는 윌슨 부인 어머니의 희미한 확대 사진도 그의 작품이라는 것을 알게 되었다.'},
#   {'file_url': 'python 서예진/314.m4a',
#    'text': '그의 아내는 호감가는 가냘픈 외모에 날카로운 목소리를 가졌는데 인상이 날카로워 보였다.'},
#   {'file_url': 'python 서예진/315.m4a',
#    'text': '그녀는 자기 남편이 결혼한 이후로 자기 사진을 127장이나 찍어 주었다고 나에게 자랑스럽게 말했다.'},
#   {'file_url': 'python 서예진/316.m4a',
#    'text': '윌슨 부인은 다시 옷을 갈아 입었는데, 이번에는 크림색 드레스였다.'},
#   {'file_url': 'python 서예진/317.m4a',
#    'text': '그 드레스는 그녀가 방안을 돌아다닐 때마다 바스락 소리를 내었기 때문에 그녀의 품위마저 달라 보이게 했다.'},
#   {'file_url': 'python 서예진/318.m4a',
#    'text': '자동차 수리소에서 보여 주었던 그녀의 온몸에 넘쳐 흐르던 생기가 이제는 인상적인 거만스러움으로 바뀌어 있었다.'},
#   {'file_url': 'python 서예진/319.m4a',
#    'text': '그녀의 웃음소리와 몸놀림, 그리고 고집 센 말투는 시간이 갈수록 격렬해졌다.'},
#   {'file_url': 'python 서예진/320.m4a',
#    'text': '그녀의 존재가 커져 감에 따라 그녀를 중심으로 한 방은 점점 더 작아졌다.'},
#   {'file_url': 'python 서예진/321.m4a',
#    'text': '기가 자욱한 방안에서 그녀는 시끄럽게 삐그덕거리는소리를 내는 회전축 위에서 빙빙 돌고 있는 것처럼 보였다.'},
#   {'file_url': 'python 서예진/322.m4a',
#    'text': '돈밖에 모르는 그런 사람들은 곧 너를 배신할 거야. 지난 주에 난 어떤 여자를 이 곳으로 불러 발을 진찰받았어.'},
#   {'file_url': 'python 서예진/323.m4a',
#    'text': '윌슨 부인은 경멸하듯이 눈썹을 치켜 뜸으로써 그 칭찬을 무시했다.'},
#   {'file_url': 'python 서예진/324.m4a',
#    'text': '"이건 유행이 지난 옷이에요. 내가 외모에 신경을 쓸 필요가 없을 때 가끔씩 걸쳐 입는 옷이지요."'},
#   {'file_url': 'python 서예진/325.m4a',
#    'text': '"그래도 당신이 입으니까 잘 어울려요. 인사치레로 하는 이야기가 아니라구요." 머키 부인은 계속 물고 늘어졌다.'},
#   {'file_url': 'python 서예진/326.m4a',
#    'text': '"만약 그런 포즈를 취하고 있는 당신을 체스터가 찍기만 한다면 무척 훌륭한 작품이 될 거에요."'},
#   {'file_url': 'python 서예진/327.m4a',
#    'text': '우리 모두는 말없이 윌슨 부인을 바라보았다. 그녀는 눈을 가렸던 머리카락을 쓸어 올리고는 환한 미소를 띠며 시선을 맞추었다.'},
#   {'file_url': 'python 서예진/328.m4a',
#    'text': '머키는 고개를 갸우뚱거리면서 그녀를 유심히 바라보았다. 그러더니 곧 한 손을 자기 얼굴 앞에서 서서히 앞뒤로 움직였다.'},
#   {'file_url': 'python 서예진/329.m4a',
#    'text': '"얼굴 윤곽을 분명하게 나타내고 싶으니까. 그리고 뒤의 머리카락도 모두 담도록 해야겠어."'},
#   {'file_url': 'python 서예진/330.m4a',
#    'text': '우리는 일제히 윌슨 부인을 바라보았는데, 그 때 탐 부캐넌이 큰 하품을 하면서 일어났다.'},
#   {'file_url': 'python 서예진/331.m4a',
#    'text': '머틀, 모두들 잠들어 버리기 전에 얼음하고 생수를 좀더 가져와요.'},
#   {'file_url': 'python 서예진/332.m4a',
#    'text': '머틀은 아랫사람들의 게으름에 진절머리가 난다는 듯 이맛살을 찌푸렸다.'},
#   {'file_url': 'python 서예진/333.m4a',
#    'text': '정말이세요? 전 한 달쯤 전에 파티가 있어서 거기에 갔었는데, 개츠비라는 분의 저택이었지요.'},
#   {'file_url': 'python 서예진/334.m4a',
#    'text': '그분은 빌헬름 황제의 조카 아니면 사촌일 거라는 소문이 있던데요. 그분의 돈 전부가 거기서 온다는 거예요.'},
#   {'file_url': 'python 서예진/335.m4a',
#    'text': '전 그분이 왠지 기분 좋지 않아요. 그런 사람이 저에게 어떤 관심을 보이는 것은 질색이에요.'},
#   {'file_url': 'python 서예진/336.m4a',
#    'text': '내 이웃에 관한 이 흥미로운 정보는 머키 부인이 갑자기 캐서린을 가리키며 말을 꺼내는 바람에 끊어지고 말았다.'},
#   {'file_url': 'python 서예진/337.m4a',
#    'text': '"체스터, 제 생각으로는 이분의 사진도 찍었으면 좋겠는데요."'},
#   {'file_url': 'python 서예진/338.m4a',
#    'text': '그녀가 불쑥 말을 꺼냈으나 머키는 귀찮다는 듯이 고개만 끄덕이고 관심을 탐에게 돌려 버렸다.'},
#   {'file_url': 'python 서예진/339.m4a',
#    'text': '기회가 주어지면 롱아일랜드에서 일을 더 하고 싶습니다. 내가 바라는 것은 나에게 일을 시작할 기회를 주었으면 하는 것뿐입니다.'},
#   {'file_url': 'python 서예진/340.m4a',
#    'text': '탐은 윌슨 부인이 쟁반을 들고 들어오자 갑자기 웃음을 터뜨렸다.'},
#   {'file_url': 'python 서예진/341.m4a',
#    'text': '이 사람이 소개장을 써 줄 겁니다. 그렇지 않소, 머틀?'},
#   {'file_url': 'python 서예진/342.m4a',
#    'text': '당신 남편에게 머키 씨를 소개하는 편지를 써 주구려. 그러면 머키 씨는 그 사람을 모델로 해서 작품을 만들 수 있을 테니까 말이요.'},
#   {'file_url': 'python 서예진/343.m4a',
#    'text': '뭔가 좋은 문구를 생각해 내려는 듯이 탐의 입술은 잠시 조용히 움직였다.'},
#   {'file_url': 'python 서예진/344.m4a',
#    'text': '캐서린은 내게로 몸을 바짝 기울이고는 귓속말로 속삭였다.'},
#   {'file_url': 'python 서예진/345.m4a',
#    'text': '언니나 저분은 둘 다 결혼해서 살고 있는 상대에 대해 못마땅해하고 있어요.'},
#   {'file_url': 'python 서예진/346.m4a',
#    'text': '제가 하고 싶은 말은 서로 참고 견딜 수가 없을 정도이면 무엇하러 계속 같이 사느냐 하는 거예요.'},
#   {'file_url': 'python 서예진/347.m4a',
#    'text': '이 물음에 대한 대답은 뜻밖의 사람한테서 들을 수 있었다.'},
#   {'file_url': 'python 서예진/348.m4a',
#    'text': '캐서린이 의기양양하게 소리치고는 다시 목소리를 낮추어 말했다.'},
#   {'file_url': 'python 서예진/349.m4a',
#    'text': '두 사람을 떼어 놓고 있는 사람은 탐의 부인이에요. 그녀는 카톨릭 신자인데, 카톨릭에서는 이혼을 인정하지 않거든요.'},
#   {'file_url': 'python 서예진/350.m4a',
#    'text': '데이지는 카톨릭 신자가 아니라는 사실을 알고 있었으므로 나는 이 완전한 거짓말에 약간 충격을 받았다.'},
#   {'file_url': 'python 서예진/351.m4a', 'text': '그 일이 잊혀질 때까지 한동안 서부에 가서 살 거예요.'},
#   {'file_url': 'python 서예진/352.m4a', 'text': '전 몬테카를로에서 돌아온 지 얼마 안 되었어요.'},
#   {'file_url': 'python 서예진/353.m4a',
#    'text': '아니에요. 우린 그저 몬테카를로만 다녀왔어요. 마르세유를 거쳐서 갔었지만요.'},
#   {'file_url': 'python 서예진/354.m4a',
#    'text': '출발할 때는 1,200달러 이상 갖고 있었지만, 그 곳의 도박장에서 이틀 만에 몽땅 잃고 말았어요.'},
#   {'file_url': 'python 서예진/355.m4a',
#    'text': '거짓말이 아니에요. 그 때문에 돌아올 때 얼마나 고생을 했는지 그래서 아직도 몬테카를로라면 소름이 끼쳐요.'},
#   {'file_url': 'python 서예진/356.m4a',
#    'text': '늦은 오후의 하늘은 지중해의 푸른 바다색으로 잠시 창문에 머물렀다.'},
#   {'file_url': 'python 서예진/357.m4a',
#    'text': '그때 머키 부인의 날카로운 목소리가 나서 나는 정신을 차렸다.'},
#   {'file_url': 'python 서예진/358.m4a',
#    'text': '몇 해 동안이나 제 뒤를 쫓아다니던 조그만 애송이와 하마터면 결혼할 뻔했던 거죠.'},
#   {'file_url': 'python 서예진/359.m4a',
#    'text': "주위에서도 '루실, 그 사람은 너보다 훨씬 못한 남자야!' 하고 모두들 늘 말했어요."},
#   {'file_url': 'python 서예진/360.m4a',
#    'text': '제가 체스터를 만나지 않았더라면, 그는 틀림없이 저를 차지했을 거예요.'},
#   {'file_url': 'python 서예진/361.m4a', 'text': '바로 그것이 당신 경우와 내 경우의 다른 점이지요.'},
#   {'file_url': 'python 서예진/362.m4a',
#    'text': '그 사람을 신사라고 생각했기 때문에 난 그와 결혼했던 거야.'},
#   {'file_url': 'python 서예진/363.m4a',
#    'text': '교양이 무엇인지를 조금은 알고 있다고 생각했지. 그런데 그것은 내 착각이었어.'},
#   {'file_url': 'python 서예진/364.m4a',
#    'text': '내가 그 사람한테 빠졌었다고 말을 한 게 누구지? 나는 누구에게 미칠 정도로 사랑에 빠진 적이 없어.'},
#   {'file_url': 'python 서예진/365.m4a',
#    'text': '나는 그녀의 관심 따위는 기대하고 있지 않다는 것을 얼굴에 나타내려고 애썼다.'},
#   {'file_url': 'python 서예진/366.m4a',
#    'text': '내가 단 한 번 미친 듯이 그에게 반했던 것은 결혼식 때였어. 그러나 나는 곧 내가 실수했음을 깨닫게 되었지.'},
#   {'file_url': 'python 서예진/367.m4a',
#    'text': '그는 결혼식 때 다른 사람의 양복을 빌려 입었으면서도 나에게 그런 얘기는 한 마디도 하지 않았어.'},
#   {'file_url': 'python 서예진/368.m4a',
#    'text': '하루는 그가 외출했을 때 그 옷 임자가 빌려 준 옷을 찾으러 왔어.'},
#   {'file_url': 'python 서예진/369.m4a',
#    'text': '나는 그 옷을 임자에게 돌려 주고는 오후 내내 침대에서 한없이 울었어.'},
#   {'file_url': 'python 서예진/370.m4a',
#    'text': '나는 밖으로 나가 부드러운 황혼 속의 공원을 향해 동쪽으로 걷고 싶었다.'},
#   {'file_url': 'python 서예진/371.m4a',
#    'text': '나오려고 할 때마다 요란하고도 귀에 거슬리는 말다툼에 휘말려 마치 밧줄에 매여 끌리듯 다시 제자리로 되돌아오게 되었다.'},
#   {'file_url': 'python 서예진/372.m4a', 'text': '난 이상하다는 듯이 올려다보고 있는 그 사람을 보았다.'},
#   {'file_url': 'python 서예진/373.m4a',
#    'text': '나는 인생의 무한한 다양성에 이끌림과 동시에 반발도 하면서 창문 안팎으로 방황을 했다.'},
#   {'file_url': 'python 서예진/374.m4a',
#    'text': '갑자기 탑을 처음 만났을 때의 이야기를 나에게 하기 시작했다.'},
#   {'file_url': 'python 서예진/375.m4a',
#    'text': '우리가 처음 만난 것은 언제나 맨 마지막까지 빈자리로 남아 있던, 마주 보고 있는 두 개의 작은 의자에서였어요.'},
#   {'file_url': 'python 서예진/376.m4a',
#    'text': '전 뉴욕으로 와서 동생을 만나고 그날밤은 여기서 묵을 생각이었지요.'},
#   {'file_url': 'python 서예진/377.m4a',
#    'text': '그이는 야회복에 에나멜 구두를 신고 있었는데 전 그이에게서 눈을 뗄 수가 없었어요.'},
#   {'file_url': 'python 서예진/378.m4a',
#    'text': '그이가 저를 바라볼 때마다 저는 탐의 머리 위쪽의 광고를 보고 있는 척해야만 했어요.'},
#   {'file_url': 'python 서예진/379.m4a',
#    'text': '우리가 뉴욕 역에 도착했을 때, 그리는 바로 제 곁에 서 있었는데, 그이의 흰 셔츠의 가슴 부분이 제 팔을 눌렀어요.'},
#   {'file_url': 'python 서예진/380.m4a', 'text': '전 그이에게 순경을 부르겠다고 말했지요.'},
#   {'file_url': 'python 서예진/381.m4a',
#    'text': '그이는 제가 절대 그런 행동을 하지 않을 것을 알고 있었어요.'},
#   {'file_url': 'python 서예진/382.m4a',
#    'text': '전 너무 흥분했던 탓이 그이와 함께 택시를 탔을 때도 거의 알아채지 못했어요.'},
#   {'file_url': 'python 서예진/383.m4a',
#    'text': "제가 그때 머릿속으로 되풀이해서 생각한 것은 '어차피 영원히 사는 것도 아닌데...'라는 말뿐이었어요."},
#   {'file_url': 'python 서예진/384.m4a',
#    'text': '그녀가 머키 부인을 돌아보자 방안은 온통 머키 부인의 부자연스런 웃음소리로 가득 찼다.'},
#   {'file_url': 'python 서예진/385.m4a',
#    'text': '이 드레스를 오늘 벗는 대로 당신에게 줄게요. 내일 다른 것을 사면 되니까.'},
#   {'file_url': 'python 서예진/386.m4a', 'text': '난 마련해야 할 물건의 목록을 만들려고 해요.'},
#   {'file_url': 'python 서예진/387.m4a',
#    'text': '목록을 만들어서 사야 할 물건을 잊어버리지 않도록 해야겠어요.'},
#   {'file_url': 'python 서예진/388.m4a',
#    'text': '9시였다, 그리고 얼마 되지 않아 다시 내 손목 시계를 보니 10시를 가리키고 있었다.'},
#   {'file_url': 'python 서예진/389.m4a',
#    'text': '머키는 꽉 쥔 두 주먹을 무릎 위에 얹은 재 사진 속의 모델처럼 의자에서 잠들어 있었다.'},
#   {'file_url': 'python 서예진/390.m4a',
#    'text': '나는 손수건을 꺼내 오후 내내 나의 마음을 거슬리게 했던, 그의 광대뼈 위에 말라붙은 비누 거품을 닦아 주었다.'},
#   {'file_url': 'python 서예진/391.m4a',
#    'text': '강아지는 테이블 위에 앉아서 자욱한 연기 때문에 잘 보이지 않는지 사방을 두리번거리며 이따금씩 나직하게 낑낑거리고 있었다.'},
#   {'file_url': 'python 서예진/392.m4a',
#    'text': '탐은 빠르고 익숙하게 그 큰 손으로 그녀의 코를 후려쳤다.'},
#   {'file_url': 'python 서예진/393.m4a',
#    'text': '욕실 바닥에 피투성이의 타월들이 쌓이고 여자들의 아우성이 들렸다.'},
#   {'file_url': 'python 서예진/394.m4a',
#    'text': '그 소리보다 한층 높게 고통을 호소하며 울부짖는 소리가 들렸다.'},
#   {'file_url': 'python 서예진/395.m4a',
#    'text': '나는 샹들리에에 걸어 두었던 모자를 집어 들고 그의 뒤를 따라갔다.'},
#   {'file_url': 'python 서예진/396.m4a',
#    'text': '나는 펜실베니아 역의 아래층 플랫폼에 쪼그리고 앉은 채 신문을 들여다보며 4시에 떠날 기차를 기다리고 있었다.'},
#   {'file_url': 'python 서예진/397.m4a',
#    'text': '여름 밤, 개츠비의 집에서는 날마다 흥겨운 음악 소리가 났다.'},
#   {'file_url': 'python 서예진/398.m4a',
#    'text': '그의 푸른 정원에서는 남녀들이 속삭임과 샴페인, 별들 사이를 바쁘게 오가곤 했다.'},
#   {'file_url': 'python 서예진/399.m4a',
#    'text': '그의 이름으로 되어 있는 해변의 뜨거운 모래 위에서 일광욕을 하고 있는 것을 바라보았다.'},
#   {'file_url': 'python 서예진/400.m4a',
#    'text': '그의 두 척의 모터보트는 바다 위에 떠 물살을 가르며 하얀 물거품 위로 수상 스키를 끌고 달렸다.'},
#   {'file_url': 'python 서예진/401.m4a',
#    'text': '주말이면 그의 롤즈로이스 승용차가 아침 9시부터 한밤중까지 시내를 왔다갔다하면서 손님들을 실어 날랐다.'},
#   {'file_url': 'python 서예진/402.m4a',
#    'text': '스테이션왜건은 모든 기차를 마중 나가려고 마치 활기찬 투구벌레처럼 지칠 줄 모르고 돌아다녔다.'},
#   {'file_url': 'python 서예진/403.m4a',
#    'text': '월요일에는 임시로 고용된 정원사까지 합쳐 모두 8명의 고용인이 간밤에 손상된 부분을 손질하느라고 하루 종일 힘들게 돌아다녔다.'},
#   {'file_url': 'python 서예진/404.m4a',
#    'text': '매주 금요일마다 뉴욕의 청과물점으로부터 다섯 상자의 오렌지와 레몬이 도착했다.'},
#   {'file_url': 'python 서예진/405.m4a',
#    'text': '월요일이면 이 오렌지와 레몬은 알맹이가 없는 껍질이 되어서 피라미드 모양으로 쌓인 채 저택 뒷문으로 사라졌다.'},
#   {'file_url': 'python 서예진/406.m4a',
#    'text': '부엌에는 엄지손가락으로 조그만 단추를 누르기만 하면 30분 만에 200개의 오렌지 주스를 짜낼 수 있는기계 한 대가 설치되어 있었다.'},
#   {'file_url': 'python 서예진/407.m4a',
#    'text': '뷔페 식탁에는 구운 햄, 오색으로 만든 샐러드, 밀가루를 씌워 누런색으로 구운 통돼지와 칠면조 들이 가득 놓여 있었다.'},
#   {'file_url': 'python 서예진/408.m4a',
#    'text': '중앙에는 진짜 놋쇠 난간의 바가 마련되어 있었고, 갖가지의 독한 진이나 위스키들이 진열되어 있었다.'},
#   {'file_url': 'python 서예진/409.m4a',
#    'text': '너무 오랫동안 금주법으로 잊혀졌기 때문에 대부분의 여자 손님들은 나이가 어려 그 종류를 구별해 내지 못했다.'},
#   {'file_url': 'python 서예진/410.m4a',
#    'text': '늦게까지 수영을 하던 사람들도 이제는 바닷가에서 돌아와 이층에서 옷을 갈아 입고 있었다.'},
#   {'file_url': 'python 서예진/411.m4a',
#    'text': '택 안의 주차장에는 뉴욕에서 온 차들이 다섯 줄로 질서정연하게 주차해 있었다.'},
#   {'file_url': 'python 서예진/412.m4a',
#    'text': '카스틸의 꿈도 무색한 호화로운 숄을 두른 사람들로 북적댔다.'},
#   {'file_url': 'python 서예진/413.m4a',
#    'text': '바에서는 이제 분위기가 무르익었고, 여러 차례 반복되고 있는 칵테일 쟁반의 서비스가 정원 바깥까지 이어지고 있었다.'},
#   {'file_url': 'python 서예진/414.m4a',
#    'text': '부담없이 즐길 수 있는 풍자와 인사 소개가 간단히 행해졌으며, 서로 이름도 모르는 여자들끼리의 열띤 이야기가 시작되었다.'},
#   {'file_url': 'python 서예진/415.m4a', 'text': '밤이 깊어 감에 따라 불빛은 더욱 밝아져 갔다.'},
#   {'file_url': 'python 서예진/416.m4a',
#    'text': '오케스트라는 대중적인 혼합곡을 연주하고 오페라 같은 사람들의 이야기 소리는 한 옥타브 더 높아졌다.'},
#   {'file_url': 'python 서예진/417.m4a', 'text': '웃음 소리는 시간이 갈수록 커졌으며 자주 들려 왔다.'},
#   {'file_url': 'python 서예진/418.m4a',
#    'text': '모인 사람들이 빠른 속도로 바뀌었으며 새로 온 사람들로 모임이 흩어졌다가는 곧 다시 모이곤 했다.'},
#   {'file_url': 'python 서예진/419.m4a',
#    'text': '오케스트라 지휘자가 친절하게도 그녀의 춤에 맞는 곡으로 바꾸어 연주하기 시작했다.'},
#   {'file_url': 'python 서예진/420.m4a',
#    'text': '내가 개츠비의 저택에 처음으로 간 날 밤, 나는 초대된 몇몇 손님 가운데 하나라 믿고 있었다.'},
#   {'file_url': 'python 서예진/421.m4a',
#    'text': '상당수의 사람들은 초대를 받은 것이 아니었다. 그들은 그냥 그의 저택으로 왔던 것이다.'},
#   {'file_url': 'python 서예진/422.m4a',
#    'text': '롱아일랜드로 오는 자동차를 타고 있다 보니 개츠비의 저택 앞에서 차가 섰던 것이다.'},
#   {'file_url': 'python 서예진/423.m4a',
#    'text': '그 다음부터는 오락 유원지에서 지키면 되는 정도의 행동 규칙에 따라 스스로가 행동하게 되었다.'},
#   {'file_url': 'python 서예진/424.m4a',
#    'text': '그들은 때론 개츠비를 만나 보지도 않은 채 돌아갔고, 단지 파티가 좋아서 오는 솔직한 마음이 초대장의 역할을 할 뿐이었다.'},
#   {'file_url': 'python 서예진/425.m4a',
#    'text': '거기에는 그 날 밤의 조촐한 파티에 내가 참석해 주면 자기에게 다시 없는 영광이 될 것이라고 씌여 있었다.'},
#   {'file_url': 'python 서예진/426.m4a',
#    'text': '오래 전부터 찾아갈 계획을 세웠으나 그 때마다 사정들이 생겨 기회를 놓쳐 버렸다고 적고 있었다.'},
#   {'file_url': 'python 서예진/427.m4a',
#    'text': '끝에는 위엄 있는 필적으로 제이 개츠비라고 서명되어 있었다.'},
#   {'file_url': 'python 서예진/428.m4a',
#    'text': '7시가 조금 지나서 나는 차려 입고 그의 저택 잔디밭으로 건너가서 낯선 사람들 틈에 끼여 다소 어색한 모습으로 서성거렸다.'},
#   {'file_url': 'python 서예진/429.m4a',
#    'text': '실은 통근 기차에서 본 적이 있는 얼굴들도 많이 보였다.'},
#   {'file_url': 'python 서예진/430.m4a',
#    'text': '나는 파티장에 영국계 청년들이 여러 명 눈에 띈 것에 대해 놀라워했다.'},
#   {'file_url': 'python 서예진/431.m4a',
#    'text': '그들은 옷을 잘 차려 입고 무게 있고 돈이 있어 보이는 미국인들과 나지막하나 열띤 목소리로 이야기를 나누고 있었다.'},
#   {'file_url': 'python 서예진/432.m4a',
#    'text': '나는 그들이 채권이나 보험 증권이나 자동차 같은 것을 팔고 있는 중이라고 확신했다.'},
#   {'file_url': 'python 서예진/433.m4a',
#    'text': '그들 영국인들은 손쉽게 벌어들일 수 있는 돈이 근처에 있다는 것을 분명하게 인식하고 있었다.'},
#   {'file_url': 'python 서예진/434.m4a',
#    'text': '적절한 음조로 말 몇 마디만 하면 그 돈은 자기들의 것이 될 것으로 확신하고 있는 것 같았다.'},
#   {'file_url': 'python 서예진/435.m4a', 'text': '나는 그 집에 도착하자마자 개츠비를 만나 보려 했다.'},
#   {'file_url': 'python 서예진/436.m4a',
#    'text': '나로부터 그가 있는 곳을 묻는 말을 들은 두서너 사람은 아주 놀란 얼굴로 나를 빤히 쳐다보면서 모른다고 고개를 흔들었다.'},
#   {'file_url': 'python 서예진/437.m4a',
#    'text': '그 바람에 나는 칵테일 테이블 쪽으로 슬금슬금 다가갔다.'},
#   {'file_url': 'python 서예진/438.m4a',
#    'text': '그 곳은 목적도 없고 혼자라는 기색을 보이지 않고 남자 혼자 서성거릴 수 있는, 정원 속의 유일한 장소였기 때문이다.'},
#   {'file_url': 'python 서예진/439.m4a',
#    'text': '도무지 어색한 분위기를 참을 수 없어 나는 술에라도 취해 떠들어 대려고 했다.'},
#   {'file_url': 'python 서예진/440.m4a',
#    'text': '그녀가 집 안에서 나와 대리석 계단 꼭대기에 서서는 몸을 약간 뒤로 젖힌 채 경멸에 찬 눈빛을 보이며 정원을 내려다보고 있었다.'},
#   {'file_url': 'python 서예진/441.m4a',
#    'text': '지나가는 사람들에게 아는 척이라도 하기 위해서는 우선 나는 상대방이 좋아하든 말든 사람들과 어룰릴 필요가 있다고 생각했다.'},
#   {'file_url': 'python 서예진/442.m4a', 'text': '나는 그녀 쪽으로 걸어가면서 소리를 질렀다.'},
#   {'file_url': 'python 서예진/443.m4a',
#    'text': '내 목소리는 부자연스러울 정도로 크게 정원 밖으로 퍼져 나가는 것 같았다.'},
#   {'file_url': 'python 서예진/444.m4a',
#    'text': '그녀는 내가 다가가자 별로 관심이 없다는 말투로 대꾸했다.'},
#   {'file_url': 'python 서예진/445.m4a',
#    'text': '그녀는 조금 있다가 챙겨 주겠다는 약속처럼 내 손을 잡고는 계단 밑에 와서 멈추어 선 두 아가씨의 말에 귀를 기울였다.'},
#   {'file_url': 'python 서예진/446.m4a',
#    'text': '그것은 골프 시합에 관한 인사였다. 그녀는 지난 주 결승전에서 지고 말았던 것이다.'},
#   {'file_url': 'python 서예진/447.m4a', 'text': '하지만 우리는 한 달쯤 전에 여기서 당신을 뵈었어요.'},
#   {'file_url': 'python 서예진/448.m4a',
#    'text': '나는 걷기 시작했다. 아가씨들은 이미 나보다 먼저 앞으로 걸어가 버려 조던의 말은 허공을 향해 중얼거리는 넋두리가 되고 말았다.'},
#   {'file_url': 'python 서예진/449.m4a', 'text': '조던은 가냘프고 금빛이 도는 팔로 내 팔을 잡았다.'},
#   {'file_url': 'python 서예진/450.m4a',
#    'text': '리는 자연스럽게 팔짱을 낀 채 계단을 내려와 정원의 구석구석을 돌아다녔다.'},
#   {'file_url': 'python 서예진/451.m4a',
#    'text': '칵테일 쟁반이 우리에게로 전달되었고, 우리는 두 아가씨와 또 다른 세 남자와 함께 같은 테이블에 자리를 잡고 앉았다.'},
#   {'file_url': 'python 서예진/452.m4a', 'text': '그 남자들은 멈블 씨라고 소개되었다.'},
#   {'file_url': 'python 서예진/453.m4a', 'text': '얼마 전 당신을 만난 파티가 최근에 참석한 파티예요.'},
#   {'file_url': 'python 서예진/454.m4a',
#    'text': '그 아가씨가 빠르면서도 자신에 찬 말투로 대답했다. 그리고 그녀는 자기 친구를 돌아다보며 물었다.'},
#   {'file_url': 'python 서예진/455.m4a',
#    'text': '저는 아주 자연스럽게 생활하지요. 그래서 언제나 즐겁지요. 지난번 파티에서 제 가운이 의자에 걸려 찢어졌었지요.'},
#   {'file_url': 'python 서예진/456.m4a',
#    'text': '오늘 밤에 입고 올 생각이었는데 가슴 둘레가 너무 커서 수선을 부탁했어요.'},
#   {'file_url': 'python 서예진/457.m4a',
#    'text': '라벤더빛 구슬이 달린, 파란 가스 빛 드레스인데 265달러나 하는 것이라나봐요.'},
#   {'file_url': 'python 서예진/458.m4a',
#    'text': '그런 식으로 호의를 지나치게 보이는 사람은 어딘지 이상한 데가 있어요.'},
#   {'file_url': 'python 서예진/459.m4a', 'text': '두 아가씨와 조던은 친근한 듯 서로 몸을 기댔다.'},
#   {'file_url': 'python 서예진/460.m4a',
#    'text': '누가 그러던데 말이에요, 사람들은 그분이 전에 사람을 죽인 적이 있대요.'},
#   {'file_url': 'python 서예진/461.m4a',
#    'text': '순간 모두가 몸서리를 쳤다. 세 명의 멈블 씨는 몸을 앞으로 굽히고 좀더 자세히 듣기 위해 열심히 귀를 기울였다.'},
#   {'file_url': 'python 서예진/462.m4a', 'text': '루실이 의심스럽다는 듯이 말하고 나섰다.'},
#   {'file_url': 'python 서예진/463.m4a', 'text': '그보다는 전쟁중에 독일의 스파이였을 가능성이 더 많아.'},
# ...
#    'text': "자신은 단지 어느 날 오후 남의 집 정원으로 '초대받을 수 있기를' 기다리고 있었던 것이다."},
#   {'file_url': 'python 서예진/841.m4a',
#    'text': '그는 만나는 사람마다 혹시 데이지를 아느냐고 묻기 시작했어요.'},
#   {'file_url': 'python 서예진/842.m4a',
#    'text': '내가 바로 데이지를 알고 있는 첫 번째 사람이 되었어요.'},
#   {'file_url': 'python 서예진/843.m4a',
#    'text': '그가 댄스 파티에서 사람을 시켜 나를 초대한 바로 그 날 밤의 일이었어요.'},
#   {'file_url': 'python 서예진/844.m4a',
#    'text': '그가 그렇게 하려고 노력했던 그 세심한 자세를 당신도 들으셨더라면 좋았을 텐데요.'},
#   {'file_url': 'python 서예진/845.m4a',
#    'text': '나는 물론 그에게 당신을 뉴욕에서의 점심식사에 초대하라는 제안을 즉시 해 주었어요.'},
#   {'file_url': 'python 서예진/846.m4a',
#    'text': '당신이 탐의 각별한 친구라고 말하자, 그는 모든 계획을 포기해 버리려고 했어요.'},
#   {'file_url': 'python 서예진/847.m4a',
#    'text': '어둠이 서서히 깔리기 시작했고 우리가 탄 마차는 조그마한 다리 아랫길로 접어들고 있었다.'},
#   {'file_url': 'python 서예진/848.m4a',
#    'text': '나는 한 팔로 조던의 황금빛이 도는 어깨를 껴안아 내 쪽으로 끌어당기면서 그녀를 저녁 식사에 초대했다.'},
#   {'file_url': 'python 서예진/849.m4a',
#    'text': '어느 새 나는 데이지나 개츠비에 대해서는 잊어버리고 말았다.'},
#   {'file_url': 'python 서예진/850.m4a',
#    'text': '검은 나무숲의 장벽을 지나 59번가로 접어들자 희미한 한 줄기 불빛이 공원쪽을 내리비추고 있었다.'},
#   {'file_url': 'python 서예진/851.m4a',
#    'text': '내게는 몇 년씩 잊지 못하고 가슴아파하는 그런 여인이 없었다.'},
#   {'file_url': 'python 서예진/852.m4a', 'text': '그래서 나는 두 팔에 힘을 주어 조던을 끌어당겼다.'},
#   {'file_url': 'python 서예진/853.m4a', 'text': '그녀의 파리하고 비웃는 듯한 미소가 입가에 떠올랐다.'},
#   {'file_url': 'python 서예진/854.m4a',
#    'text': '그것을 보고 나는 그녀를 더 가까이 끌어당겼고 마침내는 내 얼굴에까지 끌어당겼다.'},
#   {'file_url': 'python 서예진/855.m4a',
#    'text': '그 날 밤 웨스트에그로 돌아왔을 때, 나는 내 집에 불이 난 게 아닌가 하는 착각에 빠졌다.'},
#   {'file_url': 'python 서예진/856.m4a', 'text': '새벽 2시였는데 집 주변 전체가 불빛으로 이글거렸다.'},
#   {'file_url': 'python 서예진/857.m4a',
#    'text': '그 불빛은 관목숲을 영화 속의 한 장면처럼 비춰 주었으며, 길가의 전선들을 가느다란 황금빛 선으로 번뜩이게 했다.'},
#   {'file_url': 'python 서예진/858.m4a',
#    'text': '처음 나는 무슨 파티라도 열려서 화려한 야회가 끝나고 놀이를 위해 개방된 것으로 생각했다.'},
#   {'file_url': 'python 서예진/859.m4a',
#    'text': '길모퉁이를 돌아서야 나는 개츠비의 저택 전체에 불이 켜져 있어 그렇게 보였다는 것을 알았다.'},
#   {'file_url': 'python 서예진/860.m4a', 'text': '그러나 그 곳에서는 아무 소리도 들리지 않았다.'},
#   {'file_url': 'python 서예진/861.m4a',
#    'text': '나무들 사이에서 바람이 일어 전선을 움직이게 했고 그래서 불빛이 계속 비쳤다 사라졌다 했다.'},
#   {'file_url': 'python 서예진/862.m4a',
#    'text': '나는 개츠비가 잔디밭을 가로질러 내게로 걸어오는 것을 볼 수 있었다.'},
#   {'file_url': 'python 서예진/863.m4a', 'text': '그는 얼빠진 모습으로 시선을 그 쪽으로 돌렸다.'},
#   {'file_url': 'python 서예진/864.m4a', 'text': '그는 잠시 생각에 잠기더니 주저하며 말했다.'},
#   {'file_url': 'python 서예진/865.m4a',
#    'text': '내 집의 볼품없는 잔디밭이 끝난 곳에 선명하게 선이 그어져 그 지점부터 손질이 잘 된 그의 잔디밭이 시작되고 있었다.'},
#   {'file_url': 'python 서예진/866.m4a',
#    'text': '나는 그가 내 잔디밭을 두고 하는 말이 아닌가 하고 생각했다.'},
#   {'file_url': 'python 서예진/867.m4a', 'text': '그는 어쩔 줄 몰라하며 말을 잇지 못하고 더듬거렸다.'},
#   {'file_url': 'python 서예진/868.m4a',
#    'text': '이 말이 그를 안심시킨 듯 했다. 그는 조금 전보다 한결 자신 있게 말을 계속했다.'},
#   {'file_url': 'python 서예진/869.m4a',
#    'text': '지금에야 깨달은 것인데, 다른 상황에서였다면 그 이야기는 내 인생을 바꿀 사건이 되었을지도 모르는 것이다.'},
#   {'file_url': 'python 서예진/870.m4a',
#    'text': '그 당시 그 제안을 형식적인 것이었으므로 나로서는 그 자리에서 깨끗하게 거절할 수밖에 없었다.'},
#   {'file_url': 'python 서예진/871.m4a',
#    'text': "분명히 그는 앞서의 점심 식사 때 언급된 '거래선'이라는 말 때문에 내가 물러선 것으로 생각한 모양이었다."},
#   {'file_url': 'python 서예진/872.m4a', 'text': '그래서 나는 그가 잘못 생각한 것이라고 말해주었다.'},
#   {'file_url': 'python 서예진/873.m4a',
#    'text': '그는 내가 이야기를 계속하기를 바라면서 잠시 더 기다렸다.'},
#   {'file_url': 'python 서예진/874.m4a',
#    'text': '나는 내 생각이 너무 강했기 때문에 거기에 응하질 못했다.'},
#   {'file_url': 'python 서예진/875.m4a', 'text': '그러자 그는 하는 수 없이 집으로 돌아갔다.'},
#   {'file_url': 'python 서예진/876.m4a',
#    'text': '그 날 밤 나는 마음이 개운하고 즐거웠다. 나는 현관문을 들어서자 곧 깊은 잠에 빠져들었다.'},
#   {'file_url': 'python 서예진/877.m4a',
#    'text': "나는 개츠비가 코니아일랜드로 갔었는지 아니면 저택에 불을 현란하게 켜 놓고 몇 시간이나 '방들을 살펴보았는지'를 모른다."},
#   {'file_url': 'python 서예진/878.m4a',
#    'text': '다음날 아침 나는 사무실에서 데이지에게 전화를 걸어 만찬에 초대했다.'},
#   {'file_url': 'python 서예진/879.m4a',
#    'text': '11시쯤 우의를 입은 한 남자가 제초기를 끌고 와서 현관문을 두드렸다.'},
#   {'file_url': 'python 서예진/880.m4a',
#    'text': '개츠비가 우리 집 잔디를 갂으라고 보냈다는 말을 덧붙였다.'},
#   {'file_url': 'python 서예진/881.m4a',
#    'text': '그것은 내가 핀란드인 가정부에게 일하러 오라고 말한다는 걸 그만 잊어 버린 것을 생각나게 해 주었다.'},
#   {'file_url': 'python 서예진/882.m4a',
#    'text': '나는 빗물이 깨끗이 씻어 내린 골목길들을 정신없이 돌아다닌 끝에 그녀를 찾아냈다.'},
#   {'file_url': 'python 서예진/883.m4a',
#    'text': '약간의 컵과 레몬과 꽃을 사기 위해 차를 몰고 웨스트에그 마을로 들어갔다.'},
#   {'file_url': 'python 서예진/884.m4a',
#    'text': '그러나 내가 사 온 꽃들은 잠시 후 필요가 없게 되었다.'},
#   {'file_url': 'python 서예진/885.m4a',
#    'text': '2시가 되자 개츠비의 저택으로부터 꽃을 담을 수많은 용기와 화분 하나가 도착했기 때문이다.'},
#   {'file_url': 'python 서예진/886.m4a',
#    'text': '1시간쯤 지나자 현관문이 거칠게 열리더니 하얀 플란넬 양복에 은빛 셔츠와 금빛 넥타이 차림의 개츠비가 허겁지겁 들어섰다.'},
#   {'file_url': 'python 서예진/887.m4a', 'text': '그의 얼굴은 창백했고 특히 눈이 피곤해 보였다.'},
#   {'file_url': 'python 서예진/888.m4a',
#    'text': '그러나 그의 표정으로 판단하건대 그의 눈에는 아무 것도 들어오지 않는 것 같았다.'},
#   {'file_url': 'python 서예진/889.m4a',
#    'text': '어느 신문을 보았더니, 비는 4시쯤이면 그칠 것이라 했더군요.'},
#   {'file_url': 'python 서예진/890.m4a',
#    'text': '나는 그를 식료품실로 데리고 들어갔는데, 그는 핀란드인 가정부를 좀 못마땅한 표정으로 바라보았다.'},
#   {'file_url': 'python 서예진/891.m4a',
#    'text': '우리 두 사람은 식료품점에서 사 온 12개의 레몬 케이크를 자세히 살펴보았다.'},
#   {'file_url': 'python 서예진/892.m4a',
#    'text': '3시 30분쯤 되자 비는 선선한 안개로 변하더니 가는 빗방울로 변했다.'},
#   {'file_url': 'python 서예진/893.m4a',
#    'text': '이따금 그 안개를 뚫고 가는 빗방울이 이슬처럼 흩날렸다.'},
#   {'file_url': 'python 서예진/894.m4a',
#    'text': "개츠비는 멍한 눈초리로 클레이의 '경제학'을 훑어보고 있었다."},
#   {'file_url': 'python 서예진/895.m4a',
#    'text': '마치 밖에서 충격적인 사건들이 벌어지고 있기라도 하듯이 가끔 흐릿한 창문 쪽으로 시선을 보내기도 했다.'},
#   {'file_url': 'python 서예진/896.m4a',
#    'text': '마침내 그는 일어서더니 나지막한 소리로 자기 집으로 돌아가겠다는 것을 나에게 알렸다.'},
#   {'file_url': 'python 서예진/897.m4a',
#    'text': '그는 무슨 다급한 약속이라도 있는 것처럼 시계를 들여다보았다.'},
#   {'file_url': 'python 서예진/898.m4a',
#    'text': '그는 마치 내가 자기를 붙잡아 눌러 버리기라도 한 것처럼 참담한 표정으로 의자에 도로 주저앉았다.'},
#   {'file_url': 'python 서예진/899.m4a',
#    'text': '바로 그 때 내 집의 오솔길로 차가 들어오는 소리가 들렸다.'},
#   {'file_url': 'python 서예진/900.m4a',
#    'text': '동시에 우리 둘은 벌떡 일어섰고, 나는 좀 걱정스런 심정으로 마당으로 나갔다.'},
#   {'file_url': 'python 서예진/901.m4a',
#    'text': '한 대의 대형 무개차가 물방울을 뚝뚝 떨어뜨리는 라일락 나무 아래를 지나 집안 차도를 달려 올라오고 있었다.'},
#   {'file_url': 'python 서예진/902.m4a',
#    'text': '차가 멈추자 삼각모를 한쪽으로 살짝 기울게 쓴 데이지가 밝고 황홀한 미소를 띠고 나를 바라보았다.'},
#   {'file_url': 'python 서예진/903.m4a',
#    'text': '사람의 마음을 울렁거리게 하는 그녀의 목소리는 빗속에서 거친 고음으로 퍼져왔다.'},
#   {'file_url': 'python 서예진/904.m4a',
#    'text': '나는 어떤 말이 나올 때까지 한동안 그저 귀를 쫑긋거리며 가만 있어야 했다.'},
#   {'file_url': 'python 서예진/905.m4a',
#    'text': '그녀의 뺨에는 한 가닥의 젖은 머리카락이 푸른 물감으로 가늘게 그은 것처럼 내려붙어 있었다.'},
#   {'file_url': 'python 서예진/906.m4a',
#    'text': '그녀가 차에서 내릴 때 거들려고 잡은 그녀의 손은 물방울로 빛나고 있었다.'},
#   {'file_url': 'python 서예진/907.m4a',
#    'text': '운전사에게 이렇게 말하고 나서 그녀는 소리를 낮춰 내게 소곤거렸다.'},
#   {'file_url': 'python 서예진/908.m4a',
#    'text': '그녀는 현관문을 점잖게 노크하는 소리가 가볍게 들려 오자 그 쪽으로 고개를 돌렸다.'},
#   {'file_url': 'python 서예진/909.m4a',
#    'text': '개츠비가 물 구덩이 속에 서서 양손을 웃옷 주머니에 찔러 넣은 채 내 눈을 주시하고 있는 것이 보였다.'},
#   {'file_url': 'python 서예진/910.m4a',
#    'text': '그는 양손을 계속 웃옷 주머니에 찔러 넣은 채 내 곁을 지나 홀로 들어가더니  몸을 홱 돌려 거실로 사라졌다.'},
#   {'file_url': 'python 서예진/911.m4a',
#    'text': '나는 가슴을 몹시 두근거리는 것을 의식하면서 한층 세차게 쏟아지는 비를 막으려고 현관문을 잡아당겼다.'},
#   {'file_url': 'python 서예진/912.m4a',
#    'text': '거실로부터 숨을 죽인 것 같은 속삭임과 짧은 웃음소리가 들리고 이어 데이지의 가식적인, 낭랑한 목소리가 들려 왔다.'},
#   {'file_url': 'python 서예진/913.m4a',
#    'text': '그 시간이 너무나 길게 느껴졌다. 나는 홀에서 할 일도 없고 해 거실로 들어갔다.'},
#   {'file_url': 'python 서예진/914.m4a',
#    'text': '개츠비는 여전히 양손을 웃옷 주머니에 찔러 넣은 채 지나칠 정도로 아주 편안한듯 보였다.'},
#   {'file_url': 'python 서예진/915.m4a',
#    'text': '아니 지루할 정도라는 여유 있는 태도를 취하며 벽난로 선반에 기대에 서 있었다.'},
#   {'file_url': 'python 서예진/916.m4a',
#    'text': '그는 시계의 숫자판에 기대 머리를 뒤로 깊숙이 젖힌 채 두 눈으로 데이지를 뚫어지게 내려다보고 있었다.'},
#   {'file_url': 'python 서예진/917.m4a',
#    'text': '데이지는 놀랐지만 우아한 자태로 딱딱한 의자의 모서리에 침착하게 앉아 있었다.'},
#   {'file_url': 'python 서예진/918.m4a',
#    'text': '그는 순간적으로 흘끗 나를 쳐다보았고, 그의 입술은 웃으려고 노력했으나 끝내 웃음은 나오지 않았다.'},
#   {'file_url': 'python 서예진/919.m4a',
#    'text': '시계가 그의 머리에 눌려서 위험할 정도로 기울어지자, 그는 뒤로 돌아서서 떨리는 손가락으로 그것을 붙잡아 다시 제자리에 걸쳐 놓았다.'},
#   {'file_url': 'python 서예진/920.m4a',
#    'text': '그는 소파에 경직되게 앉아 팔꿈치를 팔걸이에 얹고 손으로 턱을 괴었다.'},
#   {'file_url': 'python 서예진/921.m4a',
#    'text': '내 머릿속에는 하고 싶은 말이 너무나 많았으나, 단 한 마디의 평범한 말조차 꺼낼 수가 없었다.'},
#   {'file_url': 'python 서예진/922.m4a', 'text': '바로 그 순간 시계가 방바닥에서 떨어져서 박살이 났다.'},
#   {'file_url': 'python 서예진/923.m4a',
#    'text': '데이지가 말했다. 그녀의 목소리는 더할 수 없이 침착했다.'},
#   {'file_url': 'python 서예진/924.m4a',
#    'text': '개츠비가 한 이 대답의 어투가 우리로 하여금 또다시 최소한 1분간은 말을 중단하게 만들었다.'},
#   {'file_url': 'python 서예진/925.m4a',
#    'text': '간신히 그들을 일어서게 했을 때 눈치없는 핀란드 인 가정부가 차를 쟁반에 담아 가지고 들어왔다.'},
#   {'file_url': 'python 서예진/926.m4a',
#    'text': '찻잔들과 케이크를 받아 놓는 약간의 소란 속에서도 그들의 어떤 자연스런 예의는 철저히 지켜졌다.'},
#   {'file_url': 'python 서예진/927.m4a',
#    'text': '내가 데이지와 이야기를 나누는 동안 그는 긴장되고 침울한 눈초리로 물끄러미 우리 두 사람을 번갈아 바라보았다.'},
#   {'file_url': 'python 서예진/928.m4a',
#    'text': '여하튼 침묵을 어서 깨야 할 것이기에 나는 틈을 타서 핑계를 대고 일어섰다.'},
#   {'file_url': 'python 서예진/929.m4a',
#    'text': '그는 허겁지겁 내 뒤를 부엌으로 들어오더니 문을 닫고는 풀이 죽어 귓속말로 말했다.'},
#   {'file_url': 'python 서예진/930.m4a', 'text': '그는 믿어지지 않는다는 듯이 되물었다.'},
#   {'file_url': 'python 서예진/931.m4a',
#    'text': '그는 한 손을 들어 내 말을 막았고, 책망하는 눈초리로 나를 바라보고는 조심스럽게 문을 열고 그 방으로 되돌아갔다.'},
#   {'file_url': 'python 서예진/932.m4a',
#    'text': '나는 30분쯤 전에 개츠비가 불안스럽게 집을 한 바퀴 돌았을 때와 똑같은 모습으로 뒷길을 빠져 나갔다.'},
#   {'file_url': 'python 서예진/933.m4a',
#    'text': '빽빽한 나뭇잎들이 비를 막아 주는 덮개 구실을 해주었다.'},
#   {'file_url': 'python 서예진/934.m4a', 'text': '비는 또다시 억수같이 퍼붓고 있었다.'},
#   {'file_url': 'python 서예진/935.m4a',
#    'text': '개츠비의 정원사가 잘 깎아 준 나의 잔디밭은 작은 흙탕 구덩이와 늪을 많이 만들어 내고 있었다.'},
#   {'file_url': 'python 서예진/936.m4a',
#    'text': '나무 밑에서 바라볼 만한 것이라고는 개츠비의 거대한 저택밖에 없었다.'},
#   {'file_url': 'python 서예진/937.m4a',
#    'text': '나는 반 시간 동안이나 칸트가 그의 교회 첨탑을 바라보았듯이 그것을 바라보고 있었다.'},
#   {'file_url': 'python 서예진/938.m4a',
#    'text': "그 저택은 10년쯤 전에 어떤 양조업자가 '시대'의 유행에 따라 지은 최신형의 것이었다."},
#   {'file_url': 'python 서예진/939.m4a',
#    'text': '그 양조업자는 모든 이웃 오두막집 주인들에게 만약 그들이 짚으로 지붕을 이으면 5년간의 세금을 대신 내주겠다고 했다고 한다.'},
#   {'file_url': 'python 서예진/940.m4a',
#    'text': "그들의 거절로 '한 가문을 창립'하려던 그의 계획은 좌절되었고 그의 가문은 몰락해 버렸다."},
#   {'file_url': 'python 서예진/941.m4a',
#    'text': '그의 자식들은 현관문에 새긴 검은 화환을 그대로 둔 채 그 집을 팔았던 것이다.'},
#   {'file_url': 'python 서예진/942.m4a',
#    'text': '미국인들이란 기꺼이 혹은 열성적으로 농노 노릇을 하려고 하면서도 언제나 농부의 위신을 잃지 않으려는 노력한다.'},
#   {'file_url': 'python 서예진/943.m4a',
#    'text': '하인들의 저녁 식사 재료를 실은 식료품점의 자동차가 개츠비의 저택 차도로 달려오는 게 보였다.'},
#   {'file_url': 'python 서예진/944.m4a',
#    'text': '나는 개츠비는 분명히 그런 음식은 한 숟가락도 먹으려고 하지 않을 것이라고 생각했다.'},
#   {'file_url': 'python 서예진/945.m4a', 'text': '하녀 하나가 그의 저택 이층 창문을 열기 시작했다.'},
#   {'file_url': 'python 서예진/946.m4a',
#    'text': '그녀는 창문으로마다 모습을 나타내고는 밖으로 내어 커다란 창문에 몸을 기대고 정원을 향해 침을 뱉었다.'},
#   {'file_url': 'python 서예진/947.m4a',
#    'text': '계속해서 비가 내릴 때의 빗소리는 감정이 격해짐에 따라 높아지곤 하는 개츠비와 데이지의 속삭임처럼 들렸었다.'},
#   {'file_url': 'python 서예진/948.m4a',
#    'text': '비가 그친 뒤의 새로운 고요함에 빠져 들자 그 고요함은 집 안까지 깃들인 것같이 느껴졌다.'},
#   {'file_url': 'python 서예진/949.m4a',
#    'text': '난로를 넘어뜨릴 뻔한 소리를 내는 등 부엌에서 가능한 모든 시끄러운 소리를 낸 연후에 나는 거실로 들어갔다.'},
#   {'file_url': 'python 서예진/950.m4a',
#    'text': '그러나 그들이 그 어떤 소리를 들었으리라고는 생각지 않는다'},
#   {'file_url': 'python 서예진/951.m4a',
#    'text': '두 사람은 긴 의자 양 끝에 앉아 서로 마주 보고 있었다'},
#   {'file_url': 'python 서예진/952.m4a',
#    'text': '마치 무슨 질문이 오고갔거나 혹은 그것이 허공에 떠 있는 것 같았으나 조금 전의 그 당황의 흔적은 보이지 않았다.'},
#   {'file_url': 'python 서예진/953.m4a',
#    'text': '내가 들어서자 그녀는 자리에서 일어나 거울 앞으로 다가가서는 손수건으로 얼굴을 닦기 시작했다.'},
#   {'file_url': 'python 서예진/954.m4a',
#    'text': '한편 개츠비에게 놀랄 만한 변화가 있었다. 그는 정말로 환한 빛을 발하고 있었다.'},
#   {'file_url': 'python 서예진/955.m4a',
#    'text': '환희의 말 한 마디도 행동도 없었지만, 새로운 행복감이 넘쳐 흐르는 그 빛은 작은 방을 가득 채우고 있었다.'},
#   {'file_url': 'python 서예진/956.m4a',
#    'text': '그는 마치 오랜만에 나를 만난 것처럼 말했다. 나는 한 순간 그가 악수를 하려는 것으로 생각했다.'},
#   {'file_url': 'python 서예진/957.m4a',
#    'text': '그는 내가 무슨 말을 하는지를 알아차렸다. 그리고 방 안에 눈부신 방울 같은 햇살이 비치고 있는 것을 깨달았다.'},
#   {'file_url': 'python 서예진/958.m4a',
#    'text': '다시 나타난 빛을 매우 기뻐하는 사람 같은 미소를 띠며 데이지에게 그 소식을 되풀이해서 말했다.'},
#   {'file_url': 'python 서예진/959.m4a',
#    'text': '가슴아플 만큼 슬픔이 깃들인 데이지의 낭랑한 목소리는 다만 예기치 못한 기쁨만을 나타냈다.'},
#   {'file_url': 'python 서예진/960.m4a',
#    'text': '나는 내 더러운 타월을 생각하고 부끄러운 생각이 들었으나 때는 이미 늦었다,'},
#   {'file_url': 'python 서예진/961.m4a', 'text': '그 동안 개츠비와 나는 잔디밭에서 그녀를 기다렸다.'},
#   {'file_url': 'python 서예진/962.m4a',
#    'text': '그는 자신의 집의 아치형 문 하나하나와 네모난 탑으로 시선을 옮겼다.'},
#   {'file_url': 'python 서예진/963.m4a',
#    'text': '지금 생각하면 그 때 그는 자신이 무슨 말을 하고 있는지도 모르고 있었던 것 같다.'},
#   {'file_url': 'python 서예진/964.m4a',
#    'text': '내가 무슨 일을 했었느냐고 물었을 때 그 대답이 동문서답이라는 것을 깨닫기도 전에 그는 대답했다.'},
#   {'file_url': 'python 서예진/965.m4a',
#    'text': '내가 미처 대답하기 전에 데이지가 집 밖으로 나왔기 때문에 더 이상 이야기하지 못했다.'},
#   {'file_url': 'python 서예진/966.m4a',
#    'text': '그녀의 드레스에 두 줄로 달린 놋쇠 단추가 햇빛을 받아 반짝였다.'},
#   {'file_url': 'python 서예진/967.m4a',
#    'text': '우리는 해협을 따라 난 지름길로 가는 대신 한길까지 내려가 거대한 뒷문을 통해서 개츠비의 저택으로 들어갔다.'},
#   {'file_url': 'python 서예진/968.m4a',
#    'text': '데이지는 푸른 하늘을 배경으로 한 봉건시대풍 건물의 검은 윤곽을 여기저기로 살펴보면서 감탄했다.'},
#   {'file_url': 'python 서예진/969.m4a',
#    'text': '그녀는 또한 정원과 수선화의 향기, 아가위와 서양 자두꽃의 거품 같은 향기, 그리고 야생 오랑캐꽃의 연한 향기에 감탄했다.'},
#   {'file_url': 'python 서예진/970.m4a',
#    'text': '집 앞 대리석 계단에 이르렀는데도 현관문 안팎에 인적은 보이지 않고 새소리밖에 들리지 않는 것이 이상했다.'},
#   {'file_url': 'python 서예진/971.m4a',
#    'text': '집안으로 들어가 마리 앙투아네트 음악실들과 왕정복고시대풍의 객실들을 서성거리다가 나는 비로소 그 이유를 알게 되었다.'},
#   {'file_url': 'python 서예진/972.m4a',
#    'text': '모든 손님들은 긴 의자와 테이블 뒤에 숨어서 우리가 지나갈 때까지 숨을 죽이고 가만히 있으라는 지시를 받았던 것이다.'},
#   {'file_url': 'python 서예진/973.m4a',
#    'text': '나는 분명히 그 올빼미 눈 같은 안경을 낀 남자가 유령 같은 기분 나쁜 웃음을 터뜨리는 소리를 들은 것 같았다.'},
#   {'file_url': 'python 서예진/974.m4a',
#    'text': '우리는 이층으로 올라가 침실들과 화장실, 그리고 당구장을 지나 욕조가 움푹 들어간 욕실들을 둘러보았다.'},
#   {'file_url': 'python 서예진/975.m4a',
#    'text': '다음 어떤 방으로 들어가자 머리가 헝클어진 남자 파자마 바람으로 방바닥에서 간장 운동을 하고 있었다.'},
#   {'file_url': 'python 서예진/976.m4a', 'text': "그는 '하숙생'이라는 별명을 가진 클립스프링거였다."},
#   {'file_url': 'python 서예진/977.m4a',
#    'text': '나는 그날 아침에 해변가에서 할 일없이 서성거리는 그를 보았었다.'},
#   {'file_url': 'python 서예진/978.m4a',
#    'text': '우리는 침실과 욕실, 그리고 서재가 갖춰진 개츠비의 거처로 가서 앉아 그가 벽장에서 꺼내 온 술을 한 잔씩 마셨다.'},
#   {'file_url': 'python 서예진/979.m4a', 'text': '개츠비는 잠시도 데이지에게서 눈을 떼지 않았다.'},
#   {'file_url': 'python 서예진/980.m4a',
#    'text': '그는 자신의 집에 있는 모든 물건들을 데이지의 아름다운 두 눈에 비치는 반응에 따라 재평가하고 있다고 느꼈다.'},
#   {'file_url': 'python 서예진/981.m4a',
#    'text': '그는 데이지가 자기 눈앞에 실제로 와 있는 상황에서는 소유하고 있는 물건 따위는 이제 하나도 현실감이 없다는 듯이 멍하게 둘러보았다.'},
#   {'file_url': 'python 서예진/982.m4a',
#    'text': '그러다가 한 번은 계단에서 거의 굴러 떨어질 뻔하기도 했다.'},
#   {'file_url': 'python 서예진/983.m4a',
#    'text': '그의 침실은 모든 방중에서 제일 수수했다, 다만 경대가 순금제 화장 세트로 장식되어 있는 것을 빼고는.'},
#   {'file_url': 'python 서예진/984.m4a',
#    'text': '데이지는 그 앞에서 아주 좋아하며 머리솔을 집어들어 자신의 머리를 빗었다.'},
#   {'file_url': 'python 서예진/985.m4a',
#    'text': '그러는 동안에 개츠비는 의자에 앉아 두 눈을 가리고 웃음을 보였다.'},
#   {'file_url': 'python 서예진/986.m4a',
#    'text': '그는 이제 두 가지 과정을 거쳐서 세 번째 과정으로 접어들고 있는 것이 분명했다.'},
#   {'file_url': 'python 서예진/987.m4a',
#    'text': '당황함과 이유 없는 환희를 거쳐 이제는 데이지가 눈앞에 있는 데에 대한 놀라움으로 어리둥절해지고 있었다.'},
#   {'file_url': 'python 서예진/988.m4a',
#    'text': '그는 아주 오랫동안 이렇게 되리라는 생각만을 해 왔고 처음부터 끝까지 꼭 이렇게 되리라고 상상해 왔다.'},
#   {'file_url': 'python 서예진/989.m4a',
#    'text': '말하자면 상상조차 할 수 없을 정도로 이를 악물고 기다려 왔던 것이다.'},
#   {'file_url': 'python 서예진/990.m4a',
#    'text': '이제 그는 그 반동으로 태엽을 너무 감아 놓은 시계처럼 천천히 풀리고 있었다.'},
#   {'file_url': 'python 서예진/991.m4a',
#    'text': '그는 우리에게 양복과 화장 가운과 넥타이가 가득차 있고 셔츠가 수북히 쌓인 두 개의 커다란 옷장을 열어 보여 주었다.'},
#   {'file_url': 'python 서예진/992.m4a',
#    'text': '그는 셔츠 더미 하나를 꺼내 하나씩 우리 앞으로 던졌다.'},
#   {'file_url': 'python 서예진/993.m4a',
#    'text': '두터운 비단, 곱게 짠 플란넬 셔츠들이 풀려 형형색색의 색깔로 테이블을 뒤덮었다.'},
#   {'file_url': 'python 서예진/994.m4a',
#    'text': '우리가 감탄하는 가운데 그는 다른 한 더미의 셔츠들을 꺼내 테이블 위에 올려놓았다.'},
#   {'file_url': 'python 서예진/995.m4a',
#    'text': '산호색, 풋사과의 녹색, 라벤더색 그리고 연한 오렌지색 바탕에 줄무늬, 소용돌이 무늬, 체크 무늬가 있는 셔츠들이었다.'},
#   {'file_url': 'python 서예진/996.m4a', 'text': '그 속엔 하늘색 글자로 모노그램이 수놓여 있었다.'},
#   {'file_url': 'python 서예진/997.m4a',
#    'text': '그것들을 본 데이지가 갑자기 그 속에 머리를 파묻고 흥분한 소리로 격렬하게 울어대기 시작했다.'},
#   {'file_url': 'python 서예진/998.m4a',
#    'text': '그녀는 흐느끼며 말했는데, 그 소리는 겹겹으로 쌓인 셔츠에 묻혀 잘 들리지 않았다.'},
#   {'file_url': 'python 서예진/999.m4a',
#    'text': '집안을 둘러본 뒤엔 마당과 풀장, 그리고 수상기와 잘 가꿔진 꽃들을 볼 계획이었다.'},
#   {'file_url': 'python 서예진/1000.m4a',
#    'text': '밖엔 다시 비가 내리기 시작했으므로 우리는 나란히 서서 파도치는 바다를 바라보고 있었다.'},
#   ...],
#  'input/json/01234_181105.json')

# %%
len(preproc.get_input_map())
# Out:
# 6357

# %%
def write_json(path, data):
    with open(path, 'w') as f:
        json.dump(data, f, indent=4, sort_keys=True, ensure_ascii=False,)    
        
        

input_map = {}
tcount = 0
meta_json = {}
meta_json['muse_id'] = museid
meta_json['records'] = []

# with zipfile.ZipFile(src) as zip:
zip = zipfile.ZipFile(src)
metafile = [ x for x in zip.namelist() if x and x.find('.csv') >= 0 ]
if len(metafile) == 1:
    zip.extract(metafile[0], path=dst_root)
    csv_file_path = os.path.join(dst_root, metafile[0])

    try:
        # utf-8로 읽기
        print('utf-8')
        with open(csv_file_path, 'r', encoding='utf-8') as meta_f:
            reader = csv.reader(meta_f)
            for line in reader:
                iname = re.sub(codecs.BOM_UTF8.decode('utf-8'), '', line[0])
                input_map[iname] = line[1].strip()

    except:
        print('cp949')
        try:
            #cp949 형식으로 읽기
            with open(csv_file_path,'r',encoding='cp949') as meta_f:
                reader = csv.reader(meta_f)
                for line in reader:
                    iname = re.sub(codecs.BOM_UTF8.decode('utf-8'), '', line[0])
                    input_map[iname] = line[1].strip()

        except Exception as ex:
#                       
            traceback.print_exc()
#   
zip.close()
# Out:
# utf-8

# %%
input_map
# Out:
# {'1': '내가 아직 어리고 지금보다 훨씬 더 쉽게 남의 말에 곧잘 화를 내던 시절 아버지께서는 나에게 한 가지 충고를 해주셨다.',
#  '2': '그 후로 나는 그 충고를 마음속으로 항상 되새기곤 했다.',
#  '3': '남 의 잘잘못을 따질 때는 언제든지 이 세상 사람들이 너처럼 좋은 환경에서 자라지 못했다는 것을 기억해야 한다.',
#  '4': '아버지께서는 더 이상 말씀하시지 않았지만, 우리는 말없는 가운데서도 서로의 뜻을 잘 이해할 수 있었다.',
#  '5': '나는 아버지의 그 충고 속에는 보다 더 깊은 뜻이 담겨 있다는 것을 알아차렸다.',
#  '6': '아버지의 그 충고로 말미암아 나는 모든 판단을 될 수 있으면 뒤로 미루는 태도를 취하곤 했다.',
#  '7': '그것 때문에 성가시게 치근덕거리는 몇몇 사람들로부터 어려움을 겪기도 했다.',
#  '8': '이러한 성격의 소유자들은 나와 같은 정상적인 사람이 나타나면 금방 눈치채고 가까이 오게 마련이다.',
#  '9': '그것은 내가 거친, 세상에 알려지지 않은 사람들의 은밀한 비애를 많이 알고 있었기 때문이었다.',
#  '10': '어떤 확실한 근거로 은밀한 이야기가 드러나려 할 때면 나는 잠을 자는 척하거나, 적의에 찬 경박한 짓을 하곤 했다.',
#  '11': '사실 젊은이들의 은밀한 이야기는, 적어도 그것을 표현할 때 쓰는 말투도 대개 남의 말을 표절하게 마련이다.',
#  '12': '때로는 어떤 의견 표명을 삼가고 있다는 것이 상대에게 무한한 희망을 줄 때도 있는 법이다.',
#  '13': '이처럼 나의 너그러움을 한껏 과시하고 난 후에야 나는 너그러움에도 한계가 있다는 것을 알게 되었다.',
#  '14': '어떤 한계만 넘기게 되면 나는 그 행위가 어떤 곳을 기반으로 해서 겉으로 드러나게 된 것이든 상관하지 않는다.',
#  '15': '작년 가을, 동부에서 돌아왔을 때 나는 사람들이 똑같은 차림을 하고 일종의 도덕적인 자세를 취해 주었으면 하고 바랐다.',
#  '16': '무슨 특권이라도 지닌 듯이 사람의 마음속을 힐끔힐끔 들여다보는, 야단스럽게 나서는 일에 진저리가 났다.',
#  '17': '오직 한 사람, 이 책의 주인공인 개츠비만은 앞에서 말한 나의 반발에서 제외된 사람이다.',
#  '18': '개츠비는 바로 내가 노골적으로 경멸한 모든 것을 포함하고 있는 대표적인 사람이었던 것이다.',
#  '19': '내가 지금껏 그 누구에게서도 발견하지 못했을 뿐 아니라 앞으로도 영원히 발견하지 못할 낭만적 감수성이었다.',
#  '20': "이 감수성은 저 '창의적인 기질'아래에 위엄을 떨치는 그 허약한 감수성과는 분명히 차이가 있었다.",
#  '21': '우리 가족들은 이 중서부의 도시에서 3대에 걸쳐 꽤 이름이 알려진 유지로 부유하게 살아 왔다.',
#  '22': '캐러웨이가는 뛰어난 가문이며, 우리는 부클류 공작의 자손이라고 전해지고 있다.',
#  '23': '실제로 나의 가계를 일으켜 세운 사람은 1851년에 이 곳에 이주하셨다.',
#  '24': '남북 전쟁 때 자기 대신 다른 사람을 대신 내보내고, 철물 도매상을 시작하셨던 나의 증조부이시다.',
#  '25': '지금은 아버지가 그 사업을 이어받아 경영하고 계시다. 나는 그 증조부를 한 번도 뵌 적이 없다',
#  '26': '나는 1915년에 예일 대학을 졸업했는데, 그것은 아버지께서 그 학교를 졸업하신지 25년째 되던 해의 일이었다.',
#  '27': '얼마 후에 나는 1차 세계 대전이라는, 튜튼족의 때늦은 이동 작업에 참가했다.',
#  '28': '그때 나는 미국인의 유럽 역습을 마음껏 즐겼기 때문에 집에 와서도 한동안 들뜬 마음을 진정시킬 수가 없었다.',
#  '29': '미국의 중서부 지방이 이제는 세계의 활기찬 중심지가 아니라 우주의 초라한 변두리같이 보였다.',
#  '30': '나는 동부로 가서 증권업을 배우기로 결심했다. 내가 아는 사람들은 하나같이 증권업에 종사하고 있었기 때문이었다.',
#  '31': '집안 아주머니들은 마치 나를 위해 무슨 대학 진학의 예비 고교를 골라 주기라도 하는 것처럼 그 문제에 대해 여러 가지로 의논하셨다.',
#  '32': '마지막으로 매우 엄숙하고 망설이는 표정으로, "글세, 괜찮을 거야."라고 말씀하셨다.',
#  '33': '사무실의 한 젊은 동료가 기차 통근 거리의 마을에 셋집을 얻어 같이 생활하자고 말해 왔을 때 그것은 멋진 생각처럼 들렸다.',
#  '34': '월세 80달러짜리로 비바람에 낡은 싸구려 방갈로 집이었다. 마지막 순간에 그는 회사로부터 워싱턴으로의 전근 명령을 받았다.',
#  '35': '. 나는 그 때 개 한 마리를 갖고 있었는데 그 개가 달아나기 전까지 적어도 2, 3일 동안은 함께 생활했다.',
#  '36': '요리용 전기 난로 위로 몸을 구부리고는 알 수 없는 혼잣말로 핀란드 속담을 중얼거리곤 했다.',
#  '37': '하루 이틀은 무척 외로웠는데, 어느 날 아침 길에서 나보다 늦게 이사 온 어떤 사람이 나를 불러 세웠다.',
#  '38': '나는 안내자요 개척자요 맨 처음 이 곳에 초기 정착한 사람이 되었던 것이다.',
#  '39': '나는 햇빛과 그리고 고속 촬영 영화에서 식물이 자라는 것처럼 쑥쑥 크는 나뭇잎들을 보았다.',
#  '40': '인생은 여름과 함께 다시 시작된다는, 지극히 평범한 사실을 깨닫기에 이르렀다.',
#  '41': '우선 먼저 할 일은 독서와 더불어 신선한 호흡을 하게 해 주는 맑은 공기에서 건강을 얻어내는 일이었다.',
#  '42': '그것들은 조폐국에서 금방 찍어 낸 새 돈처럼 붉은빛과 황금빛을 띤 채 내 서가에 꽂혀있다.',
#  '43': "나는 대학 시절 문학에 제법 자신이 있었다. 1년간 '예일 뉴스'지에 아주 품위 있고 명확한 논설을 연재한 적도 있을 정도였다.",
#  '44': "난 지금의 내 생활에서 이러한 것들을 다시 찾아냄으로써, 다시 '박식하고 원만한 사람'이 되어 보려는 생각이었다.",
#  '45': '결국 인생이란 여럿이 아닌 단 하나의 창문으로 바라보면 성공하기가 훨씬 더 쉬운 것이다.',
#  '46': '내가 북아메리카에서 가장 낯선 동네에 집을 얻게 된 것은 우연히 일어난 일 때문이었다.',
#  '47': '집은 뉴욕의 동쪽으로 곧장 뻗은 그 길쭉하고 요란스러운 섬 위에 있었다.',
#  '48': '그곳에는 천연의 진기물들이 많이 있었는데, 그 가운데 특이한 지역이 두 군데 있었다.',
#  '49': '롱아일랜드 해협이라 불리는, 물에 젖은 넓은 뒷마당 안으로 솟아 나온 그 두 지대는 완전한 달걀 모양은 아니었다.',
#  '50': '날개가 없는 인간을 더욱 재미있게 하는 것은 그 두 지대가 모양과 크기를 빼고는 모든 점에서 닮은 점이 하나도 없다는 사실이었다.',
#  '51': '해협에서 50야드밖에 안 떨어진 맨 꼭대기 부분에 있는 나의 집은 어마어마하게 좋은 두 채의 저택 사이에 끼여 있었다.',
#  '52': '내가 세든 집의 오른쪽에 있는 저택은 어느 모로 보나 위압감을 주는 대저택이었다.',
#  '53': '노르망디의 어떤 시의 청사를 본떠 만든 것이었는데, 그 집은 개츠비의 저택이었다.',
#  '54': '나는 개츠비라는 사람을 단 한 번도 보지 못했으므로 그런 이름을 가진 신사가 살고 있는 저택이었다고 해야 옳을 것이다.',
#  '55': '내가 세든 집은 주위의 환경과는 어울리지 않았지만 아주 작았기 때문에 그다지 거슬리는 것은 아니었다.',
#  '56': '나는 바다도 바라보고, 내 이웃집 잔디밭도 내다보면서 백만장자들의 이웃이라는 위안을 받았다.',
#  '57': '이름뿐인 만 건너편은 바닷가를 따라 호화로운 이스트에그의 하얀 저택들이 번쩍거리고 있었다.',
#  '58': '내가 탐 부캐넌 부부와 저녁 식사를 하러 그 곳으로 차를 몰고 간 바로 그 날 저녁에 이 여름의 역사는 시작되었다.',
#  '59': '전쟁이 끝난 직후에 나는 시카고에 사는 그들 부부와 이틀 동안 함께 지냈었다',
#  '60': '탐은 여러 가지 운동을 했는데, 특히 예일 대학의 축구 선수로는 보기 드문 강력한 스크럼 선수 가운데 하나였다.',
#  '61': '젊은 나이에 이미 정상의 위치에 올라 있었기에 그 후로는 모든 일에 있어 내리막길을 걷고 있는 듯한 느낌을 주는 인물이었다.',
#  '62': '그는 굉장한 부자였다. 대학을 다닐 때도 돈에 전혀 신경 쓰지 않는 그의 생활은 비난의 대상이 되기도 했다.',
#  '63': '지금 그는 시카고를 떠난 사람들을 깜짝 놀라게 할 정도의 멋진 계획을 세워서 동부에 와 있는 것이다.',
#  '64': '그 한 예로 그는 레이크 퍼리트로부터 폴로 경기용 말 한 떼를 끌고 왔던 것이다.',
#  '65': '내 또래의 남자로 어마어마한 그런 일을 할 정도로 돈이 많다니, 정말로 이해하기가 어려웠다.',
#  '66': '그들은 1년 동안을 프랑스에서 지냈다. 돌아와서는 폴로 경기를 하며 돈 많은 사람들이 있는 곳을 찾아다녔다.',
#  '67': '데이지는 내게 전화를 걸어 이번에는 영원히 이 곳에서 살고 싶다고 말했지만 나는 믿지 않았다.',
#  '68': '나는 따뜻한 바람이 불던 어느 날 저녁, 안면만 있는 두 명의 친구를 만나기 위해 이스트에그로 자동차를 몰고 갔다.',
#  '69': '그들의 집은 내가 상상한 것보다 훨씬 정교하게 지은, 왕조 시대의 식민지풍 저택이었다.',
#  '70': '잔디가 해안에서부터 집의 현관문까지, 그것은 도중에 해시계와 벽돌을 깐 보도 그리고 붉게 타는 듯한 정원을 지나서도 계속되었다.',
#  '71': '마침내 집까지 이어져서는 한쪽으로 마치 관성의 법칙으로 인한 양 선명한 빛깔의 덩굴 숲으로 이어져 있었다.',
#  '72': '저택의 정면은 햇빛을 받아 금빛으로 반짝이고 한 줄로 가지런하게 달린 창문들은 따뜻한 바람을 맞으려고 활짝 열려져 있었다.',
#  '73': '마복 차림의 탐 부캐넌이 두 다리를 벌린 꼿꼿한 자세로 정면 베란다에 서 있었다.',
#  '74': '지금의 그는 건강한 체격에 밀짚빛 머리칼을 지닌 30대의 사나이로, 굳게 다문 입이 오만한 느낌을 주었다.',
#  '75': '거만스러운 두 눈이 얼굴을 온통 뒤덮고 있었으며, 싸울 상대를 만나기라도 한 것처럼 몸을 앞으로 굽히고 있었다.',
#  '76': '여자의 옷처럼 화려한 승마복도 그의 육체의 엄청난 힘을 감추지는 못했다.',
#  '77': '꽉 끼이는 것처럼 보이는 번쩍이는 장화의 맨 위쪽 끈은 팽팽하게 죄어져 있었다.',
#  '78': '얇은 상의 밑으로 어깨가 움직일 때마다 우람한 근육이 꿈틀거리는 것을 볼 수 있었다.',
#  '79': '거칠고 센 듯한 그의 고음 목소리는 성깔 있어 보이는 그의 인상을 한층 더 강렬하게 보이게 했다.',
#  '80': '그의 목소리에는 친절한 사람들을 대할 때조차 고압적이고 경멸감이 담겨 있는 것처럼 보였다.',
#  '81': '"이러한 문제들에 대한 나의 의견이 결론적인 것이라고 생각하면 안되지. 내가 당신보다 힘이 세고 남자답다는 이유만으로 말이야"',
#  '82': '그와 나는 4학년 때 같은 사교 클럽에 들어 있었다. 결코 친한 사이는 아니었지만 그는 내게 항상 친절했다.',
#  '83': '특유의 거칠고 시비조인 불만스러운 태도를 취하기는 했지만 내가 자기를 좋아하기를 바라는 눈치였다.',
#  '84': '한 팔로 나를 돌려 세우며 넓적하고 편편한 손을 들어 앞으로 펼쳐져 있는 경치를 가리켰다.',
#  '85': '그는 공손하면서도 갑작스럽게 나를 또다시 빙 돌려세우면서 말했다. "이제 안으로 들어가세."',
#  '86': '창문 아래로는 집 안쪽으로 침입한 듯한, 싱그러움을 안겨 주는 풀밭이 펼쳐져 있었다.',
#  '87': '방 안 의자에는 젊은 여자 두 명이 마치 강철 줄로 매 놓은 기구에 앉은 것처럼 앉아 있었다.',
#  '88': '그 옷들은 마치 집의 주변을 잠시 날아다니다 바람에 밀려 지금 막 들어온 것처럼 가볍게 나부끼고 있었다.',
#  '89': '나는 커튼의 펄럭이는 소리와 벽에 걸린 액자의 흔들리는 소리에 정신에 빼앗긴 채 한동안 그대로 서 있었음에 틀림없다.',
#  '90': '탐 부캐넌이 뒤뜰의 창문을 닫는 소리가 들리더니 이어 바람이 멎어 조용해졌다.',
#  '91': '그녀는 긴 의자의 한쪽 끝에 몸을 쭉 펴고 앉아서는 석고상처럼 움직이지 않았다.',
#  '92': '마치 그 위에다 뭔가를 얹어 놓고 그것이 떨어지면 큰일날까 걱정이 되어 균형을 잡고 있는 것처럼 보였다.',
#  '93': '그녀가 나를 곁눈질해 보았는지는 몰라도 전혀 아는 척하지 않았다.',
#  '94': '사실 나는 놀랐고, 그래서 방안에 들어와서 그녀의 심리적 균형을 깬 것에 대해 사과의 말을 중얼거릴 뻔했다.',
#  '95': '어색하지만 매력적인 웃음을 지었다. 얼떨결에 나 역시 따라 웃고는 방안으로 들어갔다.',
#  '96': '그녀는 내 손을 잡고 얼굴을 쳐다보면서 그 동안 보고 싶었다고 강조해서 말했다.',
#  '97': '그녀는 턱의 균형을 잡고 있는 것처럼 행동하고 있는 그 여자의 성은 베이커라고 나직하게 속삭여 주었다.',
#  '98': '데이지가 일부러 속삭이는 것은 듣는 사람이 자기에게로 몸을 기울이게 하기 위함이라는 말을 들은 적이 있다.',
#  '99': '그것은 얼토당토않은 모함이었으나, 그런 모함에도 불구하고 데이지의 그러한 속삭임은 매력적으로 보였다.',
#  '100': '베이커 양의 입술이 움직였고, 나를 향해 고개를 끄덕여 인사한 그녀는 다시 아까처럼 머리를 뒤로 젖혔다.',
#  '101': '그녀가 턱의 균형을 잡고 떨어뜨리지 않으려 하고 있던 물건이 약간 뒤뚱거려 그녀를 얼마쯤 놀래게 했다.',
#  '102': '누군가 자기 만족에 빠진 사람을 보면 항상 감동해서 찬사를 보내고 싶어진다.',
#  '103': '내가 다시 데이지 쪽을 쳐다보자 그녀는 나지막하지만 자극적인 목소리로 여러 가지에 대해 묻기 시작했다.',
#  '104': '그 목소리는 마치 다시는 연주될 수 없는 악곡과 같아서 듣는 사람의 귀는 그 목소리를 따라서 오르락내리락하게 되었다.',
#  '105': '그녀의 목소리는 좀 흥분되어 있어서 그녀에게 호감을 갖고 있는 남자라면 여간해서 그것을 잊을 수 없게 했다.',
#  '106': '나는 동부로 오는 길에 시카고에 들렀던 이야기를 해 주면서 그 곳의 친척이 그녀에게 안부를 전하더라고 알려주었다.',
#  '107': '"그분들이 저를 잊지 않았나요?"하고 그녀는 흥분을 감추지 못하며 들뜬 목소리로 소리쳤다.',
#  '108': '아까부터 방안을 불안스럽게 서성거리고 있던 탐 부캐넌이 갑자기 다가와서 내 어깨에 손을 얹었다.',
#  '109': '그는 더 중요한 어떤 일에 마음을 쓰고 있기나 한 듯 데이지를 힐끔 쳐다보고는 다시 나를 보면서 말했다.',
#  '110': '"정말 그래요!" 그녀가 너무나 갑작스럽게 소리쳤으므로 나는 깜짝 놀랐다.',
#  '111': '"몸이 너무 찌뿌드드해요." 자리에서 일어선 그녀가 투덜거렸다.',
#  '112': '내가 이 방에 들어온 후로 내가 처음 한 말이었다. 그 한 마디에 내가 놀란 것만큼이나 그녀도 놀란 것이 분명했다.',
#  '113': '왜냐하면 그녀는 입을 크게 벌리고는 빠르고도 능숙한 동작으로 일어섰으니까 말이다.',
#  '114': '그는 마치 술이 잔 밑바닥에 한 방울이라도 남아 있으면 안되기라도 한 듯 칵테일을 단숨에 마셨다.',
#  '115': "나는 베이커 양의 그 '해낸 일이 무엇인지 궁금했기 때문에 그녀를 바라보았다.",
#  '116': '그녀는 가냘픈 몸에 곧은 몸매를 하고 있었는데, 마치 젊은 사관 후보생처럼 어깨를 뒤로 젖혀 곧은 몸매를 더욱 드러나게 했다.',
#  '117': '햇빛으로 찡그린 그녀의 회색 눈동자가 호기심에 찬 눈빛으로 나를 돌아다보았다.',
#  '118': '나는 문득 어디에선가 그녀를 혹은 그녀의 사진을 본 적이 있다는 생각이 들었다.',
#  '119': '"웨스트에그에 살고 계시다고요?" 그녀는 무시하는 투로 말했다.',
#  '120': '그 사람은 바로 내 집 옆에 살고 있다고 미처 대답하기 전에 하인이 저녁 식사가 준비되어 있다고 알려 왔다.',
#  '121': '그는 그의 억센 팔을 자기 마음대로 내 겨드랑이 밑으로 넣더니 장기 알을 다른 칸으로 옮기듯이 나를 방에서 이끌고 나갔다.',
#  '122': '두 여인은 손을 허리에 살며시 얹은 채 가볍고도 경쾌한 발걸음으로 앞장서서 지는 해를 향해 훤히 트여 있는 장밋빛 방으로 갔다.',
#  '123': '"촛불은 뭐 하러 켰지?" 데이지가 눈살을 찌푸리면서 짜증을 냈다.',
#  '124': '"2주일만 지나면 1년 중 가장 길다는 하지예요." 그녀는 밝은 얼굴로 우리들을 쳐다보았다.',
#  '125': '당신들도 일 년 중에서 낮이 가장 길다는 그 날을 기다렸으면서도 막상 다가오니까 그 날을 깜박 잊고 지나쳐 버리지요?',
#  '126': '저는 말이에요, 항상 그 날을 기다렸으면서도 깜박 그 날을 지나쳐 버리지 뭐예요.',
#  '127': '베이커 양이 하품을 하며 마치 잠자리에 들기라고 하듯이 식탁에 앉으면서 말했다.',
#  '128': '"무슨 계획을 세울까요?" 그녀는 별 뚜렷한 것이 생각나지 않는 듯 나를 쳐다보았다.',
#  '129': '내가 대답하기도 전에 그녀는 눈에 걱정스러운 빛을 띠고 자기의 새끼손가락을 천천히 들여다보았다.',
#  '130': '"여길 다쳤어요." 우리의 시선이 모두 그녀의 손가락을 향했다. 새끼손가락 마디는 검고 푸르스름했다.',
#  '131': '이것 역시 짐승 같은 남자, 산더미 만한, 괴물처럼 엄청나게 큰 몸집의 본보기 같은 남자와 결혼한 탓이에요.',
#  '132': '"괴물 같다는 소리는 정말로 듣기 싫소." 탐이 얼굴을 찡그리며 투덜거렸다.',
#  '133': '데이지와 베이커 양은 동시에 얘기를 하곤 했는데, 그들의 얘기는 아주 평범했다.',
#  '134': '그들은 입고 있는 흰옷이나 아무 욕망도 없어 보이는 무심한 눈만큼이나 태연한, 무미건조한 농담처럼 말했다.',
#  '135': '그들은 그저 이 곳에 있고, 대접을 받으려고 겸손하고 즐거운 척 위장을 하고 있었던 것뿐이다.',
#  '136': '그들은 식사가 곧 끝날 것이고, 조금 더 있으면 이 밤 또한 끝나 평범하게 잊혀지리라는 것을 알고 있었던 것이다.',
#  '137': '순간 자체가 긴장된 두려움 속에서 저녁의 끝을 향하여 한 단계 한 단계씩 급히 지나가 버리게 마련이었다.',
#  '138': '나는 코르크 냄새가 나지만 그런 대로 맛이 좋은 적포도주를 두 잔째 마시면서 진실을 말했다.',
#  '139': "나는 매사에 지독한 비관론자가 되어 버렸다네. 자네, '유색인 제국의 발흥'이라는 책을 읽어 본 적이 있나?",
#  '140': '그 책의 요지는 우리가 경계하지 않으면 백색 인종은 완전히 멸망해 버린다는 거야. 과학적으로 증명까지 하고 있지.',
#  '141': '"탐은 요즘 매우 심각한 생각을 많이 해." 데이지가 측은한 표정을 지으며 말했다.',
#  '142': '뜻도 모를 난해한 책들이 많아. 그 낱말의 뜻이 뭐였더라...?',
#  '143': '"모두 과학적인 책들이야." 탐은 참을성 없게 데이지를 힐끔 바라보며 자기 주장을 내세웠다.',
#  '144': '그건 지배적인 인종인 우리의 책임이야. 조심하지 않으면 다른 인종들이 모든 것을 지배하게 될 거야.',
#  '145': '"그 인종들을 타도해야죠." 강렬한 햇빛에 눈을 사납게 깜박이면서 그녀가 귓속말로 말했다.',
#  '146': '그가 둔한 몸을 일으켜 고쳐 앉음으로써 그녀의 말을 가로막았다.',
#  '147': '그 책이 말하고 있는 것은 우리가 북유럽 인종이라는 것이지. 나도 자네도, 그리고 당신도 말이야.',
#  '148': '그는 잠시 망설이더니 머리를 조금 끄덕이는 것으로 데이지도 그 속에 포함시켰다.',
#  '149': '문명을 형성하는 데에 필요한 모든 것들을 우리 백인이 만들어 냈던 것이네.',
#  '150': '평소보다 더 두드러진 자기 만족감도 더 이상 그를 충족시켜 주지 못하는 것같이 보였다.',
#  '151': '이 때 안에서 전화벨이 울려 하인이 방을 나가자, 데이지는 순간적으로 말이 중단된 틈을 타서 내게로 몸을 기울였다.',
#  '152': '"우리 집안의 비밀을 하나 가르쳐 드릴게요."  그녀는 신나는 듯이 속삭이었다.',
#  '153': '그녀의 붉어진 얼굴은 늦은 석양빛으로 낭만적인 감정이 맴돌았다.',
#  '154': '그녀의 목소리는 나로 하여금 숨을 죽이고 그녀의 몸 쪽으로 다가가도록 했다.',
#  '155': '탐은 찡그리며 의자를 뒤로 밀고는 한 마디 말도 없이 안으로 들어갔다.',
#  '156': '그것이 무슨 신호라도 된 듯이 데이지는 다시 앞으로 몸을 숙였고, 그녀의 목소리는 열기를 띠고 들떠 있었다.',
#  '157': '닉 오빠를 우리 집 저녁 식사에 모시게 되어 기뻐요. 오빠를 보고 있으면 아름답게 핀 장미꽃이 생각나요.',
#  '158': '데이지는 그저 생각나는 대로 말한 것이었지만, 그녀에게서는 사람을 충동시키는 마력이 넘쳐흐르고 있었다.',
#  '159': '그녀는 갑자기 냅킨을 식탁 위에 던지고는 실례하겠다고 짧게 말한 뒤 안으로 들어가 버렸다.',
#  '160': '베이커 양과 나는 아무 뜻 없이 무의식적으로 잠시 눈길을 주고받았다.',
#  '161': '내가 막 입을 열려고 하는 순간, 그녀가 재빠르게 자세를 고쳐 앉으며 경계하는 목소리로,  "쉬!"하고 말했다.',
#  '162': '저 쪽 방에서 흥분을 억제하며 숨을 죽여 가며 수군거리는 소리가 들려왔다.',
#  '163': '베이커 양은 예의도 잊은 듯 엿들으려고 몸을 안쪽으로 굽혔다.',
#  '164': '수군거리는 소리는 끊어질 듯 떨리며 낮아졌다가 흥분되어 커지더니 마침내 완전히 그쳐 버렸다.',
#  '165': '조금 전에 말한 그 개츠비라는 사람은 바로 나의 이웃입니다. 옆집에 살고 있지요.',
#  '166': '그녀는 망설이며 말했다. "탐은 뉴욕에 사귀는 여자가 있어요."',
#  '167': '그녀가 저녁 식사시간에는 전화를 삼가는 조심성 정도는 있어야 할 텐데요. 그렇게 생각하지 않아요?',
#  '168': '무슨 뜻인지 제대로 이해하기도 전에 탐과 데이지가 식탁으로 되돌아왔다.',
#  '169': '그녀는 자리에 앉아서 베이커 양과 나의 눈치를 살피고 나서 말을 이었다.',
#  '170': '나가 보니 아주 상쾌하더군요. 새가 한 마리 앉아 있었는데, 배를 타고 건너온 나이팅게일 같았어요.',
#  '171': '그녀의 목소리는 노래를 부르는 것 같았다. "로맨틱하지요, 안 그래요, 탐?"',
#  '172': '"굉장히 로맨틱한데." 탐은 이렇게 말하고 난 뒤 괴로운 표정으로 내게 말했다.',
#  '173': '"저녁 식사 후에도 날이 어두워지지 않으면 저 아래 있는 마구간을 보여 주고 싶은데."',
#  '174': '또다시 안에서 전화벨이 요란하게 울렸다. 데이지가 탐을 향해 단호하게 고개를 흔들자 마구간 문제는 없어져 버렸다.',
#  '175': '엉망이 된 그 날 저녁 식탁에서 기억에 남는 일이라고는 아무 의미도 없이 촛불이 다시 켜졌던 일뿐이었다.',
#  '176': '나는 모두가 어떤 표정을 짓고 있는지 살펴보고 싶었으나 왠지 모두의 시선과 마주치는 것을 피하게 되었다.',
#  '177': '나로서는 탐이나 데이지가 무슨 생각을 하고 있는지 도무지 짐작할 길이 없었다.',
#  '178': '베이커 양마저 그 전화벨의 주인공이 누구인지 궁금해하고 있는 것 같았다.',
#  '179': '어떤 사람에게는 일이 복잡하게 얽힌 것으로 보일는지도 모른다. 내 성미대로라면 전화로 경찰을 당장 불렀으면 싶었다.',
#  '180': '나는 흥미를 느끼는 동시에 데이지의 뒤를 따라 연결된 길다란 베란다를 돌아 정면 현관으로 갔다.',
#  '181': '데이지는 마치 자신의 사랑스러운 얼굴을 손으로 느끼기라도 하려는 듯이 두 손으로 얼굴을 감쌌다.',
#  '182': '그녀의 두 눈은 벨벳 색의 어둠 속으로 천천히 움직였다. 그녀가 몹시 흥분한 것처럼 보였다.',
#  '183': '나는 다소나마 그녀를 진정시켜 주고 싶었다. 그래서 그녀의 어린 딸에 대해 이것저것 물어 보았다.',
#  '184': '저는 무슨 일에든지 상당히 냉소적으로 대하는 나쁜 버릇이 생기고 말았죠.',
#  '185': '나는 다음 말을 기다렸지만, 그녀는 더 이상 아무 말도 하지 않았다.',
#  '186': '아이를 낳고 채 한 시간도 지나지 않았는데 탐은 행방을 감추었어요.',
#  '187': '마취에서 깨어나면서 완전히 자포자기해 버린 저는 간호사에게 아들인지 딸인지를 물었어요. 그러자 딸이라고 대답하더군요.',
#  '188': '여자 애라 다행이다. 그러나 좀 멍청해졌으면 좋겠다. 그게 이 세상에서 여자가 될 수 있는 최상의 것이니까.',
#  '189': '"오빠도 알겠지만, 전 이 세상 모든 일이 끔찍하다고 생각해요."그녀는 확신에 찬 목소리로 말을 계속했다.',
#  '190': '그녀의 눈은 탐의 눈과 닮은 도전적인 눈초리로 주위를 둘러보았다. 그러고는 소름 끼치는 자조적인 모습으로 웃어댔다.',
#  '191': '마치 이 저녁이 내게서 어떤 어울릴 감정을 자아내기 위한 술책인 것처럼 여겨져 불안하기만 했다.',
#  '192': '역시 생각한대로 그려는 그 사랑스러운 얼굴에 매우 능글맞은 웃음을 머금고 나를 바라볼 뿐이었다.',
#  '193': '그것은 마치 그녀와 탐이 속한 비교적 유명한 비밀 조직에 가입한 그녀의 회원 자격을 내세우는 듯한 태도였다.',
#  '194': '집 안에서는 진홍색 방이 등불로 눈부시게 빛나고 있었다. 탐과 베이커 양은 긴 의자의 양끝에 앉아 있었다.',
#  '195': '램프의 불빛이 탐의 장화를 밝게 비치고 가을 낙엽같이 노란 베이커 양의 머리도 희미하게 비치고 있었다.',
#  '196': '그녀의 가냘픈 두 팔이 움직이며 잡지를 넘길 때마다 종이도 따라 번득였다.',
#  '197': '우리가 들어서자 그녀는 손을 들어 잠깐 멈춰 있으라고 신호를 보냈다.',
#  '198': '그녀는 잡지를 테이블 위로 던지며 말했다. 그러고는 힘들게 일어섰다.  "10시군요."',
#  '199': '나는 그녀의 얼굴이 어디서 많이 본 듯했던 이유를 이제야 알게 되었다.',
#  '200': '나는 그녀에 대한 몇 가지 비판조의 좋지 않은 얘기도 들은 적이 있지만, 무슨 내용이었는지는 잊어버린 지 오래 되었다.',
#  '201': '별안간 두 사람을 린네르 옷장에 가두어서는 보트에 태워 바다로 띄워 보낸다거나, 뭐 그런 일들 있잖아요?',
#  '202': '"안녕히 주무세요." 베이커 양이 계단을 올라가며 소리쳤다.',
#  '203': '나는 아무 말도 듣지 않았다고 가볍게 받아넘기고 잠시 후 집에 가기 위해 일어섰다.',
#  '204': '기다려요! 뭘 좀 물어 본다는 게 그만 잊고 말았어요, 오빠가 서부에서 약혼을 했다는 얘기가 있던데요.',
#  '205': '"저는 그 소문을 세 사람한테서 들었으니까 사실임에 틀림없어요."',
#  '206': '물론 나도 그들이 무슨 말을 하고 있는지 알고는 있었지만, 나는 약혼 비슷한 것조차 한 적이 없었다.',
#  '207': '내가 동부로 오게 된 이유 중에 하나가 바로 그 소문 때문이었다. 뜬소문 때문에 오랜 친구와 교제를 끊을 수는 없었다.',
#  '208': '탐 부부의 관심은 모름지기 나를 감동시켰고, 그래서 그들이 굉장한 부자가 아닌 것처럼 보이게 했다.',
#  '209': '그럼에도 불구하고 나는 차를 몰면서 머리가 혼란스러워지고 약간 불쾌해지는 것을 느꼈다.',
#  '210': '내 생각에는 데이지가 할 수 있는 최선의 방법은 아이를 안고 그 집에서 뛰쳐나오는 것이었다.',
#  '211': '그것은 마치 그의 건장한 육체적 이기성이 더 이상은 건방진 심성에 자양분을 줄 수 없다는 것을 보이는 것과 같았다.',
#  '212': '길가에 늘어선 집들의 지붕 앞은 이미 여름이 온 듯했고, 빨간색 새 휘발유 펌프들이 한꺼번에 불빛을 받아 근사하게 보였다.',
#  '213': '내 집에 다다른 나는 차를 차고에 집어넣고 나서 마당에 내팽개쳐진 제초기에 잠시 걸터앉았다.',
#  '214': '바람이 불어오자 밤하늘에 나무들이 부딪히는 소리가 요란하게 울려 퍼졌고, 개구리들에게 생명을 가득 불어넣어 주었다.',
#  '215': '달빛 속에 움직이는 고양이 그림자가 아른거리고 있었는데, 고개를 돌렸다가 나는 내가 혼자가 아니었음을 알게 되었다.',
#  '216': '내 이웃의 저택 그늘로부터 어떤 사람의 모습이 손을 주머니에 찔러 넣은 채 은색 후추를 뿌려 놓은 것 같은 별들을 쳐다보고 있었다.',
#  '217': '어딘지 여유 있어 보이는 그 몸놀림과 잔디를 밟고 서 있는 다리의 확고한 자세가 그 사람이 개츠비임을 짐작하게 했다.',
#  '218': '그는 우리 고장의 하늘 중에서 자기 몫의 하늘을 찾아내기 위해 나온 사람처럼 보였다. 나는 그를 부르기로 마음먹었다.',
#  '219': '베이커 양이 저녁 식사 때 그의 얘기를 한 것이 소개 역할을 해 줄 것 같았다. 그렇지만 나는 그를 부르지 않았다.',
#  '220': '나는 그와 멀리 떨어져 있기는 했지만 그가 몸을 떨고 있다는 것을 확실히 알 수 있었다.',
#  '221': '어쩌면 부두의 끝일지도 모를 곳에서 녹색 불빛 하나가 반짝이는 걸 보았을 뿐 다른 것은 전혀 알아볼 수가 없었다.',
#  '222': '내가 다시 개츠비 쪽으로 시선을 돌렸을 때 그의 모습은 어느 새 사라지고 없었다.',
#  '223': '뉴욕으로 가는 중간쯤에서 자동차 도로는 철도 쪽으로 합해져서 4분의 1마일쯤 뻗어 나가다가 어떤 황량한 곳에 이르러 끝난다.',
#  '224': '재가 밀처럼 자라서 산마루도 되고 언덕도 되며 괴이한 정원도 되는 해괴한 농장이다.',
#  '225': '그 곳에서 재는 또 집이나 굴뚝 그리고 피어오르는 연기, 마침내는 어떤 대단한 노력을 거쳐서 잿빛 인간으로까지 변하는 것이다.',
#  '226': '그 인간들은 먼지투성이의 공기 속에서 무기력하게 움직이며 이미 거의 다 쓰러져 가고 있다.',
#  '227': '가끔 뿌연 먼지를 일으키는 차 행렬이 끝없는 도로를 따라 들어와서 소름 끼치는 소리를 내며 멈춰 선다.',
#  '228': '곧 잿빛 사람들이 떼지어 납빛 삽들을 가지고 모여 먼지 구름을 더욱 크게 일으켜 놓았다.',
#  '229': '그 먼지 구름이 그들의 희미한 동작을 가려 버려 우리 눈에는 보이지 않게 한다.',
#  '230': '잿빛 땅과 그 위를 끊임없이 떠도는, 경련적으로 일어나는 먼지 구름 넘어 살며시 박사의 눈이 나타난다.',
#  '231': '푸른빛을 띤 데다 위압감이 느껴질 정도로 큰 눈이 보인다.',
#  '232': '그 눈은 있지도 않은 콧등에 가로 걸려 있는 어마어마한 노란색 안경 너머로 이 쪽을 보고 있다.',
#  '233': '어떤 뻔뻔한 안과 의사가 퀸즈 구에서 거창하게 병원을 차리려고 그 곳에 설치해 놓았던 것이다.',
#  '234': '그 자신이 영원히 미지의 세계로 사라져 버렸거나 아니면 그 선전 간판을 설치해 놓았다는 사실을 잊어버리고 이사를 한 것이리라.',
#  '235': '그 눈은 세월이 흐르는 동안 햇빛과 비에 시달려 좀 흐려진 채 이 엄숙한 쓰레기 하치장을 아직도 의연하게 내려다보고 있다.',
#  '236': '화물선이 지나갈 수 있게 다리가 올라갈 때면 기차 안의 승객들은 길게는 30분 동안이나 그 광경을 지켜보면서 기다려야 했다.',
#  '237': '기차는 그 곳에서 이런 일이 아니더라도 1분간은 정차해 있었다.',
#  '238': '내가 탐 부캐넌의 정부를 처음으로 만나게 된 것도 이 때였다.',
#  '239': '탐에게 정부가 한 명 있다는 사실은 그가 나타나는 곳이라면 어디서든 화제가 되었다.',
#  '240': '그를 아는 사람들은 그가 정부를 데리고 대중 카페에 나타나  잡담 나누는 모습을 좋은 시선으로 보아주지 않았다.',
#  '241': '나는 그 여자를 한 번 보고 싶었지만 일부러 만나고 싶은 생각은 없었다. 그러나 나는 그녀를 만났다.',
#  '242': '기차가 잿더미 곁에 정차하자 탐은 벌떡 일어나더니 내 팔꿈치를 잡고서 막무가내로 나를 차에서 내리게 했다.',
#  '243': '그는 점심때 뭘 잘 먹은 모양이었다. 그리고 나를 대하는 모습은 거의 폭력에 가까웠다.',
#  '244': '그는 마침 일요일 오후라 내게 별다른 일이 없을 것이라고 멋대로 생각했던 것이다.',
#  '245': '나는 그를 따라 하얗게 칠한 나지막한 철로변 담을 넘었고, 박사의 끈질긴 시선을 받으며 기차를 타고 왔던 길을 되돌아갔다.',
#  '246': '건물이라고는 오직 그 황무지 가장자리에 서 있는 조그맣고 노란 벽돌 건물뿐이었다.',
#  '247': '그것은 이 황무지에 자리한 일종의 압축된 중심가라고 할 수 있는 것이었다.',
#  '248': '건물에는 가게가 있었는데, 하나는 야간 영업 레스토랑이었으며, 나머지 하나는 자동차 수리소였다.',
#  '249': '안은 생각보다 초라하고 썰렁했다. 보이는 것이라곤 어두운 구석에 처박혀 있는, 먼지투성이의 고물 포드 승용차 한 대뿐이었다.',
#  '250': '사치스럽고 로맨틱한 아파트가 위층에 감추어져 있을지도 모른다는 생각이 문득 떠올랐다.',
#  '251': '그 때 정비소 주인이 헝겊 조각으로 손을 닦으며 사무실 문간에 나타났다.',
#  '252': '금발의 그는 건강이 좋지 않은지 생기가 없어 보였으며 윤곽만은 제법 뚜렷한 미남이었다.',
#  '253': '우리를 본 그의 연푸른 두 눈에 흐릿한 희망의 빛이 스쳐 지나갔다.',
#  '254': '탐이 활기에 찬 목소리로 그의 어깨를 두드리며 말했다.',
#  '255': '"그저 그렇습니다."  윌슨이 힘없는 목소리로 대답했다.',
#  '256': '그런데 당신이 그렇게 생각하고 있다면 차라리 어디 다른 곳에다 파는 게 낫겠소',
#  '257': '잠시 후 좀 뚱뚱해 보이는 여자가 사무실 문으로 새어 나오는 불빛을 막아버렸다.',
#  '258': '30대 중반으로 보이는 그녀는 좀 뚱뚱하긴 했지만 관능적인 몸매를 지니고 있었다.',
#  '259': '짙푸른 점무늬의 크레프드신 드레스 위로 솟은 얼굴은 아무리 뜯어 봐도 평범할 뿐이었다.',
#  '260': '온몸의 신경이 끊임없이 불에 그을리고 타고 있기라도 한 것처럼 어디서나 눈에 띌 정도로 몸 전체에 생기가 흘러 넘쳤다.',
#  '261': '"의자라도 가져와요. 왜 가만히 있어요? 그래야 손님이 앉으실 수 있잖아요?"',
#  '262': '윌슨은 황급히 대답하고 나서 벽의 시멘트 색깔과 섞여 사라지듯이 조그마한 사무실 쪽으로 갔다.',
#  '263': '하얀 재먼지가 주변의 모든 것을 먼지로 덮어 버린 것과 마찬가지로 윌슨의 검정색 양복과 연한 빛의 머리칼도 먼지로 덮여 있었다.',
#  '264': '탐 곁에 바싹 다가와 있는 그의 아내만은 예외였다. "만나고 싶소." 탐이 은근한 목소리로 말했다.',
#  '265': '고개를 끄덕인 그녀가 의미심장한 웃음을 지으며 다가가자마자 조지 윌슨이 의자 두 개를 가지고 나타났다.',
#  '266': '우리는 길 아래쪽에서 남의 눈에 띄지 않게 그녀를 기다렸다. 그 날은 독립기념일인 7월 4일을 며칠 앞둔 날이었다.',
#  '267': '회색 옷을 입은 바싹 마른 이탈리아계 어린애가 철로 위에 딱총알을 일렬로 올려놓고 있었다.',
#  '268': '"지독한 동네군. 그렇지 않아?" 하고 탐이 얼굴을 찡그리고 박사의 얼굴을 쳐다보며 말했다.',
#  '269': '윌슨 말인가? 그는 아내가 뉴욕에 있는 처제를 만나러 가는 걸로 알고 있지. 너무 멍청해서 자기가 살아 있다는 것조차도 모르고 있어.',
#  '270': '이리하여 탐 부캐넌과 그의 정부, 그리고 나 이렇게 세 사람은 함께 뉴욕으로 갔다.',
#  '271': '정확하게 말하면 함께 갔다고는 할 수 없다. 왜냐하면 윌슨 부인은 다른 사람들의 눈을 피해 다른 칸에 앉아 있었기 때문이다.',
#  '272': '탐은 혹시 그 기차에 탔을지도 모를 이스트에그 사람들의 구설수에 그만큼 신경을 썼던 것이다.',
#  '273': '윌슨 부인은 모슬린 드레스로 갈아입고 있었는데, 탐의 부축을 받아 플랫폼에 내렸을 때 그 옷은 비교적 꽉 끼어 불편하게 보였다.',
#  '274': "그녀는 신문 판매점에서 '타운태틀'지 1부와 영화 잡지 1권, 그리고 역의 약국에서 콜드크림과 조그만 병에 든 향수를 샀다.",
#  '275': '차에 오른 우리는 혼잡한 역을 빠져나가 이글거리는 햇볕 속으로 미끄러져 들어갔다.',
#  '276': '창문으로 바깥을 내다보고 있던 그녀가 갑자기 몸을 홱 돌려 앞으로 굽히고는 차창을 두드리며 말했다.',
#  '277': '"저런 강아지를 한 마리 갖고 싶어요." 그녀는 진지하게 말했다.',
#  '278': '"평소부터 아파트에 한 마리 기르고 싶었어요. 멋진 일이잖아요, 강아지를 한 마리 기른다는 건 말이에요."',
#  '279': '노인의 목에 매달린 바구니 안에는 태어난 지 얼마 되지 않은 혈통 좋은 강아지 10여 마리가 웅크리고 있었다.',
#  '280': '노인은 고개를 갸우뚱하며 바구니 속을 들여다보고는 손을 집어넣어서 한 마리의 강아지 뒷덜미를 잡아 끌어올렸다.',
#  '281': '그 강아지는 두려운 듯 바둥거리고 있었다. "그건 경찰견이 아니오."',
#  '282': '노인은 한 손으로 갈색 타월처럼 부드러운 강아지의 등을 쓰다듬었다.',
#  '283': '이 털을 좀 보세요. 대단하지요. 잔병치레로 주인을 성가시게 할 개는 결코 아닙니다.',
#  '284': '우리는 5번가 쪽으로 달렸다. 따뜻하고 온화한 여름철의 일요일 오후였다.',
#  '285': '하얀 양떼가 그 거리의 모퉁이를 돌아다닌다 하더라도 나는 놀라지 않았을 것이다.',
#  '286': '"자네가 아파트까지 같이 가지 않는다면 머틀이 기분 나빠할 걸. 안 그렇소, 머틀?"',
#  '287': '"제 동생 캐서린에게 전화하겠어요. 주위에 있는 사람들은 그 애가 아주 예쁘다고 칭찬을 하지요."',
#  '288': '우리가 이야기를 하고 있는 사이 차는 다시 한 번 센트럴 파크를 가로질러서 웨스트헌드리즈 가 쪽으로 가고 있었다.',
#  '289': '택시는 158번가에서 멋지게 생긴 아파트 단지로 들어가더니 한 동 앞에 멈춰 섰다.',
#  '290': '윌슨 부인은 외출에서 돌아온 사람처럼 주위를 한 바퀴 둘러본 후, 강아지와 그밖에 사 온 물건들을 들고 거만스럽게 안으로 들어갔다.',
#  '291': '그녀의 아파트는 꼭대기 층에 있었는데, 자그마한 거실과 식당, 침실 그리고 욕실로 나누어져 있었다.',
#  '292': '갖가지 무늬를 한 양탄자가 깔려 있는 거실에는 방에 비해 너무 큰 가구들이 문 앞을 가로막고 있었다.',
#  '293': '방안을 거닐다 보면 양탄자에 그려진 베르사유 궁전의 정원에서 그네를 타는 귀부인들 위를 넘어가는 것 같은 착각에 빠지게 했다.',
#  '294': '유일하게 걸려 있는 그림은 커다랗게 확대시킨 사진이었는데, 선명하지는 않지만 바위에 앉아 있는 암탉을 찍은 것이었다.',
#  '295': '그 암탉은 부인용 보네트처럼 보이기도 하고 비대하게 생긴 노부인이 빙그레 웃으며 방 안을 내려다보는 그림처럼 보이기도 했다.',
#  '296': '그 중 한 개의 비스켓은 우유잔에 담겨져 오후 내내 풀어질 대로 풀어지고 있었다.',
#  '297': '그 동안 탐은 잠겨 있던 장식장 문을 열고 위스키 한 병을 꺼냈다.',
#  '298': '나는 지금까지 취한 적이 딱 두 번 있었는데, 그 두 번째가 바로 이 날이었다.',
#  '299': '오후 8시가 넘도록 따사로운 햇볕이 아파트 안을 가득 채우고 있었다.',
#  '300': '그의 무릎에 걸터앉은 윌슨 부인은 전화로 사람들을 초대했다.',
#  '301': '나는 마침 담배가 떨어져서 길모퉁이에 있는 약국으로 담배를 사러 나갔다.',
#  '302': "나는 거실에 다소곳이 앉아 '사이먼은 피터를 불렀다'라는 책의 첫장을 폈다.",
#  '303': '책이 형편없는 것이어서인지 아니면 위스키가 정신을 흐려 놓아서인지는 모르나, 그 책의 내용을 전혀 파악할 수 없었다.',
#  '304': '탐과 머틀이 잠시 후 나타났고, 이어서 손님들이 하나둘 도착하기 시작했다.',
#  '305': '캐서린은 가냘프고 고생을 많이 한 것 같아 보이는 30세 가량의 여자로, 붉은색 단발머리에 얼굴에는 화장을 진하게 하고 있었다.',
#  '306': '눈썹을 모두 뽑고 보다 더 요염하게 그리려 노력했지만, 그 노력은 얼굴의 분위기를 깨뜨리는 결과가 되고 말았다.',
#  '307': '몸을 움직일 때마다 양팔에 가득 찬 사기 팔찌들이 달그락거렸다.',
#  '308': '그녀는 마치 이 아파트의 주인이라도 되는 것처럼 가구에 이상이 없는지 일일이 둘러보기 시작했다.',
#  '309': '내가 그것에 대해 묻자, 그녀는 호들갑스럽게 웃고 나서 자기는 여자 친구와 호텔에서 살고 있다고 말했다.',
#  '310': '아래층에 산다는 머키는 얼굴이 창백하고 여성적인 사람이었다.',
#  '311': '그는 면도를 하다가 왔는지 광대뼈에 하얀 비누 거품이 묻어 있었다.',
#  '312': "방안에 있는 사람들에게 일일이 정중하게 인사를 한 그는 나에게 자신은 '예술업'에 종사하고 있다고 말했다.",
#  '313': '나는 나중에야 그가 사진작가이며, 벽에 붙어 있는 윌슨 부인 어머니의 희미한 확대 사진도 그의 작품이라는 것을 알게 되었다.',
#  '314': '그의 아내는 호감가는 가냘픈 외모에 날카로운 목소리를 가졌는데 인상이 날카로워 보였다.',
#  '315': '그녀는 자기 남편이 결혼한 이후로 자기 사진을 127장이나 찍어 주었다고 나에게 자랑스럽게 말했다.',
#  '316': '윌슨 부인은 다시 옷을 갈아 입었는데, 이번에는 크림색 드레스였다.',
#  '317': '그 드레스는 그녀가 방안을 돌아다닐 때마다 바스락 소리를 내었기 때문에 그녀의 품위마저 달라 보이게 했다.',
#  '318': '자동차 수리소에서 보여 주었던 그녀의 온몸에 넘쳐 흐르던 생기가 이제는 인상적인 거만스러움으로 바뀌어 있었다.',
#  '319': '그녀의 웃음소리와 몸놀림, 그리고 고집 센 말투는 시간이 갈수록 격렬해졌다.',
#  '320': '그녀의 존재가 커져 감에 따라 그녀를 중심으로 한 방은 점점 더 작아졌다.',
#  '321': '기가 자욱한 방안에서 그녀는 시끄럽게 삐그덕거리는소리를 내는 회전축 위에서 빙빙 돌고 있는 것처럼 보였다.',
#  '322': '돈밖에 모르는 그런 사람들은 곧 너를 배신할 거야. 지난 주에 난 어떤 여자를 이 곳으로 불러 발을 진찰받았어.',
#  '323': '윌슨 부인은 경멸하듯이 눈썹을 치켜 뜸으로써 그 칭찬을 무시했다.',
#  '324': '"이건 유행이 지난 옷이에요. 내가 외모에 신경을 쓸 필요가 없을 때 가끔씩 걸쳐 입는 옷이지요."',
#  '325': '"그래도 당신이 입으니까 잘 어울려요. 인사치레로 하는 이야기가 아니라구요." 머키 부인은 계속 물고 늘어졌다.',
#  '326': '"만약 그런 포즈를 취하고 있는 당신을 체스터가 찍기만 한다면 무척 훌륭한 작품이 될 거에요."',
#  '327': '우리 모두는 말없이 윌슨 부인을 바라보았다. 그녀는 눈을 가렸던 머리카락을 쓸어 올리고는 환한 미소를 띠며 시선을 맞추었다.',
#  '328': '머키는 고개를 갸우뚱거리면서 그녀를 유심히 바라보았다. 그러더니 곧 한 손을 자기 얼굴 앞에서 서서히 앞뒤로 움직였다.',
#  '329': '"얼굴 윤곽을 분명하게 나타내고 싶으니까. 그리고 뒤의 머리카락도 모두 담도록 해야겠어."',
#  '330': '우리는 일제히 윌슨 부인을 바라보았는데, 그 때 탐 부캐넌이 큰 하품을 하면서 일어났다.',
#  '331': '머틀, 모두들 잠들어 버리기 전에 얼음하고 생수를 좀더 가져와요.',
#  '332': '머틀은 아랫사람들의 게으름에 진절머리가 난다는 듯 이맛살을 찌푸렸다.',
#  '333': '정말이세요? 전 한 달쯤 전에 파티가 있어서 거기에 갔었는데, 개츠비라는 분의 저택이었지요.',
#  '334': '그분은 빌헬름 황제의 조카 아니면 사촌일 거라는 소문이 있던데요. 그분의 돈 전부가 거기서 온다는 거예요.',
#  '335': '전 그분이 왠지 기분 좋지 않아요. 그런 사람이 저에게 어떤 관심을 보이는 것은 질색이에요.',
#  '336': '내 이웃에 관한 이 흥미로운 정보는 머키 부인이 갑자기 캐서린을 가리키며 말을 꺼내는 바람에 끊어지고 말았다.',
#  '337': '"체스터, 제 생각으로는 이분의 사진도 찍었으면 좋겠는데요."',
#  '338': '그녀가 불쑥 말을 꺼냈으나 머키는 귀찮다는 듯이 고개만 끄덕이고 관심을 탐에게 돌려 버렸다.',
#  '339': '기회가 주어지면 롱아일랜드에서 일을 더 하고 싶습니다. 내가 바라는 것은 나에게 일을 시작할 기회를 주었으면 하는 것뿐입니다.',
#  '340': '탐은 윌슨 부인이 쟁반을 들고 들어오자 갑자기 웃음을 터뜨렸다.',
#  '341': '이 사람이 소개장을 써 줄 겁니다. 그렇지 않소, 머틀?',
#  '342': '당신 남편에게 머키 씨를 소개하는 편지를 써 주구려. 그러면 머키 씨는 그 사람을 모델로 해서 작품을 만들 수 있을 테니까 말이요.',
#  '343': '뭔가 좋은 문구를 생각해 내려는 듯이 탐의 입술은 잠시 조용히 움직였다.',
#  '344': '캐서린은 내게로 몸을 바짝 기울이고는 귓속말로 속삭였다.',
#  '345': '언니나 저분은 둘 다 결혼해서 살고 있는 상대에 대해 못마땅해하고 있어요.',
#  '346': '제가 하고 싶은 말은 서로 참고 견딜 수가 없을 정도이면 무엇하러 계속 같이 사느냐 하는 거예요.',
#  '347': '이 물음에 대한 대답은 뜻밖의 사람한테서 들을 수 있었다.',
#  '348': '캐서린이 의기양양하게 소리치고는 다시 목소리를 낮추어 말했다.',
#  '349': '두 사람을 떼어 놓고 있는 사람은 탐의 부인이에요. 그녀는 카톨릭 신자인데, 카톨릭에서는 이혼을 인정하지 않거든요.',
#  '350': '데이지는 카톨릭 신자가 아니라는 사실을 알고 있었으므로 나는 이 완전한 거짓말에 약간 충격을 받았다.',
#  '351': '그 일이 잊혀질 때까지 한동안 서부에 가서 살 거예요.',
#  '352': '전 몬테카를로에서 돌아온 지 얼마 안 되었어요.',
#  '353': '아니에요. 우린 그저 몬테카를로만 다녀왔어요. 마르세유를 거쳐서 갔었지만요.',
#  '354': '출발할 때는 1,200달러 이상 갖고 있었지만, 그 곳의 도박장에서 이틀 만에 몽땅 잃고 말았어요.',
#  '355': '거짓말이 아니에요. 그 때문에 돌아올 때 얼마나 고생을 했는지 그래서 아직도 몬테카를로라면 소름이 끼쳐요.',
#  '356': '늦은 오후의 하늘은 지중해의 푸른 바다색으로 잠시 창문에 머물렀다.',
#  '357': '그때 머키 부인의 날카로운 목소리가 나서 나는 정신을 차렸다.',
#  '358': '몇 해 동안이나 제 뒤를 쫓아다니던 조그만 애송이와 하마터면 결혼할 뻔했던 거죠.',
#  '359': "주위에서도 '루실, 그 사람은 너보다 훨씬 못한 남자야!' 하고 모두들 늘 말했어요.",
#  '360': '제가 체스터를 만나지 않았더라면, 그는 틀림없이 저를 차지했을 거예요.',
#  '361': '바로 그것이 당신 경우와 내 경우의 다른 점이지요.',
#  '362': '그 사람을 신사라고 생각했기 때문에 난 그와 결혼했던 거야.',
#  '363': '교양이 무엇인지를 조금은 알고 있다고 생각했지. 그런데 그것은 내 착각이었어.',
#  '364': '내가 그 사람한테 빠졌었다고 말을 한 게 누구지? 나는 누구에게 미칠 정도로 사랑에 빠진 적이 없어.',
#  '365': '나는 그녀의 관심 따위는 기대하고 있지 않다는 것을 얼굴에 나타내려고 애썼다.',
#  '366': '내가 단 한 번 미친 듯이 그에게 반했던 것은 결혼식 때였어. 그러나 나는 곧 내가 실수했음을 깨닫게 되었지.',
#  '367': '그는 결혼식 때 다른 사람의 양복을 빌려 입었으면서도 나에게 그런 얘기는 한 마디도 하지 않았어.',
#  '368': '하루는 그가 외출했을 때 그 옷 임자가 빌려 준 옷을 찾으러 왔어.',
#  '369': '나는 그 옷을 임자에게 돌려 주고는 오후 내내 침대에서 한없이 울었어.',
#  '370': '나는 밖으로 나가 부드러운 황혼 속의 공원을 향해 동쪽으로 걷고 싶었다.',
#  '371': '나오려고 할 때마다 요란하고도 귀에 거슬리는 말다툼에 휘말려 마치 밧줄에 매여 끌리듯 다시 제자리로 되돌아오게 되었다.',
#  '372': '난 이상하다는 듯이 올려다보고 있는 그 사람을 보았다.',
#  '373': '나는 인생의 무한한 다양성에 이끌림과 동시에 반발도 하면서 창문 안팎으로 방황을 했다.',
#  '374': '갑자기 탑을 처음 만났을 때의 이야기를 나에게 하기 시작했다.',
#  '375': '우리가 처음 만난 것은 언제나 맨 마지막까지 빈자리로 남아 있던, 마주 보고 있는 두 개의 작은 의자에서였어요.',
#  '376': '전 뉴욕으로 와서 동생을 만나고 그날밤은 여기서 묵을 생각이었지요.',
#  '377': '그이는 야회복에 에나멜 구두를 신고 있었는데 전 그이에게서 눈을 뗄 수가 없었어요.',
#  '378': '그이가 저를 바라볼 때마다 저는 탐의 머리 위쪽의 광고를 보고 있는 척해야만 했어요.',
#  '379': '우리가 뉴욕 역에 도착했을 때, 그리는 바로 제 곁에 서 있었는데, 그이의 흰 셔츠의 가슴 부분이 제 팔을 눌렀어요.',
#  '380': '전 그이에게 순경을 부르겠다고 말했지요.',
#  '381': '그이는 제가 절대 그런 행동을 하지 않을 것을 알고 있었어요.',
#  '382': '전 너무 흥분했던 탓이 그이와 함께 택시를 탔을 때도 거의 알아채지 못했어요.',
#  '383': "제가 그때 머릿속으로 되풀이해서 생각한 것은 '어차피 영원히 사는 것도 아닌데...'라는 말뿐이었어요.",
#  '384': '그녀가 머키 부인을 돌아보자 방안은 온통 머키 부인의 부자연스런 웃음소리로 가득 찼다.',
#  '385': '이 드레스를 오늘 벗는 대로 당신에게 줄게요. 내일 다른 것을 사면 되니까.',
#  '386': '난 마련해야 할 물건의 목록을 만들려고 해요.',
#  '387': '목록을 만들어서 사야 할 물건을 잊어버리지 않도록 해야겠어요.',
#  '388': '9시였다, 그리고 얼마 되지 않아 다시 내 손목 시계를 보니 10시를 가리키고 있었다.',
#  '389': '머키는 꽉 쥔 두 주먹을 무릎 위에 얹은 재 사진 속의 모델처럼 의자에서 잠들어 있었다.',
#  '390': '나는 손수건을 꺼내 오후 내내 나의 마음을 거슬리게 했던, 그의 광대뼈 위에 말라붙은 비누 거품을 닦아 주었다.',
#  '391': '강아지는 테이블 위에 앉아서 자욱한 연기 때문에 잘 보이지 않는지 사방을 두리번거리며 이따금씩 나직하게 낑낑거리고 있었다.',
#  '392': '탐은 빠르고 익숙하게 그 큰 손으로 그녀의 코를 후려쳤다.',
#  '393': '욕실 바닥에 피투성이의 타월들이 쌓이고 여자들의 아우성이 들렸다.',
#  '394': '그 소리보다 한층 높게 고통을 호소하며 울부짖는 소리가 들렸다.',
#  '395': '나는 샹들리에에 걸어 두었던 모자를 집어 들고 그의 뒤를 따라갔다.',
#  '396': '나는 펜실베니아 역의 아래층 플랫폼에 쪼그리고 앉은 채 신문을 들여다보며 4시에 떠날 기차를 기다리고 있었다.',
#  '397': '여름 밤, 개츠비의 집에서는 날마다 흥겨운 음악 소리가 났다.',
#  '398': '그의 푸른 정원에서는 남녀들이 속삭임과 샴페인, 별들 사이를 바쁘게 오가곤 했다.',
#  '399': '그의 이름으로 되어 있는 해변의 뜨거운 모래 위에서 일광욕을 하고 있는 것을 바라보았다.',
#  '400': '그의 두 척의 모터보트는 바다 위에 떠 물살을 가르며 하얀 물거품 위로 수상 스키를 끌고 달렸다.',
#  '401': '주말이면 그의 롤즈로이스 승용차가 아침 9시부터 한밤중까지 시내를 왔다갔다하면서 손님들을 실어 날랐다.',
#  '402': '스테이션왜건은 모든 기차를 마중 나가려고 마치 활기찬 투구벌레처럼 지칠 줄 모르고 돌아다녔다.',
#  '403': '월요일에는 임시로 고용된 정원사까지 합쳐 모두 8명의 고용인이 간밤에 손상된 부분을 손질하느라고 하루 종일 힘들게 돌아다녔다.',
#  '404': '매주 금요일마다 뉴욕의 청과물점으로부터 다섯 상자의 오렌지와 레몬이 도착했다.',
#  '405': '월요일이면 이 오렌지와 레몬은 알맹이가 없는 껍질이 되어서 피라미드 모양으로 쌓인 채 저택 뒷문으로 사라졌다.',
#  '406': '부엌에는 엄지손가락으로 조그만 단추를 누르기만 하면 30분 만에 200개의 오렌지 주스를 짜낼 수 있는기계 한 대가 설치되어 있었다.',
#  '407': '뷔페 식탁에는 구운 햄, 오색으로 만든 샐러드, 밀가루를 씌워 누런색으로 구운 통돼지와 칠면조 들이 가득 놓여 있었다.',
#  '408': '중앙에는 진짜 놋쇠 난간의 바가 마련되어 있었고, 갖가지의 독한 진이나 위스키들이 진열되어 있었다.',
#  '409': '너무 오랫동안 금주법으로 잊혀졌기 때문에 대부분의 여자 손님들은 나이가 어려 그 종류를 구별해 내지 못했다.',
#  '410': '늦게까지 수영을 하던 사람들도 이제는 바닷가에서 돌아와 이층에서 옷을 갈아 입고 있었다.',
#  '411': '택 안의 주차장에는 뉴욕에서 온 차들이 다섯 줄로 질서정연하게 주차해 있었다.',
#  '412': '카스틸의 꿈도 무색한 호화로운 숄을 두른 사람들로 북적댔다.',
#  '413': '바에서는 이제 분위기가 무르익었고, 여러 차례 반복되고 있는 칵테일 쟁반의 서비스가 정원 바깥까지 이어지고 있었다.',
#  '414': '부담없이 즐길 수 있는 풍자와 인사 소개가 간단히 행해졌으며, 서로 이름도 모르는 여자들끼리의 열띤 이야기가 시작되었다.',
#  '415': '밤이 깊어 감에 따라 불빛은 더욱 밝아져 갔다.',
#  '416': '오케스트라는 대중적인 혼합곡을 연주하고 오페라 같은 사람들의 이야기 소리는 한 옥타브 더 높아졌다.',
#  '417': '웃음 소리는 시간이 갈수록 커졌으며 자주 들려 왔다.',
#  '418': '모인 사람들이 빠른 속도로 바뀌었으며 새로 온 사람들로 모임이 흩어졌다가는 곧 다시 모이곤 했다.',
#  '419': '오케스트라 지휘자가 친절하게도 그녀의 춤에 맞는 곡으로 바꾸어 연주하기 시작했다.',
#  '420': '내가 개츠비의 저택에 처음으로 간 날 밤, 나는 초대된 몇몇 손님 가운데 하나라 믿고 있었다.',
#  '421': '상당수의 사람들은 초대를 받은 것이 아니었다. 그들은 그냥 그의 저택으로 왔던 것이다.',
#  '422': '롱아일랜드로 오는 자동차를 타고 있다 보니 개츠비의 저택 앞에서 차가 섰던 것이다.',
#  '423': '그 다음부터는 오락 유원지에서 지키면 되는 정도의 행동 규칙에 따라 스스로가 행동하게 되었다.',
#  '424': '그들은 때론 개츠비를 만나 보지도 않은 채 돌아갔고, 단지 파티가 좋아서 오는 솔직한 마음이 초대장의 역할을 할 뿐이었다.',
#  '425': '거기에는 그 날 밤의 조촐한 파티에 내가 참석해 주면 자기에게 다시 없는 영광이 될 것이라고 씌여 있었다.',
#  '426': '오래 전부터 찾아갈 계획을 세웠으나 그 때마다 사정들이 생겨 기회를 놓쳐 버렸다고 적고 있었다.',
#  '427': '끝에는 위엄 있는 필적으로 제이 개츠비라고 서명되어 있었다.',
#  '428': '7시가 조금 지나서 나는 차려 입고 그의 저택 잔디밭으로 건너가서 낯선 사람들 틈에 끼여 다소 어색한 모습으로 서성거렸다.',
#  '429': '실은 통근 기차에서 본 적이 있는 얼굴들도 많이 보였다.',
#  '430': '나는 파티장에 영국계 청년들이 여러 명 눈에 띈 것에 대해 놀라워했다.',
#  '431': '그들은 옷을 잘 차려 입고 무게 있고 돈이 있어 보이는 미국인들과 나지막하나 열띤 목소리로 이야기를 나누고 있었다.',
#  '432': '나는 그들이 채권이나 보험 증권이나 자동차 같은 것을 팔고 있는 중이라고 확신했다.',
#  '433': '그들 영국인들은 손쉽게 벌어들일 수 있는 돈이 근처에 있다는 것을 분명하게 인식하고 있었다.',
#  '434': '적절한 음조로 말 몇 마디만 하면 그 돈은 자기들의 것이 될 것으로 확신하고 있는 것 같았다.',
#  '435': '나는 그 집에 도착하자마자 개츠비를 만나 보려 했다.',
#  '436': '나로부터 그가 있는 곳을 묻는 말을 들은 두서너 사람은 아주 놀란 얼굴로 나를 빤히 쳐다보면서 모른다고 고개를 흔들었다.',
#  '437': '그 바람에 나는 칵테일 테이블 쪽으로 슬금슬금 다가갔다.',
#  '438': '그 곳은 목적도 없고 혼자라는 기색을 보이지 않고 남자 혼자 서성거릴 수 있는, 정원 속의 유일한 장소였기 때문이다.',
#  '439': '도무지 어색한 분위기를 참을 수 없어 나는 술에라도 취해 떠들어 대려고 했다.',
#  '440': '그녀가 집 안에서 나와 대리석 계단 꼭대기에 서서는 몸을 약간 뒤로 젖힌 채 경멸에 찬 눈빛을 보이며 정원을 내려다보고 있었다.',
#  '441': '지나가는 사람들에게 아는 척이라도 하기 위해서는 우선 나는 상대방이 좋아하든 말든 사람들과 어룰릴 필요가 있다고 생각했다.',
#  '442': '나는 그녀 쪽으로 걸어가면서 소리를 질렀다.',
#  '443': '내 목소리는 부자연스러울 정도로 크게 정원 밖으로 퍼져 나가는 것 같았다.',
#  '444': '그녀는 내가 다가가자 별로 관심이 없다는 말투로 대꾸했다.',
#  '445': '그녀는 조금 있다가 챙겨 주겠다는 약속처럼 내 손을 잡고는 계단 밑에 와서 멈추어 선 두 아가씨의 말에 귀를 기울였다.',
#  '446': '그것은 골프 시합에 관한 인사였다. 그녀는 지난 주 결승전에서 지고 말았던 것이다.',
#  '447': '하지만 우리는 한 달쯤 전에 여기서 당신을 뵈었어요.',
#  '448': '나는 걷기 시작했다. 아가씨들은 이미 나보다 먼저 앞으로 걸어가 버려 조던의 말은 허공을 향해 중얼거리는 넋두리가 되고 말았다.',
#  '449': '조던은 가냘프고 금빛이 도는 팔로 내 팔을 잡았다.',
#  '450': '리는 자연스럽게 팔짱을 낀 채 계단을 내려와 정원의 구석구석을 돌아다녔다.',
#  '451': '칵테일 쟁반이 우리에게로 전달되었고, 우리는 두 아가씨와 또 다른 세 남자와 함께 같은 테이블에 자리를 잡고 앉았다.',
#  '452': '그 남자들은 멈블 씨라고 소개되었다.',
#  '453': '얼마 전 당신을 만난 파티가 최근에 참석한 파티예요.',
#  '454': '그 아가씨가 빠르면서도 자신에 찬 말투로 대답했다. 그리고 그녀는 자기 친구를 돌아다보며 물었다.',
#  '455': '저는 아주 자연스럽게 생활하지요. 그래서 언제나 즐겁지요. 지난번 파티에서 제 가운이 의자에 걸려 찢어졌었지요.',
#  '456': '오늘 밤에 입고 올 생각이었는데 가슴 둘레가 너무 커서 수선을 부탁했어요.',
#  '457': '라벤더빛 구슬이 달린, 파란 가스 빛 드레스인데 265달러나 하는 것이라나봐요.',
#  '458': '그런 식으로 호의를 지나치게 보이는 사람은 어딘지 이상한 데가 있어요.',
#  '459': '두 아가씨와 조던은 친근한 듯 서로 몸을 기댔다.',
#  '460': '누가 그러던데 말이에요, 사람들은 그분이 전에 사람을 죽인 적이 있대요.',
#  '461': '순간 모두가 몸서리를 쳤다. 세 명의 멈블 씨는 몸을 앞으로 굽히고 좀더 자세히 듣기 위해 열심히 귀를 기울였다.',
#  '462': '루실이 의심스럽다는 듯이 말하고 나섰다.',
#  '463': '그보다는 전쟁중에 독일의 스파이였을 가능성이 더 많아.',
#  '464': '세 남자 가운데 한 명이 고개를 끄덕였다.',
#  '465': '나도 그 사람에 대한 이야기를 많이 들었는데 그와 함께 독일에서 자란 사람에게서 들었습니다.',
#  '466': '그럴 리가 없어요. 왜냐하면 그분은 전쟁중에 계속 미국에 있었으니까요.',
#  '467': '우리가 자기의 말을 믿는 눈치를 보이자 그녀는 몸을 앞으로 굽히며 한층 강한 어조로 말을 이었다.',
#  '468': '아무도 자신을 보고 있지 않다고 생각할 때 그분을 한 번 쳐다보세요. 사람을 죽인 것임에 틀림없어요.',
#  '469': '우리는 누가 먼저랄 것 없이 모두 몸을 돌려 주위를 둘러보며 개츠비를 찾았다.',
#  '470': '개츠비 자신이 남들에게 그런 낭만적인 억측을 하도록 충동질했다는 증거이다.',
#  '471': '첫 번째 저녁 식사가 막 차려지고 있을 때 조던이 자기의 일행과 함께 식사를 하자고 초대했다.',
#  '472': '그들은 정원의 한쪽 구석에 있는 테이블에 둘러앉아 있었다.',
#  '473': '그 대학생은 조만간에 그녀가 자기에게 몸을 내맡기게 될 것이라는 생각을 갖고 있는 듯했다.',
#  '474': '그 일행은 이리저리 돌아다니는 대신 한결같이 위엄 있는 자세를 취하면서 고상한 척 거만을 떨었다.',
#  '475': '따분하고 어색한 시간이 30분쯤 지났을 때 조던이 귓속말로 말했다.',
#  '476': '우리는 자리에서 일어났다. 조던은 지금부터 우리는 이 집 주인을 찾으러 간다는 설명을 했다.',
#  '477': '그녀는 내게 주인을 만난 적이 없기 때문에 불안해하는 것 같다고 덧붙여 말했다.',
#  '478': '그 대학생은 냉소적이며 침울한 표정으로 고개를 끄덕였으나 여전히 못마땅한 표정을 하고 있었다.',
#  '479': '우리는 먼저 바를 둘러보았는데, 그 곳은 사람들로 붐볐지만 개츠비는 없었다.',
#  '480': '그녀는 계단 꼭대기에서도 그를 찾아 내지 못했다.',
#  '481': '베란다에도 그는 없었다. 그러다 우리는 우연히 묵직해 보이는 문을 열고 천장이 높은 고딕 서재로 들어갔다.',
#  '482': '그 방의 벽은 조각이 된 영국산 참나무 널빤지로 되어 있었다.',
#  '483': '안경을 쓴 건장한 중년 남자가 술에 약간 취한 듯 커다란 테이블 모서리에 걸터앉아서 서가들을 불안한 눈초리로 응시하고 있었다.',
#  '484': '우리가 안으로 들어가자 그는 당황한 듯 몸을 홱 돌리더니 조던을 아래위로 훑어보았다.',
#  '485': '그는 서가를 향해 손을 흔들며 말했다.',
#  '486': '저것에 대해서 말이요. 당신이 일부러 확인하려고 신경 쓸 필요는 없어요. 내가 확인했으니까. 저것들은 진짜요.',
#  '487': '우리가 의아해하는 것을 당연하다고 생각했는지 그는 서가로 달려가더니책 한권을 들고 돌아왔다.',
#  '488': '이건 진짜 인쇄물입니다. 이게 날 우롱했어요. 이것은 진짜입니다.',
#  '489': '이건 하나의 승리입니다. 완벽하기 이를 데 없지요. 기막힌 리얼리즘이에요.',
#  '490': '당신은 이 곳에 무슨 일로 오셨죠? 뭘 기대하고 있지요?',
#  '491': '그는 내 손에서 책을 홱 낚아채 한 권이라도 빠지면 전체가 무너져 버리기 쉽다고 중얼거리면서 서가의 제자리에 급히 갖다 꽂았다.',
#  '492': '그녀는 대답하지 않고 즐거운 표정으로 알 수 없는 신사를 쳐다보았다.',
#  '493': '클로드 루즈벨트 부인 말입니다. 그녀를 아시나요? 난 어젯밤에 어디선가 그녀를 만났지요.',
#  '494': '난 일주일쯤 전부터 술에 취해 있답니다. 서재에 앉아 있으면 혹시 정신이 들지 않을까 해서 이렇게..',
#  '495': '약간 나아진 것 같아요. 하지만 아직은 뭐라고 말할 수 없소. 이 곳에 온 지 한 시간밖에 되지 않았거든.',
#  '496': '우리는 그와 정중하게 악수를 나누고 다시 밖으로 나왔다.',
#  '497': '정원의 천막 안에서는 무도회가 벌어지고 있었다.',
#  '498': '거만스러운 남녀들은 구부정하면서도 우아하게 서로 껴안고 구석 쪽에서 춤을 추고 있었다.',
#  '499': '밤이 깊어지게 되자 분위기는 한층 더 무르익어 갔다.',
#  '500': '유명한 테너 가수가 이탈리아어로 노래를 부르고 있었다.',
#  '501': '어떤 인기 있는 콘트랄로 가수는 재즈곡을 불렀다.',
#  '502': '오케스트라가 쉴 때마다 정원 곳곳에서 사람들이 장기자랑을 했고, 얼빠진 웃음소리가 끊임없이 여름 하늘을 향해 솟아올랐다.',
#  '503': '알고 보니 노란 드레스를 입은 그 아가씨들이었다.',
#  '504': '의상을 갖춰 입고 유치한 단막극을 선보이고 있었다.',
#  '505': '핑거볼보다 큰 샴페인 잔이 돌았다. 달은 더 높이 솟아올라 롱아일랜드 해협에 지느러미같이 떠 있었다.',
#  '506': '마치 잔디 위에서 울려 대는 밴조 소리에 맞춰 파르르 떨고 있는 것 같았다.',
#  '507': '우리는 내 나이 또래의 한 남자와 호들갑스런 아가씨와 같이 테이블에 앉아 있었다.',
#  '508': '나 역시 이젠 나름대로 분위기를 즐기고 있었다.',
#  '509': '핑거볼보다 큰 잔으로 샴페인을 두 잔이나 마셨기 때문인지 파티가 흥겹게 느껴졌다.',
#  '510': '분위기가 좀 가라앉자 옆에 앉아 있던 남자가 나를 보며 빙그레 웃었다.',
#  '511': '혹시 전쟁중에 제1사단에 소속되어 있지 않았습니까?',
#  '512': '나는 1918년 6월까지 제16보병 연대에 소속되어 있었습니다. 왠지 낯이 익다 했더니.',
#  '513': '우리는 프랑스의 어떤 축축하고 잿빛이 도는 작은 마을에 대해 한동안 이야기를 나누었다.',
#  '514': '그는 얼마 전에 수상기를 샀는데 내일 아침에 시승해 보려고 한다는 말을 했기 때문이다.',
#  '515': '시간이 있으면 함께 타지요. 친구분? 해협의 해변 가까이 있으니까요.',
#  '516': '내가 그의 이름을 막 물어 보려는 순간 조던이 내게로 고개를 돌리고 미소를 지었다.',
#  '517': '나는 새로 사귄 사람에게로 다시 얼굴을 돌렸다.',
#  '518': '이런 파티는 처음입니다. 아직 주인을 만나 보지 못했으니까요. 나는 저기서 살고 있습니다.',
#  '519': '나는 멀리 있는, 보이지도 않는 울타리 쪽을 가리키며 말했다.',
#  '520': '집 주인인 개츠비 씨가 운전사에게 초대장을 들려 보냈더군요.',
#  '521': '잠시 그는 마치 내 말을 이해하지 못한 것처럼 나를 바라보았다.',
#  '522': '난 당신이 알고 계신 줄로 생각했습니다, 친구분. 내가 주인 노릇을 제대로 못 하고 있군요.',
#  '523': '그는 이해하는 듯이 미소를 지어 보였다.',
#  '524': '그것은 일종의 무한한 다짐이 담겨 있는 한평생을 통해서 몇 번 볼까말까한 아주 진기한 미소였다.',
#  '525': '그것은 한순간이었지만 세계 전체를 대하고 있었다.',
#  '526': '억누를 수 없는 편견으로 상대방에게 호의를 베풀려고 온 정신을 쏟고 있었다.',
#  '527': '그것은 상대방이 자신을 이해해 주기를 바라는 만큼 상대방을 이해해 주는 미소였다.',
#  '528': '상대방이 믿어 주기를 바라는 만큼 상대방을 믿어 주는 확신이 있는 미소였다.',
#  '529': '상대방이 최선의 상태에서 전달하고 싶어하는 인상을 정확하게 파악했음을 암시하는 미소였다.',
#  '530': '정확하게 그 시점에서 그 미소는 일순간에 사라져 버렸다.',
#  '531': '나는 서른을 한두살 넘긴 듯한, 우아하며 건장한 한 청년을 보고 있었는데, 그의 빈틈없이 꾸민 말투는 간신히 어색함을 면했다.',
#  '532': '나는 그가 자기 소개를 하기 얼마 전에 말을 조심성 있게 골라 하고 있다는 인상을 강하게 받았었다.',
#  '533': '개츠비가 자신의 신분을 밝히고 있을 때 하인이 달려와서 시카고에서 전화가 왔다고 말했다.',
#  '534': '그는 우리에게 차례로 고개를 가볍게 숙이며 실례한다고 말했다.',
#  '535': '필요하신 게 있으면 뭐든 그저 청하기만 하십시오, 친구분',
#  '536': '나는 지금껏 개츠비를 중년의 혈색 좋고 뚱뚱한 사람으로 예상하고 있었다.',
#  '537': '개츠비라는 이름의 남자라는 사실밖에 몰라요.',
#  '538': '글쎄요. 언젠가 제게 옥스퍼드 대학 출신이라고 말한 적이 있어요.',
#  '539': '막연하게나마 그의 배경에 대해 머릿속에 그려보기 시작했으나 그녀의 다음말로 그것은 지워져 버리고 말았다.',
#  '540': '단지 저는 그분이 옥스퍼드에 다녔으리라고 생각하지 않을 뿐이에요.',
#  '541': "그녀의 말투는 앞서의, '사람들은 그분이 전에 사람을 죽인 적이 있다고 생각하고 있대요.' 라는 말을 생각하게 했다.",
#  '542': '개츠비가 뉴욕의 출신이라는 정보였던들 나도 의심 없이 받아들였을지 모른다.',
#  '543': '그가 롱아일랜드 해협 지대에 호화 주택을 샀다는 사실은 시골 출신인 나로서는 도무지 믿을 수가 없는 일이었다.',
#  '544': '어쨌든 그분은 호화로운 파티를 자주 열고 있어요.',
#  '545': '구체적인 이야기를 싫어하는 도시인 특유의 기질을 보이며 조던이 화제를 바꾸었다.',
#  '546': '저는 호화로운 파티를 좋아해요. 호화로운 파티는 정말 친밀감이 들어요.',
#  '547': '작은 파티에서는 개인적인 자유를 가질 수가 없잖아요.',
#  '548': '큰북이 둥둥 울리고 오케스트라 지휘자의 목소리가 정원의 소음을 억누르고 갑자기 울려 퍼졌다.',
#  '549': '개츠비 씨의 요청에 따라 지난 5월 카네기 홀에서 많은 관심을 끈 적이 있는 최신 작품을 연주해 드리도록 하겠습니다.',
#  '550': '신문을 읽으신 분은 그것이 음악인들에게 커다란 충격을 주었다는 사실을 아실 것입니다.',
#  '551': "이 곡은 블라디미르 토스토프 씨의 '세계 재즈사'라는 곡입니다.",
#  '552': '토스토프 작곡의 음악은 내 가슴에 와 닿지 않았다.',
#  '553': '나의 관심은 대리석 계단에 혼자 서서 이 그룹에서 저 그룹으로 시선을 옮기고 있는 개츠비에게 쏠려 있었기 때문이다.',
#  '554': '햇볕에 그을린 그의 피부는 매력적으로 보였고 짧은 머리는 매일 다듬는 듯 정갈하게 보였다.',
#  '555': '그에게선 어두운 면이라고는 조금도 느낄 수가 없었다.',
#  '556': '그가 술을 마시지 않기 때문에 손님들로부터 떨어져 있는 것이 아닐까 하는 생각이 들었다.',
#  '557': '서로 우애의 흥겨움이 더해 갈수록 그의 행동은 더욱 냉철해지는 것 같았기 때문이다.',
#  '558': '어떤 사람이 부축해 주리라는 것을 알고 장난스럽게 남자들의 품에 슬쩍 쓰러지기도 했다.',
#  '559': '심지어는 몰려 있는 사람들 한가운데로 벌렁 눕기도 했다.',
#  '560': '어떤 여자도 개츠비 쪽으로 드러눕지 않았다.',
#  '561': '프랑스식 단발머리를 한 아가씨도 그의 어깨를 건드리지 못했으며, 어떤 4중창도 그를 무리의 틈에 끼이게 하지는 못했다.',
#  '562': '개츠비의 하인이 갑자기 우리 곁으로 다가오더니 말했다.',
#  '563': '죄송합니다만 주인께서 당신하고만 조용히 말씀을 나누고 싶으시답니다.',
#  '564': '그녀는 의외라는 듯이 놀란 표정으로 눈썹을 치켜올리고 나를 한 번 쳐다보고는 천천히 일어나서는 하인을 따라 저택 쪽으로 걸어갔다.',
#  '565': '녀의 몸놀림에서는 골프 코스를 따라 걷는 법을 처음 배운 사람에게서 느낄 수 있는 쾌활함을 느낄 수 있었다.',
#  '566': '드레스를 입은 아가씨가 피아노를 치고 있었고, 합창단에서 온 젊은 여자가 그 옆에 서서 노래를 부르고 있었다.',
#  '567': '그녀는 샴페인을 제법 많이 마셨고, 노래를 부르는 동안 세상만사는 너무너무 슬프다고 제멋대로 단정짓고 있었다.',
#  '568': '그녀는 노래만 부르는 것이 아니라 울기도 했다.',
#  '569': '노래의 쉬는 부분을 그녀는 한숨과 흐느낌으로 메우고는 다시 떨리는 소프라노로 서정곡을 계속하는 것이었다.',
#  '570': '눈물이 그녀의 두 뺨으로 흘러내렸으나 거침없이 흘러내리지는 않았다.',
#  '571': '짙게 화장한 속눈썹이 흡수하고 난 나머지 눈물만 검정색 줄기가 되어 느리게 흘러내렸기 때문이다.',
#  '572': '누군가가 그녀에게 노래하고 있다고 익살을 떨자, 그녀는 샴페인에 취해 깊은 잠에 빠져 버렸다.',
#  '573': '내 곁에 있던 한 아가씨가 얘기해 주었다. 나는 주위를 둘러보았다.',
#  '574': '남아 있는 대부분의 여자들은 그 남편들과 다투고 있었다.',
#  '575': '조던의 일행이었던, 4중창단도 서로 의견이 엇갈려 뿔뿔이 흩어져 있었다.',
#  '576': '그들 중 한 남자가 호기심에 차서 어떤 젊은 여배우와 이야기를 나누고 있었다.',
#  '577': '그의 아내는 처음에는 모른 척하고 웃어넘기려고 했으나 끝내는 질투의 화신이 되고 말았다.',
#  '578': '그녀는 이따금씩 잔뜩 화가 난 모습으로 갑자기 남편 곁에 나타나서 그의 귀에 대고 말했다.',
#  '579': '집으로 돌아가기를 주저하는 사람은 바람난 남자들만이 아니었다.',
#  '580': '홀엔 뒤늦게 술에서 깨어나 한심스러울 정도로 말똥말똥한 두 남자와 굉장히 화가 난 그들의 아내들만 남아 있었다.',
#  '581': '그 아내들은 약간 높은 목소리로 서로 위로의 말을 주고받고 있었다.',
#  '582': '내가 즐거워하는 것을 보기만 하면 저 사람은 집에 가고 싶어한다니까요.',
#  '583': '그런 이기적인 사람은 내 생전에 본 적이 없어요.',
#  '584': '우리는 언제나 가장 먼저 돌아가는 사람이었어요.',
#  '585': '하지만 오늘 밤엔 아마 우리가 마지막 사람이 되겠지요.',
#  '586': '두 여자는 자리에서 일어나 어둠 속으로 비틀거리며 사라져 갔다.',
#  '587': '이런 악의에 찬 마음씨를 가진 사람은 믿을 수가 없다는 데에 아내들의 의견이 일치했음에도 불구하고 말다툼은 쉽게 끝이 나지않았다.',
#  '588': '나는 홀에서 하인이 모자를 가져다주기를 기다리고 있었는데, 그 때 서재의 문이 열렸다.',
#  '589': '그의 태도에서 엿보이던 진지함은 몇몇 사람들이 작별 인사를 하려고 다가가자 갑자기 형식적인 자세로 바뀌어 버렸다.',
#  '590': '조던 일행은 더 이상 못 기다리겠다는 듯이 복도에서 그녀를 불러 댔다.',
#  '591': '그녀는 나와 악수를 하느라 잠시 시간을 끌었다.',
#  '592': '그렇지만 더 이상 말씀드리지 않고 선생님께 궁금증만 남긴 채 오늘은 그만 헤어져야겠어요.',
#  '593': '그녀는 내 얼굴 앞에서 귀엽게 하품을 했다.',
#  '594': '그녀는 문 앞에서 녹아들 듯 일행 속으로 들어가 갈색 손을 흔들며 쾌활하게 작별 인사를 했다.',
#  '595': '처음 방문한 처지에 너무 오래 머무는 것을 조금 부끄러워하면서도 나는 개츠비를 둘러싸고 있는 손님들 틈에 끼이게 되었다.',
#  '596': '나는 그에게 이른 저녁시간부터 그를 찾아다녔던 사실을 설명하고 정원에서 그를 알아보지 못한 데 대해 사과하고 싶었다.',
#  '597': '그는 아무렇지도 않다는 듯 미소를 띄며 말했다.',
#  '598': '이 친근한 말투는 그저 다짐하듯이 내 어깨를 쓰다듬는 그의 손이 감촉 이상의 친밀감은 갖고 있지 못했다.',
#  '599': '그리고 내일 아침 9시에 우리가 수상기를 타기로 한 걸 잊지 마세요.',
#  '600': '바로 이 때 하인이 그의 어깨 뒤에서 말했다.',
#  '601': '알았네, 곧 가도록 하지. 곧 받겠다고 말해 주게. 그럼 안녕히 가십시오.',
#  '602': '계단을 내려오며 나는 파티가 아직 완전히 끝나지 않았다는 것을 알게 되었다.',
#  '603': '현관문에서 50피트 가량 떨어진 곳에서 10여 개의 헤드라이트가 뒤죽박죽 섞여서 괴상한 광경을 비추고 있었던 것이다.',
#  '604': '쿠페형 새 자동차가 오른쪽 차체를 위로 하고 바퀴 하나가 흉하게 빠진 채 처박혀 있는 모습이 보였다.',
#  '605': '벽이 날카롭게 튀어나온 것이 바퀴가 빠져나간 것을 설명하고 있었다.',
#  '606': '그 광경을 5,6명의 운전사들이 호기심을 가지고 보고 있었다.',
#  '607': '뒤에서 오는 차들은 거칠고 시끄러운 경적 소리를 계속 내서 그러잖아도 이미 혼란스러운 상태를 더욱 심하게 했다.',
#  '608': '어이가 없다는 표정으로 자기 차에서 빠져나간 바퀴를 바라보았다.',
#  '609': '그는 차가 개천에 빠졌다는 사실을 믿지 않는다는 투로 말했다.',
#  '610': '그가 그것을 의외로 여기고 있는 것 자체를 이상하게 생각하고 있던 나는 그 남자가 누구인지 알게 되었다.',
#  '611': '그는 조금 전에 개츠비의 서재에 앉아 있던 바로 그 사람이었다.',
#  '612': '그런데 어떻게 된 거야? 벽을 들이받았나요?',
#  '613': '마치 올빼미 눈 같은 안경을 낀 그 남자는 이 사고와 자기는 관계가 없다는 태도로 말했다.',
#  '614': '기계 구조에 대해서는 아무 것도 모른다니까요. 전혀 몰라요.',
#  '615': '내가 아는 것이라곤 사고가 발생했다는 것뿐이에요.',
#  '616': '운전이 서투르다면 밤에 운전을 하지 말았어야지요.',
#  '617': '구경꾼들은 그의 거친 말투에 감히 말을 꺼내지 못하고 있었다.',
#  '618': '바퀴 하나만 빠진 게 천만다행이었소. 운전도 서투르고 할 마음도 없었다면서요!',
#  '619': '난 운전을 하지 않았어요. 차 안에 또 한 사람이 있어요.',
#  '620': "이 말에 모두들 깜짝 놀랐는데, 쿠페형 차의 문이 조금씩 열리며 '아이고, 아이고.' 하며 길게 끄는 목소리가 들려 왔다.",
#  '621': '차의 문이 완전히 열리자 순간적으로 침묵이 흘렀다.',
#  '622': '아주 창백한 얼굴의 사나이가 부서진 차에서 비틀거리며 나오려는 모습이 보였다.',
#  '623': '한 부분씩을 차례로 드러내더니 엄청나게 큰 무도화를 신은 발로 더듬더듬 땅을 밟아 보았다.',
#  '624': '남자는 잠시 몸을 비틀거린 후에야 먼지 방지용의 긴 외투를 입은 그 사람을 알아보았다.',
#  '625': '대여섯 사람이 손가락으로 빠져나간 바퀴를 가리켰다.',
#  '626': '그 남자는 잠시 그것을 바라보더니 그게 하늘에서 떨어져 내린 것이 아닌가 하고 의심이라도 하듯이 위를 쳐다보았다.',
#  '627': '침묵이 흘렀다. 곧 그는 길게 숨을 내쉬고 어깨를 쭉 펴고는 진지한 목소리로 이렇게 말했다.',
#  '628': '주유소가 어디에 있는지를 알려 주시겠습니까?',
#  '629': '이 바퀴와 차는 이제 어떤 방법으로도 고칠 수 없다는 것을 그에게 설명했다.',
#  '630': '최소한 10여 명의 사람들-그들 중 몇 명은 부유해 보였다.',
#  '631': '이 바퀴와 차는 이제 어떤 방법으로도 고칠 수 없다는 것을 그에게 설명했다.',
#  '632': '붕붕거리는 소리가 음으로 바뀌었을 때 나는 잔디밭을 가로질러 집으로 향했다.',
#  '633': '얄팍하고 둥근 달이 개츠비의 저택 위를 비춤으로써 밤을 여전히 멋지게 해주고 있었다.',
#  '634': '아직까지 불빛이 환한 정원에서는 웃음소리와 이야기 소리가 끊기지 않고 들려 오고 있었다.',
#  '635': '창문들과 커다란 문들로부터 갑자기 공허감이 쏟아져 나오는 것 같았다.',
#  '636': '그 공허감은 현관에 서서 손을 들어 형식적인 작별 인사를 하고 있는 주인의 모습을 너무나도 외롭게 보이게 했다.',
#  '637': '이제까지 쓴 것을 다시 쭉 읽어보니 몇 주일 전의 일 가운데 사흘 밤 동안에 일어났던 사건들만 얽매여 강조해서 쓴 느낌이 든다.',
#  '638': '실은 그 반대로 그것들은 지난 여름철에 일어난 많은 사건 중에서, 한낱 우발적인 몇 가지 사건에 불과했다.',
#  '639': '그것들은 그 후 오랫동안 나 개인의 일들에 몰두했던 것에 비하면 아주 사소한 사건들이었다.',
#  '640': '이른 아침 회사를 향해 건물들 사이를 서둘러 빠져나갈 때면 햇빛은 내 그림자를 서쪽으로 쭉 뻗게 해 주었다.',
#  '641': '나는 사무원들이나 채권 외판원들과 서로 이름을 부를 정도로 친해졌다.',
#  '642': '그들과 함께 컴컴하고 북적거리는 식당에서 작은 돼지고기 소시지와 으깬 감자, 그리고 커피로 점심을 대신하곤 했다.',
#  '643': '나는 저지 시에 살면서 경리과에 근무하던 아가씨와 잠시 사귀고 있었다.',
#  '644': '그녀의 오빠가 나에게 던지는 시선이 좋지 않은 것을 눈치채고 그녀가 휴가를 떠난 7월에 조용히 관계를 정리했다.',
#  '645': '그 즈음 나는 저녁 식사를 늘 예일 클럽에서 했다.',
#  '646': '여러 가지 이유 때문에 그 시간은 나의 하루 중에서 가장 우울한 시간이 되었다.',
#  '647': '저녁 식사를 마치면 나는 이층의 도서실에 올라가서 투자와 유가 증권 공부를 하느라고 시간을 보냈다.',
#  '648': '그 근처에는 소란을 피우는 두세 사람이 있었으나 그들이 도서실에는 절대로 들어오지 않았다.',
#  '649': '그 곳은 공부하기에 더할 수 없이 좋은 장소였다.',
#  '650': '기분이 좋은 밤이면 나는 천천히 걸어 내려가서 오래 된 호텔을 지나 33번가를 건너 펜실베니아 역까지 걷곤 했다.',
#  '651': '끊임없이 오가는 연인들과 자동차 행렬이 우리의 불안한 눈에 안겨 주는 만족감으로 뉴욕을 좋아하기 시작했다.',
#  '652': '마음속으로는 때때로 으슥한 길모퉁이에 있는 그녀들의 아파트까지 따라가곤 했다.',
#  '653': '그녀들은 나를 향해 살짝 돌아보고 미소를 짓고 나서 문을 열고 어둠 속으로 사라지는 것이었다.',
#  '654': '해가 질 때면 가끔 나는 이상한 기분 속으로 몰아넣었다.',
#  '655': '나는 자주 고독감에 휩싸였는데, 나 아닌 다른 사람들에게서도 그것을 느꼈다.',
#  '656': '인생의 가장 황홀한 순간들을 헛되게 낭비하고 있는 젊은 사무원들에게서 나는 그 고독감을 느꼈다.',
#  '657': '택시를 탄 사람들은 출발을 기다리는 동안 서로 몸을 기대고 앉아 노래를 부르기도 하고 곧잘 웃음을 터뜨리곤 했다.',
#  '658': '그들이 피워 대는 담배는 차안의 사람들 모습을 분간할 수 없을 정도로 자욱했다.',
#  '659': '그럴 때면 나는 즐거운 곳으로 서둘러 가고 싶었으며 그들의 은밀한 흥분을 나도 나누어 갖고 있다고 생각했다.',
#  '660': '나는 한동안 조던 베이커를 만나지 못하고 지내다가 한여름이 되어서야 다시 그녀를 만났다.',
#  '661': '나는 처음에는 그녀와 함께 이곳저곳 같이 다니는 것에 우쭐함을 느꼈었다.',
#  '662': '이 도시에서 골프 챔피언인 그녀를 모르는 사람이 없었기 때문이다.',
#  '663': '그런데 일은 그렇게 단순하지가 않았다. 사실 나는 그녀를 사랑하지 않았다.',
#  '664': '그녀가 세상을 향해 내세우는 그 지루해 보이는 거만스러운 얼굴 뒤에는 무엇인가가 숨겨져 있다고 생각했다.',
#  '665': '허식이란 처음에는 그렇지 않지만 결국은 무엇인가를 숨기고 있게 마련인 것이다.',
#  '666': '그것은 우리가 어느 집 파티에 갔을 때였는데, 그녀는 비가 오는데도 빌려 온 자동차의 지붕을 열어 놓은 채 주차시켜 두었다.',
#  '667': '그리고 나중에 그 일을 거짓말로 얼버무리는 것이었다.',
#  '668': '그러자 내겐 문득 데이지의 집에 갔던 날 밤 건성으로 들었던 그녀의 신상에 관한 얘기가 떠올랐다.',
#  '669': '그녀가 처음으로 대골프 선수권 대회에 출전했을 때, 그녀는 하마터면 신문에까지 날 뻔했다.',
#  '670': '그녀가 준결승전 때 공이 어려운 곳에 가자 치기 쉬운 곳으로 몰래 옮겨 놓았었다는 말이 떠돌았던 것이다.',
#  '671': '그것은 하나의 추문으로 법정단계까지 갈 뻔했으나 한 캐디가 자기의 진술을 취소하고',
#  '672': '또 유일한 목격자가 자신이 잘못 보았을지도 모르겠다고 인정함으로써 잠잠해지고 말았다.',
#  '673': '난 그 사건과 당사자의 이름을 기억하고 있었다.',
#  '674': '조던 베이커는 영리하고 약삭빠른 사람들은 될 수 있는 한 멀리했는데.',
#  '675': '그것은 규범에서의 이탈을 인정하지 않는 사람들 틈에서 살아가는 것이 더 안전하고 느꼈기 때문이라는 것을 알게 되었다.',
#  '676': '그녀는 말할 수 없이 정직하지 못했고, 또한 자신이 부정하게 취급당하는 것을 참지 못했다.',
#  '677': '내 생각에 그녀는 아주 어렸을 때부터 그렇듯 마음에 내키지 않는 일을 당하면 속임수로 얼버무려 온 것 같았는데.',
#  '678': '그 차갑고 오만한 미소를 잃지 않으면서도 자기의 단단하고 활기찬 육체의 욕구는 충족시키려한 데에 있었던 것이다.',
#  '679': '어쨌든 그러한 일들이 나와는 아무 상관도 없는 일이었다. 여자의 부정직은 크게 비난할 것은 못 되는 것이다.',
#  '680': '나는 그녀의 그런 면에 대해 간혹 아쉬워했으나 곧 잊어버렸다.',
#  '681': '우리가 차를 운전하는 것에 관한 문제로 호기심을 끄는 대화를 나눈 것도 바로 그 워워크의 집에서 열린 파티에서 였다.',
#  '682': '그 대화는 그녀가 몇몇 노동자들 쪽으로 바싹 차를 몰아 차의 펜더가 한 남자의 코트 단추를 떨어뜨린 데에서 시작되었다.',
#  '683': '햇빛 때문에 찡그린 그녀의 회색 눈은 정면을 바라보고 있었다.',
#  '684': '그녀는 나와의 관계를 신중하게 유지해 왔기 때문에 한때 나는 내가 그녀를 사랑하고 있다고 생각했다.',
#  '685': '그렇지만 나는 소심하고 자신의 욕망에 제동을 거는 내면적 규칙을 엄수하고 있었다.',
#  '686': '그리고 나는 우선 고향에서 있었던 그러한 굴레로부터 완전히 벗어나려면 요령 있게 끊어 버려야만 했었다.',
#  '687': '모든 사람은 자신은 최소한 기본적 미덕을 하나쯤 지니고 있다고 생각하게 되는데, 나의 미덕은 바로 이것이다.',
#  '688': '즉 나는 일찍이 내가 알고 있는 소수의 정직한 사람 중의 한 사람인 것이다.',
#  '689': '일요일 아침, 해안을 낀 여러 마을에 교회의 종소리가 울려 퍼지는 동안 권력이나 재력이 좀 있다 하는 사람들은,',
#  '690': '개츠비의 저택으로 다시 모여 잔디밭 위를 들뜬 기분으로 거닐고  있었다.',
#  '691': '젊은 여인들이 개츠비가 마련한 칵테일과 손질 잘 된 꽃밭 사이를 돌아다니며 말했다.',
#  '692': '언젠가 나는 수첩 여백에 그 해 여름에 개츠비의 저택에서 만났던 사람들의 이름을 적어 보았다.',
#  '693': '그 수첩은 이제는 다 낡아 버렸는데, 접힌 부분은 이미 해져 버렸다.',
#  '694': "그 수첩에는 '이 예정표는 1922년 6월 5일 실행'이라는 제목이 붙어 있다.",
#  '695': '나는 아직도 그 수첩에서 낯익은 이름들을 읽을 수 있다.',
#  '696': '그 이름들은 개츠비의 환대를 받고도 그에 대해서는 아무 것도 아는 바 없다는 해괴한 말들을 하는 사람들에 관한,',
#  '697': '나의 총괄적인 설명보다도 더 강한 인상을 갖게 한다.',
#  '698': '누군가 옆으로 오는 것을 부담스럽게 느끼고 있는 것 같았다.',
#  '699': '페레트가 정원을 어슬렁거리고 돌아 다니는 것은 그가 돈을 몽땅 날려 버렸음을 뜻하는 것이었는데,',
#  '700': '그러면 다음 날 연합 철도회사는 돈을 만들어 내느라 어려움을 겪어야 했다.',
#  '701': "클립스프링거라는 이름의 남자는 너무 자주 왔고 또 머무는 기간이 무척 길었기 때문에 '하숙생'으로 통했다",
#  '702': '그들은 행동이 너무 닮아서 틀림없이 전에 개츠비의 저택에 자주 왔던 것처럼 생각되었다.',
#  '703': '성은 그 어떤 리듬 있는 꽃이름이나 달의 이름이 아니면 미국의 대자본가들의 굉장한 성씨였는지도 모른다.',
#  '704': '그들에게 만약 성명을 가르쳐 달라고 조르면 그들은 아마 그 자본가들의 사촌쯤 된다고 털어놓았을 것이다.',
#  '705': '그 모든 사람들 외에도 포스티나 오브라이언이 적어도 한 번은 왔던 것으로 기억된다.',
#  '706': '우리들이 공작이라고 불렀던, 그 이름을 그 때는 알았는지 몰라도 지금은 잊어버리고 만 어떤 왕자가 왔었다.',
#  '707': '이 모든 사람들이 그 해 여름에 개츠비의 저택에 왔던 것이다.',
#  '708': '나의 집 문 앞까지 와서는 다양한 음색의 자동차 나팔로 요란스럽게 경적을 울려 댔다.',
#  '709': '그전에 나는 그의 파티에 두 번이나 참석했었고 그의 수상기도 탔었다.',
#  '710': '그의 간곡한 권유로 그의 소유인 해변도 여러 번 이용했었다.',
#  '711': '그가 직접 나를 찾아온 것은 그것이 처음이었다.',
#  '712': '안녕하신가요, 친구분. 오늘은 점심이나 같이 하려 하는데 별다른 일은 없겠지요?',
#  '713': '그는 잠시도 가만히 있지 못하는 미국인 특유의 몸놀림을 보이며 차의 계기판에 몸을 기대고 있었다.',
#  '714': '그보다도 신경에 관계되는 운동을 때때로 한 데서 얻은 보이지 않는 우아함에서 익힌 것으로 생각되었다.',
#  '715': '그의 그런 행동은 침착성이 없는 경박스러움처럼 느껴지기도 했다.',
#  '716': '그는 잠시도 가만히 있지 못했다. 항상 발로 어딘가를 툭툭 차거나 손을 오므렸다 폈다 했다.',
#  '717': '그는 내가 자신의 차에 감탄하는 것을 보았는지 조용히 말했다.',
#  '718': '그는 내가 더 잘 볼 수 있도록 차에서 뛰어내렸다.',
#  '719': '나는 본 적이 있었다. 그것은 많은 사람들이 본 적이 있는 차로, 니켈 장식이 번쩍이는 짙은 크림색이었다.',
#  '720': '굉장히 긴 차체의 여기저기가 화려한 장식들로 꾸며져 있었다.',
#  '721': '연장 상자들이 불룩불룩 튀어나와 있고 여러 단으로 복잡하게 끼워진 10여 개의 통풍창들이 햇빛을 반사하고 있었다.',
#  '722': '여러 겹의 유리로 둘러싸인 그 차를 타고 우리는 시내로 출발했다.',
#  '723': '평소에 그가 별로 이야깃거리를 가지고 있지 않다는 것을 알고 좀 실망했었다.',
#  '724': '그저 인사나 하며 알고 지내는 이웃집의 주인 정도로만 보이게 되었다.',
#  '725': '그 무렵 그가 날 찾아와 자동차를 같이 타게 되었던 것이다.',
#  '726': '개츠비는 자기가 하던 품위 있는 말을 멈춘 채 캐러멜색 양복의 무릎 부부을 손바닥으로 방정맞게 치고 있었다.',
#  '727': '약간 압도되어 버린 나는 그 질문에 맞을 것 같은 평범한 말로 답변해 주었다.',
#  '728': '당신이 들었을 그 많은 이야기로 나를 잘못 판단하는 것을 원하지 않으니까.',
#  '729': '그는 자신의 저택에 있는 여러 개의 홀에서 이야기되었던, 자신에 대한 야비한 비난을 이미 알아차리고 있는 것 같았다.',
#  '730': '그는 갑자기 오른손을 들어 하느님의 벌을 받겠다고 맹세했다.',
#  '731': '나는 중서부의 어느 부잣집 아들로 태어났습니다. 부모님은 이미 돌아가셨지요.',
#  '732': '그는 곁눈질로 나를 쳐다보았다-문득 나는 조던 베이커가 그가 거짓말을 하고 있다고 믿고 있던 이유를 알게 되었다.',
#  '733': "그는 '교육은 옥스퍼드 대학에서 받았답니다.'라는 대목에서 질타를 받은 경험이 있는 것처럼 빠르게 말했다.",
#  '734': '아니, 말끝을 삼켜 버렸다고 할까, 아니면 그 말은 목에 걸려 나오지 않는 것 같았다.',
#  '735': '이렇게 의심하고 보니 그가 했던 얘기 전부가 거짓말처럼 여겨지고 결국 그에게 어떤 음모가 있는 것이 아닐까 싶었다.',
#  '736': '그의 목소리는 마치 자기네 가문의 급작스런 몰락을 다시 이야기하는 것이 괴로운 듯 엄숙하게 말했다.',
#  '737': '나는 한순간 그가 나를 놀리고 있는 것이 아닐까 하고 의심했다.',
#  '738': '그의 맑은 두 눈을 보고는 그렇지 않다는 것을 믿을 수 있었다.',
#  '739': '그 이후로 나는 유럽의 여러 수도-파리, 베네치아, 로마-에서 인도의 젊은 왕자처럼 살아 왔지요.',
#  '740': '나는 그의 거짓말에 웃음이 터지려는 것을 간신히 참았다.',
#  '741': '그가 지금 하고 있는 말은 속이 훤히 드러날 정도로 닳아빠져있었다.',
#  '742': '작은 몬테네그로! 그는 이 말을 힘주어 말하더니 미소를 띠며 고개를 끄덕였다.',
#  '743': '그것은 시련을 겪은 몬테네그로의 역사를 이해하고, 몬테네그로 국민의 용감한 투쟁을 동정한다는 미소였다.',
#  '744': '그 미소는 이런 훈장이 나오게 했던 국가 정세의 연쇄성을 마음껏 즐기고 있었다.',
#  '745': '그를 믿지 못하던 마음이 사라지고 나는 그의 매력에 빨려 들어갔다.',
#  '746': '그것은 산만스럽게 흩어져 있는 여러 권의 잡지를 건성으로 책장을 넘기고 있는 것 같은 기분이었다.',
#  '747': '그는 주머니에 손을 찔러 넣더니 잠시 후 리본에 달린 메달 하나를 주머니에서 꺼냈다.',
#  '748': "다닐로 훈장'이라는 글자가 원형으로 뚜렷하게 새겨져 있었다.",
#  '749': '코트를 입은 5,6명의 젊은이들이 많은 첨탑들을 배경으로 아치 밑을 서성거리고 있는 사진이었다.',
#  '750': '그들 중 개츠비가 제일 젊어 보였고 그의 손에는 크리켓 방망이가 쥐어져 있었다.',
#  '751': '모든 것이 사실이었다. 나는 중국의 대운하 위에 있는 그의 대저택 속의 불타는 듯한 호랑이 모피들을 보았다.',
#  '752': '루비가 들어 있는 상자를 열고 빛나는 그 진홍빛 보석을 바라보며 상처 입은 가슴의 아픔을 달래고 있는 그의 모습도 보았다.',
#  '753': '오늘은 친구에게 한 가지 중요한 부탁을 드려야겠습니다.',
#  '754': '개츠비는 만족스러운 표정을 지으며 기념품들을 도로 주머니에 집어 넣으면서 말했다.',
#  '755': "나는 그가 말한 '이 문제'라는 것이 무엇인지 전혀 짐작할 수 없었다.",
#  '756': '그것은 나에게 별다른 도움이 될 것 같지 않았다. 오히려 성가신 일이었다.',
#  '757': '나는 제이 개츠비의 얘기를 하려고 조던에게 차를 마시러 오라고 청했던 것은 아니었다.',
#  '758': '나는 그의 부탁이 아주 엉뚱한 것일 게 분명하다고 생각했다.',
#  '759': '한동안 내가 사람이 우글거리는 그의 저택을 찾아갔던 것을 후회하고 있었다.',
#  '760': '그는 더 이상 말을 하지 않았다. 뉴욕이 가까워지자 그의 자세는 더욱 단정해졌다.',
#  '761': '우리는 북적거리는 어두컴컴하고 낡아빠진 1900년대의 술집들이 즐비한 빈민가를 빠져 나가고 있었다.',
#  '762': '차는 이윽고 양쪽에 재의 골짜기가 펼쳐진 길로 접어들었다.',
#  '763': '나는 윌슨 부인이 가쁜 숨을 몰아 쉬며 주유소의 휘발유 펌프를 힘들게 잡아당기는 모습을 언뜻 보았다.',
#  '764': '우리는 차의 흙받기를 날개같이 활짝 펴고 아스토리아 마을 중간까지 먼지를 뿌리며 달렸다.',
#  '765': '우리가 고가도로의 기둥들 사이로 꺾어 들었을 때 야비한 표정을 지으며 경찰이 옆으로 달려들었다.',
#  '766': '우리는 속력을 줄였다. 그는 지갑에서 하얀 카드를 꺼내더니 그것을 경찰의 눈앞에 대고 흔들었다.',
#  '767': '경찰은 그를 알아보고는 모자를 슬쩍 들어 올렸다.',
#  '768': '넓게 잘 뚫린 고가도로 사이로 내리비치는 햇빛이 지나가는 자동차들 위에서 끊임없이 빛났다.',
#  '769': '강 건너편에는 희망으로 세워진 집들과 네모 반듯한 건물들이 우뚝우뚝 솟은 도시가 보였다.',
#  '770': '그 도시는 세계의 모든 신비와 아름다움을 조화롭게 간직하고 있었기 때문에 언제나 새로운 감동을 주는 도시였다.',
#  '771': '국화꽃을 완전히 뒤덮힌 영구차가 우리 옆을 스쳐 지나갔다.',
#  '772': '곧바로 앞선 두 대의 마차보다는 슬픔이 덜한 몇 대의 마차가 뒤따랐다.',
#  '773': '그 친구들은 동남부 유럽인 특유의 짧은 윗입술과 비극적인 눈망울로 우리를 내려다보았다.',
#  '774': '개츠비의 호화판 자동차가 그들의 우울한 휴일의 구경거리 속에 끼어든 것이 나는 기뻤다.',
#  '775': '섬을 지나칠 때 리무진 한 대가 우리를 스쳐 갔다.',
#  '776': '백인 운전사가 모는 그 차에는 당시 유행하던 옷차림을 한 두 흑인 남자와 한 흑인 여자가 타고 있었다.',
#  '777': '그들의 눈동자가 거만스러운 경쟁 의식으로 우리를 바라볼 때 나는 그만 소리내어 웃고 말았다.',
#  '778': '개츠비의 얼굴에는 아무런 변화의 빛도 보이지 않았다.',
#  '779': '어느 환기 잘 되는 42번가의 지하실에서 점심을 먹기 위해 나는 개츠비를 만났다.',
#  '780': '바깥 거리의 찬란한 햇살에 익숙해 있던 나는 어떤 남자와 옆방에서 이야기를 나누고 있는 그를 간신히 찾아 낼 수 있었다.',
#  '781': '키가 작고 코가 납작하게 생긴 유태인이 커다란 머리를 들어 나를 쳐다보았다.',
#  '782': '그는 양쪽으로 가른 탐스러운 머리칼을 양 콧구멍까지 길게 내려뜨리고 있었다.',
#  '783': '나는 지하 식당에 들어간 지 한참 후에야 희미한 어둠 속에서 그의 아주 작은 눈을 발견했다.',
#  '784': '그러나 분명히 그는 내게 말하고 있는 게 아니었다. 내 손을 놓은 그는 그 표정이 풍부한 코로 개츠비를 뒤덮었으니까.',
#  '785': '개츠비는 우리 두 사람의 팔을 잡아 끌고서 식당으로 들어갔다.',
#  '786': '울프심은 막 시작한 말을 끊고 마치 몽유병에 걸린 사람처럼 멍한 상태에 빠져 버렸다.',
#  '787': '울프심이 천장에 그려진 기독교풍의 요정을 쳐다보며 말했다.',
#  '788': '개츠비는 이렇게 대답하고 나서 울프심을 향해 말했다.',
#  '789': '울프심이 갑자기 우울한 표정으로 변하더니 잠깐 생각에 잠겨 말했다.',
#  '790': '우리는 여섯이서 테이블을 둘러싸고 있었지요.',
#  '791': '울프심의 코가 분개한 듯 나에게로 홱 돌려졌다.',
#  '792': '동시에 나온 이 두 가지 이야기에 나는 놀랐다. 개츠비가 깜짝 놀라 내 대신 대답했다.',
#  '793': '그는 식당의 감상적이었던 분위기는 깨끗이 잊어버린 듯 아주 맛있게 먹어 대기 시작했다.',
#  '794': '음식을 먹는 동안 그의 눈은 아주 천천히 식당 안을 살폈다.',
#  '795': '바로 뒤에 있는 사람들까지 돌아다봄으로써 식당 안을 한 바퀴 다 둘러본 뒤에야 그는 눈을 음식에 고정시켰다.',
#  '796': '만약 내가 없었더라면 그는 우리 테이블 밑도 잠시 살폈을 것이다.',
#  '797': '개츠비가 내 쪽으로 몸을 앞으로 기울이면서 말했다.',
#  '798': '또다시 그는 그 특유의 미소를 지어 보였으나, 이번에는 난 모른 척했다.',
#  '799': '당신은 왜 솔직하게 자신이 뭘 원하고 있는지에 대해서 말해 주지 않는 거죠.',
#  '800': '그는 갑자기 자기의 손목 시계를 들여다보더니 벌떡 일어났다.',
#  '801': '그리고는 나와 울프심을 식탁에 남겨 둔 것을 개의치 않고 혼자 방을 나가 버렸다.',
#  '802': '나는 그것들을 보고 있었던 것이 아니었는데, 그 말을 듣자 그것으로 눈길이 갔다.',
#  '803': '이렇듯 본능적인 신뢰감의 장본인이 식탁에 돌아와 앉자 울프심은 커피를 훌쩍 마시고는 일어섰다.',
#  '804': '울프심은 일종의 감사 기도라도 드리는 듯이 한 손을 들어 올렸다.',
#  '805': '그는 또다시 손을 흔들어서 자기에 대해 좀더 설명해 주었다.',
#  '806': '그가 악수하고 돌아설 때, 그의 특색 있는 코는 떨리고 있었다.',
#  '807': '나는 내가 혹시 그의 기분을 상하게 하는 말을 하지나 않았었나 하고 걱정했다.',
#  '808': '개츠비는 잠시 주저하더니 곧 냉정하게 덧붙였다.',
#  '809': '나는 되물었다. 그 말이 나를 동요시켰다. 나는 월드 시리즈가 1919년에 매수되었다는 사실은 꿈에도 생각하지 못했다.',
#  '810': '그것은 어떤 피할 수 없는 사정으로 그저 우발적으로 발생한 일일 거라고 생각했을 뿐이다.',
#  '811': '한 사람이 5천만 명이나 되는 사람들의 신념을 농락하려 나설 수 있으리라고는 생각조차 하지 못했던 것이다.',
#  '812': '웨이터가 거스름돈을 갖고 왔을 때, 나는 우연히 사람들로 가득찬 방 건너편에 있는 탐 부캐넌을 발견했다.',
#  '813': '우리를 보고 탐은 급히 일어나서 우리 쪽으로 발걸음을 옮겼다.',
#  '814': '두 사람은 간단하게 악수를 했다. 순간 개츠비는 당황한 것 같기도 하고, 긴장되 보이는 어색한 표정을 지었다.',
#  '815': '나는 개츠비 쪽을 돌아다보았지만, 그는 벌써 거기에 없었다.',
#  '816': '그녀는 편지를 꼭 쥐고 욕조속으로 들어가서는 그것을 꼭 쥐어짜서 젖은 덩어리로 만들어 버렸어요.',
#  '817': '그것이 눈송이처럼 산산이 부서지는 것을 보고서야 내게 주면서 비누 접시를 놔 두게 했어요.',
#  '818': '우리는 그녀에게 강한 암모니아수를 주고 이마에 얼음 맛사지를 한 다음에, 드레스를 입혀 등의 호크를 끼워 주었다.',
#  '819': '30분 뒤 우리가 그 방을 걸어나올 때 진주 목걸이는 그녀의 목에 걸려 있었다.',
#  '820': '다음 날 5시에 그녀는 조용히 탐 부캐넌과 결혼했고 9개월간의 남태평양 여행길에 올랐다.',
#  '821': '난 여행에서 돌아온 그들을 산타바바라에서 만났다.',
#  '822': '그 때 난 그녀처럼 남편에게 푹 빠진 여자는 처음 본다고 생각했었다.',
#  '823': "그녀는 남편이 잠시라도 밖에 나가면 불안해서 사방을 두리번거리며 '탐은 어디 갔지?' 하고 묻곤했다.",
#  '824': '그가 보일 때까지 정신 나간 표정을 짓고 있었다.',
#  '825': '해변의 모래 위에 앉아서 자기의 무릎을 베고 누운 남편의 눈을 어루만지며 한없이 기쁜 표정으로 그를 들여다보았다.',
#  '826': '그들이 함께 있는 것을 보는 건 무척 기분 좋은 일이었다.',
#  '827': '사람들로 하여금 말소리를 죽이게 하고 마음을 평화롭게 해 웃게 만들었다.',
#  '828': '그가 산타바바리를 떠난 지 일주일이 되던 날 밤에 탐이 벤튜라 거리에서 마차와 충돌했다.',
#  '829': '그와 같이 탔던 여자의 팔 하나가 부러졌기 때문에 여러 신문에 그 기사가 실렸다.',
#  '830': '그 여자는 산타바바라 호텔의 침실 담당 종업원이었다.',
#  '831': '다음 해 4월에 데이지는 여자아이를 낳았고, 그들은 일 년쯤 프랑스에서 시간을 보냈다.',
#  '832': '그녀가 이 모든 이야기를 끝냈을 땐 우리가 플라자 호텔을 출발한 지 벌써 반 시간이나 지난 후였다.',
#  '833': '그 때 우리는 빅토리아 포장 마차를 타고센트럴파크를 달리고 있었다.',
#  '834': '해는 이미 50번가의 영화배우들이 살고 있는 고층 아파트 뒤로 넘어갔다.',
#  '835': '어느 틈엔가 풀숲의 귀뚜라미처럼 모여든 아이들의 맑은 목소리가 뜨거운 황혼 속에서 들려 왔다.',
#  '836': '그렇다면 6월의 그 밤, 개츠비가 애원하듯 쳐다보고 있었던 것은 단지 별들이아니었던 것이다.',
#  '837': '그는 목적없이 화려하기만 한 그의 태내로부터 다시 태어나서 생동하며 나에게 나타났다.',
#  '838': '그의 소망이 그처럼 소박한 것에 나는 적이 감동했다.',
#  '839': '그는 5년이나 기다렸고 거대한 저택을 샀으며, 그 곳에서 자기 스스로 찾아온 하루살이들에게 별빛을 나누어 주었다.',
#  '840': "자신은 단지 어느 날 오후 남의 집 정원으로 '초대받을 수 있기를' 기다리고 있었던 것이다.",
#  '841': '그는 만나는 사람마다 혹시 데이지를 아느냐고 묻기 시작했어요.',
#  '842': '내가 바로 데이지를 알고 있는 첫 번째 사람이 되었어요.',
#  '843': '그가 댄스 파티에서 사람을 시켜 나를 초대한 바로 그 날 밤의 일이었어요.',
#  '844': '그가 그렇게 하려고 노력했던 그 세심한 자세를 당신도 들으셨더라면 좋았을 텐데요.',
#  '845': '나는 물론 그에게 당신을 뉴욕에서의 점심식사에 초대하라는 제안을 즉시 해 주었어요.',
#  '846': '당신이 탐의 각별한 친구라고 말하자, 그는 모든 계획을 포기해 버리려고 했어요.',
#  '847': '어둠이 서서히 깔리기 시작했고 우리가 탄 마차는 조그마한 다리 아랫길로 접어들고 있었다.',
#  '848': '나는 한 팔로 조던의 황금빛이 도는 어깨를 껴안아 내 쪽으로 끌어당기면서 그녀를 저녁 식사에 초대했다.',
#  '849': '어느 새 나는 데이지나 개츠비에 대해서는 잊어버리고 말았다.',
#  '850': '검은 나무숲의 장벽을 지나 59번가로 접어들자 희미한 한 줄기 불빛이 공원쪽을 내리비추고 있었다.',
#  '851': '내게는 몇 년씩 잊지 못하고 가슴아파하는 그런 여인이 없었다.',
#  '852': '그래서 나는 두 팔에 힘을 주어 조던을 끌어당겼다.',
#  '853': '그녀의 파리하고 비웃는 듯한 미소가 입가에 떠올랐다.',
#  '854': '그것을 보고 나는 그녀를 더 가까이 끌어당겼고 마침내는 내 얼굴에까지 끌어당겼다.',
#  '855': '그 날 밤 웨스트에그로 돌아왔을 때, 나는 내 집에 불이 난 게 아닌가 하는 착각에 빠졌다.',
#  '856': '새벽 2시였는데 집 주변 전체가 불빛으로 이글거렸다.',
#  '857': '그 불빛은 관목숲을 영화 속의 한 장면처럼 비춰 주었으며, 길가의 전선들을 가느다란 황금빛 선으로 번뜩이게 했다.',
#  '858': '처음 나는 무슨 파티라도 열려서 화려한 야회가 끝나고 놀이를 위해 개방된 것으로 생각했다.',
#  '859': '길모퉁이를 돌아서야 나는 개츠비의 저택 전체에 불이 켜져 있어 그렇게 보였다는 것을 알았다.',
#  '860': '그러나 그 곳에서는 아무 소리도 들리지 않았다.',
#  '861': '나무들 사이에서 바람이 일어 전선을 움직이게 했고 그래서 불빛이 계속 비쳤다 사라졌다 했다.',
#  '862': '나는 개츠비가 잔디밭을 가로질러 내게로 걸어오는 것을 볼 수 있었다.',
#  '863': '그는 얼빠진 모습으로 시선을 그 쪽으로 돌렸다.',
#  '864': '그는 잠시 생각에 잠기더니 주저하며 말했다.',
#  '865': '내 집의 볼품없는 잔디밭이 끝난 곳에 선명하게 선이 그어져 그 지점부터 손질이 잘 된 그의 잔디밭이 시작되고 있었다.',
#  '866': '나는 그가 내 잔디밭을 두고 하는 말이 아닌가 하고 생각했다.',
#  '867': '그는 어쩔 줄 몰라하며 말을 잇지 못하고 더듬거렸다.',
#  '868': '이 말이 그를 안심시킨 듯 했다. 그는 조금 전보다 한결 자신 있게 말을 계속했다.',
#  '869': '지금에야 깨달은 것인데, 다른 상황에서였다면 그 이야기는 내 인생을 바꿀 사건이 되었을지도 모르는 것이다.',
#  '870': '그 당시 그 제안을 형식적인 것이었으므로 나로서는 그 자리에서 깨끗하게 거절할 수밖에 없었다.',
#  '871': "분명히 그는 앞서의 점심 식사 때 언급된 '거래선'이라는 말 때문에 내가 물러선 것으로 생각한 모양이었다.",
#  '872': '그래서 나는 그가 잘못 생각한 것이라고 말해주었다.',
#  '873': '그는 내가 이야기를 계속하기를 바라면서 잠시 더 기다렸다.',
#  '874': '나는 내 생각이 너무 강했기 때문에 거기에 응하질 못했다.',
#  '875': '그러자 그는 하는 수 없이 집으로 돌아갔다.',
#  '876': '그 날 밤 나는 마음이 개운하고 즐거웠다. 나는 현관문을 들어서자 곧 깊은 잠에 빠져들었다.',
#  '877': "나는 개츠비가 코니아일랜드로 갔었는지 아니면 저택에 불을 현란하게 켜 놓고 몇 시간이나 '방들을 살펴보았는지'를 모른다.",
#  '878': '다음날 아침 나는 사무실에서 데이지에게 전화를 걸어 만찬에 초대했다.',
#  '879': '11시쯤 우의를 입은 한 남자가 제초기를 끌고 와서 현관문을 두드렸다.',
#  '880': '개츠비가 우리 집 잔디를 갂으라고 보냈다는 말을 덧붙였다.',
#  '881': '그것은 내가 핀란드인 가정부에게 일하러 오라고 말한다는 걸 그만 잊어 버린 것을 생각나게 해 주었다.',
#  '882': '나는 빗물이 깨끗이 씻어 내린 골목길들을 정신없이 돌아다닌 끝에 그녀를 찾아냈다.',
#  '883': '약간의 컵과 레몬과 꽃을 사기 위해 차를 몰고 웨스트에그 마을로 들어갔다.',
#  '884': '그러나 내가 사 온 꽃들은 잠시 후 필요가 없게 되었다.',
#  '885': '2시가 되자 개츠비의 저택으로부터 꽃을 담을 수많은 용기와 화분 하나가 도착했기 때문이다.',
#  '886': '1시간쯤 지나자 현관문이 거칠게 열리더니 하얀 플란넬 양복에 은빛 셔츠와 금빛 넥타이 차림의 개츠비가 허겁지겁 들어섰다.',
#  '887': '그의 얼굴은 창백했고 특히 눈이 피곤해 보였다.',
#  '888': '그러나 그의 표정으로 판단하건대 그의 눈에는 아무 것도 들어오지 않는 것 같았다.',
#  '889': '어느 신문을 보았더니, 비는 4시쯤이면 그칠 것이라 했더군요.',
#  '890': '나는 그를 식료품실로 데리고 들어갔는데, 그는 핀란드인 가정부를 좀 못마땅한 표정으로 바라보았다.',
#  '891': '우리 두 사람은 식료품점에서 사 온 12개의 레몬 케이크를 자세히 살펴보았다.',
#  '892': '3시 30분쯤 되자 비는 선선한 안개로 변하더니 가는 빗방울로 변했다.',
#  '893': '이따금 그 안개를 뚫고 가는 빗방울이 이슬처럼 흩날렸다.',
#  '894': "개츠비는 멍한 눈초리로 클레이의 '경제학'을 훑어보고 있었다.",
#  '895': '마치 밖에서 충격적인 사건들이 벌어지고 있기라도 하듯이 가끔 흐릿한 창문 쪽으로 시선을 보내기도 했다.',
#  '896': '마침내 그는 일어서더니 나지막한 소리로 자기 집으로 돌아가겠다는 것을 나에게 알렸다.',
#  '897': '그는 무슨 다급한 약속이라도 있는 것처럼 시계를 들여다보았다.',
#  '898': '그는 마치 내가 자기를 붙잡아 눌러 버리기라도 한 것처럼 참담한 표정으로 의자에 도로 주저앉았다.',
#  '899': '바로 그 때 내 집의 오솔길로 차가 들어오는 소리가 들렸다.',
#  '900': '동시에 우리 둘은 벌떡 일어섰고, 나는 좀 걱정스런 심정으로 마당으로 나갔다.',
#  '901': '한 대의 대형 무개차가 물방울을 뚝뚝 떨어뜨리는 라일락 나무 아래를 지나 집안 차도를 달려 올라오고 있었다.',
#  '902': '차가 멈추자 삼각모를 한쪽으로 살짝 기울게 쓴 데이지가 밝고 황홀한 미소를 띠고 나를 바라보았다.',
#  '903': '사람의 마음을 울렁거리게 하는 그녀의 목소리는 빗속에서 거친 고음으로 퍼져왔다.',
#  '904': '나는 어떤 말이 나올 때까지 한동안 그저 귀를 쫑긋거리며 가만 있어야 했다.',
#  '905': '그녀의 뺨에는 한 가닥의 젖은 머리카락이 푸른 물감으로 가늘게 그은 것처럼 내려붙어 있었다.',
#  '906': '그녀가 차에서 내릴 때 거들려고 잡은 그녀의 손은 물방울로 빛나고 있었다.',
#  '907': '운전사에게 이렇게 말하고 나서 그녀는 소리를 낮춰 내게 소곤거렸다.',
#  '908': '그녀는 현관문을 점잖게 노크하는 소리가 가볍게 들려 오자 그 쪽으로 고개를 돌렸다.',
#  '909': '개츠비가 물 구덩이 속에 서서 양손을 웃옷 주머니에 찔러 넣은 채 내 눈을 주시하고 있는 것이 보였다.',
#  '910': '그는 양손을 계속 웃옷 주머니에 찔러 넣은 채 내 곁을 지나 홀로 들어가더니  몸을 홱 돌려 거실로 사라졌다.',
#  '911': '나는 가슴을 몹시 두근거리는 것을 의식하면서 한층 세차게 쏟아지는 비를 막으려고 현관문을 잡아당겼다.',
#  '912': '거실로부터 숨을 죽인 것 같은 속삭임과 짧은 웃음소리가 들리고 이어 데이지의 가식적인, 낭랑한 목소리가 들려 왔다.',
#  '913': '그 시간이 너무나 길게 느껴졌다. 나는 홀에서 할 일도 없고 해 거실로 들어갔다.',
#  '914': '개츠비는 여전히 양손을 웃옷 주머니에 찔러 넣은 채 지나칠 정도로 아주 편안한듯 보였다.',
#  '915': '아니 지루할 정도라는 여유 있는 태도를 취하며 벽난로 선반에 기대에 서 있었다.',
#  '916': '그는 시계의 숫자판에 기대 머리를 뒤로 깊숙이 젖힌 채 두 눈으로 데이지를 뚫어지게 내려다보고 있었다.',
#  '917': '데이지는 놀랐지만 우아한 자태로 딱딱한 의자의 모서리에 침착하게 앉아 있었다.',
#  '918': '그는 순간적으로 흘끗 나를 쳐다보았고, 그의 입술은 웃으려고 노력했으나 끝내 웃음은 나오지 않았다.',
#  '919': '시계가 그의 머리에 눌려서 위험할 정도로 기울어지자, 그는 뒤로 돌아서서 떨리는 손가락으로 그것을 붙잡아 다시 제자리에 걸쳐 놓았다.',
#  '920': '그는 소파에 경직되게 앉아 팔꿈치를 팔걸이에 얹고 손으로 턱을 괴었다.',
#  '921': '내 머릿속에는 하고 싶은 말이 너무나 많았으나, 단 한 마디의 평범한 말조차 꺼낼 수가 없었다.',
#  '922': '바로 그 순간 시계가 방바닥에서 떨어져서 박살이 났다.',
#  '923': '데이지가 말했다. 그녀의 목소리는 더할 수 없이 침착했다.',
#  '924': '개츠비가 한 이 대답의 어투가 우리로 하여금 또다시 최소한 1분간은 말을 중단하게 만들었다.',
#  '925': '간신히 그들을 일어서게 했을 때 눈치없는 핀란드 인 가정부가 차를 쟁반에 담아 가지고 들어왔다.',
#  '926': '찻잔들과 케이크를 받아 놓는 약간의 소란 속에서도 그들의 어떤 자연스런 예의는 철저히 지켜졌다.',
#  '927': '내가 데이지와 이야기를 나누는 동안 그는 긴장되고 침울한 눈초리로 물끄러미 우리 두 사람을 번갈아 바라보았다.',
#  '928': '여하튼 침묵을 어서 깨야 할 것이기에 나는 틈을 타서 핑계를 대고 일어섰다.',
#  '929': '그는 허겁지겁 내 뒤를 부엌으로 들어오더니 문을 닫고는 풀이 죽어 귓속말로 말했다.',
#  '930': '그는 믿어지지 않는다는 듯이 되물었다.',
#  '931': '그는 한 손을 들어 내 말을 막았고, 책망하는 눈초리로 나를 바라보고는 조심스럽게 문을 열고 그 방으로 되돌아갔다.',
#  '932': '나는 30분쯤 전에 개츠비가 불안스럽게 집을 한 바퀴 돌았을 때와 똑같은 모습으로 뒷길을 빠져 나갔다.',
#  '933': '빽빽한 나뭇잎들이 비를 막아 주는 덮개 구실을 해주었다.',
#  '934': '비는 또다시 억수같이 퍼붓고 있었다.',
#  '935': '개츠비의 정원사가 잘 깎아 준 나의 잔디밭은 작은 흙탕 구덩이와 늪을 많이 만들어 내고 있었다.',
#  '936': '나무 밑에서 바라볼 만한 것이라고는 개츠비의 거대한 저택밖에 없었다.',
#  '937': '나는 반 시간 동안이나 칸트가 그의 교회 첨탑을 바라보았듯이 그것을 바라보고 있었다.',
#  '938': "그 저택은 10년쯤 전에 어떤 양조업자가 '시대'의 유행에 따라 지은 최신형의 것이었다.",
#  '939': '그 양조업자는 모든 이웃 오두막집 주인들에게 만약 그들이 짚으로 지붕을 이으면 5년간의 세금을 대신 내주겠다고 했다고 한다.',
#  '940': "그들의 거절로 '한 가문을 창립'하려던 그의 계획은 좌절되었고 그의 가문은 몰락해 버렸다.",
#  '941': '그의 자식들은 현관문에 새긴 검은 화환을 그대로 둔 채 그 집을 팔았던 것이다.',
#  '942': '미국인들이란 기꺼이 혹은 열성적으로 농노 노릇을 하려고 하면서도 언제나 농부의 위신을 잃지 않으려는 노력한다.',
#  '943': '하인들의 저녁 식사 재료를 실은 식료품점의 자동차가 개츠비의 저택 차도로 달려오는 게 보였다.',
#  '944': '나는 개츠비는 분명히 그런 음식은 한 숟가락도 먹으려고 하지 않을 것이라고 생각했다.',
#  '945': '하녀 하나가 그의 저택 이층 창문을 열기 시작했다.',
#  '946': '그녀는 창문으로마다 모습을 나타내고는 밖으로 내어 커다란 창문에 몸을 기대고 정원을 향해 침을 뱉었다.',
#  '947': '계속해서 비가 내릴 때의 빗소리는 감정이 격해짐에 따라 높아지곤 하는 개츠비와 데이지의 속삭임처럼 들렸었다.',
#  '948': '비가 그친 뒤의 새로운 고요함에 빠져 들자 그 고요함은 집 안까지 깃들인 것같이 느껴졌다.',
#  '949': '난로를 넘어뜨릴 뻔한 소리를 내는 등 부엌에서 가능한 모든 시끄러운 소리를 낸 연후에 나는 거실로 들어갔다.',
#  '950': '그러나 그들이 그 어떤 소리를 들었으리라고는 생각지 않는다',
#  '951': '두 사람은 긴 의자 양 끝에 앉아 서로 마주 보고 있었다',
#  '952': '마치 무슨 질문이 오고갔거나 혹은 그것이 허공에 떠 있는 것 같았으나 조금 전의 그 당황의 흔적은 보이지 않았다.',
#  '953': '내가 들어서자 그녀는 자리에서 일어나 거울 앞으로 다가가서는 손수건으로 얼굴을 닦기 시작했다.',
#  '954': '한편 개츠비에게 놀랄 만한 변화가 있었다. 그는 정말로 환한 빛을 발하고 있었다.',
#  '955': '환희의 말 한 마디도 행동도 없었지만, 새로운 행복감이 넘쳐 흐르는 그 빛은 작은 방을 가득 채우고 있었다.',
#  '956': '그는 마치 오랜만에 나를 만난 것처럼 말했다. 나는 한 순간 그가 악수를 하려는 것으로 생각했다.',
#  '957': '그는 내가 무슨 말을 하는지를 알아차렸다. 그리고 방 안에 눈부신 방울 같은 햇살이 비치고 있는 것을 깨달았다.',
#  '958': '다시 나타난 빛을 매우 기뻐하는 사람 같은 미소를 띠며 데이지에게 그 소식을 되풀이해서 말했다.',
#  '959': '가슴아플 만큼 슬픔이 깃들인 데이지의 낭랑한 목소리는 다만 예기치 못한 기쁨만을 나타냈다.',
#  '960': '나는 내 더러운 타월을 생각하고 부끄러운 생각이 들었으나 때는 이미 늦었다,',
#  '961': '그 동안 개츠비와 나는 잔디밭에서 그녀를 기다렸다.',
#  '962': '그는 자신의 집의 아치형 문 하나하나와 네모난 탑으로 시선을 옮겼다.',
#  '963': '지금 생각하면 그 때 그는 자신이 무슨 말을 하고 있는지도 모르고 있었던 것 같다.',
#  '964': '내가 무슨 일을 했었느냐고 물었을 때 그 대답이 동문서답이라는 것을 깨닫기도 전에 그는 대답했다.',
#  '965': '내가 미처 대답하기 전에 데이지가 집 밖으로 나왔기 때문에 더 이상 이야기하지 못했다.',
#  '966': '그녀의 드레스에 두 줄로 달린 놋쇠 단추가 햇빛을 받아 반짝였다.',
#  '967': '우리는 해협을 따라 난 지름길로 가는 대신 한길까지 내려가 거대한 뒷문을 통해서 개츠비의 저택으로 들어갔다.',
#  '968': '데이지는 푸른 하늘을 배경으로 한 봉건시대풍 건물의 검은 윤곽을 여기저기로 살펴보면서 감탄했다.',
#  '969': '그녀는 또한 정원과 수선화의 향기, 아가위와 서양 자두꽃의 거품 같은 향기, 그리고 야생 오랑캐꽃의 연한 향기에 감탄했다.',
#  '970': '집 앞 대리석 계단에 이르렀는데도 현관문 안팎에 인적은 보이지 않고 새소리밖에 들리지 않는 것이 이상했다.',
#  '971': '집안으로 들어가 마리 앙투아네트 음악실들과 왕정복고시대풍의 객실들을 서성거리다가 나는 비로소 그 이유를 알게 되었다.',
#  '972': '모든 손님들은 긴 의자와 테이블 뒤에 숨어서 우리가 지나갈 때까지 숨을 죽이고 가만히 있으라는 지시를 받았던 것이다.',
#  '973': '나는 분명히 그 올빼미 눈 같은 안경을 낀 남자가 유령 같은 기분 나쁜 웃음을 터뜨리는 소리를 들은 것 같았다.',
#  '974': '우리는 이층으로 올라가 침실들과 화장실, 그리고 당구장을 지나 욕조가 움푹 들어간 욕실들을 둘러보았다.',
#  '975': '다음 어떤 방으로 들어가자 머리가 헝클어진 남자 파자마 바람으로 방바닥에서 간장 운동을 하고 있었다.',
#  '976': "그는 '하숙생'이라는 별명을 가진 클립스프링거였다.",
#  '977': '나는 그날 아침에 해변가에서 할 일없이 서성거리는 그를 보았었다.',
#  '978': '우리는 침실과 욕실, 그리고 서재가 갖춰진 개츠비의 거처로 가서 앉아 그가 벽장에서 꺼내 온 술을 한 잔씩 마셨다.',
#  '979': '개츠비는 잠시도 데이지에게서 눈을 떼지 않았다.',
#  '980': '그는 자신의 집에 있는 모든 물건들을 데이지의 아름다운 두 눈에 비치는 반응에 따라 재평가하고 있다고 느꼈다.',
#  '981': '그는 데이지가 자기 눈앞에 실제로 와 있는 상황에서는 소유하고 있는 물건 따위는 이제 하나도 현실감이 없다는 듯이 멍하게 둘러보았다.',
#  '982': '그러다가 한 번은 계단에서 거의 굴러 떨어질 뻔하기도 했다.',
#  '983': '그의 침실은 모든 방중에서 제일 수수했다, 다만 경대가 순금제 화장 세트로 장식되어 있는 것을 빼고는.',
#  '984': '데이지는 그 앞에서 아주 좋아하며 머리솔을 집어들어 자신의 머리를 빗었다.',
#  '985': '그러는 동안에 개츠비는 의자에 앉아 두 눈을 가리고 웃음을 보였다.',
#  '986': '그는 이제 두 가지 과정을 거쳐서 세 번째 과정으로 접어들고 있는 것이 분명했다.',
#  '987': '당황함과 이유 없는 환희를 거쳐 이제는 데이지가 눈앞에 있는 데에 대한 놀라움으로 어리둥절해지고 있었다.',
#  '988': '그는 아주 오랫동안 이렇게 되리라는 생각만을 해 왔고 처음부터 끝까지 꼭 이렇게 되리라고 상상해 왔다.',
#  '989': '말하자면 상상조차 할 수 없을 정도로 이를 악물고 기다려 왔던 것이다.',
#  '990': '이제 그는 그 반동으로 태엽을 너무 감아 놓은 시계처럼 천천히 풀리고 있었다.',
#  '991': '그는 우리에게 양복과 화장 가운과 넥타이가 가득차 있고 셔츠가 수북히 쌓인 두 개의 커다란 옷장을 열어 보여 주었다.',
#  '992': '그는 셔츠 더미 하나를 꺼내 하나씩 우리 앞으로 던졌다.',
#  '993': '두터운 비단, 곱게 짠 플란넬 셔츠들이 풀려 형형색색의 색깔로 테이블을 뒤덮었다.',
#  '994': '우리가 감탄하는 가운데 그는 다른 한 더미의 셔츠들을 꺼내 테이블 위에 올려놓았다.',
#  '995': '산호색, 풋사과의 녹색, 라벤더색 그리고 연한 오렌지색 바탕에 줄무늬, 소용돌이 무늬, 체크 무늬가 있는 셔츠들이었다.',
#  '996': '그 속엔 하늘색 글자로 모노그램이 수놓여 있었다.',
#  '997': '그것들을 본 데이지가 갑자기 그 속에 머리를 파묻고 흥분한 소리로 격렬하게 울어대기 시작했다.',
#  '998': '그녀는 흐느끼며 말했는데, 그 소리는 겹겹으로 쌓인 셔츠에 묻혀 잘 들리지 않았다.',
#  '999': '집안을 둘러본 뒤엔 마당과 풀장, 그리고 수상기와 잘 가꿔진 꽃들을 볼 계획이었다.',
#  '1000': '밖엔 다시 비가 내리기 시작했으므로 우리는 나란히 서서 파도치는 바다를 바라보고 있었다.',
#  ...}

# %%
zip = zipfile.ZipFile(src)

if input_map:
    zip.extractall(dst_root)
    zip.close()

# %%
for (path, text) in input_map.items():
    rpath = path
    ipath = os.path.join(dst_root, path.lstrip('/'))
    tcount += 1


    if not os.path.exists(ipath):
        #ipath = os.path.join(dst_root, '**', '%s.*' % path.lstrip('/'))
        ipath = os.path.join(dst_root, '%s.*' % path.lstrip('/'))

        ipath_list = glob.glob(ipath, recursive=True) #오래걸리는 주범
        if not ipath_list:
#                           
            continue

#                            
        rpath = os.path.relpath(ipath_list[0], dst_root)

    meta_json['records'].append({
        'file_url': os.path.join(dst_postfix_dir, rpath),
        'text': text
    })

# %%
meta_json
# Out:
# {'muse_id': '0123',
#  'records': [{'file_url': 'python 스터디/2',
#    'text': '그 후로 나는 그 충고를 마음속으로 항상 되새기곤 했다.'},
#   {'file_url': 'python 스터디/3',
#    'text': '남 의 잘잘못을 따질 때는 언제든지 이 세상 사람들이 너처럼 좋은 환경에서 자라지 못했다는 것을 기억해야 한다.'},
#   {'file_url': 'python 스터디/4',
#    'text': '아버지께서는 더 이상 말씀하시지 않았지만, 우리는 말없는 가운데서도 서로의 뜻을 잘 이해할 수 있었다.'},
#   {'file_url': 'python 스터디/5',
#    'text': '나는 아버지의 그 충고 속에는 보다 더 깊은 뜻이 담겨 있다는 것을 알아차렸다.'},
#   {'file_url': 'python 스터디/6',
#    'text': '아버지의 그 충고로 말미암아 나는 모든 판단을 될 수 있으면 뒤로 미루는 태도를 취하곤 했다.'},
#   {'file_url': 'python 스터디/7',
#    'text': '그것 때문에 성가시게 치근덕거리는 몇몇 사람들로부터 어려움을 겪기도 했다.'},
#   {'file_url': 'python 스터디/8',
#    'text': '이러한 성격의 소유자들은 나와 같은 정상적인 사람이 나타나면 금방 눈치채고 가까이 오게 마련이다.'},
#   {'file_url': 'python 스터디/9',
#    'text': '그것은 내가 거친, 세상에 알려지지 않은 사람들의 은밀한 비애를 많이 알고 있었기 때문이었다.'},
#   {'file_url': 'python 스터디/10',
#    'text': '어떤 확실한 근거로 은밀한 이야기가 드러나려 할 때면 나는 잠을 자는 척하거나, 적의에 찬 경박한 짓을 하곤 했다.'},
#   {'file_url': 'python 스터디/11',
#    'text': '사실 젊은이들의 은밀한 이야기는, 적어도 그것을 표현할 때 쓰는 말투도 대개 남의 말을 표절하게 마련이다.'},
#   {'file_url': 'python 스터디/12',
#    'text': '때로는 어떤 의견 표명을 삼가고 있다는 것이 상대에게 무한한 희망을 줄 때도 있는 법이다.'},
#   {'file_url': 'python 스터디/13',
#    'text': '이처럼 나의 너그러움을 한껏 과시하고 난 후에야 나는 너그러움에도 한계가 있다는 것을 알게 되었다.'},
#   {'file_url': 'python 스터디/14',
#    'text': '어떤 한계만 넘기게 되면 나는 그 행위가 어떤 곳을 기반으로 해서 겉으로 드러나게 된 것이든 상관하지 않는다.'},
#   {'file_url': 'python 스터디/15',
#    'text': '작년 가을, 동부에서 돌아왔을 때 나는 사람들이 똑같은 차림을 하고 일종의 도덕적인 자세를 취해 주었으면 하고 바랐다.'},
#   {'file_url': 'python 스터디/16',
#    'text': '무슨 특권이라도 지닌 듯이 사람의 마음속을 힐끔힐끔 들여다보는, 야단스럽게 나서는 일에 진저리가 났다.'},
#   {'file_url': 'python 스터디/17',
#    'text': '오직 한 사람, 이 책의 주인공인 개츠비만은 앞에서 말한 나의 반발에서 제외된 사람이다.'},
#   {'file_url': 'python 스터디/18',
#    'text': '개츠비는 바로 내가 노골적으로 경멸한 모든 것을 포함하고 있는 대표적인 사람이었던 것이다.'},
#   {'file_url': 'python 스터디/19',
#    'text': '내가 지금껏 그 누구에게서도 발견하지 못했을 뿐 아니라 앞으로도 영원히 발견하지 못할 낭만적 감수성이었다.'},
#   {'file_url': 'python 스터디/20',
#    'text': "이 감수성은 저 '창의적인 기질'아래에 위엄을 떨치는 그 허약한 감수성과는 분명히 차이가 있었다."},
#   {'file_url': 'python 스터디/21',
#    'text': '우리 가족들은 이 중서부의 도시에서 3대에 걸쳐 꽤 이름이 알려진 유지로 부유하게 살아 왔다.'},
#   {'file_url': 'python 스터디/22',
#    'text': '캐러웨이가는 뛰어난 가문이며, 우리는 부클류 공작의 자손이라고 전해지고 있다.'},
#   {'file_url': 'python 스터디/23',
#    'text': '실제로 나의 가계를 일으켜 세운 사람은 1851년에 이 곳에 이주하셨다.'},
#   {'file_url': 'python 스터디/24',
#    'text': '남북 전쟁 때 자기 대신 다른 사람을 대신 내보내고, 철물 도매상을 시작하셨던 나의 증조부이시다.'},
#   {'file_url': 'python 스터디/25',
#    'text': '지금은 아버지가 그 사업을 이어받아 경영하고 계시다. 나는 그 증조부를 한 번도 뵌 적이 없다'},
#   {'file_url': 'python 스터디/26',
#    'text': '나는 1915년에 예일 대학을 졸업했는데, 그것은 아버지께서 그 학교를 졸업하신지 25년째 되던 해의 일이었다.'},
#   {'file_url': 'python 스터디/27',
#    'text': '얼마 후에 나는 1차 세계 대전이라는, 튜튼족의 때늦은 이동 작업에 참가했다.'},
#   {'file_url': 'python 스터디/28',
#    'text': '그때 나는 미국인의 유럽 역습을 마음껏 즐겼기 때문에 집에 와서도 한동안 들뜬 마음을 진정시킬 수가 없었다.'},
#   {'file_url': 'python 스터디/29',
#    'text': '미국의 중서부 지방이 이제는 세계의 활기찬 중심지가 아니라 우주의 초라한 변두리같이 보였다.'},
#   {'file_url': 'python 스터디/30',
#    'text': '나는 동부로 가서 증권업을 배우기로 결심했다. 내가 아는 사람들은 하나같이 증권업에 종사하고 있었기 때문이었다.'},
#   {'file_url': 'python 스터디/31',
#    'text': '집안 아주머니들은 마치 나를 위해 무슨 대학 진학의 예비 고교를 골라 주기라도 하는 것처럼 그 문제에 대해 여러 가지로 의논하셨다.'},
#   {'file_url': 'python 스터디/32',
#    'text': '마지막으로 매우 엄숙하고 망설이는 표정으로, "글세, 괜찮을 거야."라고 말씀하셨다.'},
#   {'file_url': 'python 스터디/33',
#    'text': '사무실의 한 젊은 동료가 기차 통근 거리의 마을에 셋집을 얻어 같이 생활하자고 말해 왔을 때 그것은 멋진 생각처럼 들렸다.'},
#   {'file_url': 'python 스터디/34',
#    'text': '월세 80달러짜리로 비바람에 낡은 싸구려 방갈로 집이었다. 마지막 순간에 그는 회사로부터 워싱턴으로의 전근 명령을 받았다.'},
#   {'file_url': 'python 스터디/35',
#    'text': '. 나는 그 때 개 한 마리를 갖고 있었는데 그 개가 달아나기 전까지 적어도 2, 3일 동안은 함께 생활했다.'},
#   {'file_url': 'python 스터디/36',
#    'text': '요리용 전기 난로 위로 몸을 구부리고는 알 수 없는 혼잣말로 핀란드 속담을 중얼거리곤 했다.'},
#   {'file_url': 'python 스터디/37',
#    'text': '하루 이틀은 무척 외로웠는데, 어느 날 아침 길에서 나보다 늦게 이사 온 어떤 사람이 나를 불러 세웠다.'},
#   {'file_url': 'python 스터디/38',
#    'text': '나는 안내자요 개척자요 맨 처음 이 곳에 초기 정착한 사람이 되었던 것이다.'},
#   {'file_url': 'python 스터디/39',
#    'text': '나는 햇빛과 그리고 고속 촬영 영화에서 식물이 자라는 것처럼 쑥쑥 크는 나뭇잎들을 보았다.'},
#   {'file_url': 'python 스터디/40',
#    'text': '인생은 여름과 함께 다시 시작된다는, 지극히 평범한 사실을 깨닫기에 이르렀다.'},
#   {'file_url': 'python 스터디/41',
#    'text': '우선 먼저 할 일은 독서와 더불어 신선한 호흡을 하게 해 주는 맑은 공기에서 건강을 얻어내는 일이었다.'},
#   {'file_url': 'python 스터디/42',
#    'text': '그것들은 조폐국에서 금방 찍어 낸 새 돈처럼 붉은빛과 황금빛을 띤 채 내 서가에 꽂혀있다.'},
#   {'file_url': 'python 스터디/43',
#    'text': "나는 대학 시절 문학에 제법 자신이 있었다. 1년간 '예일 뉴스'지에 아주 품위 있고 명확한 논설을 연재한 적도 있을 정도였다."},
#   {'file_url': 'python 스터디/44',
#    'text': "난 지금의 내 생활에서 이러한 것들을 다시 찾아냄으로써, 다시 '박식하고 원만한 사람'이 되어 보려는 생각이었다."},
#   {'file_url': 'python 스터디/45',
#    'text': '결국 인생이란 여럿이 아닌 단 하나의 창문으로 바라보면 성공하기가 훨씬 더 쉬운 것이다.'},
#   {'file_url': 'python 스터디/46',
#    'text': '내가 북아메리카에서 가장 낯선 동네에 집을 얻게 된 것은 우연히 일어난 일 때문이었다.'},
#   {'file_url': 'python 스터디/47',
#    'text': '집은 뉴욕의 동쪽으로 곧장 뻗은 그 길쭉하고 요란스러운 섬 위에 있었다.'},
#   {'file_url': 'python 스터디/48',
#    'text': '그곳에는 천연의 진기물들이 많이 있었는데, 그 가운데 특이한 지역이 두 군데 있었다.'},
#   {'file_url': 'python 스터디/49',
#    'text': '롱아일랜드 해협이라 불리는, 물에 젖은 넓은 뒷마당 안으로 솟아 나온 그 두 지대는 완전한 달걀 모양은 아니었다.'},
#   {'file_url': 'python 스터디/50',
#    'text': '날개가 없는 인간을 더욱 재미있게 하는 것은 그 두 지대가 모양과 크기를 빼고는 모든 점에서 닮은 점이 하나도 없다는 사실이었다.'},
#   {'file_url': 'python 스터디/51',
#    'text': '해협에서 50야드밖에 안 떨어진 맨 꼭대기 부분에 있는 나의 집은 어마어마하게 좋은 두 채의 저택 사이에 끼여 있었다.'},
#   {'file_url': 'python 스터디/52',
#    'text': '내가 세든 집의 오른쪽에 있는 저택은 어느 모로 보나 위압감을 주는 대저택이었다.'},
#   {'file_url': 'python 스터디/53',
#    'text': '노르망디의 어떤 시의 청사를 본떠 만든 것이었는데, 그 집은 개츠비의 저택이었다.'},
#   {'file_url': 'python 스터디/54',
#    'text': '나는 개츠비라는 사람을 단 한 번도 보지 못했으므로 그런 이름을 가진 신사가 살고 있는 저택이었다고 해야 옳을 것이다.'},
#   {'file_url': 'python 스터디/55',
#    'text': '내가 세든 집은 주위의 환경과는 어울리지 않았지만 아주 작았기 때문에 그다지 거슬리는 것은 아니었다.'},
#   {'file_url': 'python 스터디/56',
#    'text': '나는 바다도 바라보고, 내 이웃집 잔디밭도 내다보면서 백만장자들의 이웃이라는 위안을 받았다.'},
#   {'file_url': 'python 스터디/57',
#    'text': '이름뿐인 만 건너편은 바닷가를 따라 호화로운 이스트에그의 하얀 저택들이 번쩍거리고 있었다.'},
#   {'file_url': 'python 스터디/58',
#    'text': '내가 탐 부캐넌 부부와 저녁 식사를 하러 그 곳으로 차를 몰고 간 바로 그 날 저녁에 이 여름의 역사는 시작되었다.'},
#   {'file_url': 'python 스터디/59',
#    'text': '전쟁이 끝난 직후에 나는 시카고에 사는 그들 부부와 이틀 동안 함께 지냈었다'},
#   {'file_url': 'python 스터디/60',
#    'text': '탐은 여러 가지 운동을 했는데, 특히 예일 대학의 축구 선수로는 보기 드문 강력한 스크럼 선수 가운데 하나였다.'},
#   {'file_url': 'python 스터디/61',
#    'text': '젊은 나이에 이미 정상의 위치에 올라 있었기에 그 후로는 모든 일에 있어 내리막길을 걷고 있는 듯한 느낌을 주는 인물이었다.'},
#   {'file_url': 'python 스터디/62',
#    'text': '그는 굉장한 부자였다. 대학을 다닐 때도 돈에 전혀 신경 쓰지 않는 그의 생활은 비난의 대상이 되기도 했다.'},
#   {'file_url': 'python 스터디/63',
#    'text': '지금 그는 시카고를 떠난 사람들을 깜짝 놀라게 할 정도의 멋진 계획을 세워서 동부에 와 있는 것이다.'},
#   {'file_url': 'python 스터디/64',
#    'text': '그 한 예로 그는 레이크 퍼리트로부터 폴로 경기용 말 한 떼를 끌고 왔던 것이다.'},
#   {'file_url': 'python 스터디/65',
#    'text': '내 또래의 남자로 어마어마한 그런 일을 할 정도로 돈이 많다니, 정말로 이해하기가 어려웠다.'},
#   {'file_url': 'python 스터디/66',
#    'text': '그들은 1년 동안을 프랑스에서 지냈다. 돌아와서는 폴로 경기를 하며 돈 많은 사람들이 있는 곳을 찾아다녔다.'},
#   {'file_url': 'python 스터디/67',
#    'text': '데이지는 내게 전화를 걸어 이번에는 영원히 이 곳에서 살고 싶다고 말했지만 나는 믿지 않았다.'},
#   {'file_url': 'python 스터디/68',
#    'text': '나는 따뜻한 바람이 불던 어느 날 저녁, 안면만 있는 두 명의 친구를 만나기 위해 이스트에그로 자동차를 몰고 갔다.'},
#   {'file_url': 'python 스터디/69',
#    'text': '그들의 집은 내가 상상한 것보다 훨씬 정교하게 지은, 왕조 시대의 식민지풍 저택이었다.'},
#   {'file_url': 'python 스터디/70',
#    'text': '잔디가 해안에서부터 집의 현관문까지, 그것은 도중에 해시계와 벽돌을 깐 보도 그리고 붉게 타는 듯한 정원을 지나서도 계속되었다.'},
#   {'file_url': 'python 스터디/71',
#    'text': '마침내 집까지 이어져서는 한쪽으로 마치 관성의 법칙으로 인한 양 선명한 빛깔의 덩굴 숲으로 이어져 있었다.'},
#   {'file_url': 'python 스터디/72',
#    'text': '저택의 정면은 햇빛을 받아 금빛으로 반짝이고 한 줄로 가지런하게 달린 창문들은 따뜻한 바람을 맞으려고 활짝 열려져 있었다.'},
#   {'file_url': 'python 스터디/73',
#    'text': '마복 차림의 탐 부캐넌이 두 다리를 벌린 꼿꼿한 자세로 정면 베란다에 서 있었다.'},
#   {'file_url': 'python 스터디/74',
#    'text': '지금의 그는 건강한 체격에 밀짚빛 머리칼을 지닌 30대의 사나이로, 굳게 다문 입이 오만한 느낌을 주었다.'},
#   {'file_url': 'python 스터디/75',
#    'text': '거만스러운 두 눈이 얼굴을 온통 뒤덮고 있었으며, 싸울 상대를 만나기라도 한 것처럼 몸을 앞으로 굽히고 있었다.'},
#   {'file_url': 'python 스터디/76',
#    'text': '여자의 옷처럼 화려한 승마복도 그의 육체의 엄청난 힘을 감추지는 못했다.'},
#   {'file_url': 'python 스터디/77',
#    'text': '꽉 끼이는 것처럼 보이는 번쩍이는 장화의 맨 위쪽 끈은 팽팽하게 죄어져 있었다.'},
#   {'file_url': 'python 스터디/78',
#    'text': '얇은 상의 밑으로 어깨가 움직일 때마다 우람한 근육이 꿈틀거리는 것을 볼 수 있었다.'},
#   {'file_url': 'python 스터디/79',
#    'text': '거칠고 센 듯한 그의 고음 목소리는 성깔 있어 보이는 그의 인상을 한층 더 강렬하게 보이게 했다.'},
#   {'file_url': 'python 스터디/80',
#    'text': '그의 목소리에는 친절한 사람들을 대할 때조차 고압적이고 경멸감이 담겨 있는 것처럼 보였다.'},
#   {'file_url': 'python 스터디/81',
#    'text': '"이러한 문제들에 대한 나의 의견이 결론적인 것이라고 생각하면 안되지. 내가 당신보다 힘이 세고 남자답다는 이유만으로 말이야"'},
#   {'file_url': 'python 스터디/82',
#    'text': '그와 나는 4학년 때 같은 사교 클럽에 들어 있었다. 결코 친한 사이는 아니었지만 그는 내게 항상 친절했다.'},
#   {'file_url': 'python 스터디/83',
#    'text': '특유의 거칠고 시비조인 불만스러운 태도를 취하기는 했지만 내가 자기를 좋아하기를 바라는 눈치였다.'},
#   {'file_url': 'python 스터디/84',
#    'text': '한 팔로 나를 돌려 세우며 넓적하고 편편한 손을 들어 앞으로 펼쳐져 있는 경치를 가리켰다.'},
#   {'file_url': 'python 스터디/85',
#    'text': '그는 공손하면서도 갑작스럽게 나를 또다시 빙 돌려세우면서 말했다. "이제 안으로 들어가세."'},
#   {'file_url': 'python 스터디/86',
#    'text': '창문 아래로는 집 안쪽으로 침입한 듯한, 싱그러움을 안겨 주는 풀밭이 펼쳐져 있었다.'},
#   {'file_url': 'python 스터디/87',
#    'text': '방 안 의자에는 젊은 여자 두 명이 마치 강철 줄로 매 놓은 기구에 앉은 것처럼 앉아 있었다.'},
#   {'file_url': 'python 스터디/88',
#    'text': '그 옷들은 마치 집의 주변을 잠시 날아다니다 바람에 밀려 지금 막 들어온 것처럼 가볍게 나부끼고 있었다.'},
#   {'file_url': 'python 스터디/89',
#    'text': '나는 커튼의 펄럭이는 소리와 벽에 걸린 액자의 흔들리는 소리에 정신에 빼앗긴 채 한동안 그대로 서 있었음에 틀림없다.'},
#   {'file_url': 'python 스터디/90',
#    'text': '탐 부캐넌이 뒤뜰의 창문을 닫는 소리가 들리더니 이어 바람이 멎어 조용해졌다.'},
#   {'file_url': 'python 스터디/91',
#    'text': '그녀는 긴 의자의 한쪽 끝에 몸을 쭉 펴고 앉아서는 석고상처럼 움직이지 않았다.'},
#   {'file_url': 'python 스터디/92',
#    'text': '마치 그 위에다 뭔가를 얹어 놓고 그것이 떨어지면 큰일날까 걱정이 되어 균형을 잡고 있는 것처럼 보였다.'},
#   {'file_url': 'python 스터디/93',
#    'text': '그녀가 나를 곁눈질해 보았는지는 몰라도 전혀 아는 척하지 않았다.'},
#   {'file_url': 'python 스터디/94',
#    'text': '사실 나는 놀랐고, 그래서 방안에 들어와서 그녀의 심리적 균형을 깬 것에 대해 사과의 말을 중얼거릴 뻔했다.'},
#   {'file_url': 'python 스터디/95',
#    'text': '어색하지만 매력적인 웃음을 지었다. 얼떨결에 나 역시 따라 웃고는 방안으로 들어갔다.'},
#   {'file_url': 'python 스터디/96',
#    'text': '그녀는 내 손을 잡고 얼굴을 쳐다보면서 그 동안 보고 싶었다고 강조해서 말했다.'},
#   {'file_url': 'python 스터디/97',
#    'text': '그녀는 턱의 균형을 잡고 있는 것처럼 행동하고 있는 그 여자의 성은 베이커라고 나직하게 속삭여 주었다.'},
#   {'file_url': 'python 스터디/98',
#    'text': '데이지가 일부러 속삭이는 것은 듣는 사람이 자기에게로 몸을 기울이게 하기 위함이라는 말을 들은 적이 있다.'},
#   {'file_url': 'python 스터디/99',
#    'text': '그것은 얼토당토않은 모함이었으나, 그런 모함에도 불구하고 데이지의 그러한 속삭임은 매력적으로 보였다.'},
#   {'file_url': 'python 스터디/100',
#    'text': '베이커 양의 입술이 움직였고, 나를 향해 고개를 끄덕여 인사한 그녀는 다시 아까처럼 머리를 뒤로 젖혔다.'},
#   {'file_url': 'python 스터디/101',
#    'text': '그녀가 턱의 균형을 잡고 떨어뜨리지 않으려 하고 있던 물건이 약간 뒤뚱거려 그녀를 얼마쯤 놀래게 했다.'},
#   {'file_url': 'python 스터디/102',
#    'text': '누군가 자기 만족에 빠진 사람을 보면 항상 감동해서 찬사를 보내고 싶어진다.'},
#   {'file_url': 'python 스터디/103',
#    'text': '내가 다시 데이지 쪽을 쳐다보자 그녀는 나지막하지만 자극적인 목소리로 여러 가지에 대해 묻기 시작했다.'},
#   {'file_url': 'python 스터디/104',
#    'text': '그 목소리는 마치 다시는 연주될 수 없는 악곡과 같아서 듣는 사람의 귀는 그 목소리를 따라서 오르락내리락하게 되었다.'},
#   {'file_url': 'python 스터디/105',
#    'text': '그녀의 목소리는 좀 흥분되어 있어서 그녀에게 호감을 갖고 있는 남자라면 여간해서 그것을 잊을 수 없게 했다.'},
#   {'file_url': 'python 스터디/106',
#    'text': '나는 동부로 오는 길에 시카고에 들렀던 이야기를 해 주면서 그 곳의 친척이 그녀에게 안부를 전하더라고 알려주었다.'},
#   {'file_url': 'python 스터디/107',
#    'text': '"그분들이 저를 잊지 않았나요?"하고 그녀는 흥분을 감추지 못하며 들뜬 목소리로 소리쳤다.'},
#   {'file_url': 'python 스터디/108',
#    'text': '아까부터 방안을 불안스럽게 서성거리고 있던 탐 부캐넌이 갑자기 다가와서 내 어깨에 손을 얹었다.'},
#   {'file_url': 'python 스터디/109',
#    'text': '그는 더 중요한 어떤 일에 마음을 쓰고 있기나 한 듯 데이지를 힐끔 쳐다보고는 다시 나를 보면서 말했다.'},
#   {'file_url': 'python 스터디/110',
#    'text': '"정말 그래요!" 그녀가 너무나 갑작스럽게 소리쳤으므로 나는 깜짝 놀랐다.'},
#   {'file_url': 'python 스터디/111',
#    'text': '"몸이 너무 찌뿌드드해요." 자리에서 일어선 그녀가 투덜거렸다.'},
#   {'file_url': 'python 스터디/112',
#    'text': '내가 이 방에 들어온 후로 내가 처음 한 말이었다. 그 한 마디에 내가 놀란 것만큼이나 그녀도 놀란 것이 분명했다.'},
#   {'file_url': 'python 스터디/113',
#    'text': '왜냐하면 그녀는 입을 크게 벌리고는 빠르고도 능숙한 동작으로 일어섰으니까 말이다.'},
#   {'file_url': 'python 스터디/114',
#    'text': '그는 마치 술이 잔 밑바닥에 한 방울이라도 남아 있으면 안되기라도 한 듯 칵테일을 단숨에 마셨다.'},
#   {'file_url': 'python 스터디/115',
#    'text': "나는 베이커 양의 그 '해낸 일이 무엇인지 궁금했기 때문에 그녀를 바라보았다."},
#   {'file_url': 'python 스터디/116',
#    'text': '그녀는 가냘픈 몸에 곧은 몸매를 하고 있었는데, 마치 젊은 사관 후보생처럼 어깨를 뒤로 젖혀 곧은 몸매를 더욱 드러나게 했다.'},
#   {'file_url': 'python 스터디/117',
#    'text': '햇빛으로 찡그린 그녀의 회색 눈동자가 호기심에 찬 눈빛으로 나를 돌아다보았다.'},
#   {'file_url': 'python 스터디/118',
#    'text': '나는 문득 어디에선가 그녀를 혹은 그녀의 사진을 본 적이 있다는 생각이 들었다.'},
#   {'file_url': 'python 스터디/119',
#    'text': '"웨스트에그에 살고 계시다고요?" 그녀는 무시하는 투로 말했다.'},
#   {'file_url': 'python 스터디/120',
#    'text': '그 사람은 바로 내 집 옆에 살고 있다고 미처 대답하기 전에 하인이 저녁 식사가 준비되어 있다고 알려 왔다.'},
#   {'file_url': 'python 스터디/121',
#    'text': '그는 그의 억센 팔을 자기 마음대로 내 겨드랑이 밑으로 넣더니 장기 알을 다른 칸으로 옮기듯이 나를 방에서 이끌고 나갔다.'},
#   {'file_url': 'python 스터디/122',
#    'text': '두 여인은 손을 허리에 살며시 얹은 채 가볍고도 경쾌한 발걸음으로 앞장서서 지는 해를 향해 훤히 트여 있는 장밋빛 방으로 갔다.'},
#   {'file_url': 'python 스터디/123',
#    'text': '"촛불은 뭐 하러 켰지?" 데이지가 눈살을 찌푸리면서 짜증을 냈다.'},
#   {'file_url': 'python 스터디/124',
#    'text': '"2주일만 지나면 1년 중 가장 길다는 하지예요." 그녀는 밝은 얼굴로 우리들을 쳐다보았다.'},
#   {'file_url': 'python 스터디/125',
#    'text': '당신들도 일 년 중에서 낮이 가장 길다는 그 날을 기다렸으면서도 막상 다가오니까 그 날을 깜박 잊고 지나쳐 버리지요?'},
#   {'file_url': 'python 스터디/126',
#    'text': '저는 말이에요, 항상 그 날을 기다렸으면서도 깜박 그 날을 지나쳐 버리지 뭐예요.'},
#   {'file_url': 'python 스터디/127',
#    'text': '베이커 양이 하품을 하며 마치 잠자리에 들기라고 하듯이 식탁에 앉으면서 말했다.'},
#   {'file_url': 'python 스터디/128',
#    'text': '"무슨 계획을 세울까요?" 그녀는 별 뚜렷한 것이 생각나지 않는 듯 나를 쳐다보았다.'},
#   {'file_url': 'python 스터디/129',
#    'text': '내가 대답하기도 전에 그녀는 눈에 걱정스러운 빛을 띠고 자기의 새끼손가락을 천천히 들여다보았다.'},
#   {'file_url': 'python 스터디/130',
#    'text': '"여길 다쳤어요." 우리의 시선이 모두 그녀의 손가락을 향했다. 새끼손가락 마디는 검고 푸르스름했다.'},
#   {'file_url': 'python 스터디/131',
#    'text': '이것 역시 짐승 같은 남자, 산더미 만한, 괴물처럼 엄청나게 큰 몸집의 본보기 같은 남자와 결혼한 탓이에요.'},
#   {'file_url': 'python 스터디/132',
#    'text': '"괴물 같다는 소리는 정말로 듣기 싫소." 탐이 얼굴을 찡그리며 투덜거렸다.'},
#   {'file_url': 'python 스터디/133',
#    'text': '데이지와 베이커 양은 동시에 얘기를 하곤 했는데, 그들의 얘기는 아주 평범했다.'},
#   {'file_url': 'python 스터디/134',
#    'text': '그들은 입고 있는 흰옷이나 아무 욕망도 없어 보이는 무심한 눈만큼이나 태연한, 무미건조한 농담처럼 말했다.'},
#   {'file_url': 'python 스터디/135',
#    'text': '그들은 그저 이 곳에 있고, 대접을 받으려고 겸손하고 즐거운 척 위장을 하고 있었던 것뿐이다.'},
#   {'file_url': 'python 스터디/136',
#    'text': '그들은 식사가 곧 끝날 것이고, 조금 더 있으면 이 밤 또한 끝나 평범하게 잊혀지리라는 것을 알고 있었던 것이다.'},
#   {'file_url': 'python 스터디/137',
#    'text': '순간 자체가 긴장된 두려움 속에서 저녁의 끝을 향하여 한 단계 한 단계씩 급히 지나가 버리게 마련이었다.'},
#   {'file_url': 'python 스터디/138',
#    'text': '나는 코르크 냄새가 나지만 그런 대로 맛이 좋은 적포도주를 두 잔째 마시면서 진실을 말했다.'},
#   {'file_url': 'python 스터디/139',
#    'text': "나는 매사에 지독한 비관론자가 되어 버렸다네. 자네, '유색인 제국의 발흥'이라는 책을 읽어 본 적이 있나?"},
#   {'file_url': 'python 스터디/140',
#    'text': '그 책의 요지는 우리가 경계하지 않으면 백색 인종은 완전히 멸망해 버린다는 거야. 과학적으로 증명까지 하고 있지.'},
#   {'file_url': 'python 스터디/141',
#    'text': '"탐은 요즘 매우 심각한 생각을 많이 해." 데이지가 측은한 표정을 지으며 말했다.'},
#   {'file_url': 'python 스터디/142',
#    'text': '뜻도 모를 난해한 책들이 많아. 그 낱말의 뜻이 뭐였더라...?'},
#   {'file_url': 'python 스터디/143',
#    'text': '"모두 과학적인 책들이야." 탐은 참을성 없게 데이지를 힐끔 바라보며 자기 주장을 내세웠다.'},
#   {'file_url': 'python 스터디/144',
#    'text': '그건 지배적인 인종인 우리의 책임이야. 조심하지 않으면 다른 인종들이 모든 것을 지배하게 될 거야.'},
#   {'file_url': 'python 스터디/145',
#    'text': '"그 인종들을 타도해야죠." 강렬한 햇빛에 눈을 사납게 깜박이면서 그녀가 귓속말로 말했다.'},
#   {'file_url': 'python 스터디/146',
#    'text': '그가 둔한 몸을 일으켜 고쳐 앉음으로써 그녀의 말을 가로막았다.'},
#   {'file_url': 'python 스터디/147',
#    'text': '그 책이 말하고 있는 것은 우리가 북유럽 인종이라는 것이지. 나도 자네도, 그리고 당신도 말이야.'},
#   {'file_url': 'python 스터디/148',
#    'text': '그는 잠시 망설이더니 머리를 조금 끄덕이는 것으로 데이지도 그 속에 포함시켰다.'},
#   {'file_url': 'python 스터디/149',
#    'text': '문명을 형성하는 데에 필요한 모든 것들을 우리 백인이 만들어 냈던 것이네.'},
#   {'file_url': 'python 스터디/150',
#    'text': '평소보다 더 두드러진 자기 만족감도 더 이상 그를 충족시켜 주지 못하는 것같이 보였다.'},
#   {'file_url': 'python 스터디/151',
#    'text': '이 때 안에서 전화벨이 울려 하인이 방을 나가자, 데이지는 순간적으로 말이 중단된 틈을 타서 내게로 몸을 기울였다.'},
#   {'file_url': 'python 스터디/152',
#    'text': '"우리 집안의 비밀을 하나 가르쳐 드릴게요."  그녀는 신나는 듯이 속삭이었다.'},
#   {'file_url': 'python 스터디/153',
#    'text': '그녀의 붉어진 얼굴은 늦은 석양빛으로 낭만적인 감정이 맴돌았다.'},
#   {'file_url': 'python 스터디/154',
#    'text': '그녀의 목소리는 나로 하여금 숨을 죽이고 그녀의 몸 쪽으로 다가가도록 했다.'},
#   {'file_url': 'python 스터디/155',
#    'text': '탐은 찡그리며 의자를 뒤로 밀고는 한 마디 말도 없이 안으로 들어갔다.'},
#   {'file_url': 'python 스터디/156',
#    'text': '그것이 무슨 신호라도 된 듯이 데이지는 다시 앞으로 몸을 숙였고, 그녀의 목소리는 열기를 띠고 들떠 있었다.'},
#   {'file_url': 'python 스터디/157',
#    'text': '닉 오빠를 우리 집 저녁 식사에 모시게 되어 기뻐요. 오빠를 보고 있으면 아름답게 핀 장미꽃이 생각나요.'},
#   {'file_url': 'python 스터디/158',
#    'text': '데이지는 그저 생각나는 대로 말한 것이었지만, 그녀에게서는 사람을 충동시키는 마력이 넘쳐흐르고 있었다.'},
#   {'file_url': 'python 스터디/159',
#    'text': '그녀는 갑자기 냅킨을 식탁 위에 던지고는 실례하겠다고 짧게 말한 뒤 안으로 들어가 버렸다.'},
#   {'file_url': 'python 스터디/160',
#    'text': '베이커 양과 나는 아무 뜻 없이 무의식적으로 잠시 눈길을 주고받았다.'},
#   {'file_url': 'python 스터디/161',
#    'text': '내가 막 입을 열려고 하는 순간, 그녀가 재빠르게 자세를 고쳐 앉으며 경계하는 목소리로,  "쉬!"하고 말했다.'},
#   {'file_url': 'python 스터디/162',
#    'text': '저 쪽 방에서 흥분을 억제하며 숨을 죽여 가며 수군거리는 소리가 들려왔다.'},
#   {'file_url': 'python 스터디/163', 'text': '베이커 양은 예의도 잊은 듯 엿들으려고 몸을 안쪽으로 굽혔다.'},
#   {'file_url': 'python 스터디/164',
#    'text': '수군거리는 소리는 끊어질 듯 떨리며 낮아졌다가 흥분되어 커지더니 마침내 완전히 그쳐 버렸다.'},
#   {'file_url': 'python 스터디/165',
#    'text': '조금 전에 말한 그 개츠비라는 사람은 바로 나의 이웃입니다. 옆집에 살고 있지요.'},
#   {'file_url': 'python 스터디/166',
#    'text': '그녀는 망설이며 말했다. "탐은 뉴욕에 사귀는 여자가 있어요."'},
#   {'file_url': 'python 스터디/167',
#    'text': '그녀가 저녁 식사시간에는 전화를 삼가는 조심성 정도는 있어야 할 텐데요. 그렇게 생각하지 않아요?'},
#   {'file_url': 'python 스터디/168',
#    'text': '무슨 뜻인지 제대로 이해하기도 전에 탐과 데이지가 식탁으로 되돌아왔다.'},
#   {'file_url': 'python 스터디/169',
#    'text': '그녀는 자리에 앉아서 베이커 양과 나의 눈치를 살피고 나서 말을 이었다.'},
#   {'file_url': 'python 스터디/170',
#    'text': '나가 보니 아주 상쾌하더군요. 새가 한 마리 앉아 있었는데, 배를 타고 건너온 나이팅게일 같았어요.'},
#   {'file_url': 'python 스터디/171',
#    'text': '그녀의 목소리는 노래를 부르는 것 같았다. "로맨틱하지요, 안 그래요, 탐?"'},
#   {'file_url': 'python 스터디/172',
#    'text': '"굉장히 로맨틱한데." 탐은 이렇게 말하고 난 뒤 괴로운 표정으로 내게 말했다.'},
#   {'file_url': 'python 스터디/173',
#    'text': '"저녁 식사 후에도 날이 어두워지지 않으면 저 아래 있는 마구간을 보여 주고 싶은데."'},
#   {'file_url': 'python 스터디/174',
#    'text': '또다시 안에서 전화벨이 요란하게 울렸다. 데이지가 탐을 향해 단호하게 고개를 흔들자 마구간 문제는 없어져 버렸다.'},
#   {'file_url': 'python 스터디/175',
#    'text': '엉망이 된 그 날 저녁 식탁에서 기억에 남는 일이라고는 아무 의미도 없이 촛불이 다시 켜졌던 일뿐이었다.'},
#   {'file_url': 'python 스터디/176',
#    'text': '나는 모두가 어떤 표정을 짓고 있는지 살펴보고 싶었으나 왠지 모두의 시선과 마주치는 것을 피하게 되었다.'},
#   {'file_url': 'python 스터디/177',
#    'text': '나로서는 탐이나 데이지가 무슨 생각을 하고 있는지 도무지 짐작할 길이 없었다.'},
#   {'file_url': 'python 스터디/178',
#    'text': '베이커 양마저 그 전화벨의 주인공이 누구인지 궁금해하고 있는 것 같았다.'},
#   {'file_url': 'python 스터디/179',
#    'text': '어떤 사람에게는 일이 복잡하게 얽힌 것으로 보일는지도 모른다. 내 성미대로라면 전화로 경찰을 당장 불렀으면 싶었다.'},
#   {'file_url': 'python 스터디/180',
#    'text': '나는 흥미를 느끼는 동시에 데이지의 뒤를 따라 연결된 길다란 베란다를 돌아 정면 현관으로 갔다.'},
#   {'file_url': 'python 스터디/181',
#    'text': '데이지는 마치 자신의 사랑스러운 얼굴을 손으로 느끼기라도 하려는 듯이 두 손으로 얼굴을 감쌌다.'},
#   {'file_url': 'python 스터디/182',
#    'text': '그녀의 두 눈은 벨벳 색의 어둠 속으로 천천히 움직였다. 그녀가 몹시 흥분한 것처럼 보였다.'},
#   {'file_url': 'python 스터디/183',
#    'text': '나는 다소나마 그녀를 진정시켜 주고 싶었다. 그래서 그녀의 어린 딸에 대해 이것저것 물어 보았다.'},
#   {'file_url': 'python 스터디/184',
#    'text': '저는 무슨 일에든지 상당히 냉소적으로 대하는 나쁜 버릇이 생기고 말았죠.'},
#   {'file_url': 'python 스터디/185',
#    'text': '나는 다음 말을 기다렸지만, 그녀는 더 이상 아무 말도 하지 않았다.'},
#   {'file_url': 'python 스터디/186',
#    'text': '아이를 낳고 채 한 시간도 지나지 않았는데 탐은 행방을 감추었어요.'},
#   {'file_url': 'python 스터디/187',
#    'text': '마취에서 깨어나면서 완전히 자포자기해 버린 저는 간호사에게 아들인지 딸인지를 물었어요. 그러자 딸이라고 대답하더군요.'},
#   {'file_url': 'python 스터디/188',
#    'text': '여자 애라 다행이다. 그러나 좀 멍청해졌으면 좋겠다. 그게 이 세상에서 여자가 될 수 있는 최상의 것이니까.'},
#   {'file_url': 'python 스터디/189',
#    'text': '"오빠도 알겠지만, 전 이 세상 모든 일이 끔찍하다고 생각해요."그녀는 확신에 찬 목소리로 말을 계속했다.'},
#   {'file_url': 'python 스터디/190',
#    'text': '그녀의 눈은 탐의 눈과 닮은 도전적인 눈초리로 주위를 둘러보았다. 그러고는 소름 끼치는 자조적인 모습으로 웃어댔다.'},
#   {'file_url': 'python 스터디/191',
#    'text': '마치 이 저녁이 내게서 어떤 어울릴 감정을 자아내기 위한 술책인 것처럼 여겨져 불안하기만 했다.'},
#   {'file_url': 'python 스터디/192',
#    'text': '역시 생각한대로 그려는 그 사랑스러운 얼굴에 매우 능글맞은 웃음을 머금고 나를 바라볼 뿐이었다.'},
#   {'file_url': 'python 스터디/193',
#    'text': '그것은 마치 그녀와 탐이 속한 비교적 유명한 비밀 조직에 가입한 그녀의 회원 자격을 내세우는 듯한 태도였다.'},
#   {'file_url': 'python 스터디/194',
#    'text': '집 안에서는 진홍색 방이 등불로 눈부시게 빛나고 있었다. 탐과 베이커 양은 긴 의자의 양끝에 앉아 있었다.'},
#   {'file_url': 'python 스터디/195',
#    'text': '램프의 불빛이 탐의 장화를 밝게 비치고 가을 낙엽같이 노란 베이커 양의 머리도 희미하게 비치고 있었다.'},
#   {'file_url': 'python 스터디/196',
#    'text': '그녀의 가냘픈 두 팔이 움직이며 잡지를 넘길 때마다 종이도 따라 번득였다.'},
#   {'file_url': 'python 스터디/197',
#    'text': '우리가 들어서자 그녀는 손을 들어 잠깐 멈춰 있으라고 신호를 보냈다.'},
#   {'file_url': 'python 스터디/198',
#    'text': '그녀는 잡지를 테이블 위로 던지며 말했다. 그러고는 힘들게 일어섰다.  "10시군요."'},
#   {'file_url': 'python 스터디/199',
#    'text': '나는 그녀의 얼굴이 어디서 많이 본 듯했던 이유를 이제야 알게 되었다.'},
#   {'file_url': 'python 스터디/200',
#    'text': '나는 그녀에 대한 몇 가지 비판조의 좋지 않은 얘기도 들은 적이 있지만, 무슨 내용이었는지는 잊어버린 지 오래 되었다.'},
#   {'file_url': 'python 스터디/201',
#    'text': '별안간 두 사람을 린네르 옷장에 가두어서는 보트에 태워 바다로 띄워 보낸다거나, 뭐 그런 일들 있잖아요?'},
#   {'file_url': 'python 스터디/202', 'text': '"안녕히 주무세요." 베이커 양이 계단을 올라가며 소리쳤다.'},
#   {'file_url': 'python 스터디/203',
#    'text': '나는 아무 말도 듣지 않았다고 가볍게 받아넘기고 잠시 후 집에 가기 위해 일어섰다.'},
#   {'file_url': 'python 스터디/204',
#    'text': '기다려요! 뭘 좀 물어 본다는 게 그만 잊고 말았어요, 오빠가 서부에서 약혼을 했다는 얘기가 있던데요.'},
#   {'file_url': 'python 스터디/205',
#    'text': '"저는 그 소문을 세 사람한테서 들었으니까 사실임에 틀림없어요."'},
#   {'file_url': 'python 스터디/206',
#    'text': '물론 나도 그들이 무슨 말을 하고 있는지 알고는 있었지만, 나는 약혼 비슷한 것조차 한 적이 없었다.'},
#   {'file_url': 'python 스터디/207',
#    'text': '내가 동부로 오게 된 이유 중에 하나가 바로 그 소문 때문이었다. 뜬소문 때문에 오랜 친구와 교제를 끊을 수는 없었다.'},
#   {'file_url': 'python 스터디/208',
#    'text': '탐 부부의 관심은 모름지기 나를 감동시켰고, 그래서 그들이 굉장한 부자가 아닌 것처럼 보이게 했다.'},
#   {'file_url': 'python 스터디/209',
#    'text': '그럼에도 불구하고 나는 차를 몰면서 머리가 혼란스러워지고 약간 불쾌해지는 것을 느꼈다.'},
#   {'file_url': 'python 스터디/210',
#    'text': '내 생각에는 데이지가 할 수 있는 최선의 방법은 아이를 안고 그 집에서 뛰쳐나오는 것이었다.'},
#   {'file_url': 'python 스터디/211',
#    'text': '그것은 마치 그의 건장한 육체적 이기성이 더 이상은 건방진 심성에 자양분을 줄 수 없다는 것을 보이는 것과 같았다.'},
#   {'file_url': 'python 스터디/212',
#    'text': '길가에 늘어선 집들의 지붕 앞은 이미 여름이 온 듯했고, 빨간색 새 휘발유 펌프들이 한꺼번에 불빛을 받아 근사하게 보였다.'},
#   {'file_url': 'python 스터디/213',
#    'text': '내 집에 다다른 나는 차를 차고에 집어넣고 나서 마당에 내팽개쳐진 제초기에 잠시 걸터앉았다.'},
#   {'file_url': 'python 스터디/214',
#    'text': '바람이 불어오자 밤하늘에 나무들이 부딪히는 소리가 요란하게 울려 퍼졌고, 개구리들에게 생명을 가득 불어넣어 주었다.'},
#   {'file_url': 'python 스터디/215',
#    'text': '달빛 속에 움직이는 고양이 그림자가 아른거리고 있었는데, 고개를 돌렸다가 나는 내가 혼자가 아니었음을 알게 되었다.'},
#   {'file_url': 'python 스터디/216',
#    'text': '내 이웃의 저택 그늘로부터 어떤 사람의 모습이 손을 주머니에 찔러 넣은 채 은색 후추를 뿌려 놓은 것 같은 별들을 쳐다보고 있었다.'},
#   {'file_url': 'python 스터디/217',
#    'text': '어딘지 여유 있어 보이는 그 몸놀림과 잔디를 밟고 서 있는 다리의 확고한 자세가 그 사람이 개츠비임을 짐작하게 했다.'},
#   {'file_url': 'python 스터디/218',
#    'text': '그는 우리 고장의 하늘 중에서 자기 몫의 하늘을 찾아내기 위해 나온 사람처럼 보였다. 나는 그를 부르기로 마음먹었다.'},
#   {'file_url': 'python 스터디/219',
#    'text': '베이커 양이 저녁 식사 때 그의 얘기를 한 것이 소개 역할을 해 줄 것 같았다. 그렇지만 나는 그를 부르지 않았다.'},
#   {'file_url': 'python 스터디/220',
#    'text': '나는 그와 멀리 떨어져 있기는 했지만 그가 몸을 떨고 있다는 것을 확실히 알 수 있었다.'},
#   {'file_url': 'python 스터디/221',
#    'text': '어쩌면 부두의 끝일지도 모를 곳에서 녹색 불빛 하나가 반짝이는 걸 보았을 뿐 다른 것은 전혀 알아볼 수가 없었다.'},
#   {'file_url': 'python 스터디/222',
#    'text': '내가 다시 개츠비 쪽으로 시선을 돌렸을 때 그의 모습은 어느 새 사라지고 없었다.'},
#   {'file_url': 'python 스터디/223',
#    'text': '뉴욕으로 가는 중간쯤에서 자동차 도로는 철도 쪽으로 합해져서 4분의 1마일쯤 뻗어 나가다가 어떤 황량한 곳에 이르러 끝난다.'},
#   {'file_url': 'python 스터디/224',
#    'text': '재가 밀처럼 자라서 산마루도 되고 언덕도 되며 괴이한 정원도 되는 해괴한 농장이다.'},
#   {'file_url': 'python 스터디/225',
#    'text': '그 곳에서 재는 또 집이나 굴뚝 그리고 피어오르는 연기, 마침내는 어떤 대단한 노력을 거쳐서 잿빛 인간으로까지 변하는 것이다.'},
#   {'file_url': 'python 스터디/226',
#    'text': '그 인간들은 먼지투성이의 공기 속에서 무기력하게 움직이며 이미 거의 다 쓰러져 가고 있다.'},
#   {'file_url': 'python 스터디/227',
#    'text': '가끔 뿌연 먼지를 일으키는 차 행렬이 끝없는 도로를 따라 들어와서 소름 끼치는 소리를 내며 멈춰 선다.'},
#   {'file_url': 'python 스터디/228',
#    'text': '곧 잿빛 사람들이 떼지어 납빛 삽들을 가지고 모여 먼지 구름을 더욱 크게 일으켜 놓았다.'},
#   {'file_url': 'python 스터디/229',
#    'text': '그 먼지 구름이 그들의 희미한 동작을 가려 버려 우리 눈에는 보이지 않게 한다.'},
#   {'file_url': 'python 스터디/230',
#    'text': '잿빛 땅과 그 위를 끊임없이 떠도는, 경련적으로 일어나는 먼지 구름 넘어 살며시 박사의 눈이 나타난다.'},
#   {'file_url': 'python 스터디/231', 'text': '푸른빛을 띤 데다 위압감이 느껴질 정도로 큰 눈이 보인다.'},
#   {'file_url': 'python 스터디/232',
#    'text': '그 눈은 있지도 않은 콧등에 가로 걸려 있는 어마어마한 노란색 안경 너머로 이 쪽을 보고 있다.'},
#   {'file_url': 'python 스터디/233',
#    'text': '어떤 뻔뻔한 안과 의사가 퀸즈 구에서 거창하게 병원을 차리려고 그 곳에 설치해 놓았던 것이다.'},
#   {'file_url': 'python 스터디/234',
#    'text': '그 자신이 영원히 미지의 세계로 사라져 버렸거나 아니면 그 선전 간판을 설치해 놓았다는 사실을 잊어버리고 이사를 한 것이리라.'},
#   {'file_url': 'python 스터디/235',
#    'text': '그 눈은 세월이 흐르는 동안 햇빛과 비에 시달려 좀 흐려진 채 이 엄숙한 쓰레기 하치장을 아직도 의연하게 내려다보고 있다.'},
#   {'file_url': 'python 스터디/236',
#    'text': '화물선이 지나갈 수 있게 다리가 올라갈 때면 기차 안의 승객들은 길게는 30분 동안이나 그 광경을 지켜보면서 기다려야 했다.'},
#   {'file_url': 'python 스터디/237',
#    'text': '기차는 그 곳에서 이런 일이 아니더라도 1분간은 정차해 있었다.'},
#   {'file_url': 'python 스터디/238', 'text': '내가 탐 부캐넌의 정부를 처음으로 만나게 된 것도 이 때였다.'},
#   {'file_url': 'python 스터디/239',
#    'text': '탐에게 정부가 한 명 있다는 사실은 그가 나타나는 곳이라면 어디서든 화제가 되었다.'},
#   {'file_url': 'python 스터디/240',
#    'text': '그를 아는 사람들은 그가 정부를 데리고 대중 카페에 나타나  잡담 나누는 모습을 좋은 시선으로 보아주지 않았다.'},
#   {'file_url': 'python 스터디/241',
#    'text': '나는 그 여자를 한 번 보고 싶었지만 일부러 만나고 싶은 생각은 없었다. 그러나 나는 그녀를 만났다.'},
#   {'file_url': 'python 스터디/242',
#    'text': '기차가 잿더미 곁에 정차하자 탐은 벌떡 일어나더니 내 팔꿈치를 잡고서 막무가내로 나를 차에서 내리게 했다.'},
#   {'file_url': 'python 스터디/243',
#    'text': '그는 점심때 뭘 잘 먹은 모양이었다. 그리고 나를 대하는 모습은 거의 폭력에 가까웠다.'},
#   {'file_url': 'python 스터디/244',
#    'text': '그는 마침 일요일 오후라 내게 별다른 일이 없을 것이라고 멋대로 생각했던 것이다.'},
#   {'file_url': 'python 스터디/245',
#    'text': '나는 그를 따라 하얗게 칠한 나지막한 철로변 담을 넘었고, 박사의 끈질긴 시선을 받으며 기차를 타고 왔던 길을 되돌아갔다.'},
#   {'file_url': 'python 스터디/246',
#    'text': '건물이라고는 오직 그 황무지 가장자리에 서 있는 조그맣고 노란 벽돌 건물뿐이었다.'},
#   {'file_url': 'python 스터디/247',
#    'text': '그것은 이 황무지에 자리한 일종의 압축된 중심가라고 할 수 있는 것이었다.'},
#   {'file_url': 'python 스터디/248',
#    'text': '건물에는 가게가 있었는데, 하나는 야간 영업 레스토랑이었으며, 나머지 하나는 자동차 수리소였다.'},
#   {'file_url': 'python 스터디/249',
#    'text': '안은 생각보다 초라하고 썰렁했다. 보이는 것이라곤 어두운 구석에 처박혀 있는, 먼지투성이의 고물 포드 승용차 한 대뿐이었다.'},
#   {'file_url': 'python 스터디/250',
#    'text': '사치스럽고 로맨틱한 아파트가 위층에 감추어져 있을지도 모른다는 생각이 문득 떠올랐다.'},
#   {'file_url': 'python 스터디/251',
#    'text': '그 때 정비소 주인이 헝겊 조각으로 손을 닦으며 사무실 문간에 나타났다.'},
#   {'file_url': 'python 스터디/252',
#    'text': '금발의 그는 건강이 좋지 않은지 생기가 없어 보였으며 윤곽만은 제법 뚜렷한 미남이었다.'},
#   {'file_url': 'python 스터디/253',
#    'text': '우리를 본 그의 연푸른 두 눈에 흐릿한 희망의 빛이 스쳐 지나갔다.'},
#   {'file_url': 'python 스터디/254', 'text': '탐이 활기에 찬 목소리로 그의 어깨를 두드리며 말했다.'},
#   {'file_url': 'python 스터디/255', 'text': '"그저 그렇습니다."  윌슨이 힘없는 목소리로 대답했다.'},
#   {'file_url': 'python 스터디/256',
#    'text': '그런데 당신이 그렇게 생각하고 있다면 차라리 어디 다른 곳에다 파는 게 낫겠소'},
#   {'file_url': 'python 스터디/257',
#    'text': '잠시 후 좀 뚱뚱해 보이는 여자가 사무실 문으로 새어 나오는 불빛을 막아버렸다.'},
#   {'file_url': 'python 스터디/258',
#    'text': '30대 중반으로 보이는 그녀는 좀 뚱뚱하긴 했지만 관능적인 몸매를 지니고 있었다.'},
#   {'file_url': 'python 스터디/259',
#    'text': '짙푸른 점무늬의 크레프드신 드레스 위로 솟은 얼굴은 아무리 뜯어 봐도 평범할 뿐이었다.'},
#   {'file_url': 'python 스터디/260',
#    'text': '온몸의 신경이 끊임없이 불에 그을리고 타고 있기라도 한 것처럼 어디서나 눈에 띌 정도로 몸 전체에 생기가 흘러 넘쳤다.'},
#   {'file_url': 'python 스터디/261',
#    'text': '"의자라도 가져와요. 왜 가만히 있어요? 그래야 손님이 앉으실 수 있잖아요?"'},
#   {'file_url': 'python 스터디/262',
#    'text': '윌슨은 황급히 대답하고 나서 벽의 시멘트 색깔과 섞여 사라지듯이 조그마한 사무실 쪽으로 갔다.'},
#   {'file_url': 'python 스터디/263',
#    'text': '하얀 재먼지가 주변의 모든 것을 먼지로 덮어 버린 것과 마찬가지로 윌슨의 검정색 양복과 연한 빛의 머리칼도 먼지로 덮여 있었다.'},
#   {'file_url': 'python 스터디/264',
#    'text': '탐 곁에 바싹 다가와 있는 그의 아내만은 예외였다. "만나고 싶소." 탐이 은근한 목소리로 말했다.'},
#   {'file_url': 'python 스터디/265',
#    'text': '고개를 끄덕인 그녀가 의미심장한 웃음을 지으며 다가가자마자 조지 윌슨이 의자 두 개를 가지고 나타났다.'},
#   {'file_url': 'python 스터디/266',
#    'text': '우리는 길 아래쪽에서 남의 눈에 띄지 않게 그녀를 기다렸다. 그 날은 독립기념일인 7월 4일을 며칠 앞둔 날이었다.'},
#   {'file_url': 'python 스터디/267',
#    'text': '회색 옷을 입은 바싹 마른 이탈리아계 어린애가 철로 위에 딱총알을 일렬로 올려놓고 있었다.'},
#   {'file_url': 'python 스터디/268',
#    'text': '"지독한 동네군. 그렇지 않아?" 하고 탐이 얼굴을 찡그리고 박사의 얼굴을 쳐다보며 말했다.'},
#   {'file_url': 'python 스터디/269',
#    'text': '윌슨 말인가? 그는 아내가 뉴욕에 있는 처제를 만나러 가는 걸로 알고 있지. 너무 멍청해서 자기가 살아 있다는 것조차도 모르고 있어.'},
#   {'file_url': 'python 스터디/270',
#    'text': '이리하여 탐 부캐넌과 그의 정부, 그리고 나 이렇게 세 사람은 함께 뉴욕으로 갔다.'},
#   {'file_url': 'python 스터디/271',
#    'text': '정확하게 말하면 함께 갔다고는 할 수 없다. 왜냐하면 윌슨 부인은 다른 사람들의 눈을 피해 다른 칸에 앉아 있었기 때문이다.'},
#   {'file_url': 'python 스터디/272',
#    'text': '탐은 혹시 그 기차에 탔을지도 모를 이스트에그 사람들의 구설수에 그만큼 신경을 썼던 것이다.'},
#   {'file_url': 'python 스터디/273',
#    'text': '윌슨 부인은 모슬린 드레스로 갈아입고 있었는데, 탐의 부축을 받아 플랫폼에 내렸을 때 그 옷은 비교적 꽉 끼어 불편하게 보였다.'},
#   {'file_url': 'python 스터디/274',
#    'text': "그녀는 신문 판매점에서 '타운태틀'지 1부와 영화 잡지 1권, 그리고 역의 약국에서 콜드크림과 조그만 병에 든 향수를 샀다."},
#   {'file_url': 'python 스터디/275',
#    'text': '차에 오른 우리는 혼잡한 역을 빠져나가 이글거리는 햇볕 속으로 미끄러져 들어갔다.'},
#   {'file_url': 'python 스터디/276',
#    'text': '창문으로 바깥을 내다보고 있던 그녀가 갑자기 몸을 홱 돌려 앞으로 굽히고는 차창을 두드리며 말했다.'},
#   {'file_url': 'python 스터디/277',
#    'text': '"저런 강아지를 한 마리 갖고 싶어요." 그녀는 진지하게 말했다.'},
#   {'file_url': 'python 스터디/278',
#    'text': '"평소부터 아파트에 한 마리 기르고 싶었어요. 멋진 일이잖아요, 강아지를 한 마리 기른다는 건 말이에요."'},
#   {'file_url': 'python 스터디/279',
#    'text': '노인의 목에 매달린 바구니 안에는 태어난 지 얼마 되지 않은 혈통 좋은 강아지 10여 마리가 웅크리고 있었다.'},
#   {'file_url': 'python 스터디/280',
#    'text': '노인은 고개를 갸우뚱하며 바구니 속을 들여다보고는 손을 집어넣어서 한 마리의 강아지 뒷덜미를 잡아 끌어올렸다.'},
#   {'file_url': 'python 스터디/281',
#    'text': '그 강아지는 두려운 듯 바둥거리고 있었다. "그건 경찰견이 아니오."'},
#   {'file_url': 'python 스터디/282',
#    'text': '노인은 한 손으로 갈색 타월처럼 부드러운 강아지의 등을 쓰다듬었다.'},
#   {'file_url': 'python 스터디/283',
#    'text': '이 털을 좀 보세요. 대단하지요. 잔병치레로 주인을 성가시게 할 개는 결코 아닙니다.'},
#   {'file_url': 'python 스터디/284',
#    'text': '우리는 5번가 쪽으로 달렸다. 따뜻하고 온화한 여름철의 일요일 오후였다.'},
#   {'file_url': 'python 스터디/285',
#    'text': '하얀 양떼가 그 거리의 모퉁이를 돌아다닌다 하더라도 나는 놀라지 않았을 것이다.'},
#   {'file_url': 'python 스터디/286',
#    'text': '"자네가 아파트까지 같이 가지 않는다면 머틀이 기분 나빠할 걸. 안 그렇소, 머틀?"'},
#   {'file_url': 'python 스터디/287',
#    'text': '"제 동생 캐서린에게 전화하겠어요. 주위에 있는 사람들은 그 애가 아주 예쁘다고 칭찬을 하지요."'},
#   {'file_url': 'python 스터디/288',
#    'text': '우리가 이야기를 하고 있는 사이 차는 다시 한 번 센트럴 파크를 가로질러서 웨스트헌드리즈 가 쪽으로 가고 있었다.'},
#   {'file_url': 'python 스터디/289',
#    'text': '택시는 158번가에서 멋지게 생긴 아파트 단지로 들어가더니 한 동 앞에 멈춰 섰다.'},
#   {'file_url': 'python 스터디/290',
#    'text': '윌슨 부인은 외출에서 돌아온 사람처럼 주위를 한 바퀴 둘러본 후, 강아지와 그밖에 사 온 물건들을 들고 거만스럽게 안으로 들어갔다.'},
#   {'file_url': 'python 스터디/291',
#    'text': '그녀의 아파트는 꼭대기 층에 있었는데, 자그마한 거실과 식당, 침실 그리고 욕실로 나누어져 있었다.'},
#   {'file_url': 'python 스터디/292',
#    'text': '갖가지 무늬를 한 양탄자가 깔려 있는 거실에는 방에 비해 너무 큰 가구들이 문 앞을 가로막고 있었다.'},
#   {'file_url': 'python 스터디/293',
#    'text': '방안을 거닐다 보면 양탄자에 그려진 베르사유 궁전의 정원에서 그네를 타는 귀부인들 위를 넘어가는 것 같은 착각에 빠지게 했다.'},
#   {'file_url': 'python 스터디/294',
#    'text': '유일하게 걸려 있는 그림은 커다랗게 확대시킨 사진이었는데, 선명하지는 않지만 바위에 앉아 있는 암탉을 찍은 것이었다.'},
#   {'file_url': 'python 스터디/295',
#    'text': '그 암탉은 부인용 보네트처럼 보이기도 하고 비대하게 생긴 노부인이 빙그레 웃으며 방 안을 내려다보는 그림처럼 보이기도 했다.'},
#   {'file_url': 'python 스터디/296',
#    'text': '그 중 한 개의 비스켓은 우유잔에 담겨져 오후 내내 풀어질 대로 풀어지고 있었다.'},
#   {'file_url': 'python 스터디/297',
#    'text': '그 동안 탐은 잠겨 있던 장식장 문을 열고 위스키 한 병을 꺼냈다.'},
#   {'file_url': 'python 스터디/298',
#    'text': '나는 지금까지 취한 적이 딱 두 번 있었는데, 그 두 번째가 바로 이 날이었다.'},
#   {'file_url': 'python 스터디/299',
#    'text': '오후 8시가 넘도록 따사로운 햇볕이 아파트 안을 가득 채우고 있었다.'},
#   {'file_url': 'python 스터디/300', 'text': '그의 무릎에 걸터앉은 윌슨 부인은 전화로 사람들을 초대했다.'},
#   {'file_url': 'python 스터디/301',
#    'text': '나는 마침 담배가 떨어져서 길모퉁이에 있는 약국으로 담배를 사러 나갔다.'},
#   {'file_url': 'python 스터디/302',
#    'text': "나는 거실에 다소곳이 앉아 '사이먼은 피터를 불렀다'라는 책의 첫장을 폈다."},
#   {'file_url': 'python 스터디/303',
#    'text': '책이 형편없는 것이어서인지 아니면 위스키가 정신을 흐려 놓아서인지는 모르나, 그 책의 내용을 전혀 파악할 수 없었다.'},
#   {'file_url': 'python 스터디/304',
#    'text': '탐과 머틀이 잠시 후 나타났고, 이어서 손님들이 하나둘 도착하기 시작했다.'},
#   {'file_url': 'python 스터디/305',
#    'text': '캐서린은 가냘프고 고생을 많이 한 것 같아 보이는 30세 가량의 여자로, 붉은색 단발머리에 얼굴에는 화장을 진하게 하고 있었다.'},
#   {'file_url': 'python 스터디/306',
#    'text': '눈썹을 모두 뽑고 보다 더 요염하게 그리려 노력했지만, 그 노력은 얼굴의 분위기를 깨뜨리는 결과가 되고 말았다.'},
#   {'file_url': 'python 스터디/307',
#    'text': '몸을 움직일 때마다 양팔에 가득 찬 사기 팔찌들이 달그락거렸다.'},
#   {'file_url': 'python 스터디/308',
#    'text': '그녀는 마치 이 아파트의 주인이라도 되는 것처럼 가구에 이상이 없는지 일일이 둘러보기 시작했다.'},
#   {'file_url': 'python 스터디/309',
#    'text': '내가 그것에 대해 묻자, 그녀는 호들갑스럽게 웃고 나서 자기는 여자 친구와 호텔에서 살고 있다고 말했다.'},
#   {'file_url': 'python 스터디/310', 'text': '아래층에 산다는 머키는 얼굴이 창백하고 여성적인 사람이었다.'},
#   {'file_url': 'python 스터디/311',
#    'text': '그는 면도를 하다가 왔는지 광대뼈에 하얀 비누 거품이 묻어 있었다.'},
#   {'file_url': 'python 스터디/312',
#    'text': "방안에 있는 사람들에게 일일이 정중하게 인사를 한 그는 나에게 자신은 '예술업'에 종사하고 있다고 말했다."},
#   {'file_url': 'python 스터디/313',
#    'text': '나는 나중에야 그가 사진작가이며, 벽에 붙어 있는 윌슨 부인 어머니의 희미한 확대 사진도 그의 작품이라는 것을 알게 되었다.'},
#   {'file_url': 'python 스터디/314',
#    'text': '그의 아내는 호감가는 가냘픈 외모에 날카로운 목소리를 가졌는데 인상이 날카로워 보였다.'},
#   {'file_url': 'python 스터디/315',
#    'text': '그녀는 자기 남편이 결혼한 이후로 자기 사진을 127장이나 찍어 주었다고 나에게 자랑스럽게 말했다.'},
#   {'file_url': 'python 스터디/316',
#    'text': '윌슨 부인은 다시 옷을 갈아 입었는데, 이번에는 크림색 드레스였다.'},
#   {'file_url': 'python 스터디/317',
#    'text': '그 드레스는 그녀가 방안을 돌아다닐 때마다 바스락 소리를 내었기 때문에 그녀의 품위마저 달라 보이게 했다.'},
#   {'file_url': 'python 스터디/318',
#    'text': '자동차 수리소에서 보여 주었던 그녀의 온몸에 넘쳐 흐르던 생기가 이제는 인상적인 거만스러움으로 바뀌어 있었다.'},
#   {'file_url': 'python 스터디/319',
#    'text': '그녀의 웃음소리와 몸놀림, 그리고 고집 센 말투는 시간이 갈수록 격렬해졌다.'},
#   {'file_url': 'python 스터디/320',
#    'text': '그녀의 존재가 커져 감에 따라 그녀를 중심으로 한 방은 점점 더 작아졌다.'},
#   {'file_url': 'python 스터디/321.m4a',
#    'text': '기가 자욱한 방안에서 그녀는 시끄럽게 삐그덕거리는소리를 내는 회전축 위에서 빙빙 돌고 있는 것처럼 보였다.'},
#   {'file_url': 'python 스터디/322',
#    'text': '돈밖에 모르는 그런 사람들은 곧 너를 배신할 거야. 지난 주에 난 어떤 여자를 이 곳으로 불러 발을 진찰받았어.'},
#   {'file_url': 'python 스터디/323',
#    'text': '윌슨 부인은 경멸하듯이 눈썹을 치켜 뜸으로써 그 칭찬을 무시했다.'},
#   {'file_url': 'python 스터디/324',
#    'text': '"이건 유행이 지난 옷이에요. 내가 외모에 신경을 쓸 필요가 없을 때 가끔씩 걸쳐 입는 옷이지요."'},
#   {'file_url': 'python 스터디/325',
#    'text': '"그래도 당신이 입으니까 잘 어울려요. 인사치레로 하는 이야기가 아니라구요." 머키 부인은 계속 물고 늘어졌다.'},
#   {'file_url': 'python 스터디/326',
#    'text': '"만약 그런 포즈를 취하고 있는 당신을 체스터가 찍기만 한다면 무척 훌륭한 작품이 될 거에요."'},
#   {'file_url': 'python 스터디/327',
#    'text': '우리 모두는 말없이 윌슨 부인을 바라보았다. 그녀는 눈을 가렸던 머리카락을 쓸어 올리고는 환한 미소를 띠며 시선을 맞추었다.'},
#   {'file_url': 'python 스터디/328',
#    'text': '머키는 고개를 갸우뚱거리면서 그녀를 유심히 바라보았다. 그러더니 곧 한 손을 자기 얼굴 앞에서 서서히 앞뒤로 움직였다.'},
#   {'file_url': 'python 스터디/329',
#    'text': '"얼굴 윤곽을 분명하게 나타내고 싶으니까. 그리고 뒤의 머리카락도 모두 담도록 해야겠어."'},
#   {'file_url': 'python 스터디/330',
#    'text': '우리는 일제히 윌슨 부인을 바라보았는데, 그 때 탐 부캐넌이 큰 하품을 하면서 일어났다.'},
#   {'file_url': 'python 스터디/331',
#    'text': '머틀, 모두들 잠들어 버리기 전에 얼음하고 생수를 좀더 가져와요.'},
#   {'file_url': 'python 스터디/332',
#    'text': '머틀은 아랫사람들의 게으름에 진절머리가 난다는 듯 이맛살을 찌푸렸다.'},
#   {'file_url': 'python 스터디/333',
#    'text': '정말이세요? 전 한 달쯤 전에 파티가 있어서 거기에 갔었는데, 개츠비라는 분의 저택이었지요.'},
#   {'file_url': 'python 스터디/334',
#    'text': '그분은 빌헬름 황제의 조카 아니면 사촌일 거라는 소문이 있던데요. 그분의 돈 전부가 거기서 온다는 거예요.'},
#   {'file_url': 'python 스터디/335',
#    'text': '전 그분이 왠지 기분 좋지 않아요. 그런 사람이 저에게 어떤 관심을 보이는 것은 질색이에요.'},
#   {'file_url': 'python 스터디/336',
#    'text': '내 이웃에 관한 이 흥미로운 정보는 머키 부인이 갑자기 캐서린을 가리키며 말을 꺼내는 바람에 끊어지고 말았다.'},
#   {'file_url': 'python 스터디/337', 'text': '"체스터, 제 생각으로는 이분의 사진도 찍었으면 좋겠는데요."'},
#   {'file_url': 'python 스터디/338',
#    'text': '그녀가 불쑥 말을 꺼냈으나 머키는 귀찮다는 듯이 고개만 끄덕이고 관심을 탐에게 돌려 버렸다.'},
#   {'file_url': 'python 스터디/339',
#    'text': '기회가 주어지면 롱아일랜드에서 일을 더 하고 싶습니다. 내가 바라는 것은 나에게 일을 시작할 기회를 주었으면 하는 것뿐입니다.'},
#   {'file_url': 'python 스터디/340',
#    'text': '탐은 윌슨 부인이 쟁반을 들고 들어오자 갑자기 웃음을 터뜨렸다.'},
#   {'file_url': 'python 스터디/341', 'text': '이 사람이 소개장을 써 줄 겁니다. 그렇지 않소, 머틀?'},
#   {'file_url': 'python 스터디/342',
#    'text': '당신 남편에게 머키 씨를 소개하는 편지를 써 주구려. 그러면 머키 씨는 그 사람을 모델로 해서 작품을 만들 수 있을 테니까 말이요.'},
#   {'file_url': 'python 스터디/343',
#    'text': '뭔가 좋은 문구를 생각해 내려는 듯이 탐의 입술은 잠시 조용히 움직였다.'},
#   {'file_url': 'python 스터디/344', 'text': '캐서린은 내게로 몸을 바짝 기울이고는 귓속말로 속삭였다.'},
#   {'file_url': 'python 스터디/345',
#    'text': '언니나 저분은 둘 다 결혼해서 살고 있는 상대에 대해 못마땅해하고 있어요.'},
#   {'file_url': 'python 스터디/346',
#    'text': '제가 하고 싶은 말은 서로 참고 견딜 수가 없을 정도이면 무엇하러 계속 같이 사느냐 하는 거예요.'},
#   {'file_url': 'python 스터디/347', 'text': '이 물음에 대한 대답은 뜻밖의 사람한테서 들을 수 있었다.'},
#   {'file_url': 'python 스터디/348', 'text': '캐서린이 의기양양하게 소리치고는 다시 목소리를 낮추어 말했다.'},
#   {'file_url': 'python 스터디/349',
#    'text': '두 사람을 떼어 놓고 있는 사람은 탐의 부인이에요. 그녀는 카톨릭 신자인데, 카톨릭에서는 이혼을 인정하지 않거든요.'},
#   {'file_url': 'python 스터디/350',
#    'text': '데이지는 카톨릭 신자가 아니라는 사실을 알고 있었으므로 나는 이 완전한 거짓말에 약간 충격을 받았다.'},
#   {'file_url': 'python 스터디/351', 'text': '그 일이 잊혀질 때까지 한동안 서부에 가서 살 거예요.'},
#   {'file_url': 'python 스터디/352', 'text': '전 몬테카를로에서 돌아온 지 얼마 안 되었어요.'},
#   {'file_url': 'python 스터디/353',
#    'text': '아니에요. 우린 그저 몬테카를로만 다녀왔어요. 마르세유를 거쳐서 갔었지만요.'},
#   {'file_url': 'python 스터디/354',
#    'text': '출발할 때는 1,200달러 이상 갖고 있었지만, 그 곳의 도박장에서 이틀 만에 몽땅 잃고 말았어요.'},
#   {'file_url': 'python 스터디/355',
#    'text': '거짓말이 아니에요. 그 때문에 돌아올 때 얼마나 고생을 했는지 그래서 아직도 몬테카를로라면 소름이 끼쳐요.'},
#   {'file_url': 'python 스터디/356',
#    'text': '늦은 오후의 하늘은 지중해의 푸른 바다색으로 잠시 창문에 머물렀다.'},
#   {'file_url': 'python 스터디/357', 'text': '그때 머키 부인의 날카로운 목소리가 나서 나는 정신을 차렸다.'},
#   {'file_url': 'python 스터디/358',
#    'text': '몇 해 동안이나 제 뒤를 쫓아다니던 조그만 애송이와 하마터면 결혼할 뻔했던 거죠.'},
#   {'file_url': 'python 스터디/359',
#    'text': "주위에서도 '루실, 그 사람은 너보다 훨씬 못한 남자야!' 하고 모두들 늘 말했어요."},
#   {'file_url': 'python 스터디/360',
#    'text': '제가 체스터를 만나지 않았더라면, 그는 틀림없이 저를 차지했을 거예요.'},
#   {'file_url': 'python 스터디/361', 'text': '바로 그것이 당신 경우와 내 경우의 다른 점이지요.'},
#   {'file_url': 'python 스터디/362', 'text': '그 사람을 신사라고 생각했기 때문에 난 그와 결혼했던 거야.'},
#   {'file_url': 'python 스터디/363',
#    'text': '교양이 무엇인지를 조금은 알고 있다고 생각했지. 그런데 그것은 내 착각이었어.'},
#   {'file_url': 'python 스터디/364',
#    'text': '내가 그 사람한테 빠졌었다고 말을 한 게 누구지? 나는 누구에게 미칠 정도로 사랑에 빠진 적이 없어.'},
#   {'file_url': 'python 스터디/365',
#    'text': '나는 그녀의 관심 따위는 기대하고 있지 않다는 것을 얼굴에 나타내려고 애썼다.'},
#   {'file_url': 'python 스터디/366',
#    'text': '내가 단 한 번 미친 듯이 그에게 반했던 것은 결혼식 때였어. 그러나 나는 곧 내가 실수했음을 깨닫게 되었지.'},
#   {'file_url': 'python 스터디/367',
#    'text': '그는 결혼식 때 다른 사람의 양복을 빌려 입었으면서도 나에게 그런 얘기는 한 마디도 하지 않았어.'},
#   {'file_url': 'python 스터디/368',
#    'text': '하루는 그가 외출했을 때 그 옷 임자가 빌려 준 옷을 찾으러 왔어.'},
#   {'file_url': 'python 스터디/369',
#    'text': '나는 그 옷을 임자에게 돌려 주고는 오후 내내 침대에서 한없이 울었어.'},
#   {'file_url': 'python 스터디/370',
#    'text': '나는 밖으로 나가 부드러운 황혼 속의 공원을 향해 동쪽으로 걷고 싶었다.'},
#   {'file_url': 'python 스터디/371',
#    'text': '나오려고 할 때마다 요란하고도 귀에 거슬리는 말다툼에 휘말려 마치 밧줄에 매여 끌리듯 다시 제자리로 되돌아오게 되었다.'},
#   {'file_url': 'python 스터디/372', 'text': '난 이상하다는 듯이 올려다보고 있는 그 사람을 보았다.'},
#   {'file_url': 'python 스터디/373',
#    'text': '나는 인생의 무한한 다양성에 이끌림과 동시에 반발도 하면서 창문 안팎으로 방황을 했다.'},
#   {'file_url': 'python 스터디/374', 'text': '갑자기 탑을 처음 만났을 때의 이야기를 나에게 하기 시작했다.'},
#   {'file_url': 'python 스터디/375',
#    'text': '우리가 처음 만난 것은 언제나 맨 마지막까지 빈자리로 남아 있던, 마주 보고 있는 두 개의 작은 의자에서였어요.'},
#   {'file_url': 'python 스터디/376',
#    'text': '전 뉴욕으로 와서 동생을 만나고 그날밤은 여기서 묵을 생각이었지요.'},
#   {'file_url': 'python 스터디/377',
#    'text': '그이는 야회복에 에나멜 구두를 신고 있었는데 전 그이에게서 눈을 뗄 수가 없었어요.'},
#   {'file_url': 'python 스터디/378',
#    'text': '그이가 저를 바라볼 때마다 저는 탐의 머리 위쪽의 광고를 보고 있는 척해야만 했어요.'},
#   {'file_url': 'python 스터디/379',
#    'text': '우리가 뉴욕 역에 도착했을 때, 그리는 바로 제 곁에 서 있었는데, 그이의 흰 셔츠의 가슴 부분이 제 팔을 눌렀어요.'},
#   {'file_url': 'python 스터디/380', 'text': '전 그이에게 순경을 부르겠다고 말했지요.'},
#   {'file_url': 'python 스터디/381', 'text': '그이는 제가 절대 그런 행동을 하지 않을 것을 알고 있었어요.'},
#   {'file_url': 'python 스터디/382.m4a',
#    'text': '전 너무 흥분했던 탓이 그이와 함께 택시를 탔을 때도 거의 알아채지 못했어요.'},
#   {'file_url': 'python 스터디/383',
#    'text': "제가 그때 머릿속으로 되풀이해서 생각한 것은 '어차피 영원히 사는 것도 아닌데...'라는 말뿐이었어요."},
#   {'file_url': 'python 스터디/384',
#    'text': '그녀가 머키 부인을 돌아보자 방안은 온통 머키 부인의 부자연스런 웃음소리로 가득 찼다.'},
#   {'file_url': 'python 스터디/385',
#    'text': '이 드레스를 오늘 벗는 대로 당신에게 줄게요. 내일 다른 것을 사면 되니까.'},
#   {'file_url': 'python 스터디/386', 'text': '난 마련해야 할 물건의 목록을 만들려고 해요.'},
#   {'file_url': 'python 스터디/387', 'text': '목록을 만들어서 사야 할 물건을 잊어버리지 않도록 해야겠어요.'},
#   {'file_url': 'python 스터디/388',
#    'text': '9시였다, 그리고 얼마 되지 않아 다시 내 손목 시계를 보니 10시를 가리키고 있었다.'},
#   {'file_url': 'python 스터디/389',
#    'text': '머키는 꽉 쥔 두 주먹을 무릎 위에 얹은 재 사진 속의 모델처럼 의자에서 잠들어 있었다.'},
#   {'file_url': 'python 스터디/390',
#    'text': '나는 손수건을 꺼내 오후 내내 나의 마음을 거슬리게 했던, 그의 광대뼈 위에 말라붙은 비누 거품을 닦아 주었다.'},
#   {'file_url': 'python 스터디/391',
#    'text': '강아지는 테이블 위에 앉아서 자욱한 연기 때문에 잘 보이지 않는지 사방을 두리번거리며 이따금씩 나직하게 낑낑거리고 있었다.'},
#   {'file_url': 'python 스터디/392', 'text': '탐은 빠르고 익숙하게 그 큰 손으로 그녀의 코를 후려쳤다.'},
#   {'file_url': 'python 스터디/393',
#    'text': '욕실 바닥에 피투성이의 타월들이 쌓이고 여자들의 아우성이 들렸다.'},
#   {'file_url': 'python 스터디/394',
#    'text': '그 소리보다 한층 높게 고통을 호소하며 울부짖는 소리가 들렸다.'},
#   {'file_url': 'python 스터디/395',
#    'text': '나는 샹들리에에 걸어 두었던 모자를 집어 들고 그의 뒤를 따라갔다.'},
#   {'file_url': 'python 스터디/396',
#    'text': '나는 펜실베니아 역의 아래층 플랫폼에 쪼그리고 앉은 채 신문을 들여다보며 4시에 떠날 기차를 기다리고 있었다.'},
#   {'file_url': 'python 스터디/397', 'text': '여름 밤, 개츠비의 집에서는 날마다 흥겨운 음악 소리가 났다.'},
#   {'file_url': 'python 스터디/398',
#    'text': '그의 푸른 정원에서는 남녀들이 속삭임과 샴페인, 별들 사이를 바쁘게 오가곤 했다.'},
#   {'file_url': 'python 스터디/399',
#    'text': '그의 이름으로 되어 있는 해변의 뜨거운 모래 위에서 일광욕을 하고 있는 것을 바라보았다.'},
#   {'file_url': 'python 스터디/400',
#    'text': '그의 두 척의 모터보트는 바다 위에 떠 물살을 가르며 하얀 물거품 위로 수상 스키를 끌고 달렸다.'},
#   {'file_url': 'python 스터디/401',
#    'text': '주말이면 그의 롤즈로이스 승용차가 아침 9시부터 한밤중까지 시내를 왔다갔다하면서 손님들을 실어 날랐다.'},
#   {'file_url': 'python 스터디/402',
#    'text': '스테이션왜건은 모든 기차를 마중 나가려고 마치 활기찬 투구벌레처럼 지칠 줄 모르고 돌아다녔다.'},
#   {'file_url': 'python 스터디/403',
#    'text': '월요일에는 임시로 고용된 정원사까지 합쳐 모두 8명의 고용인이 간밤에 손상된 부분을 손질하느라고 하루 종일 힘들게 돌아다녔다.'},
#   {'file_url': 'python 스터디/404',
#    'text': '매주 금요일마다 뉴욕의 청과물점으로부터 다섯 상자의 오렌지와 레몬이 도착했다.'},
#   {'file_url': 'python 스터디/405',
#    'text': '월요일이면 이 오렌지와 레몬은 알맹이가 없는 껍질이 되어서 피라미드 모양으로 쌓인 채 저택 뒷문으로 사라졌다.'},
#   {'file_url': 'python 스터디/406',
#    'text': '부엌에는 엄지손가락으로 조그만 단추를 누르기만 하면 30분 만에 200개의 오렌지 주스를 짜낼 수 있는기계 한 대가 설치되어 있었다.'},
#   {'file_url': 'python 스터디/407',
#    'text': '뷔페 식탁에는 구운 햄, 오색으로 만든 샐러드, 밀가루를 씌워 누런색으로 구운 통돼지와 칠면조 들이 가득 놓여 있었다.'},
#   {'file_url': 'python 스터디/408',
#    'text': '중앙에는 진짜 놋쇠 난간의 바가 마련되어 있었고, 갖가지의 독한 진이나 위스키들이 진열되어 있었다.'},
#   {'file_url': 'python 스터디/409',
#    'text': '너무 오랫동안 금주법으로 잊혀졌기 때문에 대부분의 여자 손님들은 나이가 어려 그 종류를 구별해 내지 못했다.'},
#   {'file_url': 'python 스터디/410',
#    'text': '늦게까지 수영을 하던 사람들도 이제는 바닷가에서 돌아와 이층에서 옷을 갈아 입고 있었다.'},
#   {'file_url': 'python 스터디/411.m4a',
#    'text': '택 안의 주차장에는 뉴욕에서 온 차들이 다섯 줄로 질서정연하게 주차해 있었다.'},
#   {'file_url': 'python 스터디/412', 'text': '카스틸의 꿈도 무색한 호화로운 숄을 두른 사람들로 북적댔다.'},
#   {'file_url': 'python 스터디/413',
#    'text': '바에서는 이제 분위기가 무르익었고, 여러 차례 반복되고 있는 칵테일 쟁반의 서비스가 정원 바깥까지 이어지고 있었다.'},
#   {'file_url': 'python 스터디/414',
#    'text': '부담없이 즐길 수 있는 풍자와 인사 소개가 간단히 행해졌으며, 서로 이름도 모르는 여자들끼리의 열띤 이야기가 시작되었다.'},
#   {'file_url': 'python 스터디/415', 'text': '밤이 깊어 감에 따라 불빛은 더욱 밝아져 갔다.'},
#   {'file_url': 'python 스터디/416',
#    'text': '오케스트라는 대중적인 혼합곡을 연주하고 오페라 같은 사람들의 이야기 소리는 한 옥타브 더 높아졌다.'},
#   {'file_url': 'python 스터디/417', 'text': '웃음 소리는 시간이 갈수록 커졌으며 자주 들려 왔다.'},
#   {'file_url': 'python 스터디/418',
#    'text': '모인 사람들이 빠른 속도로 바뀌었으며 새로 온 사람들로 모임이 흩어졌다가는 곧 다시 모이곤 했다.'},
#   {'file_url': 'python 스터디/419',
#    'text': '오케스트라 지휘자가 친절하게도 그녀의 춤에 맞는 곡으로 바꾸어 연주하기 시작했다.'},
#   {'file_url': 'python 스터디/420',
#    'text': '내가 개츠비의 저택에 처음으로 간 날 밤, 나는 초대된 몇몇 손님 가운데 하나라 믿고 있었다.'},
#   {'file_url': 'python 스터디/421',
#    'text': '상당수의 사람들은 초대를 받은 것이 아니었다. 그들은 그냥 그의 저택으로 왔던 것이다.'},
#   {'file_url': 'python 스터디/422',
#    'text': '롱아일랜드로 오는 자동차를 타고 있다 보니 개츠비의 저택 앞에서 차가 섰던 것이다.'},
#   {'file_url': 'python 스터디/423',
#    'text': '그 다음부터는 오락 유원지에서 지키면 되는 정도의 행동 규칙에 따라 스스로가 행동하게 되었다.'},
#   {'file_url': 'python 스터디/424',
#    'text': '그들은 때론 개츠비를 만나 보지도 않은 채 돌아갔고, 단지 파티가 좋아서 오는 솔직한 마음이 초대장의 역할을 할 뿐이었다.'},
#   {'file_url': 'python 스터디/425',
#    'text': '거기에는 그 날 밤의 조촐한 파티에 내가 참석해 주면 자기에게 다시 없는 영광이 될 것이라고 씌여 있었다.'},
#   {'file_url': 'python 스터디/426',
#    'text': '오래 전부터 찾아갈 계획을 세웠으나 그 때마다 사정들이 생겨 기회를 놓쳐 버렸다고 적고 있었다.'},
#   {'file_url': 'python 스터디/427', 'text': '끝에는 위엄 있는 필적으로 제이 개츠비라고 서명되어 있었다.'},
#   {'file_url': 'python 스터디/428',
#    'text': '7시가 조금 지나서 나는 차려 입고 그의 저택 잔디밭으로 건너가서 낯선 사람들 틈에 끼여 다소 어색한 모습으로 서성거렸다.'},
#   {'file_url': 'python 스터디/429', 'text': '실은 통근 기차에서 본 적이 있는 얼굴들도 많이 보였다.'},
#   {'file_url': 'python 스터디/430',
#    'text': '나는 파티장에 영국계 청년들이 여러 명 눈에 띈 것에 대해 놀라워했다.'},
#   {'file_url': 'python 스터디/431',
#    'text': '그들은 옷을 잘 차려 입고 무게 있고 돈이 있어 보이는 미국인들과 나지막하나 열띤 목소리로 이야기를 나누고 있었다.'},
#   {'file_url': 'python 스터디/432',
#    'text': '나는 그들이 채권이나 보험 증권이나 자동차 같은 것을 팔고 있는 중이라고 확신했다.'},
#   {'file_url': 'python 스터디/433',
#    'text': '그들 영국인들은 손쉽게 벌어들일 수 있는 돈이 근처에 있다는 것을 분명하게 인식하고 있었다.'},
#   {'file_url': 'python 스터디/434',
#    'text': '적절한 음조로 말 몇 마디만 하면 그 돈은 자기들의 것이 될 것으로 확신하고 있는 것 같았다.'},
#   {'file_url': 'python 스터디/435', 'text': '나는 그 집에 도착하자마자 개츠비를 만나 보려 했다.'},
#   {'file_url': 'python 스터디/436',
#    'text': '나로부터 그가 있는 곳을 묻는 말을 들은 두서너 사람은 아주 놀란 얼굴로 나를 빤히 쳐다보면서 모른다고 고개를 흔들었다.'},
#   {'file_url': 'python 스터디/437', 'text': '그 바람에 나는 칵테일 테이블 쪽으로 슬금슬금 다가갔다.'},
#   {'file_url': 'python 스터디/438',
#    'text': '그 곳은 목적도 없고 혼자라는 기색을 보이지 않고 남자 혼자 서성거릴 수 있는, 정원 속의 유일한 장소였기 때문이다.'},
#   {'file_url': 'python 스터디/439',
#    'text': '도무지 어색한 분위기를 참을 수 없어 나는 술에라도 취해 떠들어 대려고 했다.'},
#   {'file_url': 'python 스터디/440',
#    'text': '그녀가 집 안에서 나와 대리석 계단 꼭대기에 서서는 몸을 약간 뒤로 젖힌 채 경멸에 찬 눈빛을 보이며 정원을 내려다보고 있었다.'},
#   {'file_url': 'python 스터디/441.m4a',
#    'text': '지나가는 사람들에게 아는 척이라도 하기 위해서는 우선 나는 상대방이 좋아하든 말든 사람들과 어룰릴 필요가 있다고 생각했다.'},
#   {'file_url': 'python 스터디/442', 'text': '나는 그녀 쪽으로 걸어가면서 소리를 질렀다.'},
#   {'file_url': 'python 스터디/443',
#    'text': '내 목소리는 부자연스러울 정도로 크게 정원 밖으로 퍼져 나가는 것 같았다.'},
#   {'file_url': 'python 스터디/444', 'text': '그녀는 내가 다가가자 별로 관심이 없다는 말투로 대꾸했다.'},
#   {'file_url': 'python 스터디/445',
#    'text': '그녀는 조금 있다가 챙겨 주겠다는 약속처럼 내 손을 잡고는 계단 밑에 와서 멈추어 선 두 아가씨의 말에 귀를 기울였다.'},
#   {'file_url': 'python 스터디/446',
#    'text': '그것은 골프 시합에 관한 인사였다. 그녀는 지난 주 결승전에서 지고 말았던 것이다.'},
#   {'file_url': 'python 스터디/447', 'text': '하지만 우리는 한 달쯤 전에 여기서 당신을 뵈었어요.'},
#   {'file_url': 'python 스터디/448',
#    'text': '나는 걷기 시작했다. 아가씨들은 이미 나보다 먼저 앞으로 걸어가 버려 조던의 말은 허공을 향해 중얼거리는 넋두리가 되고 말았다.'},
#   {'file_url': 'python 스터디/449', 'text': '조던은 가냘프고 금빛이 도는 팔로 내 팔을 잡았다.'},
#   {'file_url': 'python 스터디/450.m4a',
#    'text': '리는 자연스럽게 팔짱을 낀 채 계단을 내려와 정원의 구석구석을 돌아다녔다.'},
#   {'file_url': 'python 스터디/451',
#    'text': '칵테일 쟁반이 우리에게로 전달되었고, 우리는 두 아가씨와 또 다른 세 남자와 함께 같은 테이블에 자리를 잡고 앉았다.'},
#   {'file_url': 'python 스터디/452', 'text': '그 남자들은 멈블 씨라고 소개되었다.'},
#   {'file_url': 'python 스터디/453', 'text': '얼마 전 당신을 만난 파티가 최근에 참석한 파티예요.'},
#   {'file_url': 'python 스터디/454',
#    'text': '그 아가씨가 빠르면서도 자신에 찬 말투로 대답했다. 그리고 그녀는 자기 친구를 돌아다보며 물었다.'},
#   {'file_url': 'python 스터디/455',
#    'text': '저는 아주 자연스럽게 생활하지요. 그래서 언제나 즐겁지요. 지난번 파티에서 제 가운이 의자에 걸려 찢어졌었지요.'},
#   {'file_url': 'python 스터디/456',
#    'text': '오늘 밤에 입고 올 생각이었는데 가슴 둘레가 너무 커서 수선을 부탁했어요.'},
#   {'file_url': 'python 스터디/457',
#    'text': '라벤더빛 구슬이 달린, 파란 가스 빛 드레스인데 265달러나 하는 것이라나봐요.'},
#   {'file_url': 'python 스터디/458',
#    'text': '그런 식으로 호의를 지나치게 보이는 사람은 어딘지 이상한 데가 있어요.'},
#   {'file_url': 'python 스터디/459', 'text': '두 아가씨와 조던은 친근한 듯 서로 몸을 기댔다.'},
#   {'file_url': 'python 스터디/460',
#    'text': '누가 그러던데 말이에요, 사람들은 그분이 전에 사람을 죽인 적이 있대요.'},
#   {'file_url': 'python 스터디/461.m4a',
#    'text': '순간 모두가 몸서리를 쳤다. 세 명의 멈블 씨는 몸을 앞으로 굽히고 좀더 자세히 듣기 위해 열심히 귀를 기울였다.'},
#   {'file_url': 'python 스터디/462', 'text': '루실이 의심스럽다는 듯이 말하고 나섰다.'},
#   {'file_url': 'python 스터디/463', 'text': '그보다는 전쟁중에 독일의 스파이였을 가능성이 더 많아.'},
#   {'file_url': 'python 스터디/464', 'text': '세 남자 가운데 한 명이 고개를 끄덕였다.'},
#   {'file_url': 'python 스터디/465',
#    'text': '나도 그 사람에 대한 이야기를 많이 들었는데 그와 함께 독일에서 자란 사람에게서 들었습니다.'},
#   {'file_url': 'python 스터디/466',
#    'text': '그럴 리가 없어요. 왜냐하면 그분은 전쟁중에 계속 미국에 있었으니까요.'},
#   {'file_url': 'python 스터디/467',
#    'text': '우리가 자기의 말을 믿는 눈치를 보이자 그녀는 몸을 앞으로 굽히며 한층 강한 어조로 말을 이었다.'},
#   {'file_url': 'python 스터디/468',
#    'text': '아무도 자신을 보고 있지 않다고 생각할 때 그분을 한 번 쳐다보세요. 사람을 죽인 것임에 틀림없어요.'},
#   {'file_url': 'python 스터디/469',
#    'text': '우리는 누가 먼저랄 것 없이 모두 몸을 돌려 주위를 둘러보며 개츠비를 찾았다.'},
#   {'file_url': 'python 스터디/470',
#    'text': '개츠비 자신이 남들에게 그런 낭만적인 억측을 하도록 충동질했다는 증거이다.'},
#   {'file_url': 'python 스터디/471',
#    'text': '첫 번째 저녁 식사가 막 차려지고 있을 때 조던이 자기의 일행과 함께 식사를 하자고 초대했다.'},
#   {'file_url': 'python 스터디/472', 'text': '그들은 정원의 한쪽 구석에 있는 테이블에 둘러앉아 있었다.'},
#   {'file_url': 'python 스터디/473',
#    'text': '그 대학생은 조만간에 그녀가 자기에게 몸을 내맡기게 될 것이라는 생각을 갖고 있는 듯했다.'},
#   {'file_url': 'python 스터디/474',
#    'text': '그 일행은 이리저리 돌아다니는 대신 한결같이 위엄 있는 자세를 취하면서 고상한 척 거만을 떨었다.'},
#   {'file_url': 'python 스터디/475',
#    'text': '따분하고 어색한 시간이 30분쯤 지났을 때 조던이 귓속말로 말했다.'},
#   {'file_url': 'python 스터디/476',
#    'text': '우리는 자리에서 일어났다. 조던은 지금부터 우리는 이 집 주인을 찾으러 간다는 설명을 했다.'},
#   {'file_url': 'python 스터디/477',
#    'text': '그녀는 내게 주인을 만난 적이 없기 때문에 불안해하는 것 같다고 덧붙여 말했다.'},
#   {'file_url': 'python 스터디/478',
#    'text': '그 대학생은 냉소적이며 침울한 표정으로 고개를 끄덕였으나 여전히 못마땅한 표정을 하고 있었다.'},
#   {'file_url': 'python 스터디/479',
#    'text': '우리는 먼저 바를 둘러보았는데, 그 곳은 사람들로 붐볐지만 개츠비는 없었다.'},
#   {'file_url': 'python 스터디/480', 'text': '그녀는 계단 꼭대기에서도 그를 찾아 내지 못했다.'},
#   {'file_url': 'python 스터디/481',
#    'text': '베란다에도 그는 없었다. 그러다 우리는 우연히 묵직해 보이는 문을 열고 천장이 높은 고딕 서재로 들어갔다.'},
#   {'file_url': 'python 스터디/482', 'text': '그 방의 벽은 조각이 된 영국산 참나무 널빤지로 되어 있었다.'},
#   {'file_url': 'python 스터디/483',
#    'text': '안경을 쓴 건장한 중년 남자가 술에 약간 취한 듯 커다란 테이블 모서리에 걸터앉아서 서가들을 불안한 눈초리로 응시하고 있었다.'},
#   {'file_url': 'python 스터디/484',
#    'text': '우리가 안으로 들어가자 그는 당황한 듯 몸을 홱 돌리더니 조던을 아래위로 훑어보았다.'},
# ...
#    'text': '그 때 우리는 빅토리아 포장 마차를 타고센트럴파크를 달리고 있었다.'},
#   {'file_url': 'python 스터디/834',
#    'text': '해는 이미 50번가의 영화배우들이 살고 있는 고층 아파트 뒤로 넘어갔다.'},
#   {'file_url': 'python 스터디/835',
#    'text': '어느 틈엔가 풀숲의 귀뚜라미처럼 모여든 아이들의 맑은 목소리가 뜨거운 황혼 속에서 들려 왔다.'},
#   {'file_url': 'python 스터디/836',
#    'text': '그렇다면 6월의 그 밤, 개츠비가 애원하듯 쳐다보고 있었던 것은 단지 별들이아니었던 것이다.'},
#   {'file_url': 'python 스터디/837',
#    'text': '그는 목적없이 화려하기만 한 그의 태내로부터 다시 태어나서 생동하며 나에게 나타났다.'},
#   {'file_url': 'python 스터디/838', 'text': '그의 소망이 그처럼 소박한 것에 나는 적이 감동했다.'},
#   {'file_url': 'python 스터디/839',
#    'text': '그는 5년이나 기다렸고 거대한 저택을 샀으며, 그 곳에서 자기 스스로 찾아온 하루살이들에게 별빛을 나누어 주었다.'},
#   {'file_url': 'python 스터디/840',
#    'text': "자신은 단지 어느 날 오후 남의 집 정원으로 '초대받을 수 있기를' 기다리고 있었던 것이다."},
#   {'file_url': 'python 스터디/841', 'text': '그는 만나는 사람마다 혹시 데이지를 아느냐고 묻기 시작했어요.'},
#   {'file_url': 'python 스터디/842', 'text': '내가 바로 데이지를 알고 있는 첫 번째 사람이 되었어요.'},
#   {'file_url': 'python 스터디/843',
#    'text': '그가 댄스 파티에서 사람을 시켜 나를 초대한 바로 그 날 밤의 일이었어요.'},
#   {'file_url': 'python 스터디/844',
#    'text': '그가 그렇게 하려고 노력했던 그 세심한 자세를 당신도 들으셨더라면 좋았을 텐데요.'},
#   {'file_url': 'python 스터디/845',
#    'text': '나는 물론 그에게 당신을 뉴욕에서의 점심식사에 초대하라는 제안을 즉시 해 주었어요.'},
#   {'file_url': 'python 스터디/846',
#    'text': '당신이 탐의 각별한 친구라고 말하자, 그는 모든 계획을 포기해 버리려고 했어요.'},
#   {'file_url': 'python 스터디/847',
#    'text': '어둠이 서서히 깔리기 시작했고 우리가 탄 마차는 조그마한 다리 아랫길로 접어들고 있었다.'},
#   {'file_url': 'python 스터디/848',
#    'text': '나는 한 팔로 조던의 황금빛이 도는 어깨를 껴안아 내 쪽으로 끌어당기면서 그녀를 저녁 식사에 초대했다.'},
#   {'file_url': 'python 스터디/849', 'text': '어느 새 나는 데이지나 개츠비에 대해서는 잊어버리고 말았다.'},
#   {'file_url': 'python 스터디/850',
#    'text': '검은 나무숲의 장벽을 지나 59번가로 접어들자 희미한 한 줄기 불빛이 공원쪽을 내리비추고 있었다.'},
#   {'file_url': 'python 스터디/851', 'text': '내게는 몇 년씩 잊지 못하고 가슴아파하는 그런 여인이 없었다.'},
#   {'file_url': 'python 스터디/852', 'text': '그래서 나는 두 팔에 힘을 주어 조던을 끌어당겼다.'},
#   {'file_url': 'python 스터디/853', 'text': '그녀의 파리하고 비웃는 듯한 미소가 입가에 떠올랐다.'},
#   {'file_url': 'python 스터디/854',
#    'text': '그것을 보고 나는 그녀를 더 가까이 끌어당겼고 마침내는 내 얼굴에까지 끌어당겼다.'},
#   {'file_url': 'python 스터디/855',
#    'text': '그 날 밤 웨스트에그로 돌아왔을 때, 나는 내 집에 불이 난 게 아닌가 하는 착각에 빠졌다.'},
#   {'file_url': 'python 스터디/856', 'text': '새벽 2시였는데 집 주변 전체가 불빛으로 이글거렸다.'},
#   {'file_url': 'python 스터디/857.m4a',
#    'text': '그 불빛은 관목숲을 영화 속의 한 장면처럼 비춰 주었으며, 길가의 전선들을 가느다란 황금빛 선으로 번뜩이게 했다.'},
#   {'file_url': 'python 스터디/858',
#    'text': '처음 나는 무슨 파티라도 열려서 화려한 야회가 끝나고 놀이를 위해 개방된 것으로 생각했다.'},
#   {'file_url': 'python 스터디/859',
#    'text': '길모퉁이를 돌아서야 나는 개츠비의 저택 전체에 불이 켜져 있어 그렇게 보였다는 것을 알았다.'},
#   {'file_url': 'python 스터디/860', 'text': '그러나 그 곳에서는 아무 소리도 들리지 않았다.'},
#   {'file_url': 'python 스터디/861',
#    'text': '나무들 사이에서 바람이 일어 전선을 움직이게 했고 그래서 불빛이 계속 비쳤다 사라졌다 했다.'},
#   {'file_url': 'python 스터디/862',
#    'text': '나는 개츠비가 잔디밭을 가로질러 내게로 걸어오는 것을 볼 수 있었다.'},
#   {'file_url': 'python 스터디/863', 'text': '그는 얼빠진 모습으로 시선을 그 쪽으로 돌렸다.'},
#   {'file_url': 'python 스터디/864', 'text': '그는 잠시 생각에 잠기더니 주저하며 말했다.'},
#   {'file_url': 'python 스터디/865',
#    'text': '내 집의 볼품없는 잔디밭이 끝난 곳에 선명하게 선이 그어져 그 지점부터 손질이 잘 된 그의 잔디밭이 시작되고 있었다.'},
#   {'file_url': 'python 스터디/866', 'text': '나는 그가 내 잔디밭을 두고 하는 말이 아닌가 하고 생각했다.'},
#   {'file_url': 'python 스터디/867', 'text': '그는 어쩔 줄 몰라하며 말을 잇지 못하고 더듬거렸다.'},
#   {'file_url': 'python 스터디/868',
#    'text': '이 말이 그를 안심시킨 듯 했다. 그는 조금 전보다 한결 자신 있게 말을 계속했다.'},
#   {'file_url': 'python 스터디/869',
#    'text': '지금에야 깨달은 것인데, 다른 상황에서였다면 그 이야기는 내 인생을 바꿀 사건이 되었을지도 모르는 것이다.'},
#   {'file_url': 'python 스터디/870',
#    'text': '그 당시 그 제안을 형식적인 것이었으므로 나로서는 그 자리에서 깨끗하게 거절할 수밖에 없었다.'},
#   {'file_url': 'python 스터디/871',
#    'text': "분명히 그는 앞서의 점심 식사 때 언급된 '거래선'이라는 말 때문에 내가 물러선 것으로 생각한 모양이었다."},
#   {'file_url': 'python 스터디/872', 'text': '그래서 나는 그가 잘못 생각한 것이라고 말해주었다.'},
#   {'file_url': 'python 스터디/873', 'text': '그는 내가 이야기를 계속하기를 바라면서 잠시 더 기다렸다.'},
#   {'file_url': 'python 스터디/874', 'text': '나는 내 생각이 너무 강했기 때문에 거기에 응하질 못했다.'},
#   {'file_url': 'python 스터디/875', 'text': '그러자 그는 하는 수 없이 집으로 돌아갔다.'},
#   {'file_url': 'python 스터디/876',
#    'text': '그 날 밤 나는 마음이 개운하고 즐거웠다. 나는 현관문을 들어서자 곧 깊은 잠에 빠져들었다.'},
#   {'file_url': 'python 스터디/877',
#    'text': "나는 개츠비가 코니아일랜드로 갔었는지 아니면 저택에 불을 현란하게 켜 놓고 몇 시간이나 '방들을 살펴보았는지'를 모른다."},
#   {'file_url': 'python 스터디/878',
#    'text': '다음날 아침 나는 사무실에서 데이지에게 전화를 걸어 만찬에 초대했다.'},
#   {'file_url': 'python 스터디/879',
#    'text': '11시쯤 우의를 입은 한 남자가 제초기를 끌고 와서 현관문을 두드렸다.'},
#   {'file_url': 'python 스터디/880', 'text': '개츠비가 우리 집 잔디를 갂으라고 보냈다는 말을 덧붙였다.'},
#   {'file_url': 'python 스터디/881',
#    'text': '그것은 내가 핀란드인 가정부에게 일하러 오라고 말한다는 걸 그만 잊어 버린 것을 생각나게 해 주었다.'},
#   {'file_url': 'python 스터디/882',
#    'text': '나는 빗물이 깨끗이 씻어 내린 골목길들을 정신없이 돌아다닌 끝에 그녀를 찾아냈다.'},
#   {'file_url': 'python 스터디/883',
#    'text': '약간의 컵과 레몬과 꽃을 사기 위해 차를 몰고 웨스트에그 마을로 들어갔다.'},
#   {'file_url': 'python 스터디/884', 'text': '그러나 내가 사 온 꽃들은 잠시 후 필요가 없게 되었다.'},
#   {'file_url': 'python 스터디/885',
#    'text': '2시가 되자 개츠비의 저택으로부터 꽃을 담을 수많은 용기와 화분 하나가 도착했기 때문이다.'},
#   {'file_url': 'python 스터디/886',
#    'text': '1시간쯤 지나자 현관문이 거칠게 열리더니 하얀 플란넬 양복에 은빛 셔츠와 금빛 넥타이 차림의 개츠비가 허겁지겁 들어섰다.'},
#   {'file_url': 'python 스터디/887', 'text': '그의 얼굴은 창백했고 특히 눈이 피곤해 보였다.'},
#   {'file_url': 'python 스터디/888',
#    'text': '그러나 그의 표정으로 판단하건대 그의 눈에는 아무 것도 들어오지 않는 것 같았다.'},
#   {'file_url': 'python 스터디/889', 'text': '어느 신문을 보았더니, 비는 4시쯤이면 그칠 것이라 했더군요.'},
#   {'file_url': 'python 스터디/890',
#    'text': '나는 그를 식료품실로 데리고 들어갔는데, 그는 핀란드인 가정부를 좀 못마땅한 표정으로 바라보았다.'},
#   {'file_url': 'python 스터디/891',
#    'text': '우리 두 사람은 식료품점에서 사 온 12개의 레몬 케이크를 자세히 살펴보았다.'},
#   {'file_url': 'python 스터디/892',
#    'text': '3시 30분쯤 되자 비는 선선한 안개로 변하더니 가는 빗방울로 변했다.'},
#   {'file_url': 'python 스터디/893', 'text': '이따금 그 안개를 뚫고 가는 빗방울이 이슬처럼 흩날렸다.'},
#   {'file_url': 'python 스터디/894', 'text': "개츠비는 멍한 눈초리로 클레이의 '경제학'을 훑어보고 있었다."},
#   {'file_url': 'python 스터디/895',
#    'text': '마치 밖에서 충격적인 사건들이 벌어지고 있기라도 하듯이 가끔 흐릿한 창문 쪽으로 시선을 보내기도 했다.'},
#   {'file_url': 'python 스터디/896',
#    'text': '마침내 그는 일어서더니 나지막한 소리로 자기 집으로 돌아가겠다는 것을 나에게 알렸다.'},
#   {'file_url': 'python 스터디/897', 'text': '그는 무슨 다급한 약속이라도 있는 것처럼 시계를 들여다보았다.'},
#   {'file_url': 'python 스터디/898',
#    'text': '그는 마치 내가 자기를 붙잡아 눌러 버리기라도 한 것처럼 참담한 표정으로 의자에 도로 주저앉았다.'},
#   {'file_url': 'python 스터디/899', 'text': '바로 그 때 내 집의 오솔길로 차가 들어오는 소리가 들렸다.'},
#   {'file_url': 'python 스터디/900',
#    'text': '동시에 우리 둘은 벌떡 일어섰고, 나는 좀 걱정스런 심정으로 마당으로 나갔다.'},
#   {'file_url': 'python 스터디/901',
#    'text': '한 대의 대형 무개차가 물방울을 뚝뚝 떨어뜨리는 라일락 나무 아래를 지나 집안 차도를 달려 올라오고 있었다.'},
#   {'file_url': 'python 스터디/902',
#    'text': '차가 멈추자 삼각모를 한쪽으로 살짝 기울게 쓴 데이지가 밝고 황홀한 미소를 띠고 나를 바라보았다.'},
#   {'file_url': 'python 스터디/903',
#    'text': '사람의 마음을 울렁거리게 하는 그녀의 목소리는 빗속에서 거친 고음으로 퍼져왔다.'},
#   {'file_url': 'python 스터디/904',
#    'text': '나는 어떤 말이 나올 때까지 한동안 그저 귀를 쫑긋거리며 가만 있어야 했다.'},
#   {'file_url': 'python 스터디/905',
#    'text': '그녀의 뺨에는 한 가닥의 젖은 머리카락이 푸른 물감으로 가늘게 그은 것처럼 내려붙어 있었다.'},
#   {'file_url': 'python 스터디/906',
#    'text': '그녀가 차에서 내릴 때 거들려고 잡은 그녀의 손은 물방울로 빛나고 있었다.'},
#   {'file_url': 'python 스터디/907',
#    'text': '운전사에게 이렇게 말하고 나서 그녀는 소리를 낮춰 내게 소곤거렸다.'},
#   {'file_url': 'python 스터디/908',
#    'text': '그녀는 현관문을 점잖게 노크하는 소리가 가볍게 들려 오자 그 쪽으로 고개를 돌렸다.'},
#   {'file_url': 'python 스터디/909',
#    'text': '개츠비가 물 구덩이 속에 서서 양손을 웃옷 주머니에 찔러 넣은 채 내 눈을 주시하고 있는 것이 보였다.'},
#   {'file_url': 'python 스터디/910',
#    'text': '그는 양손을 계속 웃옷 주머니에 찔러 넣은 채 내 곁을 지나 홀로 들어가더니  몸을 홱 돌려 거실로 사라졌다.'},
#   {'file_url': 'python 스터디/911',
#    'text': '나는 가슴을 몹시 두근거리는 것을 의식하면서 한층 세차게 쏟아지는 비를 막으려고 현관문을 잡아당겼다.'},
#   {'file_url': 'python 스터디/912',
#    'text': '거실로부터 숨을 죽인 것 같은 속삭임과 짧은 웃음소리가 들리고 이어 데이지의 가식적인, 낭랑한 목소리가 들려 왔다.'},
#   {'file_url': 'python 스터디/913',
#    'text': '그 시간이 너무나 길게 느껴졌다. 나는 홀에서 할 일도 없고 해 거실로 들어갔다.'},
#   {'file_url': 'python 스터디/914',
#    'text': '개츠비는 여전히 양손을 웃옷 주머니에 찔러 넣은 채 지나칠 정도로 아주 편안한듯 보였다.'},
#   {'file_url': 'python 스터디/915',
#    'text': '아니 지루할 정도라는 여유 있는 태도를 취하며 벽난로 선반에 기대에 서 있었다.'},
#   {'file_url': 'python 스터디/916',
#    'text': '그는 시계의 숫자판에 기대 머리를 뒤로 깊숙이 젖힌 채 두 눈으로 데이지를 뚫어지게 내려다보고 있었다.'},
#   {'file_url': 'python 스터디/917',
#    'text': '데이지는 놀랐지만 우아한 자태로 딱딱한 의자의 모서리에 침착하게 앉아 있었다.'},
#   {'file_url': 'python 스터디/918',
#    'text': '그는 순간적으로 흘끗 나를 쳐다보았고, 그의 입술은 웃으려고 노력했으나 끝내 웃음은 나오지 않았다.'},
#   {'file_url': 'python 스터디/919',
#    'text': '시계가 그의 머리에 눌려서 위험할 정도로 기울어지자, 그는 뒤로 돌아서서 떨리는 손가락으로 그것을 붙잡아 다시 제자리에 걸쳐 놓았다.'},
#   {'file_url': 'python 스터디/920',
#    'text': '그는 소파에 경직되게 앉아 팔꿈치를 팔걸이에 얹고 손으로 턱을 괴었다.'},
#   {'file_url': 'python 스터디/921',
#    'text': '내 머릿속에는 하고 싶은 말이 너무나 많았으나, 단 한 마디의 평범한 말조차 꺼낼 수가 없었다.'},
#   {'file_url': 'python 스터디/922', 'text': '바로 그 순간 시계가 방바닥에서 떨어져서 박살이 났다.'},
#   {'file_url': 'python 스터디/923', 'text': '데이지가 말했다. 그녀의 목소리는 더할 수 없이 침착했다.'},
#   {'file_url': 'python 스터디/924',
#    'text': '개츠비가 한 이 대답의 어투가 우리로 하여금 또다시 최소한 1분간은 말을 중단하게 만들었다.'},
#   {'file_url': 'python 스터디/925',
#    'text': '간신히 그들을 일어서게 했을 때 눈치없는 핀란드 인 가정부가 차를 쟁반에 담아 가지고 들어왔다.'},
#   {'file_url': 'python 스터디/926',
#    'text': '찻잔들과 케이크를 받아 놓는 약간의 소란 속에서도 그들의 어떤 자연스런 예의는 철저히 지켜졌다.'},
#   {'file_url': 'python 스터디/927',
#    'text': '내가 데이지와 이야기를 나누는 동안 그는 긴장되고 침울한 눈초리로 물끄러미 우리 두 사람을 번갈아 바라보았다.'},
#   {'file_url': 'python 스터디/928',
#    'text': '여하튼 침묵을 어서 깨야 할 것이기에 나는 틈을 타서 핑계를 대고 일어섰다.'},
#   {'file_url': 'python 스터디/929.m4a',
#    'text': '그는 허겁지겁 내 뒤를 부엌으로 들어오더니 문을 닫고는 풀이 죽어 귓속말로 말했다.'},
#   {'file_url': 'python 스터디/930', 'text': '그는 믿어지지 않는다는 듯이 되물었다.'},
#   {'file_url': 'python 스터디/931',
#    'text': '그는 한 손을 들어 내 말을 막았고, 책망하는 눈초리로 나를 바라보고는 조심스럽게 문을 열고 그 방으로 되돌아갔다.'},
#   {'file_url': 'python 스터디/932',
#    'text': '나는 30분쯤 전에 개츠비가 불안스럽게 집을 한 바퀴 돌았을 때와 똑같은 모습으로 뒷길을 빠져 나갔다.'},
#   {'file_url': 'python 스터디/933', 'text': '빽빽한 나뭇잎들이 비를 막아 주는 덮개 구실을 해주었다.'},
#   {'file_url': 'python 스터디/934', 'text': '비는 또다시 억수같이 퍼붓고 있었다.'},
#   {'file_url': 'python 스터디/935',
#    'text': '개츠비의 정원사가 잘 깎아 준 나의 잔디밭은 작은 흙탕 구덩이와 늪을 많이 만들어 내고 있었다.'},
#   {'file_url': 'python 스터디/936',
#    'text': '나무 밑에서 바라볼 만한 것이라고는 개츠비의 거대한 저택밖에 없었다.'},
#   {'file_url': 'python 스터디/937',
#    'text': '나는 반 시간 동안이나 칸트가 그의 교회 첨탑을 바라보았듯이 그것을 바라보고 있었다.'},
#   {'file_url': 'python 스터디/938',
#    'text': "그 저택은 10년쯤 전에 어떤 양조업자가 '시대'의 유행에 따라 지은 최신형의 것이었다."},
#   {'file_url': 'python 스터디/939',
#    'text': '그 양조업자는 모든 이웃 오두막집 주인들에게 만약 그들이 짚으로 지붕을 이으면 5년간의 세금을 대신 내주겠다고 했다고 한다.'},
#   {'file_url': 'python 스터디/940',
#    'text': "그들의 거절로 '한 가문을 창립'하려던 그의 계획은 좌절되었고 그의 가문은 몰락해 버렸다."},
#   {'file_url': 'python 스터디/941',
#    'text': '그의 자식들은 현관문에 새긴 검은 화환을 그대로 둔 채 그 집을 팔았던 것이다.'},
#   {'file_url': 'python 스터디/942',
#    'text': '미국인들이란 기꺼이 혹은 열성적으로 농노 노릇을 하려고 하면서도 언제나 농부의 위신을 잃지 않으려는 노력한다.'},
#   {'file_url': 'python 스터디/943',
#    'text': '하인들의 저녁 식사 재료를 실은 식료품점의 자동차가 개츠비의 저택 차도로 달려오는 게 보였다.'},
#   {'file_url': 'python 스터디/944',
#    'text': '나는 개츠비는 분명히 그런 음식은 한 숟가락도 먹으려고 하지 않을 것이라고 생각했다.'},
#   {'file_url': 'python 스터디/945', 'text': '하녀 하나가 그의 저택 이층 창문을 열기 시작했다.'},
#   {'file_url': 'python 스터디/946',
#    'text': '그녀는 창문으로마다 모습을 나타내고는 밖으로 내어 커다란 창문에 몸을 기대고 정원을 향해 침을 뱉었다.'},
#   {'file_url': 'python 스터디/947',
#    'text': '계속해서 비가 내릴 때의 빗소리는 감정이 격해짐에 따라 높아지곤 하는 개츠비와 데이지의 속삭임처럼 들렸었다.'},
#   {'file_url': 'python 스터디/948',
#    'text': '비가 그친 뒤의 새로운 고요함에 빠져 들자 그 고요함은 집 안까지 깃들인 것같이 느껴졌다.'},
#   {'file_url': 'python 스터디/949',
#    'text': '난로를 넘어뜨릴 뻔한 소리를 내는 등 부엌에서 가능한 모든 시끄러운 소리를 낸 연후에 나는 거실로 들어갔다.'},
#   {'file_url': 'python 스터디/950', 'text': '그러나 그들이 그 어떤 소리를 들었으리라고는 생각지 않는다'},
#   {'file_url': 'python 스터디/951', 'text': '두 사람은 긴 의자 양 끝에 앉아 서로 마주 보고 있었다'},
#   {'file_url': 'python 스터디/952',
#    'text': '마치 무슨 질문이 오고갔거나 혹은 그것이 허공에 떠 있는 것 같았으나 조금 전의 그 당황의 흔적은 보이지 않았다.'},
#   {'file_url': 'python 스터디/953',
#    'text': '내가 들어서자 그녀는 자리에서 일어나 거울 앞으로 다가가서는 손수건으로 얼굴을 닦기 시작했다.'},
#   {'file_url': 'python 스터디/954',
#    'text': '한편 개츠비에게 놀랄 만한 변화가 있었다. 그는 정말로 환한 빛을 발하고 있었다.'},
#   {'file_url': 'python 스터디/955',
#    'text': '환희의 말 한 마디도 행동도 없었지만, 새로운 행복감이 넘쳐 흐르는 그 빛은 작은 방을 가득 채우고 있었다.'},
#   {'file_url': 'python 스터디/956',
#    'text': '그는 마치 오랜만에 나를 만난 것처럼 말했다. 나는 한 순간 그가 악수를 하려는 것으로 생각했다.'},
#   {'file_url': 'python 스터디/957',
#    'text': '그는 내가 무슨 말을 하는지를 알아차렸다. 그리고 방 안에 눈부신 방울 같은 햇살이 비치고 있는 것을 깨달았다.'},
#   {'file_url': 'python 스터디/958',
#    'text': '다시 나타난 빛을 매우 기뻐하는 사람 같은 미소를 띠며 데이지에게 그 소식을 되풀이해서 말했다.'},
#   {'file_url': 'python 스터디/959',
#    'text': '가슴아플 만큼 슬픔이 깃들인 데이지의 낭랑한 목소리는 다만 예기치 못한 기쁨만을 나타냈다.'},
#   {'file_url': 'python 스터디/960',
#    'text': '나는 내 더러운 타월을 생각하고 부끄러운 생각이 들었으나 때는 이미 늦었다,'},
#   {'file_url': 'python 스터디/961', 'text': '그 동안 개츠비와 나는 잔디밭에서 그녀를 기다렸다.'},
#   {'file_url': 'python 스터디/962',
#    'text': '그는 자신의 집의 아치형 문 하나하나와 네모난 탑으로 시선을 옮겼다.'},
#   {'file_url': 'python 스터디/963',
#    'text': '지금 생각하면 그 때 그는 자신이 무슨 말을 하고 있는지도 모르고 있었던 것 같다.'},
#   {'file_url': 'python 스터디/964',
#    'text': '내가 무슨 일을 했었느냐고 물었을 때 그 대답이 동문서답이라는 것을 깨닫기도 전에 그는 대답했다.'},
#   {'file_url': 'python 스터디/965',
#    'text': '내가 미처 대답하기 전에 데이지가 집 밖으로 나왔기 때문에 더 이상 이야기하지 못했다.'},
#   {'file_url': 'python 스터디/966',
#    'text': '그녀의 드레스에 두 줄로 달린 놋쇠 단추가 햇빛을 받아 반짝였다.'},
#   {'file_url': 'python 스터디/967',
#    'text': '우리는 해협을 따라 난 지름길로 가는 대신 한길까지 내려가 거대한 뒷문을 통해서 개츠비의 저택으로 들어갔다.'},
#   {'file_url': 'python 스터디/968',
#    'text': '데이지는 푸른 하늘을 배경으로 한 봉건시대풍 건물의 검은 윤곽을 여기저기로 살펴보면서 감탄했다.'},
#   {'file_url': 'python 스터디/969',
#    'text': '그녀는 또한 정원과 수선화의 향기, 아가위와 서양 자두꽃의 거품 같은 향기, 그리고 야생 오랑캐꽃의 연한 향기에 감탄했다.'},
#   {'file_url': 'python 스터디/970',
#    'text': '집 앞 대리석 계단에 이르렀는데도 현관문 안팎에 인적은 보이지 않고 새소리밖에 들리지 않는 것이 이상했다.'},
#   {'file_url': 'python 스터디/971',
#    'text': '집안으로 들어가 마리 앙투아네트 음악실들과 왕정복고시대풍의 객실들을 서성거리다가 나는 비로소 그 이유를 알게 되었다.'},
#   {'file_url': 'python 스터디/972',
#    'text': '모든 손님들은 긴 의자와 테이블 뒤에 숨어서 우리가 지나갈 때까지 숨을 죽이고 가만히 있으라는 지시를 받았던 것이다.'},
#   {'file_url': 'python 스터디/973',
#    'text': '나는 분명히 그 올빼미 눈 같은 안경을 낀 남자가 유령 같은 기분 나쁜 웃음을 터뜨리는 소리를 들은 것 같았다.'},
#   {'file_url': 'python 스터디/974',
#    'text': '우리는 이층으로 올라가 침실들과 화장실, 그리고 당구장을 지나 욕조가 움푹 들어간 욕실들을 둘러보았다.'},
#   {'file_url': 'python 스터디/975',
#    'text': '다음 어떤 방으로 들어가자 머리가 헝클어진 남자 파자마 바람으로 방바닥에서 간장 운동을 하고 있었다.'},
#   {'file_url': 'python 스터디/976', 'text': "그는 '하숙생'이라는 별명을 가진 클립스프링거였다."},
#   {'file_url': 'python 스터디/977',
#    'text': '나는 그날 아침에 해변가에서 할 일없이 서성거리는 그를 보았었다.'},
#   {'file_url': 'python 스터디/978.m4a',
#    'text': '우리는 침실과 욕실, 그리고 서재가 갖춰진 개츠비의 거처로 가서 앉아 그가 벽장에서 꺼내 온 술을 한 잔씩 마셨다.'},
#   {'file_url': 'python 스터디/979', 'text': '개츠비는 잠시도 데이지에게서 눈을 떼지 않았다.'},
#   {'file_url': 'python 스터디/980',
#    'text': '그는 자신의 집에 있는 모든 물건들을 데이지의 아름다운 두 눈에 비치는 반응에 따라 재평가하고 있다고 느꼈다.'},
#   {'file_url': 'python 스터디/981',
#    'text': '그는 데이지가 자기 눈앞에 실제로 와 있는 상황에서는 소유하고 있는 물건 따위는 이제 하나도 현실감이 없다는 듯이 멍하게 둘러보았다.'},
#   {'file_url': 'python 스터디/982', 'text': '그러다가 한 번은 계단에서 거의 굴러 떨어질 뻔하기도 했다.'},
#   {'file_url': 'python 스터디/983',
#    'text': '그의 침실은 모든 방중에서 제일 수수했다, 다만 경대가 순금제 화장 세트로 장식되어 있는 것을 빼고는.'},
#   {'file_url': 'python 스터디/984',
#    'text': '데이지는 그 앞에서 아주 좋아하며 머리솔을 집어들어 자신의 머리를 빗었다.'},
#   {'file_url': 'python 스터디/985',
#    'text': '그러는 동안에 개츠비는 의자에 앉아 두 눈을 가리고 웃음을 보였다.'},
#   {'file_url': 'python 스터디/986',
#    'text': '그는 이제 두 가지 과정을 거쳐서 세 번째 과정으로 접어들고 있는 것이 분명했다.'},
#   {'file_url': 'python 스터디/987',
#    'text': '당황함과 이유 없는 환희를 거쳐 이제는 데이지가 눈앞에 있는 데에 대한 놀라움으로 어리둥절해지고 있었다.'},
#   {'file_url': 'python 스터디/988',
#    'text': '그는 아주 오랫동안 이렇게 되리라는 생각만을 해 왔고 처음부터 끝까지 꼭 이렇게 되리라고 상상해 왔다.'},
#   {'file_url': 'python 스터디/989',
#    'text': '말하자면 상상조차 할 수 없을 정도로 이를 악물고 기다려 왔던 것이다.'},
#   {'file_url': 'python 스터디/990',
#    'text': '이제 그는 그 반동으로 태엽을 너무 감아 놓은 시계처럼 천천히 풀리고 있었다.'},
#   {'file_url': 'python 스터디/991',
#    'text': '그는 우리에게 양복과 화장 가운과 넥타이가 가득차 있고 셔츠가 수북히 쌓인 두 개의 커다란 옷장을 열어 보여 주었다.'},
#   {'file_url': 'python 스터디/992', 'text': '그는 셔츠 더미 하나를 꺼내 하나씩 우리 앞으로 던졌다.'},
#   {'file_url': 'python 스터디/993',
#    'text': '두터운 비단, 곱게 짠 플란넬 셔츠들이 풀려 형형색색의 색깔로 테이블을 뒤덮었다.'},
#   {'file_url': 'python 스터디/994',
#    'text': '우리가 감탄하는 가운데 그는 다른 한 더미의 셔츠들을 꺼내 테이블 위에 올려놓았다.'},
#   {'file_url': 'python 스터디/995',
#    'text': '산호색, 풋사과의 녹색, 라벤더색 그리고 연한 오렌지색 바탕에 줄무늬, 소용돌이 무늬, 체크 무늬가 있는 셔츠들이었다.'},
#   {'file_url': 'python 스터디/996', 'text': '그 속엔 하늘색 글자로 모노그램이 수놓여 있었다.'},
#   {'file_url': 'python 스터디/997',
#    'text': '그것들을 본 데이지가 갑자기 그 속에 머리를 파묻고 흥분한 소리로 격렬하게 울어대기 시작했다.'},
#   {'file_url': 'python 스터디/998',
#    'text': '그녀는 흐느끼며 말했는데, 그 소리는 겹겹으로 쌓인 셔츠에 묻혀 잘 들리지 않았다.'},
#   {'file_url': 'python 스터디/999',
#    'text': '집안을 둘러본 뒤엔 마당과 풀장, 그리고 수상기와 잘 가꿔진 꽃들을 볼 계획이었다.'},
#   {'file_url': 'python 스터디/1000',
#    'text': '밖엔 다시 비가 내리기 시작했으므로 우리는 나란히 서서 파도치는 바다를 바라보고 있었다.'},
#   {'file_url': 'python 스터디/1001', 'text': '데이지는 개츠비의 겨드랑이에 자신의 팔을 끼웠다.'},
#   ...]}

# %%
if len(meta_json['records']) > 0:
    result_json = os.path.join(input_dir, '%s_%s.json' % (museid, datetime.now().strftime('%y%m%d'))).replace('\\','/')
    ZIP_Thread.write_json(result_json, meta_json)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-330-95ef12e6e923> in <module>()
#       1 if len(meta_json['records']) > 0:
#       2     result_json = os.path.join(input_dir, '%s_%s.json' % (museid, datetime.now().strftime('%y%m%d'))).replace('\\','/')
# ----> 3     ZIP_Thread.write_json(result_json, meta_json)
#
# <ipython-input-254-4a71a82fc12e> in write_json(path, data)
#      13     def write_json(path, data):
#      14         with open(path, 'w') as f:
# ---> 15             json.dump(data, f, indent=4, sort_keys=True, ensure_ascii=False)
#      16
#      17
#
# ~\Anaconda3\envs\env1\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# UnicodeEncodeError: 'cp949' codec can't encode character '\xa0' in position 10: illegal multibyte sequence

# %%
input_zip_list = glob.glob('./*.zip', recursive=False) # input/voice 에있는 zip 찾기

ls = []
for i in input_zip_list:
    ls.append(i.replace('\\','/'))
    
zip_name = ''
number = -1
museid = ''

for idx, input_zip in enumerate(ls): # 압축파일마다 락이 걸려있는지 확인하기
    zip_name = os.path.splitext(os.path.relpath(input_zip, input_base_dir))[0].split('/') # [***]
    museid = zip_name[-1] # ***

    recordnow = datetime.now()
    if recordnow:
#         musestatus = mongo.find_status(id=museid) # DB에서 Collection 검색 
#         if musestatus: # Collection 존재한다
            pick_muse = mongo.lock_status_import(museid, instance_id, hb_seconds) # 락걸기 lock_status_import 함수 만들어야함
            if pick_muse:
                number = idx
                break

        else: # Collection 존재하지 않는다
            result = mongo.insert_status(museid, None, recordnow, 0) # collection을 만들어준다.

            pick_muse = mongo.lock_status_import(museid, instance_id, hb_seconds) # lock 걸기
            if pick_muse:
                number = idx
                break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-315-7b8cbac6349d> in <module>()
#       5     recordnow = datetime.now()
#       6     if recordnow:
# ----> 7         musestatus = mongo.find_status(id=museid) # DB에서 Collection 검색
#       8         if musestatus: # Collection 존재한다
#       9             pick_muse = mongo.lock_status_import(museid, instance_id, hb_seconds) # 락걸기 lock_status_import 함수 만들어야함
#
# NameError: name 'mongo' is not defined
